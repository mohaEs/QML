# %% [markdown]
# ## This notebook presents the reproducible procedure that we followed in comparing the performance of Hybrid Quantum-Classical Neural Networks and Classical Convolutional Neural Networks on the APTOS-2019 dataset. The APTOS dataset is a diabetic-retinopathy dataset with 3662 fundus images. The dataset was produced in France and is labeled with five-category classification (no diabetic retinopathy, mild diabetic retinopathy, moderate diabetic retinopathy, severe diabetic retinopathy, and proliferative diabetic retinopathy).

# %% [markdown]
# ### Installing and Importing Dependencies

# %%
# !pip install pennylane
# !pip install matplotlib
# !pip install opencv-python
# !pip install scikit-learn
# !pip install seaborn
# Out:
# Requirement already satisfied: pennylane in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (0.38.0)
# Requirement already satisfied: numpy<2.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (1.13.1)
# Requirement already satisfied: networkx in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (3.2.1)
# Requirement already satisfied: rustworkx>=0.14.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (0.16.0)
# Requirement already satisfied: autograd in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (1.8.0)
# Requirement already satisfied: toml in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray>=0.6.11 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (0.7.1)
# Requirement already satisfied: cachetools in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (5.5.2)
# Requirement already satisfied: pennylane-lightning>=0.38 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (0.38.0)
# Requirement already satisfied: requests in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (4.13.2)
# Requirement already satisfied: packaging in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pennylane) (25.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from requests->pennylane) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from requests->pennylane) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from requests->pennylane) (2025.4.26)
# Requirement already satisfied: matplotlib in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: opencv-python in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.17.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: seaborn in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
#import tensorflow as tf
#from tensorflow import keras
import matplotlib.pyplot as plt
import os
# from google.colab import drive
import cv2
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, Sampler
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms
from PIL import Image
import time
import os
import copy
from torch.optim.lr_scheduler import CosineAnnealingLR
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve,
    precision_recall_curve, auc
)
from sklearn.preprocessing import label_binarize
import random


# os.environ["OMP_NUM_THREADS"] = "1"

# %%
# drive.mount('/content/drive', force_remount=True)

# %%
MODEL_SAVE_PATH = "../../QMLExperiments/Resnet-18-APTOS_models/"
if not os.path.exists(MODEL_SAVE_PATH):
    os.makedirs(MODEL_SAVE_PATH)
    print(f"Directory '{MODEL_SAVE_PATH}' created.")

# %% [markdown]
# ### General Training, Validation, Testing Functions

# %%
import torchvision
from torchvision import datasets, transforms

# %%
def train_model(model, train_loader, optimizer, criterion):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_probs = []

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        probs = torch.softmax(outputs, dim=1)
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.detach().cpu().numpy())



    avg_train_loss = train_loss / len(train_loader.dataset)
    accuracy = correct / total * 100

    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_train_loss, accuracy, avg_auroc

# %%
def validate_model(model, valid_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            probs = torch.softmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.detach().cpu().numpy())

    avg_val_loss = val_loss / len(valid_loader.dataset)
    accuracy = correct / total * 100
    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_val_loss, accuracy, avg_auroc

# %%
import pickle

def train_validate_model(n_epochs, model, model_name, train_loader, valid_loader, seed):

  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

  def adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max):
        if epoch < lr_warmup_epochs:
            lr = lr_max * (epoch + 1) / lr_warmup_epochs
        else:
            lr = lr_max
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

  scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs - 10, eta_min=1e-6)

  best_val_loss = float('inf')
  best_model_weights = model.state_dict()
  epochs_without_improvement = 0
  early_stopping_patience = 10

  train_losses = []
  train_accuracies = []
  val_losses = []
  val_accuracies = []
  train_aucs = []
  val_aucs = []

  lr_max = 5e-4
  lr_warmup_epochs = 10

  for epoch in range(n_epochs):
      print(f'Epoch [{epoch+1}/{n_epochs}]')

      adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max)

      train_loss, train_accuracy, train_auroc = train_model(model, train_loader, optimizer, criterion)
      val_loss, val_accuracy, val_auroc = validate_model(model, valid_loader, criterion)


      print(f'Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Training AUROC: {train_auroc:.4f}')
      print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%, Validation AUROC: {val_auroc:.4f}')
      train_losses.append(train_loss)
      train_accuracies.append(train_accuracy)
      train_aucs.append(train_auroc)
      val_losses.append(val_loss)
      val_accuracies.append(val_accuracy)
      val_aucs.append(val_auroc)

      if epoch >= lr_warmup_epochs:
            scheduler.step()

      if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict()
            epochs_without_improvement = 0  # Reset counter

      else:
            epochs_without_improvement += 1

      if epochs_without_improvement >= early_stopping_patience:
            print(f"Early stopping triggered after {epoch+1} epochs.")
            break

  model.load_state_dict(best_model_weights)
  torch.save(model, os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}.pth'))

  metrics = {
        "train_losses": train_losses,
        "train_accuracies": train_accuracies,
        "train_aucs": train_aucs,
        "val_losses": val_losses,
        "val_accuracies": val_accuracies,
        "val_aucs": val_aucs
    }

  with open(os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}_metrics.pkl'), 'wb') as f:
        pickle.dump(metrics, f)


  return model, train_losses, train_accuracies, val_losses, val_accuracies, train_aucs, val_aucs

# %%
import math
import matplotlib.pyplot as plt

def plot(quantum_loss, normal_loss, quantum_acc, normal_acc, quantum_auc, normal_auc):
    plt.style.use("default")

    loss_min = math.floor(min(min(quantum_loss), min(normal_loss)) * 10) / 10
    loss_max = math.ceil(max(max(quantum_loss), max(normal_loss)) * 10) / 10

    acc_min = math.floor(min(min(quantum_acc), min(normal_acc)) * 10) / 10
    acc_max = math.ceil(max(max(quantum_acc), max(normal_acc)) * 10) / 10

    auc_min = math.floor(min(min(quantum_auc), min(normal_auc)) * 10) / 10
    auc_max = math.ceil(max(max(quantum_auc), max(normal_auc)) * 10) / 10

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_loss, label="With quantum layer")
    plt.plot(normal_loss, label="Without quantum layer")
    plt.ylabel("Loss")
    plt.ylim([loss_min, loss_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Loss vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_acc, label="With quantum layer")
    plt.plot(normal_acc, label="Without quantum layer")
    plt.ylabel("Accuracy")
    plt.ylim([acc_min, acc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Accuracy vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_auc, label="With quantum layer")
    plt.plot(normal_auc, label="Without quantum layer")
    plt.ylabel("ROCAUC")
    plt.ylim([auc_min, auc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("ROCAUC vs. Epoch")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.preprocessing import label_binarize
from itertools import cycle

def test(model_hybrid, model_normal, test_loader, num_classes):
    model_hybrid.eval()
    model_normal.eval()

    all_labels = []
    all_preds_hybrid = []
    all_preds_normal = []
    all_probs_hybrid = []
    all_probs_normal = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs_hybrid = model_hybrid(images)
            _, preds_hybrid = torch.max(outputs_hybrid, 1)
            probs_hybrid = torch.softmax(outputs_hybrid, dim=1)

            outputs_normal = model_normal(images)
            _, preds_normal = torch.max(outputs_normal, 1)
            probs_normal = torch.softmax(outputs_normal, dim=1)

            all_labels.extend(labels.cpu().numpy())
            all_preds_hybrid.extend(preds_hybrid.cpu().numpy())
            all_preds_normal.extend(preds_normal.cpu().numpy())
            all_probs_hybrid.extend(probs_hybrid.cpu().numpy())
            all_probs_normal.extend(probs_normal.cpu().numpy())

    all_labels = np.array(all_labels)
    all_preds_hybrid = np.array(all_preds_hybrid)
    all_preds_normal = np.array(all_preds_normal)
    all_probs_hybrid = np.array(all_probs_hybrid)
    all_probs_normal = np.array(all_probs_normal)

    accuracy_hybrid = accuracy_score(all_labels, all_preds_hybrid)
    accuracy_normal = accuracy_score(all_labels, all_preds_normal)

    f1_hybrid = f1_score(all_labels, all_preds_hybrid, average='weighted')
    f1_normal = f1_score(all_labels, all_preds_normal, average='weighted')

    if num_classes == 2:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, pos_label=1)
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, pos_label=1)
        precision_normal = precision_score(all_labels, all_preds_normal, pos_label=1)
        recall_normal = recall_score(all_labels, all_preds_normal, pos_label=1)
    else:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, average='weighted')
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, average='weighted')
        precision_normal = precision_score(all_labels, all_preds_normal, average='weighted')
        recall_normal = recall_score(all_labels, all_preds_normal, average='weighted')

    hybrid_aucs = []
    normal_aucs = []

    # ROC data to store for plotting later
    roc_data = {
        "fpr_hybrid": [],
        "tpr_hybrid": [],
        "auc_hybrid": [],
        "fpr_normal": [],
        "tpr_normal": [],
        "auc_normal": []
    }

    if num_classes == 2:
        all_probs_hybrid_class1 = all_probs_hybrid[:, 1]
        all_probs_normal_class1 = all_probs_normal[:, 1]

        auc_hybrid = roc_auc_score(all_labels, all_probs_hybrid_class1)
        auc_normal = roc_auc_score(all_labels, all_probs_normal_class1)

        print(f'Hybrid Model AUROC: {auc_hybrid:.4f}')
        print(f'Normal Model AUROC: {auc_normal:.4f}')

        fpr_hybrid, tpr_hybrid, _ = roc_curve(all_labels, all_probs_hybrid_class1)
        fpr_normal, tpr_normal, _ = roc_curve(all_labels, all_probs_normal_class1)

        roc_data["fpr_hybrid"].append(fpr_hybrid)
        roc_data["tpr_hybrid"].append(tpr_hybrid)
        roc_data["auc_hybrid"].append(auc_hybrid)
        roc_data["fpr_normal"].append(fpr_normal)
        roc_data["tpr_normal"].append(tpr_normal)
        roc_data["auc_normal"].append(auc_normal)

        # Hybrid
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_hybrid, tpr_hybrid, label=f'Hybrid Model AUROC = {auc_hybrid:.4f}', linewidth=2)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Hybrid Model', fontsize=18)
        plt.xlabel('False Positive Rate', fontsize=14)
        plt.ylabel('True Positive Rate', fontsize=14)
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.legend(loc='lower right', fontsize=12)
        plt.grid(True)
        plt.show()

        # Normal
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_normal, tpr_normal, label=f'Normal Model AUROC = {auc_normal:.4f}', linewidth=2)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Normal Model', fontsize=18)
        plt.xlabel('False Positive Rate', fontsize=14)
        plt.ylabel('True Positive Rate', fontsize=14)
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.legend(loc='lower right', fontsize=12)
        plt.grid(True)
        plt.show()

    else:  # Multi-class
        all_labels_binarized = label_binarize(all_labels, classes=np.arange(num_classes))
        colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red'])

        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_hybrid[:, i])
            roc_auc = auc(fpr, tpr)
            hybrid_aucs.append(roc_auc)
            roc_data["fpr_hybrid"].append(fpr)
            roc_data["tpr_hybrid"].append(tpr)
            roc_data["auc_hybrid"].append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')

        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlabel('False Positive Rate', fontsize=14)
        plt.ylabel('True Positive Rate', fontsize=14)
        plt.title('ROC Curves - Hybrid Model', fontsize=18)
        plt.legend(loc='lower right', fontsize=12)
        plt.grid(True)
        plt.show()

        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_normal[:, i])
            roc_auc = auc(fpr, tpr)
            normal_aucs.append(roc_auc)
            roc_data["fpr_normal"].append(fpr)
            roc_data["tpr_normal"].append(tpr)
            roc_data["auc_normal"].append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')

        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlabel('False Positive Rate', fontsize=14)
        plt.ylabel('True Positive Rate', fontsize=14)
        plt.title('ROC Curves - Normal Model', fontsize=18)
        plt.legend(loc='lower right', fontsize=12)
        plt.grid(True)
        plt.show()

    hybrid_auc_avg = f"{sum(hybrid_aucs) / len(hybrid_aucs):.4f}" if hybrid_aucs else f"{auc_hybrid:.4f}"
    normal_auc_avg = f"{sum(normal_aucs) / len(normal_aucs):.4f}" if normal_aucs else f"{auc_normal:.4f}"

    print("\nHybrid Model Metrics:")
    print(f'Accuracy: {accuracy_hybrid:.4f}')
    print(f'F1 Score: {f1_hybrid:.4f}')
    print(f'Precision: {precision_hybrid:.4f}')
    print(f'Recall: {recall_hybrid:.4f}')
    print(f'AUROC: {hybrid_auc_avg}')

    print("\nNormal Model Metrics:")
    print(f'Accuracy: {accuracy_normal:.4f}')
    print(f'F1 Score: {f1_normal:.4f}')
    print(f'Precision: {precision_normal:.4f}')
    print(f'Recall: {recall_normal:.4f}')
    print(f'AUROC: {normal_auc_avg}\n')

    cm_hybrid = confusion_matrix(all_labels, all_preds_hybrid)
    cm_normal = confusion_matrix(all_labels, all_preds_normal)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_hybrid, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Hybrid Model (Avg AUC = {hybrid_auc_avg})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_normal, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Classical Model (Avg AUC = {normal_auc_avg})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    test_results = {
        "roc_data": roc_data
    }

    os.makedirs(MODEL_SAVE_PATH, exist_ok=True)
    with open(os.path.join(MODEL_SAVE_PATH, f'{seed}_test_results.pkl'), 'wb') as f:
        pickle.dump(test_results, f)

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
def load_data(batch_size, dataset):

  train_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])

  valid_test_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])


  if dataset == 'APTOS':
    data_dir = "../../Data/APTOS2019/"

  elif dataset == "IDRID":
    data_dir = "../../Data/IDRiD_data/"

  elif dataset == "Messidor":
    data_dir = "../../Data/MESSIDOR2/"

  elif dataset == "GlaucomaFundus":
    data_dir = "../../Data/Glaucoma_fundus/"

  elif dataset == "PAPILA":
    data_dir = "../../Data/PAPILA/"

  elif dataset == 'G1020':
    data_dir = "../../Data/G1020/"

  train_dataset = datasets.ImageFolder(root=data_dir + 'train', transform=train_transform)
  val_dataset = datasets.ImageFolder(root=data_dir + 'val', transform=valid_test_transform)
  test_dataset = datasets.ImageFolder(root=data_dir + 'test', transform=valid_test_transform)

  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
  valid_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

  return train_loader, valid_loader, test_loader

# %% [markdown]
# ### Classical Resnet-18 Construction

# %%
class NormalModel(nn.Module):
  def __init__(self, freeze, num_classes, device='cuda'):
        super(NormalModel, self).__init__()

        weights = torchvision.models.ResNet18_Weights.IMAGENET1K_V1
        self.model = torchvision.models.resnet18(weights=weights)

        if freeze:
          for param in self.model.parameters():
              param.requires_grad = False

        self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)
        self.model = self.model.to(device)

  def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Hybrid Quantum-Classical Resnet-18 Construction

# %%
n_qubits = 4                # Number of qubits
step = 0.0004               # Learning rate
batch_size = 4              # Number of samples for each training step
q_delta = 0.01              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer

# %%
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)


def RY_layer(w):
    """Layer of parametrized qubit rotations around the y axis.
    """
    for idx, element in enumerate(w):
        qml.RY(element, wires=idx)


def entangling_layer(nqubits):
    """Layer of CNOTs followed by another shifted layer of CNOT.
    """
    for i in range(0, nqubits - 1, 2):
        qml.CNOT(wires=[i, i + 1])
    for i in range(1, nqubits - 1, 2):
        qml.CNOT(wires=[i, i + 1])

# %%
dev = qml.device("default.qubit", wires=n_qubits)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
@qml.qnode(dev)
def quantum_net(q_input_features, q_weights_flat):
    """
    The variational quantum circuit.
    """

    # Reshape weights
    q_weights = q_weights_flat.reshape(q_depth, n_qubits)

    # Start from state |+> , unbiased w.r.t. |0> and |1>
    H_layer(n_qubits)

    # Embed features in the quantum node
    RY_layer(q_input_features)

    # Sequence of trainable variational layers
    for k in range(q_depth):
        entangling_layer(n_qubits)
        RY_layer(q_weights[k])

    # Expectation values in the Z basis
    exp_vals = [qml.expval(qml.PauliZ(position)) for position in range(n_qubits)]
    return tuple(exp_vals)

# %%
class DressedQuantumNet(nn.Module):

    def __init__(self, q_depth, num_classes):

        super().__init__()
        self.pre_net = nn.Linear(512, n_qubits)
        self.q_params = nn.Parameter(q_delta * torch.randn(q_depth * n_qubits))
        self.post_net = nn.Linear(n_qubits, num_classes)

    def forward(self, input_features):


        pre_out = self.pre_net(input_features)
        q_in = torch.tanh(pre_out) * np.pi / 2.0

        # Apply the quantum circuit to each element of the batch and append to q_out
        q_out = torch.Tensor(0, n_qubits)
        q_out = q_out.to(device)
        for elem in q_in:
            q_out_elem = torch.hstack(quantum_net(elem, self.q_params)).float().unsqueeze(0)
            q_out = torch.cat((q_out, q_out_elem))

        # return the two-dimensional prediction from the postprocessing layer
        return self.post_net(q_out)

# %%
class QuantumHybridModel(nn.Module):
  def __init__(self, q_depth, freeze, num_classes, device='cuda'):
        super(QuantumHybridModel, self).__init__()

        weights = torchvision.models.ResNet18_Weights.IMAGENET1K_V1
        self.model = torchvision.models.resnet18(weights=weights)

        if freeze:
          for param in self.model.parameters():
              param.requires_grad = False

        self.model.fc = DressedQuantumNet(q_depth, num_classes)

        self.model = self.model.to(device)

  def forward(self, x):
        return self.model(x)

# %% [markdown]
# # Experiments

# %%
n_epochs = 100
num_classes = 5
batch_size = 32
dataset = "APTOS"
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
q_depth = 4

# %% [markdown]
# ## Seed Experiment 1

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device: ', device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 34:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.7628, Training Accuracy: 16.85%, Training AUROC: 0.4166
# Validation Loss: 1.4917, Validation Accuracy: 28.21%, Validation AUROC: 0.4130
# Epoch [2/100]
# Training Loss: 1.3631, Training Accuracy: 45.75%, Training AUROC: 0.4707
# Validation Loss: 1.2573, Validation Accuracy: 51.95%, Validation AUROC: 0.6015
# Epoch [3/100]
# Training Loss: 1.1710, Training Accuracy: 55.57%, Training AUROC: 0.6804
# Validation Loss: 1.0840, Validation Accuracy: 62.84%, Validation AUROC: 0.7611
# Epoch [4/100]
# Training Loss: 1.0263, Training Accuracy: 65.97%, Training AUROC: 0.7806
# Validation Loss: 0.9627, Validation Accuracy: 70.43%, Validation AUROC: 0.8166
# Epoch [5/100]
# Training Loss: 0.9160, Training Accuracy: 69.82%, Training AUROC: 0.8273
# Validation Loss: 0.8782, Validation Accuracy: 71.21%, Validation AUROC: 0.8453
# Epoch [6/100]
# Training Loss: 0.8468, Training Accuracy: 71.78%, Training AUROC: 0.8507
# Validation Loss: 0.8408, Validation Accuracy: 71.79%, Validation AUROC: 0.8571
# Epoch [7/100]
# Training Loss: 0.7972, Training Accuracy: 72.17%, Training AUROC: 0.8680
# Validation Loss: 0.7845, Validation Accuracy: 73.54%, Validation AUROC: 0.8678
# Epoch [8/100]
# Training Loss: 0.7467, Training Accuracy: 73.97%, Training AUROC: 0.8866
# Validation Loss: 0.7573, Validation Accuracy: 73.15%, Validation AUROC: 0.8754
# Epoch [9/100]
# Training Loss: 0.7245, Training Accuracy: 74.61%, Training AUROC: 0.8885
# Validation Loss: 0.7326, Validation Accuracy: 74.12%, Validation AUROC: 0.8816
# Epoch [10/100]
# Training Loss: 0.6943, Training Accuracy: 75.49%, Training AUROC: 0.8995
# Validation Loss: 0.7223, Validation Accuracy: 73.93%, Validation AUROC: 0.8870
# Epoch [11/100]
# Training Loss: 0.6727, Training Accuracy: 76.66%, Training AUROC: 0.9014
# Validation Loss: 0.7066, Validation Accuracy: 75.29%, Validation AUROC: 0.8913
# Epoch [12/100]
# Training Loss: 0.6636, Training Accuracy: 76.71%, Training AUROC: 0.9029
# Validation Loss: 0.6987, Validation Accuracy: 75.49%, Validation AUROC: 0.8963
# Epoch [13/100]
# Training Loss: 0.6509, Training Accuracy: 76.46%, Training AUROC: 0.9107
# Validation Loss: 0.6936, Validation Accuracy: 75.10%, Validation AUROC: 0.8970
# Epoch [14/100]
# Training Loss: 0.6381, Training Accuracy: 77.05%, Training AUROC: 0.9121
# Validation Loss: 0.6750, Validation Accuracy: 74.71%, Validation AUROC: 0.8993
# Epoch [15/100]
# Training Loss: 0.6262, Training Accuracy: 77.39%, Training AUROC: 0.9152
# Validation Loss: 0.6749, Validation Accuracy: 75.49%, Validation AUROC: 0.9017
# Epoch [16/100]
# Training Loss: 0.6250, Training Accuracy: 77.69%, Training AUROC: 0.9155
# Validation Loss: 0.6625, Validation Accuracy: 75.49%, Validation AUROC: 0.9013
# Epoch [17/100]
# Training Loss: 0.6075, Training Accuracy: 77.25%, Training AUROC: 0.9210
# Validation Loss: 0.6603, Validation Accuracy: 76.65%, Validation AUROC: 0.9030
# Epoch [18/100]
# Training Loss: 0.6008, Training Accuracy: 78.22%, Training AUROC: 0.9224
# Validation Loss: 0.6529, Validation Accuracy: 75.29%, Validation AUROC: 0.9044
# Epoch [19/100]
# Training Loss: 0.5941, Training Accuracy: 78.03%, Training AUROC: 0.9240
# Validation Loss: 0.6463, Validation Accuracy: 76.85%, Validation AUROC: 0.9057
# Epoch [20/100]
# Training Loss: 0.5939, Training Accuracy: 77.93%, Training AUROC: 0.9239
# Validation Loss: 0.6525, Validation Accuracy: 75.10%, Validation AUROC: 0.9058
# Epoch [21/100]
# Training Loss: 0.5836, Training Accuracy: 79.15%, Training AUROC: 0.9279
# Validation Loss: 0.6481, Validation Accuracy: 76.07%, Validation AUROC: 0.9061
# Epoch [22/100]
# Training Loss: 0.5808, Training Accuracy: 79.35%, Training AUROC: 0.9259
# Validation Loss: 0.6463, Validation Accuracy: 76.65%, Validation AUROC: 0.9059
# Epoch [23/100]
# Training Loss: 0.5748, Training Accuracy: 79.00%, Training AUROC: 0.9280
# Validation Loss: 0.6430, Validation Accuracy: 76.46%, Validation AUROC: 0.9083
# Epoch [24/100]
# Training Loss: 0.5667, Training Accuracy: 79.39%, Training AUROC: 0.9304
# Validation Loss: 0.6323, Validation Accuracy: 76.85%, Validation AUROC: 0.9089
# Epoch [25/100]
# Training Loss: 0.5614, Training Accuracy: 79.30%, Training AUROC: 0.9324
# Validation Loss: 0.6543, Validation Accuracy: 76.07%, Validation AUROC: 0.9078
# Epoch [26/100]
# Training Loss: 0.5444, Training Accuracy: 79.59%, Training AUROC: 0.9376
# Validation Loss: 0.6276, Validation Accuracy: 77.43%, Validation AUROC: 0.9090
# Epoch [27/100]
# Training Loss: 0.5528, Training Accuracy: 79.64%, Training AUROC: 0.9355
# Validation Loss: 0.6294, Validation Accuracy: 77.63%, Validation AUROC: 0.9096
# Epoch [28/100]
# Training Loss: 0.5596, Training Accuracy: 79.35%, Training AUROC: 0.9336
# Validation Loss: 0.6316, Validation Accuracy: 76.46%, Validation AUROC: 0.9101
# Epoch [29/100]
# Training Loss: 0.5446, Training Accuracy: 80.03%, Training AUROC: 0.9362
# Validation Loss: 0.6486, Validation Accuracy: 78.02%, Validation AUROC: 0.9095
# Epoch [30/100]
# Training Loss: 0.5280, Training Accuracy: 80.57%, Training AUROC: 0.9401
# Validation Loss: 0.6183, Validation Accuracy: 77.63%, Validation AUROC: 0.9110
# Epoch [31/100]
# Training Loss: 0.5302, Training Accuracy: 81.15%, Training AUROC: 0.9384
# Validation Loss: 0.6259, Validation Accuracy: 77.43%, Validation AUROC: 0.9118
# Epoch [32/100]
# Training Loss: 0.5235, Training Accuracy: 81.45%, Training AUROC: 0.9421
# Validation Loss: 0.6412, Validation Accuracy: 76.85%, Validation AUROC: 0.9102
# Epoch [33/100]
# Training Loss: 0.5408, Training Accuracy: 80.62%, Training AUROC: 0.9370
# Validation Loss: 0.6244, Validation Accuracy: 76.85%, Validation AUROC: 0.9113
# Epoch [34/100]
# Training Loss: 0.5341, Training Accuracy: 80.47%, Training AUROC: 0.9378
# Validation Loss: 0.6268, Validation Accuracy: 77.63%, Validation AUROC: 0.9101
# Epoch [35/100]
# Training Loss: 0.5176, Training Accuracy: 81.69%, Training AUROC: 0.9417
# Validation Loss: 0.6161, Validation Accuracy: 77.63%, Validation AUROC: 0.9108
# Epoch [36/100]
# Training Loss: 0.5176, Training Accuracy: 80.22%, Training AUROC: 0.9416
# Validation Loss: 0.6160, Validation Accuracy: 77.82%, Validation AUROC: 0.9119
# Epoch [37/100]
# Training Loss: 0.5163, Training Accuracy: 81.45%, Training AUROC: 0.9421
# Validation Loss: 0.6214, Validation Accuracy: 77.04%, Validation AUROC: 0.9108
# Epoch [38/100]
# Training Loss: 0.5231, Training Accuracy: 80.96%, Training AUROC: 0.9416
# Validation Loss: 0.6270, Validation Accuracy: 77.82%, Validation AUROC: 0.9119
# Epoch [39/100]
# Training Loss: 0.5177, Training Accuracy: 80.08%, Training AUROC: 0.9419
# Validation Loss: 0.6136, Validation Accuracy: 77.43%, Validation AUROC: 0.9126
# Epoch [40/100]
# Training Loss: 0.5102, Training Accuracy: 81.64%, Training AUROC: 0.9446
# Validation Loss: 0.6111, Validation Accuracy: 77.04%, Validation AUROC: 0.9131
# Epoch [41/100]
# Training Loss: 0.5095, Training Accuracy: 81.54%, Training AUROC: 0.9447
# Validation Loss: 0.6188, Validation Accuracy: 77.43%, Validation AUROC: 0.9134
# Epoch [42/100]
# Training Loss: 0.5067, Training Accuracy: 82.03%, Training AUROC: 0.9443
# Validation Loss: 0.6085, Validation Accuracy: 77.82%, Validation AUROC: 0.9136
# Epoch [43/100]
# Training Loss: 0.5252, Training Accuracy: 81.30%, Training AUROC: 0.9400
# Validation Loss: 0.6199, Validation Accuracy: 78.02%, Validation AUROC: 0.9139
# Epoch [44/100]
# Training Loss: 0.5047, Training Accuracy: 81.40%, Training AUROC: 0.9448
# Validation Loss: 0.6244, Validation Accuracy: 77.24%, Validation AUROC: 0.9127
# Epoch [45/100]
# Training Loss: 0.5046, Training Accuracy: 81.10%, Training AUROC: 0.9439
# Validation Loss: 0.6042, Validation Accuracy: 78.21%, Validation AUROC: 0.9139
# Epoch [46/100]
# Training Loss: 0.4938, Training Accuracy: 81.93%, Training AUROC: 0.9470
# Validation Loss: 0.6272, Validation Accuracy: 77.24%, Validation AUROC: 0.9122
# Epoch [47/100]
# Training Loss: 0.5016, Training Accuracy: 82.28%, Training AUROC: 0.9448
# Validation Loss: 0.6196, Validation Accuracy: 76.65%, Validation AUROC: 0.9129
# Epoch [48/100]
# Training Loss: 0.4923, Training Accuracy: 81.54%, Training AUROC: 0.9475
# Validation Loss: 0.6194, Validation Accuracy: 75.29%, Validation AUROC: 0.9131
# Epoch [49/100]
# Training Loss: 0.4965, Training Accuracy: 81.98%, Training AUROC: 0.9473
# Validation Loss: 0.6131, Validation Accuracy: 77.43%, Validation AUROC: 0.9140
# Epoch [50/100]
# Training Loss: 0.4931, Training Accuracy: 81.15%, Training AUROC: 0.9483
# Validation Loss: 0.6097, Validation Accuracy: 78.21%, Validation AUROC: 0.9129
# Epoch [51/100]
# Training Loss: 0.5078, Training Accuracy: 81.45%, Training AUROC: 0.9444
# Validation Loss: 0.6027, Validation Accuracy: 77.63%, Validation AUROC: 0.9148
# Epoch [52/100]
# Training Loss: 0.4866, Training Accuracy: 82.57%, Training AUROC: 0.9502
# Validation Loss: 0.6086, Validation Accuracy: 77.43%, Validation AUROC: 0.9150
# Epoch [53/100]
# Training Loss: 0.4891, Training Accuracy: 82.32%, Training AUROC: 0.9495
# Validation Loss: 0.6127, Validation Accuracy: 78.79%, Validation AUROC: 0.9137
# Epoch [54/100]
# Training Loss: 0.4996, Training Accuracy: 81.59%, Training AUROC: 0.9459
# Validation Loss: 0.6114, Validation Accuracy: 77.82%, Validation AUROC: 0.9139
# Epoch [55/100]
# Training Loss: 0.4966, Training Accuracy: 81.59%, Training AUROC: 0.9465
# Validation Loss: 0.6094, Validation Accuracy: 78.02%, Validation AUROC: 0.9136
# Epoch [56/100]
# Training Loss: 0.4698, Training Accuracy: 83.25%, Training AUROC: 0.9514
# Validation Loss: 0.6113, Validation Accuracy: 78.60%, Validation AUROC: 0.9134
# Epoch [57/100]
# Training Loss: 0.4727, Training Accuracy: 83.06%, Training AUROC: 0.9521
# Validation Loss: 0.6061, Validation Accuracy: 77.63%, Validation AUROC: 0.9135
# Epoch [58/100]
# Training Loss: 0.4835, Training Accuracy: 82.62%, Training AUROC: 0.9494
# Validation Loss: 0.6078, Validation Accuracy: 77.24%, Validation AUROC: 0.9139
# Epoch [59/100]
# Training Loss: 0.4850, Training Accuracy: 82.42%, Training AUROC: 0.9484
# Validation Loss: 0.6160, Validation Accuracy: 78.02%, Validation AUROC: 0.9135
# Epoch [60/100]
# Training Loss: 0.4789, Training Accuracy: 83.35%, Training AUROC: 0.9514
# Validation Loss: 0.6161, Validation Accuracy: 78.21%, Validation AUROC: 0.9139
# Epoch [61/100]
# Training Loss: 0.4792, Training Accuracy: 82.67%, Training AUROC: 0.9521
# Validation Loss: 0.6127, Validation Accuracy: 78.21%, Validation AUROC: 0.9140
# Early stopping triggered after 61 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.7646, Training Accuracy: 6.40%, Training AUROC: 0.4753
# Validation Loss: 1.6905, Validation Accuracy: 7.59%, Validation AUROC: 0.5036
# Epoch [2/100]
# Training Loss: 1.6561, Training Accuracy: 7.13%, Training AUROC: 0.5523
# Validation Loss: 1.6157, Validation Accuracy: 8.75%, Validation AUROC: 0.6176
# Epoch [3/100]
# Training Loss: 1.5572, Training Accuracy: 14.16%, Training AUROC: 0.6275
# Validation Loss: 1.4811, Validation Accuracy: 20.04%, Validation AUROC: 0.6411
# Epoch [4/100]
# Training Loss: 1.4364, Training Accuracy: 44.97%, Training AUROC: 0.6322
# Validation Loss: 1.3912, Validation Accuracy: 53.89%, Validation AUROC: 0.6363
# Epoch [5/100]
# Training Loss: 1.3466, Training Accuracy: 64.94%, Training AUROC: 0.6437
# Validation Loss: 1.3051, Validation Accuracy: 68.09%, Validation AUROC: 0.6522
# Epoch [6/100]
# Training Loss: 1.2697, Training Accuracy: 68.99%, Training AUROC: 0.6722
# Validation Loss: 1.2330, Validation Accuracy: 71.60%, Validation AUROC: 0.6774
# Epoch [7/100]
# Training Loss: 1.1995, Training Accuracy: 71.53%, Training AUROC: 0.6924
# Validation Loss: 1.1727, Validation Accuracy: 72.18%, Validation AUROC: 0.6834
# Epoch [8/100]
# Training Loss: 1.1261, Training Accuracy: 72.66%, Training AUROC: 0.7096
# Validation Loss: 1.1108, Validation Accuracy: 72.37%, Validation AUROC: 0.7049
# Epoch [9/100]
# Training Loss: 1.0689, Training Accuracy: 72.56%, Training AUROC: 0.7408
# Validation Loss: 1.0516, Validation Accuracy: 72.37%, Validation AUROC: 0.7282
# Epoch [10/100]
# Training Loss: 1.0141, Training Accuracy: 72.36%, Training AUROC: 0.7595
# Validation Loss: 1.0037, Validation Accuracy: 73.15%, Validation AUROC: 0.7280
# Epoch [11/100]
# Training Loss: 0.9668, Training Accuracy: 73.54%, Training AUROC: 0.7795
# Validation Loss: 0.9646, Validation Accuracy: 73.15%, Validation AUROC: 0.7828
# Epoch [12/100]
# Training Loss: 0.9263, Training Accuracy: 73.88%, Training AUROC: 0.8217
# Validation Loss: 0.9499, Validation Accuracy: 72.57%, Validation AUROC: 0.7937
# Epoch [13/100]
# Training Loss: 0.9018, Training Accuracy: 73.44%, Training AUROC: 0.8313
# Validation Loss: 0.9006, Validation Accuracy: 73.74%, Validation AUROC: 0.8163
# Epoch [14/100]
# Training Loss: 0.8790, Training Accuracy: 73.39%, Training AUROC: 0.8286
# Validation Loss: 0.8852, Validation Accuracy: 73.35%, Validation AUROC: 0.8125
# Epoch [15/100]
# Training Loss: 0.8518, Training Accuracy: 74.02%, Training AUROC: 0.8313
# Validation Loss: 0.8663, Validation Accuracy: 73.74%, Validation AUROC: 0.8154
# Epoch [16/100]
# Training Loss: 0.8227, Training Accuracy: 75.20%, Training AUROC: 0.8351
# Validation Loss: 0.8454, Validation Accuracy: 76.07%, Validation AUROC: 0.8260
# Epoch [17/100]
# Training Loss: 0.8064, Training Accuracy: 75.68%, Training AUROC: 0.8410
# Validation Loss: 0.8270, Validation Accuracy: 75.10%, Validation AUROC: 0.8201
# Epoch [18/100]
# Training Loss: 0.7934, Training Accuracy: 75.24%, Training AUROC: 0.8440
# Validation Loss: 0.8151, Validation Accuracy: 75.49%, Validation AUROC: 0.8203
# Epoch [19/100]
# Training Loss: 0.7904, Training Accuracy: 76.03%, Training AUROC: 0.8433
# Validation Loss: 0.8068, Validation Accuracy: 75.29%, Validation AUROC: 0.8219
# Epoch [20/100]
# Training Loss: 0.7782, Training Accuracy: 75.78%, Training AUROC: 0.8458
# Validation Loss: 0.8014, Validation Accuracy: 74.90%, Validation AUROC: 0.8231
# Epoch [21/100]
# Training Loss: 0.7658, Training Accuracy: 75.73%, Training AUROC: 0.8414
# Validation Loss: 0.7900, Validation Accuracy: 75.68%, Validation AUROC: 0.8245
# Epoch [22/100]
# Training Loss: 0.7546, Training Accuracy: 76.61%, Training AUROC: 0.8496
# Validation Loss: 0.7797, Validation Accuracy: 75.68%, Validation AUROC: 0.8275
# Epoch [23/100]
# Training Loss: 0.7464, Training Accuracy: 76.46%, Training AUROC: 0.8453
# Validation Loss: 0.7705, Validation Accuracy: 74.90%, Validation AUROC: 0.8324
# Epoch [24/100]
# Training Loss: 0.7338, Training Accuracy: 76.56%, Training AUROC: 0.8510
# Validation Loss: 0.7673, Validation Accuracy: 75.68%, Validation AUROC: 0.8284
# Epoch [25/100]
# Training Loss: 0.7166, Training Accuracy: 77.44%, Training AUROC: 0.8617
# Validation Loss: 0.7569, Validation Accuracy: 76.26%, Validation AUROC: 0.8340
# Epoch [26/100]
# Training Loss: 0.7205, Training Accuracy: 77.39%, Training AUROC: 0.8596
# Validation Loss: 0.7621, Validation Accuracy: 74.90%, Validation AUROC: 0.8406
# Epoch [27/100]
# Training Loss: 0.7203, Training Accuracy: 76.46%, Training AUROC: 0.8583
# Validation Loss: 0.7460, Validation Accuracy: 75.49%, Validation AUROC: 0.8438
# Epoch [28/100]
# Training Loss: 0.7113, Training Accuracy: 76.46%, Training AUROC: 0.8654
# Validation Loss: 0.7535, Validation Accuracy: 74.32%, Validation AUROC: 0.8422
# Epoch [29/100]
# Training Loss: 0.7054, Training Accuracy: 76.46%, Training AUROC: 0.8640
# Validation Loss: 0.7625, Validation Accuracy: 72.76%, Validation AUROC: 0.8496
# Epoch [30/100]
# Training Loss: 0.6912, Training Accuracy: 77.34%, Training AUROC: 0.8673
# Validation Loss: 0.7356, Validation Accuracy: 75.88%, Validation AUROC: 0.8403
# Epoch [31/100]
# Training Loss: 0.7070, Training Accuracy: 76.76%, Training AUROC: 0.8573
# Validation Loss: 0.7381, Validation Accuracy: 76.46%, Validation AUROC: 0.8454
# Epoch [32/100]
# Training Loss: 0.6892, Training Accuracy: 76.81%, Training AUROC: 0.8663
# Validation Loss: 0.7307, Validation Accuracy: 75.10%, Validation AUROC: 0.8480
# Epoch [33/100]
# Training Loss: 0.6818, Training Accuracy: 77.73%, Training AUROC: 0.8687
# Validation Loss: 0.7251, Validation Accuracy: 74.51%, Validation AUROC: 0.8555
# Epoch [34/100]
# Training Loss: 0.6659, Training Accuracy: 77.69%, Training AUROC: 0.8716
# Validation Loss: 0.7144, Validation Accuracy: 75.10%, Validation AUROC: 0.8580
# Epoch [35/100]
# Training Loss: 0.6607, Training Accuracy: 77.83%, Training AUROC: 0.8766
# Validation Loss: 0.7149, Validation Accuracy: 75.68%, Validation AUROC: 0.8532
# Epoch [36/100]
# Training Loss: 0.6623, Training Accuracy: 77.59%, Training AUROC: 0.8772
# Validation Loss: 0.7075, Validation Accuracy: 75.88%, Validation AUROC: 0.8617
# Epoch [37/100]
# Training Loss: 0.6553, Training Accuracy: 78.08%, Training AUROC: 0.8730
# Validation Loss: 0.7118, Validation Accuracy: 75.29%, Validation AUROC: 0.8619
# Epoch [38/100]
# Training Loss: 0.6519, Training Accuracy: 78.22%, Training AUROC: 0.8747
# Validation Loss: 0.7091, Validation Accuracy: 75.68%, Validation AUROC: 0.8611
# Epoch [39/100]
# Training Loss: 0.6442, Training Accuracy: 78.12%, Training AUROC: 0.8875
# Validation Loss: 0.7018, Validation Accuracy: 76.26%, Validation AUROC: 0.8669
# Epoch [40/100]
# Training Loss: 0.6419, Training Accuracy: 78.12%, Training AUROC: 0.8835
# Validation Loss: 0.7055, Validation Accuracy: 74.12%, Validation AUROC: 0.8680
# Epoch [41/100]
# Training Loss: 0.6646, Training Accuracy: 77.29%, Training AUROC: 0.8792
# Validation Loss: 0.7082, Validation Accuracy: 75.49%, Validation AUROC: 0.8648
# Epoch [42/100]
# Training Loss: 0.6518, Training Accuracy: 77.83%, Training AUROC: 0.8800
# Validation Loss: 0.6963, Validation Accuracy: 74.51%, Validation AUROC: 0.8722
# Epoch [43/100]
# Training Loss: 0.6383, Training Accuracy: 78.08%, Training AUROC: 0.8845
# Validation Loss: 0.6921, Validation Accuracy: 75.68%, Validation AUROC: 0.8707
# Epoch [44/100]
# Training Loss: 0.6369, Training Accuracy: 78.37%, Training AUROC: 0.8840
# Validation Loss: 0.6936, Validation Accuracy: 74.71%, Validation AUROC: 0.8726
# Epoch [45/100]
# Training Loss: 0.6515, Training Accuracy: 78.27%, Training AUROC: 0.8840
# Validation Loss: 0.7066, Validation Accuracy: 74.32%, Validation AUROC: 0.8709
# Epoch [46/100]
# Training Loss: 0.6260, Training Accuracy: 78.61%, Training AUROC: 0.8856
# Validation Loss: 0.7026, Validation Accuracy: 75.10%, Validation AUROC: 0.8687
# Epoch [47/100]
# Training Loss: 0.6251, Training Accuracy: 78.52%, Training AUROC: 0.8879
# Validation Loss: 0.6882, Validation Accuracy: 75.68%, Validation AUROC: 0.8761
# Epoch [48/100]
# Training Loss: 0.6321, Training Accuracy: 78.61%, Training AUROC: 0.8884
# Validation Loss: 0.6850, Validation Accuracy: 74.32%, Validation AUROC: 0.8797
# Epoch [49/100]
# Training Loss: 0.6282, Training Accuracy: 78.66%, Training AUROC: 0.8920
# Validation Loss: 0.6845, Validation Accuracy: 76.07%, Validation AUROC: 0.8813
# Epoch [50/100]
# Training Loss: 0.6251, Training Accuracy: 78.12%, Training AUROC: 0.8907
# Validation Loss: 0.6971, Validation Accuracy: 75.29%, Validation AUROC: 0.8752
# Epoch [51/100]
# Training Loss: 0.6256, Training Accuracy: 78.37%, Training AUROC: 0.8849
# Validation Loss: 0.7006, Validation Accuracy: 75.68%, Validation AUROC: 0.8726
# Epoch [52/100]
# Training Loss: 0.6213, Training Accuracy: 79.05%, Training AUROC: 0.8868
# Validation Loss: 0.6778, Validation Accuracy: 75.49%, Validation AUROC: 0.8814
# Epoch [53/100]
# Training Loss: 0.6154, Training Accuracy: 78.12%, Training AUROC: 0.8902
# Validation Loss: 0.6961, Validation Accuracy: 76.65%, Validation AUROC: 0.8746
# Epoch [54/100]
# Training Loss: 0.6266, Training Accuracy: 78.22%, Training AUROC: 0.8889
# Validation Loss: 0.6886, Validation Accuracy: 74.51%, Validation AUROC: 0.8790
# Epoch [55/100]
# Training Loss: 0.6190, Training Accuracy: 78.32%, Training AUROC: 0.8903
# Validation Loss: 0.7057, Validation Accuracy: 73.15%, Validation AUROC: 0.8772
# Epoch [56/100]
# Training Loss: 0.5959, Training Accuracy: 78.96%, Training AUROC: 0.8966
# Validation Loss: 0.6706, Validation Accuracy: 75.10%, Validation AUROC: 0.8845
# Epoch [57/100]
# Training Loss: 0.6040, Training Accuracy: 78.86%, Training AUROC: 0.9053
# Validation Loss: 0.6782, Validation Accuracy: 74.51%, Validation AUROC: 0.8890
# Epoch [58/100]
# Training Loss: 0.5973, Training Accuracy: 78.66%, Training AUROC: 0.9090
# Validation Loss: 0.6834, Validation Accuracy: 75.68%, Validation AUROC: 0.8892
# Epoch [59/100]
# Training Loss: 0.6033, Training Accuracy: 78.96%, Training AUROC: 0.9090
# Validation Loss: 0.6711, Validation Accuracy: 75.68%, Validation AUROC: 0.8935
# Epoch [60/100]
# Training Loss: 0.5978, Training Accuracy: 78.96%, Training AUROC: 0.9064
# Validation Loss: 0.6746, Validation Accuracy: 75.49%, Validation AUROC: 0.8877
# Epoch [61/100]
# Training Loss: 0.5945, Training Accuracy: 78.76%, Training AUROC: 0.9133
# Validation Loss: 0.6833, Validation Accuracy: 75.88%, Validation AUROC: 0.8909
# Epoch [62/100]
# Training Loss: 0.6053, Training Accuracy: 78.17%, Training AUROC: 0.9108
# Validation Loss: 0.6747, Validation Accuracy: 75.49%, Validation AUROC: 0.8913
# Epoch [63/100]
# Training Loss: 0.6026, Training Accuracy: 78.66%, Training AUROC: 0.9096
# Validation Loss: 0.6644, Validation Accuracy: 74.32%, Validation AUROC: 0.8934
# Epoch [64/100]
# Training Loss: 0.5802, Training Accuracy: 78.96%, Training AUROC: 0.9190
# Validation Loss: 0.6739, Validation Accuracy: 76.07%, Validation AUROC: 0.8910
# Epoch [65/100]
# Training Loss: 0.6005, Training Accuracy: 78.32%, Training AUROC: 0.9136
# Validation Loss: 0.6709, Validation Accuracy: 76.07%, Validation AUROC: 0.8904
# Epoch [66/100]
# Training Loss: 0.5753, Training Accuracy: 79.05%, Training AUROC: 0.9201
# Validation Loss: 0.6813, Validation Accuracy: 75.68%, Validation AUROC: 0.8900
# Epoch [67/100]
# Training Loss: 0.5939, Training Accuracy: 77.93%, Training AUROC: 0.9130
# Validation Loss: 0.6639, Validation Accuracy: 74.90%, Validation AUROC: 0.8973
# Epoch [68/100]
# Training Loss: 0.5741, Training Accuracy: 78.56%, Training AUROC: 0.9217
# Validation Loss: 0.6684, Validation Accuracy: 74.51%, Validation AUROC: 0.8872
# Epoch [69/100]
# Training Loss: 0.5782, Training Accuracy: 79.10%, Training AUROC: 0.9201
# Validation Loss: 0.6585, Validation Accuracy: 76.65%, Validation AUROC: 0.8982
# Epoch [70/100]
# Training Loss: 0.5687, Training Accuracy: 79.20%, Training AUROC: 0.9217
# Validation Loss: 0.6517, Validation Accuracy: 76.65%, Validation AUROC: 0.8992
# Epoch [71/100]
# Training Loss: 0.5720, Training Accuracy: 79.35%, Training AUROC: 0.9232
# Validation Loss: 0.6640, Validation Accuracy: 75.10%, Validation AUROC: 0.8960
# Epoch [72/100]
# Training Loss: 0.5612, Training Accuracy: 79.30%, Training AUROC: 0.9278
# Validation Loss: 0.6698, Validation Accuracy: 74.90%, Validation AUROC: 0.8892
# Epoch [73/100]
# Training Loss: 0.5552, Training Accuracy: 79.05%, Training AUROC: 0.9268
# Validation Loss: 0.6567, Validation Accuracy: 75.29%, Validation AUROC: 0.8989
# Epoch [74/100]
# Training Loss: 0.5621, Training Accuracy: 79.39%, Training AUROC: 0.9280
# Validation Loss: 0.6555, Validation Accuracy: 75.68%, Validation AUROC: 0.8956
# Epoch [75/100]
# Training Loss: 0.5553, Training Accuracy: 79.74%, Training AUROC: 0.9243
# Validation Loss: 0.6706, Validation Accuracy: 75.68%, Validation AUROC: 0.8892
# Epoch [76/100]
# Training Loss: 0.5594, Training Accuracy: 78.81%, Training AUROC: 0.9272
# Validation Loss: 0.6552, Validation Accuracy: 74.12%, Validation AUROC: 0.8974
# Epoch [77/100]
# Training Loss: 0.5558, Training Accuracy: 78.71%, Training AUROC: 0.9282
# Validation Loss: 0.6506, Validation Accuracy: 74.90%, Validation AUROC: 0.8966
# Epoch [78/100]
# Training Loss: 0.5405, Training Accuracy: 79.74%, Training AUROC: 0.9291
# Validation Loss: 0.6699, Validation Accuracy: 74.32%, Validation AUROC: 0.8856
# Epoch [79/100]
# Training Loss: 0.5356, Training Accuracy: 79.35%, Training AUROC: 0.9303
# Validation Loss: 0.6642, Validation Accuracy: 75.10%, Validation AUROC: 0.8940
# Epoch [80/100]
# Training Loss: 0.5408, Training Accuracy: 79.59%, Training AUROC: 0.9288
# Validation Loss: 0.6588, Validation Accuracy: 74.90%, Validation AUROC: 0.8949
# Epoch [81/100]
# Training Loss: 0.5317, Training Accuracy: 79.64%, Training AUROC: 0.9316
# Validation Loss: 0.6599, Validation Accuracy: 75.88%, Validation AUROC: 0.8918
# Epoch [82/100]
# Training Loss: 0.5321, Training Accuracy: 79.54%, Training AUROC: 0.9327
# Validation Loss: 0.6538, Validation Accuracy: 75.29%, Validation AUROC: 0.8977
# Epoch [83/100]
# Training Loss: 0.5323, Training Accuracy: 79.30%, Training AUROC: 0.9305
# Validation Loss: 0.6454, Validation Accuracy: 75.10%, Validation AUROC: 0.8975
# Epoch [84/100]
# Training Loss: 0.5195, Training Accuracy: 79.54%, Training AUROC: 0.9337
# Validation Loss: 0.6703, Validation Accuracy: 75.68%, Validation AUROC: 0.8920
# Epoch [85/100]
# Training Loss: 0.5277, Training Accuracy: 79.49%, Training AUROC: 0.9336
# Validation Loss: 0.6429, Validation Accuracy: 75.49%, Validation AUROC: 0.8997
# Epoch [86/100]
# Training Loss: 0.5366, Training Accuracy: 79.30%, Training AUROC: 0.9290
# Validation Loss: 0.6454, Validation Accuracy: 75.29%, Validation AUROC: 0.8966
# Epoch [87/100]
# Training Loss: 0.5350, Training Accuracy: 79.30%, Training AUROC: 0.9321
# Validation Loss: 0.6630, Validation Accuracy: 74.51%, Validation AUROC: 0.8956
# Epoch [88/100]
# Training Loss: 0.5156, Training Accuracy: 79.93%, Training AUROC: 0.9362
# Validation Loss: 0.6567, Validation Accuracy: 75.29%, Validation AUROC: 0.8916
# Epoch [89/100]
# Training Loss: 0.5318, Training Accuracy: 79.05%, Training AUROC: 0.9320
# Validation Loss: 0.6654, Validation Accuracy: 74.90%, Validation AUROC: 0.8892
# Epoch [90/100]
# Training Loss: 0.5329, Training Accuracy: 79.25%, Training AUROC: 0.9336
# Validation Loss: 0.6536, Validation Accuracy: 75.49%, Validation AUROC: 0.8960
# Epoch [91/100]
# Training Loss: 0.5185, Training Accuracy: 79.25%, Training AUROC: 0.9333
# Validation Loss: 0.6420, Validation Accuracy: 74.90%, Validation AUROC: 0.8973
# Epoch [92/100]
# Training Loss: 0.5079, Training Accuracy: 79.98%, Training AUROC: 0.9360
# Validation Loss: 0.6393, Validation Accuracy: 74.51%, Validation AUROC: 0.8997
# Epoch [93/100]
# Training Loss: 0.5817, Training Accuracy: 77.25%, Training AUROC: 0.9260
# Validation Loss: 0.6618, Validation Accuracy: 74.90%, Validation AUROC: 0.8930
# Epoch [94/100]
# Training Loss: 0.5122, Training Accuracy: 79.35%, Training AUROC: 0.9376
# Validation Loss: 0.6607, Validation Accuracy: 75.88%, Validation AUROC: 0.8987
# Epoch [95/100]
# Training Loss: 0.5216, Training Accuracy: 79.44%, Training AUROC: 0.9339
# Validation Loss: 0.6486, Validation Accuracy: 75.68%, Validation AUROC: 0.8993
# Epoch [96/100]
# Training Loss: 0.4959, Training Accuracy: 79.74%, Training AUROC: 0.9398
# Validation Loss: 0.6439, Validation Accuracy: 75.49%, Validation AUROC: 0.8987
# Epoch [97/100]
# Training Loss: 0.5036, Training Accuracy: 79.74%, Training AUROC: 0.9382
# Validation Loss: 0.6425, Validation Accuracy: 75.49%, Validation AUROC: 0.9004
# Epoch [98/100]
# Training Loss: 0.5209, Training Accuracy: 79.15%, Training AUROC: 0.9363
# Validation Loss: 0.6697, Validation Accuracy: 74.51%, Validation AUROC: 0.8957
# Epoch [99/100]
# Training Loss: 0.4984, Training Accuracy: 79.93%, Training AUROC: 0.9395
# Validation Loss: 0.6434, Validation Accuracy: 75.10%, Validation AUROC: 0.9010
# Epoch [100/100]
# Training Loss: 0.5295, Training Accuracy: 78.66%, Training AUROC: 0.9346
# Validation Loss: 0.6523, Validation Accuracy: 74.71%, Validation AUROC: 0.8957

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /home/eslamim/miniconda3/envs/env_QML/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.7600
# F1 Score: 0.7139
# Precision: 0.6776
# Recall: 0.7600
# AUROC: 0.8975
#
# Normal Model Metrics:
# Accuracy: 0.7855
# F1 Score: 0.7659
# Precision: 0.7743
# Recall: 0.7855
# AUROC: 0.9105
