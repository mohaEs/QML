# %% [markdown]
# ## This notebook presents the reproducible procedure that we followed in comparing the performance of Hybrid Quantum-Classical Neural Networks and Classical Convolutional Neural Networks on the APTOS-2019 dataset. The APTOS dataset is a diabetic-retinopathy dataset with 3662 fundus images. The dataset was produced in France and is labeled with five-category classification (no diabetic retinopathy, mild diabetic retinopathy, moderate diabetic retinopathy, severe diabetic retinopathy, and proliferative diabetic retinopathy).

# %% [markdown]
# ### Installing and Importing Dependencies

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.40.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.1 in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.4.2)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.7.0)
# Collecting tomlkit (from pennylane)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.1)
# Collecting pennylane-lightning>=0.40 (from pennylane)
#   Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (24.2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.40->pennylane)
#   Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (2.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.1.31)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading PennyLane-0.40.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.9 MB/s eta 0:00:00
# Downloading autoray-0.7.0-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.0/930.0 kB 57.1 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.0 MB/s eta 0:00:00
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 73.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 12.1 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 82.1 MB/s eta 0:00:00
# Installing collected packages: appdirs, tomlkit, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.0 diastatic-malt-2.15.2 pennylane-0.40.0 pennylane-lightning-0.40.0 rustworkx-0.16.0 scipy-openblas32-0.3.29.0.0 tomlkit-0.13.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
from google.colab import drive
import cv2
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, Sampler
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms
from PIL import Image
import time
import os
import copy
from torch.optim.lr_scheduler import CosineAnnealingLR
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve,
    precision_recall_curve, auc
)
from sklearn.preprocessing import label_binarize
import random


os.environ["OMP_NUM_THREADS"] = "1"

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
MODEL_SAVE_PATH = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/Resnet-18-APTOS_models/"

# %% [markdown]
# ### General Training, Validation, Testing Functions

# %%
import torchvision
from torchvision import datasets, transforms

# %%
def train_model(model, train_loader, optimizer, criterion):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_probs = []

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        probs = torch.softmax(outputs, dim=1)
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.detach().cpu().numpy())



    avg_train_loss = train_loss / len(train_loader.dataset)
    accuracy = correct / total * 100

    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_train_loss, accuracy, avg_auroc

# %%
def validate_model(model, valid_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            probs = torch.softmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.detach().cpu().numpy())

    avg_val_loss = val_loss / len(valid_loader.dataset)
    accuracy = correct / total * 100
    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_val_loss, accuracy, avg_auroc

# %%
import pickle

def train_validate_model(n_epochs, model, model_name, train_loader, valid_loader, seed):

  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

  def adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max):
        if epoch < lr_warmup_epochs:
            lr = lr_max * (epoch + 1) / lr_warmup_epochs
        else:
            lr = lr_max
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

  scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs - 10, eta_min=1e-6)

  best_val_loss = float('inf')
  best_model_weights = model.state_dict()
  epochs_without_improvement = 0
  early_stopping_patience = 10

  train_losses = []
  train_accuracies = []
  val_losses = []
  val_accuracies = []
  train_aucs = []
  val_aucs = []

  lr_max = 5e-4
  lr_warmup_epochs = 10

  for epoch in range(n_epochs):
      print(f'Epoch [{epoch+1}/{n_epochs}]')

      adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max)

      train_loss, train_accuracy, train_auroc = train_model(model, train_loader, optimizer, criterion)
      val_loss, val_accuracy, val_auroc = validate_model(model, valid_loader, criterion)


      print(f'Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Training AUROC: {train_auroc:.4f}')
      print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%, Validation AUROC: {val_auroc:.4f}')
      train_losses.append(train_loss)
      train_accuracies.append(train_accuracy)
      train_aucs.append(train_auroc)
      val_losses.append(val_loss)
      val_accuracies.append(val_accuracy)
      val_aucs.append(val_auroc)

      if epoch >= lr_warmup_epochs:
            scheduler.step()

      if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict()
            epochs_without_improvement = 0  # Reset counter

      else:
            epochs_without_improvement += 1

      if epochs_without_improvement >= early_stopping_patience:
            print(f"Early stopping triggered after {epoch+1} epochs.")
            break

  model.load_state_dict(best_model_weights)
  torch.save(model, os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}.pth'))

  metrics = {
        "train_losses": train_losses,
        "train_accuracies": train_accuracies,
        "train_aucs": train_aucs,
        "val_losses": val_losses,
        "val_accuracies": val_accuracies,
        "val_aucs": val_aucs
    }

  with open(os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}_metrics.pkl'), 'wb') as f:
        pickle.dump(metrics, f)


  return model, train_losses, train_accuracies, val_losses, val_accuracies, train_aucs, val_aucs

# %%
import math
import matplotlib.pyplot as plt

def plot(quantum_loss, normal_loss, quantum_acc, normal_acc, quantum_auc, normal_auc):
    plt.style.use("default")

    loss_min = math.floor(min(min(quantum_loss), min(normal_loss)) * 10) / 10
    loss_max = math.ceil(max(max(quantum_loss), max(normal_loss)) * 10) / 10

    acc_min = math.floor(min(min(quantum_acc), min(normal_acc)) * 10) / 10
    acc_max = math.ceil(max(max(quantum_acc), max(normal_acc)) * 10) / 10

    auc_min = math.floor(min(min(quantum_auc), min(normal_auc)) * 10) / 10
    auc_max = math.ceil(max(max(quantum_auc), max(normal_auc)) * 10) / 10

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_loss, label="With quantum layer")
    plt.plot(normal_loss, label="Without quantum layer")
    plt.ylabel("Loss")
    plt.ylim([loss_min, loss_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Loss vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_acc, label="With quantum layer")
    plt.plot(normal_acc, label="Without quantum layer")
    plt.ylabel("Accuracy")
    plt.ylim([acc_min, acc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Accuracy vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_auc, label="With quantum layer")
    plt.plot(normal_auc, label="Without quantum layer")
    plt.ylabel("ROCAUC")
    plt.ylim([auc_min, auc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("ROCAUC vs. Epoch")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.preprocessing import label_binarize
from itertools import cycle


def test(model_hybrid, model_normal, test_loader, num_classes):
    model_hybrid.eval()
    model_normal.eval()

    all_labels = []
    all_preds_hybrid = []
    all_preds_normal = []
    all_probs_hybrid = []
    all_probs_normal = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)


            outputs_hybrid = model_hybrid(images)
            _, preds_hybrid = torch.max(outputs_hybrid, 1)
            probs_hybrid = torch.softmax(outputs_hybrid, dim=1)
            # Normal model predictions
            outputs_normal = model_normal(images)
            _, preds_normal = torch.max(outputs_normal, 1)
            probs_normal = torch.softmax(outputs_normal, dim=1)

            all_labels.extend(labels.cpu().numpy())
            all_preds_hybrid.extend(preds_hybrid.cpu().numpy())
            all_preds_normal.extend(preds_normal.cpu().numpy())
            all_probs_hybrid.extend(probs_hybrid.cpu().numpy())
            all_probs_normal.extend(probs_normal.cpu().numpy())

    all_labels = np.array(all_labels)
    all_preds_hybrid = np.array(all_preds_hybrid)
    all_preds_normal = np.array(all_preds_normal)
    all_probs_hybrid = np.array(all_probs_hybrid)
    all_probs_normal = np.array(all_probs_normal)


    accuracy_hybrid = accuracy_score(all_labels, all_preds_hybrid)
    accuracy_normal = accuracy_score(all_labels, all_preds_normal)


    f1_hybrid = f1_score(all_labels, all_preds_hybrid, average='weighted')
    f1_normal = f1_score(all_labels, all_preds_normal, average='weighted')


    if num_classes == 2:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, pos_label=1)
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, pos_label=1)
        precision_normal = precision_score(all_labels, all_preds_normal, pos_label=1)
        recall_normal = recall_score(all_labels, all_preds_normal, pos_label=1)
    else:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, average='weighted')
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, average='weighted')
        precision_normal = precision_score(all_labels, all_preds_normal, average='weighted')
        recall_normal = recall_score(all_labels, all_preds_normal, average='weighted')


    hybrid_aucs = []
    normal_aucs = []

    if num_classes == 2:

        all_probs_hybrid_class1 = all_probs_hybrid[:, 1]
        all_probs_normal_class1 = all_probs_normal[:, 1]

        auc_hybrid = roc_auc_score(all_labels, all_probs_hybrid_class1)
        auc_normal = roc_auc_score(all_labels, all_probs_normal_class1)

        print(f'Hybrid Model AUROC: {auc_hybrid:.4f}')
        print(f'Normal Model AUROC: {auc_normal:.4f}')

        fpr_hybrid, tpr_hybrid, _ = roc_curve(all_labels, all_probs_hybrid_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_hybrid, tpr_hybrid, label=f'Hybrid Model AUROC = {auc_hybrid:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Hybrid Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curve for the Normal Model
        fpr_normal, tpr_normal, _ = roc_curve(all_labels, all_probs_normal_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_normal, tpr_normal, label=f'Normal Model AUROC = {auc_normal:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Normal Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

    else:  # Multi-class Classification

        all_labels_binarized = label_binarize(all_labels, classes=np.arange(num_classes))

        # Define a color cycle for plotting
        colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red'])
        # Plot ROC curves for the Hybrid Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_hybrid[:, i])
            roc_auc = auc(fpr, tpr)
            hybrid_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Hybrid Model')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curves for the Normal Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_normal[:, i])
            roc_auc = auc(fpr, tpr)
            normal_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Normal Model')
        plt.legend(loc='lower right')
        plt.show()



    normal_auc = f"{sum(normal_aucs) / len(normal_aucs):.4f}"
    hybrid_auc = f"{sum(hybrid_aucs) / len(hybrid_aucs):.4f}"

    print("\nHybrid Model Metrics:")
    print(f'Accuracy: {accuracy_hybrid:.4f}')
    print(f'F1 Score: {f1_hybrid:.4f}')
    print(f'Precision: {precision_hybrid:.4f}')
    print(f'Recall: {recall_hybrid:.4f}')
    print(f'AUROC: {hybrid_auc}')

    print("\nNormal Model Metrics:")
    print(f'Accuracy: {accuracy_normal:.4f}')
    print(f'F1 Score: {f1_normal:.4f}')
    print(f'Precision: {precision_normal:.4f}')
    print(f'Recall: {recall_normal:.4f}')
    print(f'AUROC: {normal_auc} \n')

    cm_hybrid = confusion_matrix(all_labels, all_preds_hybrid)


    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_hybrid, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Hybrid Model (Avg AUC = {hybrid_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    cm_normal = confusion_matrix(all_labels, all_preds_normal)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_normal, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Classical Model (Avg AUC = {normal_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
def load_data(batch_size, dataset):

  train_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])

  valid_test_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])


  if dataset == 'APTOS':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/APTOS2019/"

  elif dataset == "IDRID":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/IDRID_images/"

  elif dataset == "Messidor":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/MESSIDOR2/"

  elif dataset == "GlaucomaFundus":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/Glaucoma_fundus/"

  elif dataset == "PAPILA":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/PAPILA/"

  elif dataset == 'G1020':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020/"


  train_dataset = datasets.ImageFolder(root=data_dir + 'train', transform=train_transform)
  val_dataset = datasets.ImageFolder(root=data_dir + 'val', transform=valid_test_transform)
  test_dataset = datasets.ImageFolder(root=data_dir + 'test', transform=valid_test_transform)

  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
  valid_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

  return train_loader, valid_loader, test_loader

# %% [markdown]
# ### Classical Resnet-18 Construction

# %%
class NormalModel(nn.Module):
  def __init__(self, freeze, num_classes, device='cuda'):
        super(NormalModel, self).__init__()

        weights = torchvision.models.ResNet18_Weights.IMAGENET1K_V1
        self.model = torchvision.models.resnet18(weights=weights)

        if freeze:
          for param in self.model.parameters():
              param.requires_grad = False

        self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)
        self.model = self.model.to(device)

  def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Hybrid Quantum-Classical Resnet-18 Construction

# %%
n_qubits = 4                # Number of qubits
step = 0.0004               # Learning rate
batch_size = 4              # Number of samples for each training step
q_delta = 0.01              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer

# %%
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)


def RY_layer(w):
    """Layer of parametrized qubit rotations around the y axis.
    """
    for idx, element in enumerate(w):
        qml.RY(element, wires=idx)


def entangling_layer(nqubits):
    """Layer of CNOTs followed by another shifted layer of CNOT.
    """
    for i in range(0, nqubits - 1, 2):
        qml.CNOT(wires=[i, i + 1])
    for i in range(1, nqubits - 1, 2):
        qml.CNOT(wires=[i, i + 1])

# %%
dev = qml.device("default.qubit", wires=n_qubits)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
@qml.qnode(dev)
def quantum_net(q_input_features, q_weights_flat):
    """
    The variational quantum circuit.
    """

    # Reshape weights
    q_weights = q_weights_flat.reshape(q_depth, n_qubits)

    # Start from state |+> , unbiased w.r.t. |0> and |1>
    H_layer(n_qubits)

    # Embed features in the quantum node
    RY_layer(q_input_features)

    # Sequence of trainable variational layers
    for k in range(q_depth):
        entangling_layer(n_qubits)
        RY_layer(q_weights[k])

    # Expectation values in the Z basis
    exp_vals = [qml.expval(qml.PauliZ(position)) for position in range(n_qubits)]
    return tuple(exp_vals)

# %%
class DressedQuantumNet(nn.Module):

    def __init__(self, q_depth, num_classes):

        super().__init__()
        self.pre_net = nn.Linear(512, n_qubits)
        self.q_params = nn.Parameter(q_delta * torch.randn(q_depth * n_qubits))
        self.post_net = nn.Linear(n_qubits, num_classes)

    def forward(self, input_features):


        pre_out = self.pre_net(input_features)
        q_in = torch.tanh(pre_out) * np.pi / 2.0

        # Apply the quantum circuit to each element of the batch and append to q_out
        q_out = torch.Tensor(0, n_qubits)
        q_out = q_out.to(device)
        for elem in q_in:
            q_out_elem = torch.hstack(quantum_net(elem, self.q_params)).float().unsqueeze(0)
            q_out = torch.cat((q_out, q_out_elem))

        # return the two-dimensional prediction from the postprocessing layer
        return self.post_net(q_out)

# %%
class QuantumHybridModel(nn.Module):
  def __init__(self, q_depth, freeze, num_classes, device='cuda'):
        super(QuantumHybridModel, self).__init__()

        weights = torchvision.models.ResNet18_Weights.IMAGENET1K_V1
        self.model = torchvision.models.resnet18(weights=weights)

        if freeze:
          for param in self.model.parameters():
              param.requires_grad = False

        self.model.fc = DressedQuantumNet(q_depth, num_classes)

        self.model = self.model.to(device)

  def forward(self, x):
        return self.model(x)

# %% [markdown]
# # Experiments

# %%
n_epochs = 100
num_classes = 5
batch_size = 32
dataset = "APTOS"
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
q_depth = 4

# %% [markdown]
# ## Seed Experiment 1

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 16:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 191MB/s]

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.5918, Training Accuracy: 24.37%, Training AUROC: 0.4704
# Validation Loss: 1.3960, Validation Accuracy: 38.91%, Validation AUROC: 0.4658
# Epoch [2/100]
# Training Loss: 1.2887, Training Accuracy: 49.61%, Training AUROC: 0.5654
# Validation Loss: 1.2038, Validation Accuracy: 56.03%, Validation AUROC: 0.6522
# Epoch [3/100]
# Training Loss: 1.1156, Training Accuracy: 62.40%, Training AUROC: 0.7217
# Validation Loss: 1.0499, Validation Accuracy: 67.32%, Validation AUROC: 0.7524
# Epoch [4/100]
# Training Loss: 0.9843, Training Accuracy: 67.09%, Training AUROC: 0.7916
# Validation Loss: 0.9530, Validation Accuracy: 67.51%, Validation AUROC: 0.7979
# Epoch [5/100]
# Training Loss: 0.9028, Training Accuracy: 69.14%, Training AUROC: 0.8249
# Validation Loss: 0.8942, Validation Accuracy: 71.21%, Validation AUROC: 0.8099
# Epoch [6/100]
# Training Loss: 0.8411, Training Accuracy: 71.09%, Training AUROC: 0.8442
# Validation Loss: 0.8262, Validation Accuracy: 73.35%, Validation AUROC: 0.8387
# Epoch [7/100]
# Training Loss: 0.7919, Training Accuracy: 72.75%, Training AUROC: 0.8637
# Validation Loss: 0.7851, Validation Accuracy: 73.93%, Validation AUROC: 0.8560
# Epoch [8/100]
# Training Loss: 0.7465, Training Accuracy: 74.12%, Training AUROC: 0.8813
# Validation Loss: 0.7672, Validation Accuracy: 74.32%, Validation AUROC: 0.8635
# Epoch [9/100]
# Training Loss: 0.7177, Training Accuracy: 74.80%, Training AUROC: 0.8883
# Validation Loss: 0.7455, Validation Accuracy: 73.54%, Validation AUROC: 0.8759
# Epoch [10/100]
# Training Loss: 0.6983, Training Accuracy: 75.29%, Training AUROC: 0.8923
# Validation Loss: 0.7235, Validation Accuracy: 75.29%, Validation AUROC: 0.8806
# Epoch [11/100]
# Training Loss: 0.6743, Training Accuracy: 75.39%, Training AUROC: 0.9007
# Validation Loss: 0.6963, Validation Accuracy: 75.10%, Validation AUROC: 0.8874
# Epoch [12/100]
# Training Loss: 0.6552, Training Accuracy: 76.61%, Training AUROC: 0.9064
# Validation Loss: 0.7342, Validation Accuracy: 74.51%, Validation AUROC: 0.8875
# Epoch [13/100]
# Training Loss: 0.6445, Training Accuracy: 77.10%, Training AUROC: 0.9100
# Validation Loss: 0.6773, Validation Accuracy: 75.68%, Validation AUROC: 0.8944
# Epoch [14/100]
# Training Loss: 0.6369, Training Accuracy: 76.86%, Training AUROC: 0.9138
# Validation Loss: 0.6841, Validation Accuracy: 75.68%, Validation AUROC: 0.8947
# Epoch [15/100]
# Training Loss: 0.6225, Training Accuracy: 78.03%, Training AUROC: 0.9156
# Validation Loss: 0.6748, Validation Accuracy: 76.26%, Validation AUROC: 0.8983
# Epoch [16/100]
# Training Loss: 0.6239, Training Accuracy: 77.05%, Training AUROC: 0.9155
# Validation Loss: 0.6674, Validation Accuracy: 76.26%, Validation AUROC: 0.8985
# Epoch [17/100]
# Training Loss: 0.6089, Training Accuracy: 77.34%, Training AUROC: 0.9216
# Validation Loss: 0.6603, Validation Accuracy: 77.04%, Validation AUROC: 0.9008
# Epoch [18/100]
# Training Loss: 0.5948, Training Accuracy: 77.83%, Training AUROC: 0.9221
# Validation Loss: 0.6565, Validation Accuracy: 77.04%, Validation AUROC: 0.9020
# Epoch [19/100]
# Training Loss: 0.5857, Training Accuracy: 78.71%, Training AUROC: 0.9242
# Validation Loss: 0.6483, Validation Accuracy: 76.26%, Validation AUROC: 0.9043
# Epoch [20/100]
# Training Loss: 0.5911, Training Accuracy: 78.03%, Training AUROC: 0.9227
# Validation Loss: 0.6394, Validation Accuracy: 76.46%, Validation AUROC: 0.9061
# Epoch [21/100]
# Training Loss: 0.5735, Training Accuracy: 78.91%, Training AUROC: 0.9277
# Validation Loss: 0.6479, Validation Accuracy: 77.24%, Validation AUROC: 0.9055
# Epoch [22/100]
# Training Loss: 0.5666, Training Accuracy: 79.25%, Training AUROC: 0.9304
# Validation Loss: 0.6401, Validation Accuracy: 76.85%, Validation AUROC: 0.9075
# Epoch [23/100]
# Training Loss: 0.5537, Training Accuracy: 79.44%, Training AUROC: 0.9333
# Validation Loss: 0.6381, Validation Accuracy: 77.63%, Validation AUROC: 0.9070
# Epoch [24/100]
# Training Loss: 0.5634, Training Accuracy: 79.30%, Training AUROC: 0.9313
# Validation Loss: 0.6492, Validation Accuracy: 77.63%, Validation AUROC: 0.9070
# Epoch [25/100]
# Training Loss: 0.5532, Training Accuracy: 79.88%, Training AUROC: 0.9316
# Validation Loss: 0.6291, Validation Accuracy: 77.43%, Validation AUROC: 0.9078
# Epoch [26/100]
# Training Loss: 0.5584, Training Accuracy: 79.15%, Training AUROC: 0.9334
# Validation Loss: 0.6324, Validation Accuracy: 77.04%, Validation AUROC: 0.9087
# Epoch [27/100]
# Training Loss: 0.5740, Training Accuracy: 79.49%, Training AUROC: 0.9277
# Validation Loss: 0.6355, Validation Accuracy: 77.04%, Validation AUROC: 0.9087
# Epoch [28/100]
# Training Loss: 0.5601, Training Accuracy: 78.52%, Training AUROC: 0.9334
# Validation Loss: 0.6353, Validation Accuracy: 77.04%, Validation AUROC: 0.9086
# Epoch [29/100]
# Training Loss: 0.5299, Training Accuracy: 80.52%, Training AUROC: 0.9401
# Validation Loss: 0.6420, Validation Accuracy: 77.82%, Validation AUROC: 0.9085
# Epoch [30/100]
# Training Loss: 0.5336, Training Accuracy: 80.32%, Training AUROC: 0.9385
# Validation Loss: 0.6326, Validation Accuracy: 77.82%, Validation AUROC: 0.9093
# Epoch [31/100]
# Training Loss: 0.5426, Training Accuracy: 79.98%, Training AUROC: 0.9375
# Validation Loss: 0.6240, Validation Accuracy: 77.63%, Validation AUROC: 0.9087
# Epoch [32/100]
# Training Loss: 0.5340, Training Accuracy: 80.32%, Training AUROC: 0.9391
# Validation Loss: 0.6234, Validation Accuracy: 77.63%, Validation AUROC: 0.9105
# Epoch [33/100]
# Training Loss: 0.5177, Training Accuracy: 81.20%, Training AUROC: 0.9439
# Validation Loss: 0.6204, Validation Accuracy: 77.43%, Validation AUROC: 0.9103
# Epoch [34/100]
# Training Loss: 0.5315, Training Accuracy: 80.42%, Training AUROC: 0.9370
# Validation Loss: 0.6131, Validation Accuracy: 77.24%, Validation AUROC: 0.9109
# Epoch [35/100]
# Training Loss: 0.5148, Training Accuracy: 81.01%, Training AUROC: 0.9434
# Validation Loss: 0.6160, Validation Accuracy: 77.63%, Validation AUROC: 0.9109
# Epoch [36/100]
# Training Loss: 0.5054, Training Accuracy: 80.86%, Training AUROC: 0.9453
# Validation Loss: 0.6163, Validation Accuracy: 77.04%, Validation AUROC: 0.9114
# Epoch [37/100]
# Training Loss: 0.5235, Training Accuracy: 80.86%, Training AUROC: 0.9408
# Validation Loss: 0.6154, Validation Accuracy: 77.63%, Validation AUROC: 0.9112
# Epoch [38/100]
# Training Loss: 0.5210, Training Accuracy: 80.62%, Training AUROC: 0.9431
# Validation Loss: 0.6178, Validation Accuracy: 77.24%, Validation AUROC: 0.9114
# Epoch [39/100]
# Training Loss: 0.5037, Training Accuracy: 81.74%, Training AUROC: 0.9460
# Validation Loss: 0.6304, Validation Accuracy: 77.24%, Validation AUROC: 0.9107
# Epoch [40/100]
# Training Loss: 0.5135, Training Accuracy: 81.84%, Training AUROC: 0.9422
# Validation Loss: 0.6256, Validation Accuracy: 78.02%, Validation AUROC: 0.9104
# Epoch [41/100]
# Training Loss: 0.5041, Training Accuracy: 81.35%, Training AUROC: 0.9444
# Validation Loss: 0.6181, Validation Accuracy: 77.82%, Validation AUROC: 0.9124
# Epoch [42/100]
# Training Loss: 0.4999, Training Accuracy: 82.08%, Training AUROC: 0.9454
# Validation Loss: 0.6185, Validation Accuracy: 77.43%, Validation AUROC: 0.9118
# Epoch [43/100]
# Training Loss: 0.5062, Training Accuracy: 81.30%, Training AUROC: 0.9442
# Validation Loss: 0.6101, Validation Accuracy: 77.43%, Validation AUROC: 0.9129
# Epoch [44/100]
# Training Loss: 0.4948, Training Accuracy: 81.01%, Training AUROC: 0.9466
# Validation Loss: 0.6149, Validation Accuracy: 76.85%, Validation AUROC: 0.9124
# Epoch [45/100]
# Training Loss: 0.5020, Training Accuracy: 81.84%, Training AUROC: 0.9463
# Validation Loss: 0.6211, Validation Accuracy: 76.65%, Validation AUROC: 0.9122
# Epoch [46/100]
# Training Loss: 0.4838, Training Accuracy: 81.93%, Training AUROC: 0.9506
# Validation Loss: 0.6056, Validation Accuracy: 78.21%, Validation AUROC: 0.9131
# Epoch [47/100]
# Training Loss: 0.4867, Training Accuracy: 81.45%, Training AUROC: 0.9495
# Validation Loss: 0.6332, Validation Accuracy: 77.04%, Validation AUROC: 0.9114
# Epoch [48/100]
# Training Loss: 0.4842, Training Accuracy: 82.08%, Training AUROC: 0.9504
# Validation Loss: 0.6132, Validation Accuracy: 76.26%, Validation AUROC: 0.9114
# Epoch [49/100]
# Training Loss: 0.4917, Training Accuracy: 82.23%, Training AUROC: 0.9478
# Validation Loss: 0.6059, Validation Accuracy: 77.82%, Validation AUROC: 0.9132
# Epoch [50/100]
# Training Loss: 0.4992, Training Accuracy: 82.03%, Training AUROC: 0.9456
# Validation Loss: 0.6061, Validation Accuracy: 76.85%, Validation AUROC: 0.9127
# Epoch [51/100]
# Training Loss: 0.4848, Training Accuracy: 82.18%, Training AUROC: 0.9490
# Validation Loss: 0.6114, Validation Accuracy: 77.04%, Validation AUROC: 0.9118
# Epoch [52/100]
# Training Loss: 0.4793, Training Accuracy: 82.91%, Training AUROC: 0.9515
# Validation Loss: 0.6144, Validation Accuracy: 78.21%, Validation AUROC: 0.9117
# Epoch [53/100]
# Training Loss: 0.4831, Training Accuracy: 81.84%, Training AUROC: 0.9506
# Validation Loss: 0.6220, Validation Accuracy: 76.85%, Validation AUROC: 0.9126
# Epoch [54/100]
# Training Loss: 0.4970, Training Accuracy: 80.91%, Training AUROC: 0.9477
# Validation Loss: 0.6133, Validation Accuracy: 76.85%, Validation AUROC: 0.9110
# Epoch [55/100]
# Training Loss: 0.4921, Training Accuracy: 81.59%, Training AUROC: 0.9477
# Validation Loss: 0.6144, Validation Accuracy: 76.46%, Validation AUROC: 0.9126
# Epoch [56/100]
# Training Loss: 0.4706, Training Accuracy: 83.54%, Training AUROC: 0.9530
# Validation Loss: 0.6181, Validation Accuracy: 77.24%, Validation AUROC: 0.9118
# Early stopping triggered after 56 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.5641, Training Accuracy: 40.82%, Training AUROC: 0.5277
# Validation Loss: 1.4192, Validation Accuracy: 48.83%, Validation AUROC: 0.5785
# Epoch [2/100]
# Training Loss: 1.3279, Training Accuracy: 56.79%, Training AUROC: 0.6505
# Validation Loss: 1.2727, Validation Accuracy: 63.42%, Validation AUROC: 0.6782
# Epoch [3/100]
# Training Loss: 1.2418, Training Accuracy: 65.14%, Training AUROC: 0.6896
# Validation Loss: 1.1972, Validation Accuracy: 68.87%, Validation AUROC: 0.6924
# Epoch [4/100]
# Training Loss: 1.1772, Training Accuracy: 68.65%, Training AUROC: 0.6995
# Validation Loss: 1.1381, Validation Accuracy: 71.21%, Validation AUROC: 0.7034
# Epoch [5/100]
# Training Loss: 1.1221, Training Accuracy: 70.21%, Training AUROC: 0.7151
# Validation Loss: 1.0907, Validation Accuracy: 71.01%, Validation AUROC: 0.7106
# Epoch [6/100]
# Training Loss: 1.0776, Training Accuracy: 70.31%, Training AUROC: 0.7251
# Validation Loss: 1.0470, Validation Accuracy: 71.01%, Validation AUROC: 0.7233
# Epoch [7/100]
# Training Loss: 1.0307, Training Accuracy: 70.95%, Training AUROC: 0.7395
# Validation Loss: 0.9990, Validation Accuracy: 73.54%, Validation AUROC: 0.7328
# Epoch [8/100]
# Training Loss: 0.9916, Training Accuracy: 71.09%, Training AUROC: 0.7431
# Validation Loss: 0.9594, Validation Accuracy: 73.35%, Validation AUROC: 0.7367
# Epoch [9/100]
# Training Loss: 0.9467, Training Accuracy: 71.78%, Training AUROC: 0.7420
# Validation Loss: 0.9243, Validation Accuracy: 73.35%, Validation AUROC: 0.7421
# Epoch [10/100]
# Training Loss: 0.9084, Training Accuracy: 72.22%, Training AUROC: 0.7691
# Validation Loss: 0.8944, Validation Accuracy: 72.96%, Validation AUROC: 0.7962
# Epoch [11/100]
# Training Loss: 0.8793, Training Accuracy: 72.22%, Training AUROC: 0.8292
# Validation Loss: 0.8664, Validation Accuracy: 73.35%, Validation AUROC: 0.8243
# Epoch [12/100]
# Training Loss: 0.8486, Training Accuracy: 73.19%, Training AUROC: 0.8430
# Validation Loss: 0.8392, Validation Accuracy: 73.54%, Validation AUROC: 0.8270
# Epoch [13/100]
# Training Loss: 0.8352, Training Accuracy: 72.71%, Training AUROC: 0.8449
# Validation Loss: 0.8363, Validation Accuracy: 72.96%, Validation AUROC: 0.8321
# Epoch [14/100]
# Training Loss: 0.8196, Training Accuracy: 72.66%, Training AUROC: 0.8383
# Validation Loss: 0.8085, Validation Accuracy: 73.74%, Validation AUROC: 0.8286
# Epoch [15/100]
# Training Loss: 0.7967, Training Accuracy: 73.34%, Training AUROC: 0.8470
# Validation Loss: 0.7968, Validation Accuracy: 73.54%, Validation AUROC: 0.8231
# Epoch [16/100]
# Training Loss: 0.7884, Training Accuracy: 73.29%, Training AUROC: 0.8480
# Validation Loss: 0.7891, Validation Accuracy: 73.54%, Validation AUROC: 0.8315
# Epoch [17/100]
# Training Loss: 0.7806, Training Accuracy: 72.90%, Training AUROC: 0.8475
# Validation Loss: 0.7791, Validation Accuracy: 73.93%, Validation AUROC: 0.8331
# Epoch [18/100]
# Training Loss: 0.7553, Training Accuracy: 73.88%, Training AUROC: 0.8513
# Validation Loss: 0.7722, Validation Accuracy: 73.35%, Validation AUROC: 0.8378
# Epoch [19/100]
# Training Loss: 0.7515, Training Accuracy: 73.97%, Training AUROC: 0.8505
# Validation Loss: 0.7614, Validation Accuracy: 74.12%, Validation AUROC: 0.8322
# Epoch [20/100]
# Training Loss: 0.7502, Training Accuracy: 73.73%, Training AUROC: 0.8502
# Validation Loss: 0.7522, Validation Accuracy: 74.90%, Validation AUROC: 0.8381
# Epoch [21/100]
# Training Loss: 0.7247, Training Accuracy: 75.68%, Training AUROC: 0.8557
# Validation Loss: 0.7399, Validation Accuracy: 76.26%, Validation AUROC: 0.8511
# Epoch [22/100]
# Training Loss: 0.7202, Training Accuracy: 75.20%, Training AUROC: 0.8628
# Validation Loss: 0.7431, Validation Accuracy: 74.32%, Validation AUROC: 0.8378
# Epoch [23/100]
# Training Loss: 0.7233, Training Accuracy: 74.80%, Training AUROC: 0.8596
# Validation Loss: 0.7400, Validation Accuracy: 75.10%, Validation AUROC: 0.8384
# Epoch [24/100]
# Training Loss: 0.7052, Training Accuracy: 75.73%, Training AUROC: 0.8684
# Validation Loss: 0.7259, Validation Accuracy: 75.29%, Validation AUROC: 0.8448
# Epoch [25/100]
# Training Loss: 0.6895, Training Accuracy: 76.27%, Training AUROC: 0.8752
# Validation Loss: 0.7244, Validation Accuracy: 74.90%, Validation AUROC: 0.8556
# Epoch [26/100]
# Training Loss: 0.6827, Training Accuracy: 76.32%, Training AUROC: 0.8695
# Validation Loss: 0.7089, Validation Accuracy: 75.88%, Validation AUROC: 0.8531
# Epoch [27/100]
# Training Loss: 0.6733, Training Accuracy: 76.90%, Training AUROC: 0.8750
# Validation Loss: 0.7052, Validation Accuracy: 75.88%, Validation AUROC: 0.8525
# Epoch [28/100]
# Training Loss: 0.6673, Training Accuracy: 77.34%, Training AUROC: 0.8738
# Validation Loss: 0.7035, Validation Accuracy: 75.68%, Validation AUROC: 0.8510
# Epoch [29/100]
# Training Loss: 0.6588, Training Accuracy: 77.15%, Training AUROC: 0.8836
# Validation Loss: 0.6983, Validation Accuracy: 76.46%, Validation AUROC: 0.8577
# Epoch [30/100]
# Training Loss: 0.6541, Training Accuracy: 76.42%, Training AUROC: 0.8822
# Validation Loss: 0.7020, Validation Accuracy: 76.07%, Validation AUROC: 0.8535
# Epoch [31/100]
# Training Loss: 0.6467, Training Accuracy: 77.59%, Training AUROC: 0.8820
# Validation Loss: 0.6949, Validation Accuracy: 77.04%, Validation AUROC: 0.8618
# Epoch [32/100]
# Training Loss: 0.6386, Training Accuracy: 77.69%, Training AUROC: 0.8902
# Validation Loss: 0.6865, Validation Accuracy: 77.04%, Validation AUROC: 0.8674
# Epoch [33/100]
# Training Loss: 0.6258, Training Accuracy: 77.83%, Training AUROC: 0.8950
# Validation Loss: 0.6888, Validation Accuracy: 75.88%, Validation AUROC: 0.8611
# Epoch [34/100]
# Training Loss: 0.6331, Training Accuracy: 78.08%, Training AUROC: 0.8915
# Validation Loss: 0.6837, Validation Accuracy: 76.07%, Validation AUROC: 0.8599
# Epoch [35/100]
# Training Loss: 0.6434, Training Accuracy: 76.66%, Training AUROC: 0.8862
# Validation Loss: 0.6870, Validation Accuracy: 76.07%, Validation AUROC: 0.8598
# Epoch [36/100]
# Training Loss: 0.6342, Training Accuracy: 77.44%, Training AUROC: 0.8921
# Validation Loss: 0.6802, Validation Accuracy: 76.46%, Validation AUROC: 0.8638
# Epoch [37/100]
# Training Loss: 0.6327, Training Accuracy: 77.88%, Training AUROC: 0.8925
# Validation Loss: 0.6979, Validation Accuracy: 75.68%, Validation AUROC: 0.8735
# Epoch [38/100]
# Training Loss: 0.6227, Training Accuracy: 77.29%, Training AUROC: 0.8930
# Validation Loss: 0.6842, Validation Accuracy: 76.46%, Validation AUROC: 0.8629
# Epoch [39/100]
# Training Loss: 0.6031, Training Accuracy: 78.66%, Training AUROC: 0.8967
# Validation Loss: 0.6818, Validation Accuracy: 76.85%, Validation AUROC: 0.8716
# Epoch [40/100]
# Training Loss: 0.5997, Training Accuracy: 78.61%, Training AUROC: 0.9036
# Validation Loss: 0.6733, Validation Accuracy: 76.46%, Validation AUROC: 0.8737
# Epoch [41/100]
# Training Loss: 0.5979, Training Accuracy: 78.66%, Training AUROC: 0.8996
# Validation Loss: 0.6870, Validation Accuracy: 75.68%, Validation AUROC: 0.8611
# Epoch [42/100]
# Training Loss: 0.6138, Training Accuracy: 78.12%, Training AUROC: 0.9030
# Validation Loss: 0.6808, Validation Accuracy: 75.29%, Validation AUROC: 0.8697
# Epoch [43/100]
# Training Loss: 0.6018, Training Accuracy: 78.61%, Training AUROC: 0.9089
# Validation Loss: 0.6746, Validation Accuracy: 76.46%, Validation AUROC: 0.8743
# Epoch [44/100]
# Training Loss: 0.6002, Training Accuracy: 78.32%, Training AUROC: 0.9017
# Validation Loss: 0.6824, Validation Accuracy: 76.26%, Validation AUROC: 0.8761
# Epoch [45/100]
# Training Loss: 0.6080, Training Accuracy: 77.49%, Training AUROC: 0.9044
# Validation Loss: 0.6790, Validation Accuracy: 77.04%, Validation AUROC: 0.8725
# Epoch [46/100]
# Training Loss: 0.5892, Training Accuracy: 78.52%, Training AUROC: 0.9117
# Validation Loss: 0.6724, Validation Accuracy: 75.49%, Validation AUROC: 0.8720
# Epoch [47/100]
# Training Loss: 0.5855, Training Accuracy: 78.52%, Training AUROC: 0.9104
# Validation Loss: 0.6716, Validation Accuracy: 76.85%, Validation AUROC: 0.8763
# Epoch [48/100]
# Training Loss: 0.5787, Training Accuracy: 79.25%, Training AUROC: 0.9104
# Validation Loss: 0.6747, Validation Accuracy: 76.85%, Validation AUROC: 0.8774
# Epoch [49/100]
# Training Loss: 0.5732, Training Accuracy: 78.71%, Training AUROC: 0.9151
# Validation Loss: 0.6740, Validation Accuracy: 76.26%, Validation AUROC: 0.8744
# Epoch [50/100]
# Training Loss: 0.5814, Training Accuracy: 79.05%, Training AUROC: 0.9112
# Validation Loss: 0.6782, Validation Accuracy: 75.88%, Validation AUROC: 0.8732
# Epoch [51/100]
# Training Loss: 0.5902, Training Accuracy: 78.42%, Training AUROC: 0.9131
# Validation Loss: 0.6720, Validation Accuracy: 76.65%, Validation AUROC: 0.8789
# Epoch [52/100]
# Training Loss: 0.5663, Training Accuracy: 79.49%, Training AUROC: 0.9154
# Validation Loss: 0.7121, Validation Accuracy: 73.74%, Validation AUROC: 0.8650
# Epoch [53/100]
# Training Loss: 0.5804, Training Accuracy: 79.59%, Training AUROC: 0.9139
# Validation Loss: 0.6776, Validation Accuracy: 75.88%, Validation AUROC: 0.8772
# Epoch [54/100]
# Training Loss: 0.5736, Training Accuracy: 80.03%, Training AUROC: 0.9152
# Validation Loss: 0.6933, Validation Accuracy: 74.12%, Validation AUROC: 0.8733
# Epoch [55/100]
# Training Loss: 0.6027, Training Accuracy: 78.22%, Training AUROC: 0.9087
# Validation Loss: 0.6900, Validation Accuracy: 75.29%, Validation AUROC: 0.8737
# Epoch [56/100]
# Training Loss: 0.5699, Training Accuracy: 79.93%, Training AUROC: 0.9192
# Validation Loss: 0.6640, Validation Accuracy: 77.24%, Validation AUROC: 0.8821
# Epoch [57/100]
# Training Loss: 0.5681, Training Accuracy: 80.57%, Training AUROC: 0.9170
# Validation Loss: 0.6864, Validation Accuracy: 75.68%, Validation AUROC: 0.8764
# Epoch [58/100]
# Training Loss: 0.5594, Training Accuracy: 80.62%, Training AUROC: 0.9233
# Validation Loss: 0.6651, Validation Accuracy: 76.85%, Validation AUROC: 0.8821
# Epoch [59/100]
# Training Loss: 0.5614, Training Accuracy: 80.37%, Training AUROC: 0.9186
# Validation Loss: 0.6624, Validation Accuracy: 77.24%, Validation AUROC: 0.8879
# Epoch [60/100]
# Training Loss: 0.5511, Training Accuracy: 80.76%, Training AUROC: 0.9230
# Validation Loss: 0.6676, Validation Accuracy: 75.49%, Validation AUROC: 0.8844
# Epoch [61/100]
# Training Loss: 0.5466, Training Accuracy: 80.32%, Training AUROC: 0.9227
# Validation Loss: 0.6645, Validation Accuracy: 76.65%, Validation AUROC: 0.8834
# Epoch [62/100]
# Training Loss: 0.5434, Training Accuracy: 81.05%, Training AUROC: 0.9242
# Validation Loss: 0.6802, Validation Accuracy: 74.12%, Validation AUROC: 0.8829
# Epoch [63/100]
# Training Loss: 0.5519, Training Accuracy: 80.81%, Training AUROC: 0.9254
# Validation Loss: 0.6660, Validation Accuracy: 76.26%, Validation AUROC: 0.8848
# Epoch [64/100]
# Training Loss: 0.5657, Training Accuracy: 80.08%, Training AUROC: 0.9209
# Validation Loss: 0.6828, Validation Accuracy: 74.51%, Validation AUROC: 0.8886
# Epoch [65/100]
# Training Loss: 0.5468, Training Accuracy: 80.91%, Training AUROC: 0.9238
# Validation Loss: 0.6640, Validation Accuracy: 75.88%, Validation AUROC: 0.8890
# Epoch [66/100]
# Training Loss: 0.5359, Training Accuracy: 81.64%, Training AUROC: 0.9267
# Validation Loss: 0.6639, Validation Accuracy: 76.07%, Validation AUROC: 0.8883
# Epoch [67/100]
# Training Loss: 0.5456, Training Accuracy: 81.25%, Training AUROC: 0.9236
# Validation Loss: 0.6597, Validation Accuracy: 77.04%, Validation AUROC: 0.8881
# Epoch [68/100]
# Training Loss: 0.5330, Training Accuracy: 81.64%, Training AUROC: 0.9266
# Validation Loss: 0.6735, Validation Accuracy: 75.49%, Validation AUROC: 0.8914
# Epoch [69/100]
# Training Loss: 0.5590, Training Accuracy: 80.62%, Training AUROC: 0.9205
# Validation Loss: 0.6700, Validation Accuracy: 76.85%, Validation AUROC: 0.8843
# Epoch [70/100]
# Training Loss: 0.5400, Training Accuracy: 81.15%, Training AUROC: 0.9249
# Validation Loss: 0.6670, Validation Accuracy: 76.46%, Validation AUROC: 0.8876
# Epoch [71/100]
# Training Loss: 0.5365, Training Accuracy: 80.86%, Training AUROC: 0.9277
# Validation Loss: 0.6757, Validation Accuracy: 75.68%, Validation AUROC: 0.8873
# Epoch [72/100]
# Training Loss: 0.5397, Training Accuracy: 80.22%, Training AUROC: 0.9249
# Validation Loss: 0.6559, Validation Accuracy: 77.04%, Validation AUROC: 0.8906
# Epoch [73/100]
# Training Loss: 0.5168, Training Accuracy: 81.93%, Training AUROC: 0.9340
# Validation Loss: 0.6586, Validation Accuracy: 76.65%, Validation AUROC: 0.8899
# Epoch [74/100]
# Training Loss: 0.5412, Training Accuracy: 80.91%, Training AUROC: 0.9257
# Validation Loss: 0.6721, Validation Accuracy: 75.49%, Validation AUROC: 0.8887
# Epoch [75/100]
# Training Loss: 0.5202, Training Accuracy: 81.30%, Training AUROC: 0.9314
# Validation Loss: 0.6652, Validation Accuracy: 76.07%, Validation AUROC: 0.8892
# Epoch [76/100]
# Training Loss: 0.5378, Training Accuracy: 80.81%, Training AUROC: 0.9289
# Validation Loss: 0.6538, Validation Accuracy: 77.63%, Validation AUROC: 0.8915
# Epoch [77/100]
# Training Loss: 0.5175, Training Accuracy: 81.25%, Training AUROC: 0.9327
# Validation Loss: 0.6567, Validation Accuracy: 77.82%, Validation AUROC: 0.8919
# Epoch [78/100]
# Training Loss: 0.5187, Training Accuracy: 82.37%, Training AUROC: 0.9305
# Validation Loss: 0.6611, Validation Accuracy: 76.65%, Validation AUROC: 0.8912
# Epoch [79/100]
# Training Loss: 0.5305, Training Accuracy: 81.40%, Training AUROC: 0.9282
# Validation Loss: 0.6622, Validation Accuracy: 76.26%, Validation AUROC: 0.8934
# Epoch [80/100]
# Training Loss: 0.5053, Training Accuracy: 82.08%, Training AUROC: 0.9343
# Validation Loss: 0.6615, Validation Accuracy: 76.85%, Validation AUROC: 0.8907
# Epoch [81/100]
# Training Loss: 0.5153, Training Accuracy: 81.49%, Training AUROC: 0.9319
# Validation Loss: 0.6578, Validation Accuracy: 76.85%, Validation AUROC: 0.8924
# Epoch [82/100]
# Training Loss: 0.5153, Training Accuracy: 81.88%, Training AUROC: 0.9318
# Validation Loss: 0.6677, Validation Accuracy: 76.26%, Validation AUROC: 0.8903
# Epoch [83/100]
# Training Loss: 0.5198, Training Accuracy: 81.69%, Training AUROC: 0.9348
# Validation Loss: 0.6549, Validation Accuracy: 76.85%, Validation AUROC: 0.8925
# Epoch [84/100]
# Training Loss: 0.5107, Training Accuracy: 81.49%, Training AUROC: 0.9316
# Validation Loss: 0.6538, Validation Accuracy: 76.26%, Validation AUROC: 0.8954
# Epoch [85/100]
# Training Loss: 0.5194, Training Accuracy: 81.10%, Training AUROC: 0.9318
# Validation Loss: 0.6852, Validation Accuracy: 73.15%, Validation AUROC: 0.8948
# Epoch [86/100]
# Training Loss: 0.5166, Training Accuracy: 81.74%, Training AUROC: 0.9335
# Validation Loss: 0.6582, Validation Accuracy: 76.46%, Validation AUROC: 0.8917
# Epoch [87/100]
# Training Loss: 0.5197, Training Accuracy: 81.79%, Training AUROC: 0.9317
# Validation Loss: 0.6712, Validation Accuracy: 73.74%, Validation AUROC: 0.8942
# Epoch [88/100]
# Training Loss: 0.5164, Training Accuracy: 81.15%, Training AUROC: 0.9328
# Validation Loss: 0.6721, Validation Accuracy: 73.74%, Validation AUROC: 0.8943
# Epoch [89/100]
# Training Loss: 0.5012, Training Accuracy: 82.28%, Training AUROC: 0.9345
# Validation Loss: 0.6578, Validation Accuracy: 76.26%, Validation AUROC: 0.8926
# Epoch [90/100]
# Training Loss: 0.5052, Training Accuracy: 82.03%, Training AUROC: 0.9336
# Validation Loss: 0.6592, Validation Accuracy: 76.07%, Validation AUROC: 0.8932
# Epoch [91/100]
# Training Loss: 0.4987, Training Accuracy: 82.57%, Training AUROC: 0.9376
# Validation Loss: 0.6602, Validation Accuracy: 77.04%, Validation AUROC: 0.8919
# Epoch [92/100]
# Training Loss: 0.4881, Training Accuracy: 82.67%, Training AUROC: 0.9407
# Validation Loss: 0.6655, Validation Accuracy: 76.85%, Validation AUROC: 0.8892
# Epoch [93/100]
# Training Loss: 0.5060, Training Accuracy: 82.13%, Training AUROC: 0.9342
# Validation Loss: 0.6530, Validation Accuracy: 75.88%, Validation AUROC: 0.8931
# Epoch [94/100]
# Training Loss: 0.5074, Training Accuracy: 81.64%, Training AUROC: 0.9353
# Validation Loss: 0.6570, Validation Accuracy: 76.07%, Validation AUROC: 0.8963
# Epoch [95/100]
# Training Loss: 0.4925, Training Accuracy: 81.98%, Training AUROC: 0.9381
# Validation Loss: 0.6561, Validation Accuracy: 77.63%, Validation AUROC: 0.8921
# Epoch [96/100]
# Training Loss: 0.4885, Training Accuracy: 82.62%, Training AUROC: 0.9398
# Validation Loss: 0.6670, Validation Accuracy: 73.54%, Validation AUROC: 0.8918
# Epoch [97/100]
# Training Loss: 0.4844, Training Accuracy: 82.86%, Training AUROC: 0.9387
# Validation Loss: 0.6677, Validation Accuracy: 76.07%, Validation AUROC: 0.8945
# Epoch [98/100]
# Training Loss: 0.5136, Training Accuracy: 81.45%, Training AUROC: 0.9319
# Validation Loss: 0.6717, Validation Accuracy: 75.10%, Validation AUROC: 0.8944
# Epoch [99/100]
# Training Loss: 0.4847, Training Accuracy: 82.18%, Training AUROC: 0.9409
# Validation Loss: 0.6591, Validation Accuracy: 76.26%, Validation AUROC: 0.8910
# Epoch [100/100]
# Training Loss: 0.4893, Training Accuracy: 82.52%, Training AUROC: 0.9374
# Validation Loss: 0.6584, Validation Accuracy: 76.07%, Validation AUROC: 0.8918

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model Metrics:
# Accuracy: 0.7755
# F1 Score: 0.7476
# Precision: 0.7504
# Recall: 0.7755
# AUROC: 0.8958
#
# Normal Model Metrics:
# Accuracy: 0.7773
# F1 Score: 0.7575
# Precision: 0.7505
# Recall: 0.7773
# AUROC: 0.9113

# %% [markdown]
# ## Seed Experiment 2

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 47:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.5292, Training Accuracy: 32.81%, Training AUROC: 0.5167
# Validation Loss: 1.3373, Validation Accuracy: 50.78%, Validation AUROC: 0.5117
# Epoch [2/100]
# Training Loss: 1.2295, Training Accuracy: 54.10%, Training AUROC: 0.6057
# Validation Loss: 1.1832, Validation Accuracy: 56.81%, Validation AUROC: 0.6499
# Epoch [3/100]
# Training Loss: 1.1000, Training Accuracy: 60.74%, Training AUROC: 0.7143
# Validation Loss: 1.0562, Validation Accuracy: 63.42%, Validation AUROC: 0.7478
# Epoch [4/100]
# Training Loss: 0.9821, Training Accuracy: 66.75%, Training AUROC: 0.7886
# Validation Loss: 0.9528, Validation Accuracy: 68.68%, Validation AUROC: 0.8054
# Epoch [5/100]
# Training Loss: 0.8983, Training Accuracy: 68.90%, Training AUROC: 0.8317
# Validation Loss: 0.8846, Validation Accuracy: 69.84%, Validation AUROC: 0.8350
# Epoch [6/100]
# Training Loss: 0.8399, Training Accuracy: 70.46%, Training AUROC: 0.8518
# Validation Loss: 0.8315, Validation Accuracy: 70.62%, Validation AUROC: 0.8541
# Epoch [7/100]
# Training Loss: 0.7979, Training Accuracy: 72.02%, Training AUROC: 0.8643
# Validation Loss: 0.7983, Validation Accuracy: 71.98%, Validation AUROC: 0.8619
# Epoch [8/100]
# Training Loss: 0.7656, Training Accuracy: 72.80%, Training AUROC: 0.8785
# Validation Loss: 0.7777, Validation Accuracy: 71.40%, Validation AUROC: 0.8726
# Epoch [9/100]
# Training Loss: 0.7218, Training Accuracy: 74.17%, Training AUROC: 0.8936
# Validation Loss: 0.7458, Validation Accuracy: 73.35%, Validation AUROC: 0.8791
# Epoch [10/100]
# Training Loss: 0.7109, Training Accuracy: 73.88%, Training AUROC: 0.8952
# Validation Loss: 0.7259, Validation Accuracy: 73.74%, Validation AUROC: 0.8855
# Epoch [11/100]
# Training Loss: 0.6752, Training Accuracy: 75.24%, Training AUROC: 0.9042
# Validation Loss: 0.7204, Validation Accuracy: 73.74%, Validation AUROC: 0.8865
# Epoch [12/100]
# Training Loss: 0.6606, Training Accuracy: 76.12%, Training AUROC: 0.9068
# Validation Loss: 0.7124, Validation Accuracy: 74.90%, Validation AUROC: 0.8891
# Epoch [13/100]
# Training Loss: 0.6353, Training Accuracy: 77.10%, Training AUROC: 0.9137
# Validation Loss: 0.6932, Validation Accuracy: 77.24%, Validation AUROC: 0.8924
# Epoch [14/100]
# Training Loss: 0.6309, Training Accuracy: 77.34%, Training AUROC: 0.9152
# Validation Loss: 0.6824, Validation Accuracy: 74.12%, Validation AUROC: 0.8939
# Epoch [15/100]
# Training Loss: 0.6245, Training Accuracy: 77.83%, Training AUROC: 0.9152
# Validation Loss: 0.6763, Validation Accuracy: 76.07%, Validation AUROC: 0.8967
# Epoch [16/100]
# Training Loss: 0.6157, Training Accuracy: 77.98%, Training AUROC: 0.9177
# Validation Loss: 0.6731, Validation Accuracy: 74.90%, Validation AUROC: 0.8957
# Epoch [17/100]
# Training Loss: 0.6073, Training Accuracy: 77.93%, Training AUROC: 0.9210
# Validation Loss: 0.6678, Validation Accuracy: 75.68%, Validation AUROC: 0.8972
# Epoch [18/100]
# Training Loss: 0.6105, Training Accuracy: 77.00%, Training AUROC: 0.9192
# Validation Loss: 0.6697, Validation Accuracy: 76.07%, Validation AUROC: 0.8987
# Epoch [19/100]
# Training Loss: 0.5881, Training Accuracy: 78.22%, Training AUROC: 0.9255
# Validation Loss: 0.6511, Validation Accuracy: 75.68%, Validation AUROC: 0.9010
# Epoch [20/100]
# Training Loss: 0.5835, Training Accuracy: 78.03%, Training AUROC: 0.9274
# Validation Loss: 0.6832, Validation Accuracy: 75.88%, Validation AUROC: 0.8997
# Epoch [21/100]
# Training Loss: 0.5790, Training Accuracy: 79.00%, Training AUROC: 0.9273
# Validation Loss: 0.6516, Validation Accuracy: 76.85%, Validation AUROC: 0.9015
# Epoch [22/100]
# Training Loss: 0.5770, Training Accuracy: 78.81%, Training AUROC: 0.9274
# Validation Loss: 0.6456, Validation Accuracy: 76.85%, Validation AUROC: 0.9022
# Epoch [23/100]
# Training Loss: 0.5697, Training Accuracy: 78.91%, Training AUROC: 0.9308
# Validation Loss: 0.6547, Validation Accuracy: 75.88%, Validation AUROC: 0.9029
# Epoch [24/100]
# Training Loss: 0.5580, Training Accuracy: 79.05%, Training AUROC: 0.9336
# Validation Loss: 0.6423, Validation Accuracy: 76.46%, Validation AUROC: 0.9035
# Epoch [25/100]
# Training Loss: 0.5620, Training Accuracy: 79.25%, Training AUROC: 0.9329
# Validation Loss: 0.6384, Validation Accuracy: 76.46%, Validation AUROC: 0.9050
# Epoch [26/100]
# Training Loss: 0.5545, Training Accuracy: 80.18%, Training AUROC: 0.9345
# Validation Loss: 0.6375, Validation Accuracy: 75.88%, Validation AUROC: 0.9050
# Epoch [27/100]
# Training Loss: 0.5443, Training Accuracy: 80.13%, Training AUROC: 0.9374
# Validation Loss: 0.6418, Validation Accuracy: 76.46%, Validation AUROC: 0.9057
# Epoch [28/100]
# Training Loss: 0.5269, Training Accuracy: 80.71%, Training AUROC: 0.9413
# Validation Loss: 0.6364, Validation Accuracy: 76.46%, Validation AUROC: 0.9059
# Epoch [29/100]
# Training Loss: 0.5528, Training Accuracy: 80.42%, Training AUROC: 0.9334
# Validation Loss: 0.6723, Validation Accuracy: 76.07%, Validation AUROC: 0.9053
# Epoch [30/100]
# Training Loss: 0.5287, Training Accuracy: 80.18%, Training AUROC: 0.9400
# Validation Loss: 0.6335, Validation Accuracy: 77.82%, Validation AUROC: 0.9072
# Epoch [31/100]
# Training Loss: 0.5422, Training Accuracy: 79.59%, Training AUROC: 0.9375
# Validation Loss: 0.6326, Validation Accuracy: 77.04%, Validation AUROC: 0.9071
# Epoch [32/100]
# Training Loss: 0.5287, Training Accuracy: 80.32%, Training AUROC: 0.9401
# Validation Loss: 0.6314, Validation Accuracy: 76.65%, Validation AUROC: 0.9077
# Epoch [33/100]
# Training Loss: 0.5209, Training Accuracy: 81.30%, Training AUROC: 0.9402
# Validation Loss: 0.6329, Validation Accuracy: 77.82%, Validation AUROC: 0.9072
# Epoch [34/100]
# Training Loss: 0.5269, Training Accuracy: 80.52%, Training AUROC: 0.9397
# Validation Loss: 0.6404, Validation Accuracy: 76.65%, Validation AUROC: 0.9086
# Epoch [35/100]
# Training Loss: 0.5185, Training Accuracy: 80.52%, Training AUROC: 0.9430
# Validation Loss: 0.6216, Validation Accuracy: 77.24%, Validation AUROC: 0.9083
# Epoch [36/100]
# Training Loss: 0.5319, Training Accuracy: 80.32%, Training AUROC: 0.9390
# Validation Loss: 0.6359, Validation Accuracy: 76.65%, Validation AUROC: 0.9089
# Epoch [37/100]
# Training Loss: 0.5186, Training Accuracy: 80.71%, Training AUROC: 0.9417
# Validation Loss: 0.6145, Validation Accuracy: 77.82%, Validation AUROC: 0.9099
# Epoch [38/100]
# Training Loss: 0.5160, Training Accuracy: 81.59%, Training AUROC: 0.9426
# Validation Loss: 0.6220, Validation Accuracy: 78.02%, Validation AUROC: 0.9088
# Epoch [39/100]
# Training Loss: 0.5126, Training Accuracy: 81.10%, Training AUROC: 0.9430
# Validation Loss: 0.6271, Validation Accuracy: 77.24%, Validation AUROC: 0.9081
# Epoch [40/100]
# Training Loss: 0.5100, Training Accuracy: 81.20%, Training AUROC: 0.9444
# Validation Loss: 0.6207, Validation Accuracy: 77.43%, Validation AUROC: 0.9088
# Epoch [41/100]
# Training Loss: 0.5207, Training Accuracy: 80.71%, Training AUROC: 0.9413
# Validation Loss: 0.6285, Validation Accuracy: 77.24%, Validation AUROC: 0.9080
# Epoch [42/100]
# Training Loss: 0.4987, Training Accuracy: 81.15%, Training AUROC: 0.9470
# Validation Loss: 0.6208, Validation Accuracy: 77.63%, Validation AUROC: 0.9086
# Epoch [43/100]
# Training Loss: 0.4961, Training Accuracy: 81.64%, Training AUROC: 0.9468
# Validation Loss: 0.6259, Validation Accuracy: 77.24%, Validation AUROC: 0.9089
# Epoch [44/100]
# Training Loss: 0.4883, Training Accuracy: 81.84%, Training AUROC: 0.9483
# Validation Loss: 0.6178, Validation Accuracy: 77.43%, Validation AUROC: 0.9091
# Epoch [45/100]
# Training Loss: 0.4993, Training Accuracy: 82.62%, Training AUROC: 0.9445
# Validation Loss: 0.6189, Validation Accuracy: 78.40%, Validation AUROC: 0.9090
# Epoch [46/100]
# Training Loss: 0.4939, Training Accuracy: 82.42%, Training AUROC: 0.9495
# Validation Loss: 0.6174, Validation Accuracy: 77.43%, Validation AUROC: 0.9092
# Epoch [47/100]
# Training Loss: 0.4853, Training Accuracy: 82.28%, Training AUROC: 0.9499
# Validation Loss: 0.6162, Validation Accuracy: 76.85%, Validation AUROC: 0.9092
# Early stopping triggered after 47 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.6615, Training Accuracy: 20.65%, Training AUROC: 0.5244
# Validation Loss: 1.4567, Validation Accuracy: 37.55%, Validation AUROC: 0.5831
# Epoch [2/100]
# Training Loss: 1.4137, Training Accuracy: 50.24%, Training AUROC: 0.5864
# Validation Loss: 1.3887, Validation Accuracy: 57.98%, Validation AUROC: 0.6141
# Epoch [3/100]
# Training Loss: 1.3742, Training Accuracy: 58.94%, Training AUROC: 0.6557
# Validation Loss: 1.3492, Validation Accuracy: 65.76%, Validation AUROC: 0.6697
# Epoch [4/100]
# Training Loss: 1.3310, Training Accuracy: 65.77%, Training AUROC: 0.6818
# Validation Loss: 1.3057, Validation Accuracy: 68.29%, Validation AUROC: 0.6874
# Epoch [5/100]
# Training Loss: 1.2758, Training Accuracy: 68.36%, Training AUROC: 0.6660
# Validation Loss: 1.2372, Validation Accuracy: 70.23%, Validation AUROC: 0.6435
# Epoch [6/100]
# Training Loss: 1.2071, Training Accuracy: 69.68%, Training AUROC: 0.6584
# Validation Loss: 1.1791, Validation Accuracy: 71.60%, Validation AUROC: 0.6301
# Epoch [7/100]
# Training Loss: 1.1471, Training Accuracy: 70.51%, Training AUROC: 0.6582
# Validation Loss: 1.1208, Validation Accuracy: 71.60%, Validation AUROC: 0.6421
# Epoch [8/100]
# Training Loss: 1.0939, Training Accuracy: 70.80%, Training AUROC: 0.6808
# Validation Loss: 1.0767, Validation Accuracy: 71.98%, Validation AUROC: 0.6515
# Epoch [9/100]
# Training Loss: 1.0458, Training Accuracy: 71.39%, Training AUROC: 0.7145
# Validation Loss: 1.0239, Validation Accuracy: 71.79%, Validation AUROC: 0.7183
# Epoch [10/100]
# Training Loss: 1.0017, Training Accuracy: 72.02%, Training AUROC: 0.7336
# Validation Loss: 0.9809, Validation Accuracy: 72.18%, Validation AUROC: 0.7296
# Epoch [11/100]
# Training Loss: 0.9612, Training Accuracy: 72.12%, Training AUROC: 0.7552
# Validation Loss: 0.9452, Validation Accuracy: 72.37%, Validation AUROC: 0.7867
# Epoch [12/100]
# Training Loss: 0.9345, Training Accuracy: 72.02%, Training AUROC: 0.8093
# Validation Loss: 0.9154, Validation Accuracy: 72.37%, Validation AUROC: 0.8285
# Epoch [13/100]
# Training Loss: 0.9066, Training Accuracy: 71.63%, Training AUROC: 0.8269
# Validation Loss: 0.8917, Validation Accuracy: 72.18%, Validation AUROC: 0.8360
# Epoch [14/100]
# Training Loss: 0.8698, Training Accuracy: 72.56%, Training AUROC: 0.8352
# Validation Loss: 0.8720, Validation Accuracy: 72.96%, Validation AUROC: 0.8339
# Epoch [15/100]
# Training Loss: 0.8576, Training Accuracy: 72.71%, Training AUROC: 0.8395
# Validation Loss: 0.8550, Validation Accuracy: 73.54%, Validation AUROC: 0.8351
# Epoch [16/100]
# Training Loss: 0.8299, Training Accuracy: 73.00%, Training AUROC: 0.8498
# Validation Loss: 0.8310, Validation Accuracy: 73.15%, Validation AUROC: 0.8395
# Epoch [17/100]
# Training Loss: 0.8131, Training Accuracy: 73.19%, Training AUROC: 0.8508
# Validation Loss: 0.8249, Validation Accuracy: 73.35%, Validation AUROC: 0.8379
# Epoch [18/100]
# Training Loss: 0.7965, Training Accuracy: 73.19%, Training AUROC: 0.8579
# Validation Loss: 0.8118, Validation Accuracy: 73.93%, Validation AUROC: 0.8396
# Epoch [19/100]
# Training Loss: 0.7837, Training Accuracy: 73.58%, Training AUROC: 0.8611
# Validation Loss: 0.8021, Validation Accuracy: 73.74%, Validation AUROC: 0.8410
# Epoch [20/100]
# Training Loss: 0.7809, Training Accuracy: 73.58%, Training AUROC: 0.8578
# Validation Loss: 0.7919, Validation Accuracy: 73.15%, Validation AUROC: 0.8395
# Epoch [21/100]
# Training Loss: 0.7676, Training Accuracy: 72.95%, Training AUROC: 0.8692
# Validation Loss: 0.7896, Validation Accuracy: 73.15%, Validation AUROC: 0.8391
# Epoch [22/100]
# Training Loss: 0.7586, Training Accuracy: 73.54%, Training AUROC: 0.8648
# Validation Loss: 0.7831, Validation Accuracy: 73.35%, Validation AUROC: 0.8410
# Epoch [23/100]
# Training Loss: 0.7412, Training Accuracy: 74.22%, Training AUROC: 0.8739
# Validation Loss: 0.7806, Validation Accuracy: 73.74%, Validation AUROC: 0.8408
# Epoch [24/100]
# Training Loss: 0.7415, Training Accuracy: 74.07%, Training AUROC: 0.8760
# Validation Loss: 0.7687, Validation Accuracy: 73.93%, Validation AUROC: 0.8420
# Epoch [25/100]
# Training Loss: 0.7278, Training Accuracy: 74.37%, Training AUROC: 0.8747
# Validation Loss: 0.7649, Validation Accuracy: 73.74%, Validation AUROC: 0.8440
# Epoch [26/100]
# Training Loss: 0.7296, Training Accuracy: 74.17%, Training AUROC: 0.8729
# Validation Loss: 0.7615, Validation Accuracy: 73.93%, Validation AUROC: 0.8426
# Epoch [27/100]
# Training Loss: 0.7324, Training Accuracy: 74.02%, Training AUROC: 0.8711
# Validation Loss: 0.7582, Validation Accuracy: 73.93%, Validation AUROC: 0.8442
# Epoch [28/100]
# Training Loss: 0.7134, Training Accuracy: 74.27%, Training AUROC: 0.8792
# Validation Loss: 0.7550, Validation Accuracy: 74.12%, Validation AUROC: 0.8448
# Epoch [29/100]
# Training Loss: 0.7118, Training Accuracy: 74.17%, Training AUROC: 0.8814
# Validation Loss: 0.7485, Validation Accuracy: 73.74%, Validation AUROC: 0.8487
# Epoch [30/100]
# Training Loss: 0.6972, Training Accuracy: 74.32%, Training AUROC: 0.8858
# Validation Loss: 0.7469, Validation Accuracy: 74.12%, Validation AUROC: 0.8487
# Epoch [31/100]
# Training Loss: 0.6911, Training Accuracy: 74.76%, Training AUROC: 0.8824
# Validation Loss: 0.7519, Validation Accuracy: 73.93%, Validation AUROC: 0.8457
# Epoch [32/100]
# Training Loss: 0.6902, Training Accuracy: 74.90%, Training AUROC: 0.8872
# Validation Loss: 0.7414, Validation Accuracy: 73.93%, Validation AUROC: 0.8513
# Epoch [33/100]
# Training Loss: 0.6907, Training Accuracy: 74.66%, Training AUROC: 0.8818
# Validation Loss: 0.7375, Validation Accuracy: 74.71%, Validation AUROC: 0.8536
# Epoch [34/100]
# Training Loss: 0.6895, Training Accuracy: 74.61%, Training AUROC: 0.8841
# Validation Loss: 0.7342, Validation Accuracy: 74.12%, Validation AUROC: 0.8535
# Epoch [35/100]
# Training Loss: 0.6913, Training Accuracy: 74.46%, Training AUROC: 0.8862
# Validation Loss: 0.7397, Validation Accuracy: 73.93%, Validation AUROC: 0.8499
# Epoch [36/100]
# Training Loss: 0.6654, Training Accuracy: 74.76%, Training AUROC: 0.8948
# Validation Loss: 0.7388, Validation Accuracy: 74.32%, Validation AUROC: 0.8558
# Epoch [37/100]
# Training Loss: 0.6704, Training Accuracy: 75.00%, Training AUROC: 0.8926
# Validation Loss: 0.7299, Validation Accuracy: 74.12%, Validation AUROC: 0.8575
# Epoch [38/100]
# Training Loss: 0.6594, Training Accuracy: 75.29%, Training AUROC: 0.8938
# Validation Loss: 0.7255, Validation Accuracy: 74.32%, Validation AUROC: 0.8574
# Epoch [39/100]
# Training Loss: 0.6821, Training Accuracy: 74.02%, Training AUROC: 0.8891
# Validation Loss: 0.7320, Validation Accuracy: 74.32%, Validation AUROC: 0.8535
# Epoch [40/100]
# Training Loss: 0.6575, Training Accuracy: 75.24%, Training AUROC: 0.8930
# Validation Loss: 0.7371, Validation Accuracy: 74.32%, Validation AUROC: 0.8531
# Epoch [41/100]
# Training Loss: 0.6529, Training Accuracy: 74.76%, Training AUROC: 0.8970
# Validation Loss: 0.7531, Validation Accuracy: 73.54%, Validation AUROC: 0.8527
# Epoch [42/100]
# Training Loss: 0.6627, Training Accuracy: 74.61%, Training AUROC: 0.8930
# Validation Loss: 0.7244, Validation Accuracy: 73.93%, Validation AUROC: 0.8580
# Epoch [43/100]
# Training Loss: 0.6483, Training Accuracy: 75.68%, Training AUROC: 0.8985
# Validation Loss: 0.7273, Validation Accuracy: 73.35%, Validation AUROC: 0.8627
# Epoch [44/100]
# Training Loss: 0.6494, Training Accuracy: 75.39%, Training AUROC: 0.8973
# Validation Loss: 0.7522, Validation Accuracy: 72.76%, Validation AUROC: 0.8488
# Epoch [45/100]
# Training Loss: 0.6578, Training Accuracy: 75.10%, Training AUROC: 0.8946
# Validation Loss: 0.7320, Validation Accuracy: 73.93%, Validation AUROC: 0.8571
# Epoch [46/100]
# Training Loss: 0.6381, Training Accuracy: 75.39%, Training AUROC: 0.9036
# Validation Loss: 0.7107, Validation Accuracy: 74.12%, Validation AUROC: 0.8706
# Epoch [47/100]
# Training Loss: 0.6220, Training Accuracy: 76.03%, Training AUROC: 0.9086
# Validation Loss: 0.7300, Validation Accuracy: 73.35%, Validation AUROC: 0.8640
# Epoch [48/100]
# Training Loss: 0.6312, Training Accuracy: 75.93%, Training AUROC: 0.9040
# Validation Loss: 0.7085, Validation Accuracy: 74.51%, Validation AUROC: 0.8708
# Epoch [49/100]
# Training Loss: 0.6240, Training Accuracy: 76.32%, Training AUROC: 0.9090
# Validation Loss: 0.7109, Validation Accuracy: 73.93%, Validation AUROC: 0.8687
# Epoch [50/100]
# Training Loss: 0.6178, Training Accuracy: 76.71%, Training AUROC: 0.9115
# Validation Loss: 0.7072, Validation Accuracy: 74.32%, Validation AUROC: 0.8714
# Epoch [51/100]
# Training Loss: 0.6124, Training Accuracy: 77.20%, Training AUROC: 0.9139
# Validation Loss: 0.7225, Validation Accuracy: 73.35%, Validation AUROC: 0.8665
# Epoch [52/100]
# Training Loss: 0.6090, Training Accuracy: 76.90%, Training AUROC: 0.9144
# Validation Loss: 0.7098, Validation Accuracy: 73.93%, Validation AUROC: 0.8719
# Epoch [53/100]
# Training Loss: 0.6318, Training Accuracy: 76.27%, Training AUROC: 0.9075
# Validation Loss: 0.7094, Validation Accuracy: 74.12%, Validation AUROC: 0.8707
# Epoch [54/100]
# Training Loss: 0.6138, Training Accuracy: 76.81%, Training AUROC: 0.9111
# Validation Loss: 0.7134, Validation Accuracy: 73.93%, Validation AUROC: 0.8714
# Epoch [55/100]
# Training Loss: 0.6192, Training Accuracy: 76.71%, Training AUROC: 0.9092
# Validation Loss: 0.7192, Validation Accuracy: 73.74%, Validation AUROC: 0.8676
# Epoch [56/100]
# Training Loss: 0.6140, Training Accuracy: 76.71%, Training AUROC: 0.9104
# Validation Loss: 0.7066, Validation Accuracy: 74.12%, Validation AUROC: 0.8734
# Epoch [57/100]
# Training Loss: 0.6117, Training Accuracy: 76.86%, Training AUROC: 0.9146
# Validation Loss: 0.7199, Validation Accuracy: 74.71%, Validation AUROC: 0.8692
# Epoch [58/100]
# Training Loss: 0.5976, Training Accuracy: 77.49%, Training AUROC: 0.9182
# Validation Loss: 0.7021, Validation Accuracy: 75.29%, Validation AUROC: 0.8770
# Epoch [59/100]
# Training Loss: 0.5902, Training Accuracy: 77.88%, Training AUROC: 0.9154
# Validation Loss: 0.7001, Validation Accuracy: 75.10%, Validation AUROC: 0.8792
# Epoch [60/100]
# Training Loss: 0.5819, Training Accuracy: 78.52%, Training AUROC: 0.9220
# Validation Loss: 0.7042, Validation Accuracy: 73.93%, Validation AUROC: 0.8725
# Epoch [61/100]
# Training Loss: 0.6033, Training Accuracy: 77.20%, Training AUROC: 0.9126
# Validation Loss: 0.6977, Validation Accuracy: 75.10%, Validation AUROC: 0.8780
# Epoch [62/100]
# Training Loss: 0.5748, Training Accuracy: 78.86%, Training AUROC: 0.9235
# Validation Loss: 0.7006, Validation Accuracy: 73.74%, Validation AUROC: 0.8775
# Epoch [63/100]
# Training Loss: 0.5576, Training Accuracy: 79.39%, Training AUROC: 0.9308
# Validation Loss: 0.6948, Validation Accuracy: 76.07%, Validation AUROC: 0.8776
# Epoch [64/100]
# Training Loss: 0.5772, Training Accuracy: 77.93%, Training AUROC: 0.9239
# Validation Loss: 0.7104, Validation Accuracy: 74.12%, Validation AUROC: 0.8727
# Epoch [65/100]
# Training Loss: 0.5785, Training Accuracy: 77.88%, Training AUROC: 0.9225
# Validation Loss: 0.7044, Validation Accuracy: 75.10%, Validation AUROC: 0.8858
# Epoch [66/100]
# Training Loss: 0.5793, Training Accuracy: 77.98%, Training AUROC: 0.9213
# Validation Loss: 0.6941, Validation Accuracy: 75.88%, Validation AUROC: 0.8832
# Epoch [67/100]
# Training Loss: 0.5784, Training Accuracy: 78.12%, Training AUROC: 0.9190
# Validation Loss: 0.6889, Validation Accuracy: 74.71%, Validation AUROC: 0.8773
# Epoch [68/100]
# Training Loss: 0.5617, Training Accuracy: 79.10%, Training AUROC: 0.9252
# Validation Loss: 0.7177, Validation Accuracy: 74.32%, Validation AUROC: 0.8760
# Epoch [69/100]
# Training Loss: 0.5823, Training Accuracy: 79.00%, Training AUROC: 0.9208
# Validation Loss: 0.6954, Validation Accuracy: 75.10%, Validation AUROC: 0.8817
# Epoch [70/100]
# Training Loss: 0.5646, Training Accuracy: 78.76%, Training AUROC: 0.9280
# Validation Loss: 0.6974, Validation Accuracy: 75.10%, Validation AUROC: 0.8800
# Epoch [71/100]
# Training Loss: 0.5625, Training Accuracy: 78.96%, Training AUROC: 0.9262
# Validation Loss: 0.6834, Validation Accuracy: 75.88%, Validation AUROC: 0.8832
# Epoch [72/100]
# Training Loss: 0.5511, Training Accuracy: 80.91%, Training AUROC: 0.9300
# Validation Loss: 0.6847, Validation Accuracy: 75.49%, Validation AUROC: 0.8806
# Epoch [73/100]
# Training Loss: 0.5515, Training Accuracy: 79.20%, Training AUROC: 0.9295
# Validation Loss: 0.6951, Validation Accuracy: 74.32%, Validation AUROC: 0.8816
# Epoch [74/100]
# Training Loss: 0.5505, Training Accuracy: 80.42%, Training AUROC: 0.9285
# Validation Loss: 0.6807, Validation Accuracy: 74.90%, Validation AUROC: 0.8904
# Epoch [75/100]
# Training Loss: 0.5508, Training Accuracy: 79.98%, Training AUROC: 0.9307
# Validation Loss: 0.6796, Validation Accuracy: 74.51%, Validation AUROC: 0.8856
# Epoch [76/100]
# Training Loss: 0.5270, Training Accuracy: 81.25%, Training AUROC: 0.9358
# Validation Loss: 0.6780, Validation Accuracy: 75.68%, Validation AUROC: 0.8853
# Epoch [77/100]
# Training Loss: 0.5403, Training Accuracy: 80.86%, Training AUROC: 0.9319
# Validation Loss: 0.6982, Validation Accuracy: 76.46%, Validation AUROC: 0.8850
# Epoch [78/100]
# Training Loss: 0.5480, Training Accuracy: 80.47%, Training AUROC: 0.9320
# Validation Loss: 0.6732, Validation Accuracy: 75.10%, Validation AUROC: 0.8907
# Epoch [79/100]
# Training Loss: 0.5339, Training Accuracy: 80.42%, Training AUROC: 0.9340
# Validation Loss: 0.6760, Validation Accuracy: 74.32%, Validation AUROC: 0.8910
# Epoch [80/100]
# Training Loss: 0.5428, Training Accuracy: 80.42%, Training AUROC: 0.9301
# Validation Loss: 0.6818, Validation Accuracy: 73.93%, Validation AUROC: 0.8876
# Epoch [81/100]
# Training Loss: 0.5732, Training Accuracy: 79.20%, Training AUROC: 0.9281
# Validation Loss: 0.7096, Validation Accuracy: 74.12%, Validation AUROC: 0.8776
# Epoch [82/100]
# Training Loss: 0.5341, Training Accuracy: 80.13%, Training AUROC: 0.9347
# Validation Loss: 0.6999, Validation Accuracy: 73.54%, Validation AUROC: 0.8791
# Epoch [83/100]
# Training Loss: 0.5375, Training Accuracy: 80.42%, Training AUROC: 0.9316
# Validation Loss: 0.6740, Validation Accuracy: 74.71%, Validation AUROC: 0.8917
# Epoch [84/100]
# Training Loss: 0.5309, Training Accuracy: 81.15%, Training AUROC: 0.9327
# Validation Loss: 0.6738, Validation Accuracy: 74.90%, Validation AUROC: 0.8906
# Epoch [85/100]
# Training Loss: 0.5268, Training Accuracy: 81.05%, Training AUROC: 0.9343
# Validation Loss: 0.7224, Validation Accuracy: 74.71%, Validation AUROC: 0.8807
# Epoch [86/100]
# Training Loss: 0.5294, Training Accuracy: 80.91%, Training AUROC: 0.9337
# Validation Loss: 0.6833, Validation Accuracy: 74.32%, Validation AUROC: 0.8881
# Epoch [87/100]
# Training Loss: 0.5280, Training Accuracy: 80.81%, Training AUROC: 0.9366
# Validation Loss: 0.6756, Validation Accuracy: 74.51%, Validation AUROC: 0.8919
# Epoch [88/100]
# Training Loss: 0.5300, Training Accuracy: 80.62%, Training AUROC: 0.9345
# Validation Loss: 0.7083, Validation Accuracy: 71.40%, Validation AUROC: 0.8852
# Early stopping triggered after 88 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model Metrics:
# Accuracy: 0.7427
# F1 Score: 0.7365
# Precision: 0.7523
# Recall: 0.7427
# AUROC: 0.8905
#
# Normal Model Metrics:
# Accuracy: 0.7736
# F1 Score: 0.7592
# Precision: 0.7533
# Recall: 0.7736
# AUROC: 0.9112

# %% [markdown]
# ## Seed Experiment 3

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 26:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 222MB/s]

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.4667, Training Accuracy: 33.11%, Training AUROC: 0.5062
# Validation Loss: 1.3359, Validation Accuracy: 45.53%, Validation AUROC: 0.5173
# Epoch [2/100]
# Training Loss: 1.2466, Training Accuracy: 52.64%, Training AUROC: 0.6121
# Validation Loss: 1.1716, Validation Accuracy: 56.03%, Validation AUROC: 0.6980
# Epoch [3/100]
# Training Loss: 1.1012, Training Accuracy: 59.13%, Training AUROC: 0.7475
# Validation Loss: 1.0365, Validation Accuracy: 65.95%, Validation AUROC: 0.7819
# Epoch [4/100]
# Training Loss: 0.9810, Training Accuracy: 66.16%, Training AUROC: 0.8046
# Validation Loss: 0.9318, Validation Accuracy: 70.04%, Validation AUROC: 0.8234
# Epoch [5/100]
# Training Loss: 0.8971, Training Accuracy: 68.70%, Training AUROC: 0.8360
# Validation Loss: 0.8752, Validation Accuracy: 71.79%, Validation AUROC: 0.8422
# Epoch [6/100]
# Training Loss: 0.8287, Training Accuracy: 71.24%, Training AUROC: 0.8574
# Validation Loss: 0.8246, Validation Accuracy: 69.46%, Validation AUROC: 0.8604
# Epoch [7/100]
# Training Loss: 0.7899, Training Accuracy: 71.53%, Training AUROC: 0.8710
# Validation Loss: 0.7838, Validation Accuracy: 73.35%, Validation AUROC: 0.8670
# Epoch [8/100]
# Training Loss: 0.7515, Training Accuracy: 74.02%, Training AUROC: 0.8789
# Validation Loss: 0.7644, Validation Accuracy: 73.54%, Validation AUROC: 0.8740
# Epoch [9/100]
# Training Loss: 0.7178, Training Accuracy: 73.88%, Training AUROC: 0.8903
# Validation Loss: 0.7349, Validation Accuracy: 73.54%, Validation AUROC: 0.8796
# Epoch [10/100]
# Training Loss: 0.6980, Training Accuracy: 74.32%, Training AUROC: 0.8968
# Validation Loss: 0.7168, Validation Accuracy: 73.93%, Validation AUROC: 0.8834
# Epoch [11/100]
# Training Loss: 0.6782, Training Accuracy: 75.15%, Training AUROC: 0.9005
# Validation Loss: 0.6976, Validation Accuracy: 74.90%, Validation AUROC: 0.8901
# Epoch [12/100]
# Training Loss: 0.6585, Training Accuracy: 76.07%, Training AUROC: 0.9077
# Validation Loss: 0.6952, Validation Accuracy: 74.51%, Validation AUROC: 0.8927
# Epoch [13/100]
# Training Loss: 0.6564, Training Accuracy: 75.88%, Training AUROC: 0.9079
# Validation Loss: 0.6793, Validation Accuracy: 74.71%, Validation AUROC: 0.8951
# Epoch [14/100]
# Training Loss: 0.6458, Training Accuracy: 75.88%, Training AUROC: 0.9134
# Validation Loss: 0.6706, Validation Accuracy: 74.90%, Validation AUROC: 0.8972
# Epoch [15/100]
# Training Loss: 0.6190, Training Accuracy: 76.61%, Training AUROC: 0.9182
# Validation Loss: 0.6761, Validation Accuracy: 74.71%, Validation AUROC: 0.8971
# Epoch [16/100]
# Training Loss: 0.6146, Training Accuracy: 77.25%, Training AUROC: 0.9184
# Validation Loss: 0.6563, Validation Accuracy: 76.26%, Validation AUROC: 0.9005
# Epoch [17/100]
# Training Loss: 0.6004, Training Accuracy: 77.25%, Training AUROC: 0.9247
# Validation Loss: 0.6661, Validation Accuracy: 75.88%, Validation AUROC: 0.9014
# Epoch [18/100]
# Training Loss: 0.5974, Training Accuracy: 77.98%, Training AUROC: 0.9204
# Validation Loss: 0.6500, Validation Accuracy: 75.49%, Validation AUROC: 0.9031
# Epoch [19/100]
# Training Loss: 0.5891, Training Accuracy: 78.42%, Training AUROC: 0.9262
# Validation Loss: 0.6503, Validation Accuracy: 76.46%, Validation AUROC: 0.9032
# Epoch [20/100]
# Training Loss: 0.5693, Training Accuracy: 79.39%, Training AUROC: 0.9305
# Validation Loss: 0.6545, Validation Accuracy: 74.90%, Validation AUROC: 0.9027
# Epoch [21/100]
# Training Loss: 0.5670, Training Accuracy: 79.00%, Training AUROC: 0.9299
# Validation Loss: 0.6460, Validation Accuracy: 77.04%, Validation AUROC: 0.9043
# Epoch [22/100]
# Training Loss: 0.5699, Training Accuracy: 79.30%, Training AUROC: 0.9281
# Validation Loss: 0.6468, Validation Accuracy: 75.68%, Validation AUROC: 0.9055
# Epoch [23/100]
# Training Loss: 0.5603, Training Accuracy: 78.86%, Training AUROC: 0.9315
# Validation Loss: 0.6353, Validation Accuracy: 77.24%, Validation AUROC: 0.9062
# Epoch [24/100]
# Training Loss: 0.5612, Training Accuracy: 79.64%, Training AUROC: 0.9305
# Validation Loss: 0.6404, Validation Accuracy: 77.04%, Validation AUROC: 0.9064
# Epoch [25/100]
# Training Loss: 0.5600, Training Accuracy: 79.25%, Training AUROC: 0.9323
# Validation Loss: 0.6327, Validation Accuracy: 77.04%, Validation AUROC: 0.9064
# Epoch [26/100]
# Training Loss: 0.5471, Training Accuracy: 80.27%, Training AUROC: 0.9345
# Validation Loss: 0.6236, Validation Accuracy: 76.26%, Validation AUROC: 0.9082
# Epoch [27/100]
# Training Loss: 0.5519, Training Accuracy: 79.88%, Training AUROC: 0.9334
# Validation Loss: 0.6367, Validation Accuracy: 77.04%, Validation AUROC: 0.9072
# Epoch [28/100]
# Training Loss: 0.5518, Training Accuracy: 79.88%, Training AUROC: 0.9339
# Validation Loss: 0.6185, Validation Accuracy: 78.40%, Validation AUROC: 0.9093
# Epoch [29/100]
# Training Loss: 0.5387, Training Accuracy: 80.57%, Training AUROC: 0.9366
# Validation Loss: 0.6421, Validation Accuracy: 76.07%, Validation AUROC: 0.9083
# Epoch [30/100]
# Training Loss: 0.5319, Training Accuracy: 81.10%, Training AUROC: 0.9383
# Validation Loss: 0.6131, Validation Accuracy: 77.82%, Validation AUROC: 0.9103
# Epoch [31/100]
# Training Loss: 0.5352, Training Accuracy: 80.22%, Training AUROC: 0.9371
# Validation Loss: 0.6138, Validation Accuracy: 77.43%, Validation AUROC: 0.9111
# Epoch [32/100]
# Training Loss: 0.5261, Training Accuracy: 80.57%, Training AUROC: 0.9398
# Validation Loss: 0.6145, Validation Accuracy: 77.43%, Validation AUROC: 0.9113
# Epoch [33/100]
# Training Loss: 0.5262, Training Accuracy: 80.62%, Training AUROC: 0.9402
# Validation Loss: 0.6129, Validation Accuracy: 78.40%, Validation AUROC: 0.9105
# Epoch [34/100]
# Training Loss: 0.5154, Training Accuracy: 81.25%, Training AUROC: 0.9431
# Validation Loss: 0.6201, Validation Accuracy: 76.46%, Validation AUROC: 0.9116
# Epoch [35/100]
# Training Loss: 0.5285, Training Accuracy: 80.47%, Training AUROC: 0.9402
# Validation Loss: 0.6090, Validation Accuracy: 78.79%, Validation AUROC: 0.9117
# Epoch [36/100]
# Training Loss: 0.5094, Training Accuracy: 81.45%, Training AUROC: 0.9441
# Validation Loss: 0.6172, Validation Accuracy: 77.82%, Validation AUROC: 0.9099
# Epoch [37/100]
# Training Loss: 0.5113, Training Accuracy: 80.91%, Training AUROC: 0.9437
# Validation Loss: 0.6184, Validation Accuracy: 77.43%, Validation AUROC: 0.9116
# Epoch [38/100]
# Training Loss: 0.5143, Training Accuracy: 80.03%, Training AUROC: 0.9431
# Validation Loss: 0.6167, Validation Accuracy: 78.40%, Validation AUROC: 0.9115
# Epoch [39/100]
# Training Loss: 0.5320, Training Accuracy: 79.79%, Training AUROC: 0.9383
# Validation Loss: 0.6166, Validation Accuracy: 78.02%, Validation AUROC: 0.9123
# Epoch [40/100]
# Training Loss: 0.5075, Training Accuracy: 81.40%, Training AUROC: 0.9446
# Validation Loss: 0.6084, Validation Accuracy: 77.43%, Validation AUROC: 0.9120
# Epoch [41/100]
# Training Loss: 0.5117, Training Accuracy: 80.71%, Training AUROC: 0.9448
# Validation Loss: 0.6117, Validation Accuracy: 77.63%, Validation AUROC: 0.9124
# Epoch [42/100]
# Training Loss: 0.5105, Training Accuracy: 82.03%, Training AUROC: 0.9410
# Validation Loss: 0.6121, Validation Accuracy: 77.04%, Validation AUROC: 0.9120
# Epoch [43/100]
# Training Loss: 0.5000, Training Accuracy: 81.45%, Training AUROC: 0.9464
# Validation Loss: 0.6113, Validation Accuracy: 78.40%, Validation AUROC: 0.9115
# Epoch [44/100]
# Training Loss: 0.4986, Training Accuracy: 81.30%, Training AUROC: 0.9458
# Validation Loss: 0.6153, Validation Accuracy: 78.02%, Validation AUROC: 0.9117
# Epoch [45/100]
# Training Loss: 0.4893, Training Accuracy: 82.52%, Training AUROC: 0.9471
# Validation Loss: 0.6072, Validation Accuracy: 78.40%, Validation AUROC: 0.9134
# Epoch [46/100]
# Training Loss: 0.4976, Training Accuracy: 81.54%, Training AUROC: 0.9466
# Validation Loss: 0.6120, Validation Accuracy: 77.43%, Validation AUROC: 0.9129
# Epoch [47/100]
# Training Loss: 0.5014, Training Accuracy: 81.45%, Training AUROC: 0.9438
# Validation Loss: 0.6000, Validation Accuracy: 77.63%, Validation AUROC: 0.9137
# Epoch [48/100]
# Training Loss: 0.5012, Training Accuracy: 81.79%, Training AUROC: 0.9475
# Validation Loss: 0.6023, Validation Accuracy: 77.82%, Validation AUROC: 0.9124
# Epoch [49/100]
# Training Loss: 0.4997, Training Accuracy: 81.88%, Training AUROC: 0.9467
# Validation Loss: 0.6121, Validation Accuracy: 78.21%, Validation AUROC: 0.9123
# Epoch [50/100]
# Training Loss: 0.4922, Training Accuracy: 81.88%, Training AUROC: 0.9465
# Validation Loss: 0.6042, Validation Accuracy: 78.21%, Validation AUROC: 0.9126
# Epoch [51/100]
# Training Loss: 0.4797, Training Accuracy: 81.49%, Training AUROC: 0.9499
# Validation Loss: 0.6027, Validation Accuracy: 78.40%, Validation AUROC: 0.9129
# Epoch [52/100]
# Training Loss: 0.4830, Training Accuracy: 82.71%, Training AUROC: 0.9500
# Validation Loss: 0.6103, Validation Accuracy: 78.60%, Validation AUROC: 0.9122
# Epoch [53/100]
# Training Loss: 0.4812, Training Accuracy: 82.91%, Training AUROC: 0.9506
# Validation Loss: 0.5997, Validation Accuracy: 78.21%, Validation AUROC: 0.9140
# Epoch [54/100]
# Training Loss: 0.4896, Training Accuracy: 82.86%, Training AUROC: 0.9478
# Validation Loss: 0.6056, Validation Accuracy: 77.82%, Validation AUROC: 0.9129
# Epoch [55/100]
# Training Loss: 0.4739, Training Accuracy: 82.91%, Training AUROC: 0.9517
# Validation Loss: 0.6121, Validation Accuracy: 78.02%, Validation AUROC: 0.9122
# Epoch [56/100]
# Training Loss: 0.4837, Training Accuracy: 82.03%, Training AUROC: 0.9491
# Validation Loss: 0.6051, Validation Accuracy: 78.40%, Validation AUROC: 0.9133
# Epoch [57/100]
# Training Loss: 0.4728, Training Accuracy: 82.28%, Training AUROC: 0.9529
# Validation Loss: 0.6055, Validation Accuracy: 78.60%, Validation AUROC: 0.9124
# Epoch [58/100]
# Training Loss: 0.4743, Training Accuracy: 83.01%, Training AUROC: 0.9517
# Validation Loss: 0.6167, Validation Accuracy: 78.02%, Validation AUROC: 0.9125
# Epoch [59/100]
# Training Loss: 0.4802, Training Accuracy: 82.81%, Training AUROC: 0.9519
# Validation Loss: 0.6133, Validation Accuracy: 78.02%, Validation AUROC: 0.9120
# Epoch [60/100]
# Training Loss: 0.4735, Training Accuracy: 83.11%, Training AUROC: 0.9513
# Validation Loss: 0.6157, Validation Accuracy: 78.02%, Validation AUROC: 0.9117
# Epoch [61/100]
# Training Loss: 0.4687, Training Accuracy: 82.91%, Training AUROC: 0.9518
# Validation Loss: 0.6124, Validation Accuracy: 78.60%, Validation AUROC: 0.9118
# Epoch [62/100]
# Training Loss: 0.4750, Training Accuracy: 83.06%, Training AUROC: 0.9530
# Validation Loss: 0.6187, Validation Accuracy: 77.04%, Validation AUROC: 0.9112
# Epoch [63/100]
# Training Loss: 0.4719, Training Accuracy: 83.01%, Training AUROC: 0.9522
# Validation Loss: 0.6189, Validation Accuracy: 77.82%, Validation AUROC: 0.9125
# Early stopping triggered after 63 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.5044, Training Accuracy: 43.75%, Training AUROC: 0.4784
# Validation Loss: 1.4356, Validation Accuracy: 49.22%, Validation AUROC: 0.5400
# Epoch [2/100]
# Training Loss: 1.3975, Training Accuracy: 49.56%, Training AUROC: 0.5998
# Validation Loss: 1.3296, Validation Accuracy: 56.03%, Validation AUROC: 0.6414
# Epoch [3/100]
# Training Loss: 1.2772, Training Accuracy: 63.87%, Training AUROC: 0.6707
# Validation Loss: 1.2276, Validation Accuracy: 71.21%, Validation AUROC: 0.6880
# Epoch [4/100]
# Training Loss: 1.1998, Training Accuracy: 68.65%, Training AUROC: 0.7054
# Validation Loss: 1.1639, Validation Accuracy: 71.79%, Validation AUROC: 0.7056
# Epoch [5/100]
# Training Loss: 1.1454, Training Accuracy: 69.97%, Training AUROC: 0.7199
# Validation Loss: 1.1095, Validation Accuracy: 72.37%, Validation AUROC: 0.7105
# Epoch [6/100]
# Training Loss: 1.0868, Training Accuracy: 71.44%, Training AUROC: 0.7287
# Validation Loss: 1.0580, Validation Accuracy: 72.37%, Validation AUROC: 0.7142
# Epoch [7/100]
# Training Loss: 1.0387, Training Accuracy: 71.92%, Training AUROC: 0.7255
# Validation Loss: 1.0133, Validation Accuracy: 72.96%, Validation AUROC: 0.7195
# Epoch [8/100]
# Training Loss: 0.9972, Training Accuracy: 71.78%, Training AUROC: 0.7322
# Validation Loss: 0.9684, Validation Accuracy: 72.76%, Validation AUROC: 0.7305
# Epoch [9/100]
# Training Loss: 0.9532, Training Accuracy: 72.27%, Training AUROC: 0.7423
# Validation Loss: 0.9322, Validation Accuracy: 73.15%, Validation AUROC: 0.7377
# Epoch [10/100]
# Training Loss: 0.9228, Training Accuracy: 72.27%, Training AUROC: 0.7946
# Validation Loss: 0.9022, Validation Accuracy: 72.96%, Validation AUROC: 0.8207
# Epoch [11/100]
# Training Loss: 0.8973, Training Accuracy: 72.31%, Training AUROC: 0.8268
# Validation Loss: 0.8752, Validation Accuracy: 73.15%, Validation AUROC: 0.8291
# Epoch [12/100]
# Training Loss: 0.8586, Training Accuracy: 73.34%, Training AUROC: 0.8292
# Validation Loss: 0.8558, Validation Accuracy: 73.35%, Validation AUROC: 0.8296
# Epoch [13/100]
# Training Loss: 0.8463, Training Accuracy: 73.10%, Training AUROC: 0.8347
# Validation Loss: 0.8363, Validation Accuracy: 73.15%, Validation AUROC: 0.8441
# Epoch [14/100]
# Training Loss: 0.8298, Training Accuracy: 73.34%, Training AUROC: 0.8316
# Validation Loss: 0.8214, Validation Accuracy: 73.54%, Validation AUROC: 0.8443
# Epoch [15/100]
# Training Loss: 0.8140, Training Accuracy: 73.39%, Training AUROC: 0.8362
# Validation Loss: 0.8100, Validation Accuracy: 73.35%, Validation AUROC: 0.8478
# Epoch [16/100]
# Training Loss: 0.7957, Training Accuracy: 73.68%, Training AUROC: 0.8453
# Validation Loss: 0.8167, Validation Accuracy: 72.76%, Validation AUROC: 0.8228
# Epoch [17/100]
# Training Loss: 0.7798, Training Accuracy: 73.88%, Training AUROC: 0.8392
# Validation Loss: 0.7906, Validation Accuracy: 73.74%, Validation AUROC: 0.8430
# Epoch [18/100]
# Training Loss: 0.7772, Training Accuracy: 73.49%, Training AUROC: 0.8428
# Validation Loss: 0.7859, Validation Accuracy: 73.74%, Validation AUROC: 0.8523
# Epoch [19/100]
# Training Loss: 0.7753, Training Accuracy: 73.49%, Training AUROC: 0.8461
# Validation Loss: 0.7781, Validation Accuracy: 73.74%, Validation AUROC: 0.8386
# Epoch [20/100]
# Training Loss: 0.7581, Training Accuracy: 73.73%, Training AUROC: 0.8408
# Validation Loss: 0.7678, Validation Accuracy: 73.93%, Validation AUROC: 0.8453
# Epoch [21/100]
# Training Loss: 0.7402, Training Accuracy: 74.02%, Training AUROC: 0.8454
# Validation Loss: 0.7610, Validation Accuracy: 74.12%, Validation AUROC: 0.8440
# Epoch [22/100]
# Training Loss: 0.7513, Training Accuracy: 73.44%, Training AUROC: 0.8417
# Validation Loss: 0.7601, Validation Accuracy: 73.74%, Validation AUROC: 0.8417
# Epoch [23/100]
# Training Loss: 0.7452, Training Accuracy: 73.58%, Training AUROC: 0.8441
# Validation Loss: 0.7497, Validation Accuracy: 73.93%, Validation AUROC: 0.8413
# Epoch [24/100]
# Training Loss: 0.7361, Training Accuracy: 73.97%, Training AUROC: 0.8486
# Validation Loss: 0.7652, Validation Accuracy: 74.12%, Validation AUROC: 0.8299
# Epoch [25/100]
# Training Loss: 0.7391, Training Accuracy: 74.51%, Training AUROC: 0.8381
# Validation Loss: 0.7439, Validation Accuracy: 73.74%, Validation AUROC: 0.8505
# Epoch [26/100]
# Training Loss: 0.7249, Training Accuracy: 75.34%, Training AUROC: 0.8489
# Validation Loss: 0.7369, Validation Accuracy: 74.71%, Validation AUROC: 0.8456
# Epoch [27/100]
# Training Loss: 0.7091, Training Accuracy: 76.03%, Training AUROC: 0.8550
# Validation Loss: 0.7351, Validation Accuracy: 74.32%, Validation AUROC: 0.8462
# Epoch [28/100]
# Training Loss: 0.6975, Training Accuracy: 76.12%, Training AUROC: 0.8534
# Validation Loss: 0.7287, Validation Accuracy: 74.51%, Validation AUROC: 0.8460
# Epoch [29/100]
# Training Loss: 0.7027, Training Accuracy: 75.93%, Training AUROC: 0.8523
# Validation Loss: 0.7351, Validation Accuracy: 74.51%, Validation AUROC: 0.8552
# Epoch [30/100]
# Training Loss: 0.7067, Training Accuracy: 75.83%, Training AUROC: 0.8464
# Validation Loss: 0.7277, Validation Accuracy: 75.29%, Validation AUROC: 0.8404
# Epoch [31/100]
# Training Loss: 0.6842, Training Accuracy: 76.90%, Training AUROC: 0.8528
# Validation Loss: 0.7174, Validation Accuracy: 76.26%, Validation AUROC: 0.8441
# Epoch [32/100]
# Training Loss: 0.6831, Training Accuracy: 76.86%, Training AUROC: 0.8572
# Validation Loss: 0.7169, Validation Accuracy: 75.29%, Validation AUROC: 0.8477
# Epoch [33/100]
# Training Loss: 0.7004, Training Accuracy: 76.37%, Training AUROC: 0.8490
# Validation Loss: 0.7109, Validation Accuracy: 75.88%, Validation AUROC: 0.8526
# Epoch [34/100]
# Training Loss: 0.6770, Training Accuracy: 77.29%, Training AUROC: 0.8510
# Validation Loss: 0.7075, Validation Accuracy: 76.26%, Validation AUROC: 0.8495
# Epoch [35/100]
# Training Loss: 0.6714, Training Accuracy: 77.54%, Training AUROC: 0.8572
# Validation Loss: 0.7155, Validation Accuracy: 74.90%, Validation AUROC: 0.8533
# Epoch [36/100]
# Training Loss: 0.6802, Training Accuracy: 77.05%, Training AUROC: 0.8591
# Validation Loss: 0.7106, Validation Accuracy: 76.07%, Validation AUROC: 0.8472
# Epoch [37/100]
# Training Loss: 0.6700, Training Accuracy: 77.44%, Training AUROC: 0.8594
# Validation Loss: 0.7029, Validation Accuracy: 75.68%, Validation AUROC: 0.8502
# Epoch [38/100]
# Training Loss: 0.6676, Training Accuracy: 77.34%, Training AUROC: 0.8610
# Validation Loss: 0.6953, Validation Accuracy: 75.88%, Validation AUROC: 0.8567
# Epoch [39/100]
# Training Loss: 0.6581, Training Accuracy: 77.34%, Training AUROC: 0.8668
# Validation Loss: 0.7066, Validation Accuracy: 74.71%, Validation AUROC: 0.8586
# Epoch [40/100]
# Training Loss: 0.6581, Training Accuracy: 77.10%, Training AUROC: 0.8644
# Validation Loss: 0.6996, Validation Accuracy: 75.29%, Validation AUROC: 0.8572
# Epoch [41/100]
# Training Loss: 0.6726, Training Accuracy: 75.98%, Training AUROC: 0.8625
# Validation Loss: 0.6929, Validation Accuracy: 76.26%, Validation AUROC: 0.8605
# Epoch [42/100]
# Training Loss: 0.6394, Training Accuracy: 78.22%, Training AUROC: 0.8704
# Validation Loss: 0.6853, Validation Accuracy: 76.46%, Validation AUROC: 0.8616
# Epoch [43/100]
# Training Loss: 0.6469, Training Accuracy: 77.73%, Training AUROC: 0.8672
# Validation Loss: 0.6854, Validation Accuracy: 75.68%, Validation AUROC: 0.8576
# Epoch [44/100]
# Training Loss: 0.6454, Training Accuracy: 78.27%, Training AUROC: 0.8695
# Validation Loss: 0.6903, Validation Accuracy: 75.88%, Validation AUROC: 0.8602
# Epoch [45/100]
# Training Loss: 0.6556, Training Accuracy: 77.54%, Training AUROC: 0.8683
# Validation Loss: 0.6920, Validation Accuracy: 75.29%, Validation AUROC: 0.8645
# Epoch [46/100]
# Training Loss: 0.6607, Training Accuracy: 77.44%, Training AUROC: 0.8741
# Validation Loss: 0.7058, Validation Accuracy: 74.90%, Validation AUROC: 0.8611
# Epoch [47/100]
# Training Loss: 0.6510, Training Accuracy: 77.20%, Training AUROC: 0.8741
# Validation Loss: 0.7129, Validation Accuracy: 74.32%, Validation AUROC: 0.8570
# Epoch [48/100]
# Training Loss: 0.6432, Training Accuracy: 78.03%, Training AUROC: 0.8737
# Validation Loss: 0.6840, Validation Accuracy: 75.88%, Validation AUROC: 0.8674
# Epoch [49/100]
# Training Loss: 0.6662, Training Accuracy: 75.78%, Training AUROC: 0.8670
# Validation Loss: 0.6888, Validation Accuracy: 75.68%, Validation AUROC: 0.8661
# Epoch [50/100]
# Training Loss: 0.6350, Training Accuracy: 77.88%, Training AUROC: 0.8746
# Validation Loss: 0.6935, Validation Accuracy: 75.10%, Validation AUROC: 0.8675
# Epoch [51/100]
# Training Loss: 0.6325, Training Accuracy: 77.54%, Training AUROC: 0.8768
# Validation Loss: 0.6751, Validation Accuracy: 76.85%, Validation AUROC: 0.8691
# Epoch [52/100]
# Training Loss: 0.6257, Training Accuracy: 77.49%, Training AUROC: 0.8790
# Validation Loss: 0.6754, Validation Accuracy: 76.07%, Validation AUROC: 0.8681
# Epoch [53/100]
# Training Loss: 0.6254, Training Accuracy: 77.73%, Training AUROC: 0.8718
# Validation Loss: 0.6766, Validation Accuracy: 76.07%, Validation AUROC: 0.8667
# Epoch [54/100]
# Training Loss: 0.6265, Training Accuracy: 77.78%, Training AUROC: 0.8764
# Validation Loss: 0.6792, Validation Accuracy: 76.07%, Validation AUROC: 0.8681
# Epoch [55/100]
# Training Loss: 0.6175, Training Accuracy: 78.56%, Training AUROC: 0.8814
# Validation Loss: 0.6741, Validation Accuracy: 76.46%, Validation AUROC: 0.8711
# Epoch [56/100]
# Training Loss: 0.6336, Training Accuracy: 78.03%, Training AUROC: 0.8791
# Validation Loss: 0.6744, Validation Accuracy: 75.10%, Validation AUROC: 0.8677
# Epoch [57/100]
# Training Loss: 0.6253, Training Accuracy: 78.17%, Training AUROC: 0.8774
# Validation Loss: 0.6759, Validation Accuracy: 75.88%, Validation AUROC: 0.8710
# Epoch [58/100]
# Training Loss: 0.6385, Training Accuracy: 77.44%, Training AUROC: 0.8760
# Validation Loss: 0.6797, Validation Accuracy: 75.88%, Validation AUROC: 0.8659
# Epoch [59/100]
# Training Loss: 0.6230, Training Accuracy: 77.78%, Training AUROC: 0.8867
# Validation Loss: 0.6706, Validation Accuracy: 76.07%, Validation AUROC: 0.8703
# Epoch [60/100]
# Training Loss: 0.6174, Training Accuracy: 77.83%, Training AUROC: 0.8827
# Validation Loss: 0.6721, Validation Accuracy: 76.46%, Validation AUROC: 0.8696
# Epoch [61/100]
# Training Loss: 0.6098, Training Accuracy: 78.91%, Training AUROC: 0.8830
# Validation Loss: 0.6733, Validation Accuracy: 76.26%, Validation AUROC: 0.8668
# Epoch [62/100]
# Training Loss: 0.6163, Training Accuracy: 77.78%, Training AUROC: 0.8821
# Validation Loss: 0.6750, Validation Accuracy: 76.26%, Validation AUROC: 0.8671
# Epoch [63/100]
# Training Loss: 0.6084, Training Accuracy: 78.52%, Training AUROC: 0.8881
# Validation Loss: 0.6748, Validation Accuracy: 76.65%, Validation AUROC: 0.8696
# Epoch [64/100]
# Training Loss: 0.5959, Training Accuracy: 79.49%, Training AUROC: 0.8841
# Validation Loss: 0.6677, Validation Accuracy: 75.88%, Validation AUROC: 0.8723
# Epoch [65/100]
# Training Loss: 0.6140, Training Accuracy: 77.59%, Training AUROC: 0.8858
# Validation Loss: 0.6733, Validation Accuracy: 76.46%, Validation AUROC: 0.8734
# Epoch [66/100]
# Training Loss: 0.6171, Training Accuracy: 78.12%, Training AUROC: 0.8824
# Validation Loss: 0.6717, Validation Accuracy: 75.88%, Validation AUROC: 0.8670
# Epoch [67/100]
# Training Loss: 0.6149, Training Accuracy: 77.73%, Training AUROC: 0.8868
# Validation Loss: 0.6692, Validation Accuracy: 75.68%, Validation AUROC: 0.8727
# Epoch [68/100]
# Training Loss: 0.5967, Training Accuracy: 78.71%, Training AUROC: 0.8895
# Validation Loss: 0.6650, Validation Accuracy: 76.46%, Validation AUROC: 0.8765
# Epoch [69/100]
# Training Loss: 0.6164, Training Accuracy: 78.08%, Training AUROC: 0.8865
# Validation Loss: 0.6675, Validation Accuracy: 76.85%, Validation AUROC: 0.8786
# Epoch [70/100]
# Training Loss: 0.6155, Training Accuracy: 77.39%, Training AUROC: 0.8890
# Validation Loss: 0.6648, Validation Accuracy: 76.07%, Validation AUROC: 0.8781
# Epoch [71/100]
# Training Loss: 0.5885, Training Accuracy: 78.86%, Training AUROC: 0.8932
# Validation Loss: 0.6662, Validation Accuracy: 76.07%, Validation AUROC: 0.8756
# Epoch [72/100]
# Training Loss: 0.6117, Training Accuracy: 77.69%, Training AUROC: 0.8877
# Validation Loss: 0.7305, Validation Accuracy: 74.12%, Validation AUROC: 0.8650
# Epoch [73/100]
# Training Loss: 0.6385, Training Accuracy: 77.49%, Training AUROC: 0.8857
# Validation Loss: 0.6997, Validation Accuracy: 74.12%, Validation AUROC: 0.8808
# Epoch [74/100]
# Training Loss: 0.6188, Training Accuracy: 77.69%, Training AUROC: 0.8920
# Validation Loss: 0.6585, Validation Accuracy: 77.24%, Validation AUROC: 0.8813
# Epoch [75/100]
# Training Loss: 0.6151, Training Accuracy: 78.27%, Training AUROC: 0.8925
# Validation Loss: 0.6698, Validation Accuracy: 75.10%, Validation AUROC: 0.8862
# Epoch [76/100]
# Training Loss: 0.5982, Training Accuracy: 78.27%, Training AUROC: 0.8918
# Validation Loss: 0.6637, Validation Accuracy: 76.85%, Validation AUROC: 0.8819
# Epoch [77/100]
# Training Loss: 0.6005, Training Accuracy: 77.78%, Training AUROC: 0.8943
# Validation Loss: 0.6612, Validation Accuracy: 77.04%, Validation AUROC: 0.8834
# Epoch [78/100]
# Training Loss: 0.5946, Training Accuracy: 78.42%, Training AUROC: 0.8951
# Validation Loss: 0.6663, Validation Accuracy: 76.07%, Validation AUROC: 0.8853
# Epoch [79/100]
# Training Loss: 0.5941, Training Accuracy: 78.27%, Training AUROC: 0.8963
# Validation Loss: 0.6602, Validation Accuracy: 76.46%, Validation AUROC: 0.8849
# Epoch [80/100]
# Training Loss: 0.6089, Training Accuracy: 77.54%, Training AUROC: 0.8914
# Validation Loss: 0.6589, Validation Accuracy: 75.88%, Validation AUROC: 0.8865
# Epoch [81/100]
# Training Loss: 0.5918, Training Accuracy: 78.27%, Training AUROC: 0.8935
# Validation Loss: 0.6862, Validation Accuracy: 74.51%, Validation AUROC: 0.8742
# Epoch [82/100]
# Training Loss: 0.5953, Training Accuracy: 78.17%, Training AUROC: 0.8929
# Validation Loss: 0.6623, Validation Accuracy: 76.46%, Validation AUROC: 0.8822
# Epoch [83/100]
# Training Loss: 0.5801, Training Accuracy: 79.00%, Training AUROC: 0.8997
# Validation Loss: 0.6674, Validation Accuracy: 75.29%, Validation AUROC: 0.8830
# Epoch [84/100]
# Training Loss: 0.5842, Training Accuracy: 78.42%, Training AUROC: 0.8947
# Validation Loss: 0.6750, Validation Accuracy: 75.10%, Validation AUROC: 0.8811
# Early stopping triggered after 84 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.7673
# F1 Score: 0.7190
# Precision: 0.6883
# Recall: 0.7673
# AUROC: 0.8805
#
# Normal Model Metrics:
# Accuracy: 0.7900
# F1 Score: 0.7657
# Precision: 0.7753
# Recall: 0.7900
# AUROC: 0.9117

# %% [markdown]
# ## Seed Experiment 4

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 96:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.5157, Training Accuracy: 31.64%, Training AUROC: 0.5122
# Validation Loss: 1.3518, Validation Accuracy: 44.75%, Validation AUROC: 0.5406
# Epoch [2/100]
# Training Loss: 1.2418, Training Accuracy: 50.73%, Training AUROC: 0.6124
# Validation Loss: 1.1716, Validation Accuracy: 54.67%, Validation AUROC: 0.6712
# Epoch [3/100]
# Training Loss: 1.0906, Training Accuracy: 60.30%, Training AUROC: 0.7258
# Validation Loss: 1.0365, Validation Accuracy: 64.40%, Validation AUROC: 0.7562
# Epoch [4/100]
# Training Loss: 0.9816, Training Accuracy: 66.85%, Training AUROC: 0.7838
# Validation Loss: 0.9536, Validation Accuracy: 68.48%, Validation AUROC: 0.7875
# Epoch [5/100]
# Training Loss: 0.8971, Training Accuracy: 70.41%, Training AUROC: 0.8164
# Validation Loss: 0.8780, Validation Accuracy: 71.01%, Validation AUROC: 0.8201
# Epoch [6/100]
# Training Loss: 0.8463, Training Accuracy: 71.29%, Training AUROC: 0.8347
# Validation Loss: 0.8322, Validation Accuracy: 71.98%, Validation AUROC: 0.8383
# Epoch [7/100]
# Training Loss: 0.7840, Training Accuracy: 72.61%, Training AUROC: 0.8667
# Validation Loss: 0.8033, Validation Accuracy: 72.57%, Validation AUROC: 0.8526
# Epoch [8/100]
# Training Loss: 0.7508, Training Accuracy: 73.14%, Training AUROC: 0.8735
# Validation Loss: 0.7742, Validation Accuracy: 71.98%, Validation AUROC: 0.8651
# Epoch [9/100]
# Training Loss: 0.7235, Training Accuracy: 73.58%, Training AUROC: 0.8859
# Validation Loss: 0.7498, Validation Accuracy: 73.74%, Validation AUROC: 0.8711
# Epoch [10/100]
# Training Loss: 0.6924, Training Accuracy: 75.39%, Training AUROC: 0.8934
# Validation Loss: 0.7277, Validation Accuracy: 73.54%, Validation AUROC: 0.8793
# Epoch [11/100]
# Training Loss: 0.6851, Training Accuracy: 75.24%, Training AUROC: 0.8986
# Validation Loss: 0.7161, Validation Accuracy: 73.54%, Validation AUROC: 0.8855
# Epoch [12/100]
# Training Loss: 0.6658, Training Accuracy: 75.88%, Training AUROC: 0.9002
# Validation Loss: 0.7119, Validation Accuracy: 73.93%, Validation AUROC: 0.8887
# Epoch [13/100]
# Training Loss: 0.6472, Training Accuracy: 76.22%, Training AUROC: 0.9112
# Validation Loss: 0.6923, Validation Accuracy: 74.90%, Validation AUROC: 0.8914
# Epoch [14/100]
# Training Loss: 0.6351, Training Accuracy: 76.22%, Training AUROC: 0.9118
# Validation Loss: 0.6932, Validation Accuracy: 74.32%, Validation AUROC: 0.8946
# Epoch [15/100]
# Training Loss: 0.6148, Training Accuracy: 77.69%, Training AUROC: 0.9189
# Validation Loss: 0.6846, Validation Accuracy: 74.32%, Validation AUROC: 0.8972
# Epoch [16/100]
# Training Loss: 0.6029, Training Accuracy: 78.17%, Training AUROC: 0.9249
# Validation Loss: 0.6898, Validation Accuracy: 74.51%, Validation AUROC: 0.8985
# Epoch [17/100]
# Training Loss: 0.6087, Training Accuracy: 77.44%, Training AUROC: 0.9205
# Validation Loss: 0.6738, Validation Accuracy: 74.71%, Validation AUROC: 0.9012
# Epoch [18/100]
# Training Loss: 0.5895, Training Accuracy: 78.42%, Training AUROC: 0.9245
# Validation Loss: 0.6632, Validation Accuracy: 75.68%, Validation AUROC: 0.9015
# Epoch [19/100]
# Training Loss: 0.5839, Training Accuracy: 79.39%, Training AUROC: 0.9253
# Validation Loss: 0.6776, Validation Accuracy: 74.90%, Validation AUROC: 0.9028
# Epoch [20/100]
# Training Loss: 0.5894, Training Accuracy: 78.81%, Training AUROC: 0.9243
# Validation Loss: 0.6492, Validation Accuracy: 76.07%, Validation AUROC: 0.9054
# Epoch [21/100]
# Training Loss: 0.5686, Training Accuracy: 79.64%, Training AUROC: 0.9307
# Validation Loss: 0.6485, Validation Accuracy: 76.07%, Validation AUROC: 0.9045
# Epoch [22/100]
# Training Loss: 0.5699, Training Accuracy: 80.08%, Training AUROC: 0.9303
# Validation Loss: 0.6558, Validation Accuracy: 75.88%, Validation AUROC: 0.9058
# Epoch [23/100]
# Training Loss: 0.5647, Training Accuracy: 78.86%, Training AUROC: 0.9309
# Validation Loss: 0.6364, Validation Accuracy: 76.65%, Validation AUROC: 0.9075
# Epoch [24/100]
# Training Loss: 0.5477, Training Accuracy: 78.91%, Training AUROC: 0.9355
# Validation Loss: 0.6390, Validation Accuracy: 76.46%, Validation AUROC: 0.9076
# Epoch [25/100]
# Training Loss: 0.5524, Training Accuracy: 80.42%, Training AUROC: 0.9330
# Validation Loss: 0.6305, Validation Accuracy: 77.63%, Validation AUROC: 0.9085
# Epoch [26/100]
# Training Loss: 0.5552, Training Accuracy: 79.98%, Training AUROC: 0.9345
# Validation Loss: 0.6331, Validation Accuracy: 77.43%, Validation AUROC: 0.9086
# Epoch [27/100]
# Training Loss: 0.5531, Training Accuracy: 79.98%, Training AUROC: 0.9345
# Validation Loss: 0.6261, Validation Accuracy: 77.63%, Validation AUROC: 0.9091
# Epoch [28/100]
# Training Loss: 0.5636, Training Accuracy: 79.30%, Training AUROC: 0.9309
# Validation Loss: 0.6322, Validation Accuracy: 75.88%, Validation AUROC: 0.9097
# Epoch [29/100]
# Training Loss: 0.5328, Training Accuracy: 81.30%, Training AUROC: 0.9393
# Validation Loss: 0.6383, Validation Accuracy: 78.21%, Validation AUROC: 0.9088
# Epoch [30/100]
# Training Loss: 0.5424, Training Accuracy: 79.30%, Training AUROC: 0.9371
# Validation Loss: 0.6288, Validation Accuracy: 76.46%, Validation AUROC: 0.9096
# Epoch [31/100]
# Training Loss: 0.5450, Training Accuracy: 79.79%, Training AUROC: 0.9344
# Validation Loss: 0.6406, Validation Accuracy: 74.51%, Validation AUROC: 0.9088
# Epoch [32/100]
# Training Loss: 0.5356, Training Accuracy: 80.81%, Training AUROC: 0.9357
# Validation Loss: 0.6204, Validation Accuracy: 78.60%, Validation AUROC: 0.9110
# Epoch [33/100]
# Training Loss: 0.5225, Training Accuracy: 81.49%, Training AUROC: 0.9411
# Validation Loss: 0.6171, Validation Accuracy: 78.02%, Validation AUROC: 0.9108
# Epoch [34/100]
# Training Loss: 0.5218, Training Accuracy: 81.05%, Training AUROC: 0.9418
# Validation Loss: 0.6263, Validation Accuracy: 76.26%, Validation AUROC: 0.9109
# Epoch [35/100]
# Training Loss: 0.5274, Training Accuracy: 81.20%, Training AUROC: 0.9380
# Validation Loss: 0.6212, Validation Accuracy: 77.24%, Validation AUROC: 0.9103
# Epoch [36/100]
# Training Loss: 0.5177, Training Accuracy: 81.30%, Training AUROC: 0.9422
# Validation Loss: 0.6136, Validation Accuracy: 77.24%, Validation AUROC: 0.9119
# Epoch [37/100]
# Training Loss: 0.5245, Training Accuracy: 80.32%, Training AUROC: 0.9411
# Validation Loss: 0.6294, Validation Accuracy: 76.07%, Validation AUROC: 0.9113
# Epoch [38/100]
# Training Loss: 0.5231, Training Accuracy: 81.01%, Training AUROC: 0.9409
# Validation Loss: 0.6187, Validation Accuracy: 77.63%, Validation AUROC: 0.9120
# Epoch [39/100]
# Training Loss: 0.5202, Training Accuracy: 81.40%, Training AUROC: 0.9423
# Validation Loss: 0.6186, Validation Accuracy: 77.82%, Validation AUROC: 0.9115
# Epoch [40/100]
# Training Loss: 0.5019, Training Accuracy: 81.35%, Training AUROC: 0.9449
# Validation Loss: 0.6321, Validation Accuracy: 77.43%, Validation AUROC: 0.9114
# Epoch [41/100]
# Training Loss: 0.5127, Training Accuracy: 81.30%, Training AUROC: 0.9448
# Validation Loss: 0.6138, Validation Accuracy: 76.26%, Validation AUROC: 0.9130
# Epoch [42/100]
# Training Loss: 0.5035, Training Accuracy: 81.59%, Training AUROC: 0.9444
# Validation Loss: 0.6127, Validation Accuracy: 76.85%, Validation AUROC: 0.9119
# Epoch [43/100]
# Training Loss: 0.5165, Training Accuracy: 81.05%, Training AUROC: 0.9419
# Validation Loss: 0.6119, Validation Accuracy: 78.02%, Validation AUROC: 0.9131
# Epoch [44/100]
# Training Loss: 0.5102, Training Accuracy: 81.40%, Training AUROC: 0.9436
# Validation Loss: 0.6200, Validation Accuracy: 77.63%, Validation AUROC: 0.9136
# Epoch [45/100]
# Training Loss: 0.5101, Training Accuracy: 80.76%, Training AUROC: 0.9437
# Validation Loss: 0.6168, Validation Accuracy: 78.60%, Validation AUROC: 0.9135
# Epoch [46/100]
# Training Loss: 0.5106, Training Accuracy: 82.81%, Training AUROC: 0.9432
# Validation Loss: 0.6332, Validation Accuracy: 77.24%, Validation AUROC: 0.9142
# Epoch [47/100]
# Training Loss: 0.5056, Training Accuracy: 81.64%, Training AUROC: 0.9462
# Validation Loss: 0.6078, Validation Accuracy: 77.82%, Validation AUROC: 0.9133
# Epoch [48/100]
# Training Loss: 0.4999, Training Accuracy: 82.23%, Training AUROC: 0.9461
# Validation Loss: 0.6125, Validation Accuracy: 76.26%, Validation AUROC: 0.9134
# Epoch [49/100]
# Training Loss: 0.4826, Training Accuracy: 82.37%, Training AUROC: 0.9511
# Validation Loss: 0.6226, Validation Accuracy: 77.82%, Validation AUROC: 0.9131
# Epoch [50/100]
# Training Loss: 0.4874, Training Accuracy: 81.93%, Training AUROC: 0.9496
# Validation Loss: 0.6078, Validation Accuracy: 78.21%, Validation AUROC: 0.9137
# Epoch [51/100]
# Training Loss: 0.4933, Training Accuracy: 81.84%, Training AUROC: 0.9463
# Validation Loss: 0.6053, Validation Accuracy: 77.82%, Validation AUROC: 0.9135
# Epoch [52/100]
# Training Loss: 0.4869, Training Accuracy: 82.42%, Training AUROC: 0.9501
# Validation Loss: 0.6098, Validation Accuracy: 76.65%, Validation AUROC: 0.9130
# Epoch [53/100]
# Training Loss: 0.4894, Training Accuracy: 81.84%, Training AUROC: 0.9476
# Validation Loss: 0.6080, Validation Accuracy: 78.02%, Validation AUROC: 0.9137
# Epoch [54/100]
# Training Loss: 0.4719, Training Accuracy: 83.01%, Training AUROC: 0.9532
# Validation Loss: 0.6065, Validation Accuracy: 76.65%, Validation AUROC: 0.9131
# Epoch [55/100]
# Training Loss: 0.4754, Training Accuracy: 82.96%, Training AUROC: 0.9517
# Validation Loss: 0.6103, Validation Accuracy: 78.79%, Validation AUROC: 0.9131
# Epoch [56/100]
# Training Loss: 0.4856, Training Accuracy: 82.32%, Training AUROC: 0.9484
# Validation Loss: 0.6076, Validation Accuracy: 77.82%, Validation AUROC: 0.9133
# Epoch [57/100]
# Training Loss: 0.4817, Training Accuracy: 82.91%, Training AUROC: 0.9499
# Validation Loss: 0.6093, Validation Accuracy: 78.21%, Validation AUROC: 0.9133
# Epoch [58/100]
# Training Loss: 0.4685, Training Accuracy: 82.96%, Training AUROC: 0.9520
# Validation Loss: 0.6122, Validation Accuracy: 78.40%, Validation AUROC: 0.9128
# Epoch [59/100]
# Training Loss: 0.4667, Training Accuracy: 82.67%, Training AUROC: 0.9527
# Validation Loss: 0.6181, Validation Accuracy: 76.26%, Validation AUROC: 0.9106
# Epoch [60/100]
# Training Loss: 0.4657, Training Accuracy: 83.79%, Training AUROC: 0.9527
# Validation Loss: 0.6092, Validation Accuracy: 77.82%, Validation AUROC: 0.9130
# Epoch [61/100]
# Training Loss: 0.4810, Training Accuracy: 82.67%, Training AUROC: 0.9491
# Validation Loss: 0.6220, Validation Accuracy: 76.46%, Validation AUROC: 0.9126
# Early stopping triggered after 61 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.5343, Training Accuracy: 25.73%, Training AUROC: 0.4765
# Validation Loss: 1.4889, Validation Accuracy: 27.24%, Validation AUROC: 0.4644
# Epoch [2/100]
# Training Loss: 1.4715, Training Accuracy: 27.98%, Training AUROC: 0.5022
# Validation Loss: 1.4566, Validation Accuracy: 30.93%, Validation AUROC: 0.5686
# Epoch [3/100]
# Training Loss: 1.4428, Training Accuracy: 31.59%, Training AUROC: 0.5578
# Validation Loss: 1.4323, Validation Accuracy: 33.46%, Validation AUROC: 0.5944
# Epoch [4/100]
# Training Loss: 1.4187, Training Accuracy: 39.99%, Training AUROC: 0.5749
# Validation Loss: 1.4073, Validation Accuracy: 48.44%, Validation AUROC: 0.6074
# Epoch [5/100]
# Training Loss: 1.3932, Training Accuracy: 52.59%, Training AUROC: 0.5881
# Validation Loss: 1.3826, Validation Accuracy: 57.78%, Validation AUROC: 0.6166
# Epoch [6/100]
# Training Loss: 1.3665, Training Accuracy: 57.86%, Training AUROC: 0.6113
# Validation Loss: 1.3544, Validation Accuracy: 61.48%, Validation AUROC: 0.6363
# Epoch [7/100]
# Training Loss: 1.3301, Training Accuracy: 61.38%, Training AUROC: 0.6651
# Validation Loss: 1.3145, Validation Accuracy: 63.42%, Validation AUROC: 0.6793
# Epoch [8/100]
# Training Loss: 1.2802, Training Accuracy: 63.23%, Training AUROC: 0.6932
# Validation Loss: 1.2660, Validation Accuracy: 64.59%, Validation AUROC: 0.6846
# Epoch [9/100]
# Training Loss: 1.2266, Training Accuracy: 65.62%, Training AUROC: 0.7147
# Validation Loss: 1.2080, Validation Accuracy: 67.90%, Validation AUROC: 0.7029
# Epoch [10/100]
# Training Loss: 1.1675, Training Accuracy: 67.63%, Training AUROC: 0.7265
# Validation Loss: 1.1514, Validation Accuracy: 70.62%, Validation AUROC: 0.7057
# Epoch [11/100]
# Training Loss: 1.1094, Training Accuracy: 70.02%, Training AUROC: 0.7313
# Validation Loss: 1.0918, Validation Accuracy: 71.40%, Validation AUROC: 0.7119
# Epoch [12/100]
# Training Loss: 1.0565, Training Accuracy: 70.07%, Training AUROC: 0.7452
# Validation Loss: 1.0449, Validation Accuracy: 71.98%, Validation AUROC: 0.7231
# Epoch [13/100]
# Training Loss: 1.0056, Training Accuracy: 71.68%, Training AUROC: 0.7508
# Validation Loss: 1.0036, Validation Accuracy: 72.18%, Validation AUROC: 0.7226
# Epoch [14/100]
# Training Loss: 0.9734, Training Accuracy: 72.31%, Training AUROC: 0.7490
# Validation Loss: 0.9721, Validation Accuracy: 72.37%, Validation AUROC: 0.7309
# Epoch [15/100]
# Training Loss: 0.9526, Training Accuracy: 71.53%, Training AUROC: 0.7565
# Validation Loss: 0.9446, Validation Accuracy: 72.37%, Validation AUROC: 0.7949
# Epoch [16/100]
# Training Loss: 0.9151, Training Accuracy: 72.61%, Training AUROC: 0.8257
# Validation Loss: 0.9160, Validation Accuracy: 72.76%, Validation AUROC: 0.8385
# Epoch [17/100]
# Training Loss: 0.8738, Training Accuracy: 73.24%, Training AUROC: 0.8577
# Validation Loss: 0.8820, Validation Accuracy: 72.57%, Validation AUROC: 0.8511
# Epoch [18/100]
# Training Loss: 0.8602, Training Accuracy: 72.56%, Training AUROC: 0.8614
# Validation Loss: 0.8709, Validation Accuracy: 72.96%, Validation AUROC: 0.8601
# Epoch [19/100]
# Training Loss: 0.8383, Training Accuracy: 73.14%, Training AUROC: 0.8741
# Validation Loss: 0.8427, Validation Accuracy: 72.96%, Validation AUROC: 0.8691
# Epoch [20/100]
# Training Loss: 0.8163, Training Accuracy: 73.54%, Training AUROC: 0.8811
# Validation Loss: 0.8230, Validation Accuracy: 73.15%, Validation AUROC: 0.8725
# Epoch [21/100]
# Training Loss: 0.8016, Training Accuracy: 73.00%, Training AUROC: 0.8898
# Validation Loss: 0.8095, Validation Accuracy: 73.74%, Validation AUROC: 0.8790
# Epoch [22/100]
# Training Loss: 0.7904, Training Accuracy: 73.05%, Training AUROC: 0.8909
# Validation Loss: 0.8129, Validation Accuracy: 73.15%, Validation AUROC: 0.8692
# Epoch [23/100]
# Training Loss: 0.7759, Training Accuracy: 73.83%, Training AUROC: 0.8891
# Validation Loss: 0.7855, Validation Accuracy: 73.35%, Validation AUROC: 0.8778
# Epoch [24/100]
# Training Loss: 0.7582, Training Accuracy: 73.63%, Training AUROC: 0.8949
# Validation Loss: 0.7817, Validation Accuracy: 73.35%, Validation AUROC: 0.8825
# Epoch [25/100]
# Training Loss: 0.7543, Training Accuracy: 73.44%, Training AUROC: 0.8972
# Validation Loss: 0.7726, Validation Accuracy: 73.54%, Validation AUROC: 0.8827
# Epoch [26/100]
# Training Loss: 0.7395, Training Accuracy: 73.68%, Training AUROC: 0.9016
# Validation Loss: 0.7541, Validation Accuracy: 74.32%, Validation AUROC: 0.8872
# Epoch [27/100]
# Training Loss: 0.7339, Training Accuracy: 73.68%, Training AUROC: 0.8973
# Validation Loss: 0.7490, Validation Accuracy: 73.93%, Validation AUROC: 0.8854
# Epoch [28/100]
# Training Loss: 0.7241, Training Accuracy: 73.93%, Training AUROC: 0.8984
# Validation Loss: 0.7445, Validation Accuracy: 73.54%, Validation AUROC: 0.8863
# Epoch [29/100]
# Training Loss: 0.7248, Training Accuracy: 74.07%, Training AUROC: 0.8973
# Validation Loss: 0.7336, Validation Accuracy: 74.32%, Validation AUROC: 0.8885
# Epoch [30/100]
# Training Loss: 0.7138, Training Accuracy: 73.58%, Training AUROC: 0.9017
# Validation Loss: 0.7273, Validation Accuracy: 74.12%, Validation AUROC: 0.8887
# Epoch [31/100]
# Training Loss: 0.7197, Training Accuracy: 73.73%, Training AUROC: 0.8969
# Validation Loss: 0.7260, Validation Accuracy: 73.74%, Validation AUROC: 0.8918
# Epoch [32/100]
# Training Loss: 0.7050, Training Accuracy: 73.83%, Training AUROC: 0.8990
# Validation Loss: 0.7304, Validation Accuracy: 74.12%, Validation AUROC: 0.8952
# Epoch [33/100]
# Training Loss: 0.6974, Training Accuracy: 74.27%, Training AUROC: 0.9018
# Validation Loss: 0.7147, Validation Accuracy: 74.12%, Validation AUROC: 0.8892
# Epoch [34/100]
# Training Loss: 0.6983, Training Accuracy: 73.97%, Training AUROC: 0.9025
# Validation Loss: 0.7069, Validation Accuracy: 74.32%, Validation AUROC: 0.8938
# Epoch [35/100]
# Training Loss: 0.6810, Training Accuracy: 74.80%, Training AUROC: 0.9076
# Validation Loss: 0.7079, Validation Accuracy: 74.32%, Validation AUROC: 0.8940
# Epoch [36/100]
# Training Loss: 0.6707, Training Accuracy: 74.32%, Training AUROC: 0.9128
# Validation Loss: 0.6993, Validation Accuracy: 74.32%, Validation AUROC: 0.8938
# Epoch [37/100]
# Training Loss: 0.6682, Training Accuracy: 74.56%, Training AUROC: 0.9133
# Validation Loss: 0.6977, Validation Accuracy: 74.51%, Validation AUROC: 0.8945
# Epoch [38/100]
# Training Loss: 0.6644, Training Accuracy: 74.22%, Training AUROC: 0.9110
# Validation Loss: 0.7006, Validation Accuracy: 74.51%, Validation AUROC: 0.8928
# Epoch [39/100]
# Training Loss: 0.6651, Training Accuracy: 74.56%, Training AUROC: 0.9103
# Validation Loss: 0.6933, Validation Accuracy: 74.51%, Validation AUROC: 0.8934
# Epoch [40/100]
# Training Loss: 0.6565, Training Accuracy: 74.61%, Training AUROC: 0.9129
# Validation Loss: 0.6853, Validation Accuracy: 74.51%, Validation AUROC: 0.8974
# Epoch [41/100]
# Training Loss: 0.6560, Training Accuracy: 74.46%, Training AUROC: 0.9108
# Validation Loss: 0.6824, Validation Accuracy: 74.51%, Validation AUROC: 0.8963
# Epoch [42/100]
# Training Loss: 0.6601, Training Accuracy: 74.41%, Training AUROC: 0.9112
# Validation Loss: 0.6958, Validation Accuracy: 74.71%, Validation AUROC: 0.8937
# Epoch [43/100]
# Training Loss: 0.6391, Training Accuracy: 75.34%, Training AUROC: 0.9166
# Validation Loss: 0.6761, Validation Accuracy: 74.51%, Validation AUROC: 0.9008
# Epoch [44/100]
# Training Loss: 0.6437, Training Accuracy: 74.80%, Training AUROC: 0.9130
# Validation Loss: 0.6779, Validation Accuracy: 73.93%, Validation AUROC: 0.9046
# Epoch [45/100]
# Training Loss: 0.6380, Training Accuracy: 75.73%, Training AUROC: 0.9100
# Validation Loss: 0.6783, Validation Accuracy: 73.93%, Validation AUROC: 0.9009
# Epoch [46/100]
# Training Loss: 0.6317, Training Accuracy: 75.20%, Training AUROC: 0.9158
# Validation Loss: 0.6661, Validation Accuracy: 74.71%, Validation AUROC: 0.9035
# Epoch [47/100]
# Training Loss: 0.6296, Training Accuracy: 75.78%, Training AUROC: 0.9169
# Validation Loss: 0.6662, Validation Accuracy: 74.32%, Validation AUROC: 0.9047
# Epoch [48/100]
# Training Loss: 0.6169, Training Accuracy: 76.03%, Training AUROC: 0.9210
# Validation Loss: 0.6660, Validation Accuracy: 74.51%, Validation AUROC: 0.9073
# Epoch [49/100]
# Training Loss: 0.6151, Training Accuracy: 75.63%, Training AUROC: 0.9216
# Validation Loss: 0.6617, Validation Accuracy: 74.90%, Validation AUROC: 0.9036
# Epoch [50/100]
# Training Loss: 0.6146, Training Accuracy: 75.63%, Training AUROC: 0.9181
# Validation Loss: 0.6587, Validation Accuracy: 74.90%, Validation AUROC: 0.9044
# Epoch [51/100]
# Training Loss: 0.6146, Training Accuracy: 76.22%, Training AUROC: 0.9183
# Validation Loss: 0.6770, Validation Accuracy: 73.15%, Validation AUROC: 0.9055
# Epoch [52/100]
# Training Loss: 0.6030, Training Accuracy: 76.22%, Training AUROC: 0.9211
# Validation Loss: 0.6561, Validation Accuracy: 74.32%, Validation AUROC: 0.9063
# Epoch [53/100]
# Training Loss: 0.6036, Training Accuracy: 76.17%, Training AUROC: 0.9230
# Validation Loss: 0.6502, Validation Accuracy: 76.26%, Validation AUROC: 0.9033
# Epoch [54/100]
# Training Loss: 0.5976, Training Accuracy: 76.95%, Training AUROC: 0.9198
# Validation Loss: 0.6476, Validation Accuracy: 75.88%, Validation AUROC: 0.9059
# Epoch [55/100]
# Training Loss: 0.6119, Training Accuracy: 75.83%, Training AUROC: 0.9184
# Validation Loss: 0.6474, Validation Accuracy: 75.49%, Validation AUROC: 0.9052
# Epoch [56/100]
# Training Loss: 0.6063, Training Accuracy: 76.22%, Training AUROC: 0.9176
# Validation Loss: 0.6470, Validation Accuracy: 75.49%, Validation AUROC: 0.8998
# Epoch [57/100]
# Training Loss: 0.5913, Training Accuracy: 76.90%, Training AUROC: 0.9202
# Validation Loss: 0.6449, Validation Accuracy: 75.49%, Validation AUROC: 0.9027
# Epoch [58/100]
# Training Loss: 0.6040, Training Accuracy: 77.00%, Training AUROC: 0.9185
# Validation Loss: 0.6416, Validation Accuracy: 74.90%, Validation AUROC: 0.9082
# Epoch [59/100]
# Training Loss: 0.5977, Training Accuracy: 76.42%, Training AUROC: 0.9195
# Validation Loss: 0.6402, Validation Accuracy: 75.10%, Validation AUROC: 0.9064
# Epoch [60/100]
# Training Loss: 0.5838, Training Accuracy: 77.05%, Training AUROC: 0.9243
# Validation Loss: 0.6389, Validation Accuracy: 75.68%, Validation AUROC: 0.9062
# Epoch [61/100]
# Training Loss: 0.5800, Training Accuracy: 77.25%, Training AUROC: 0.9241
# Validation Loss: 0.6468, Validation Accuracy: 74.51%, Validation AUROC: 0.9062
# Epoch [62/100]
# Training Loss: 0.5882, Training Accuracy: 77.05%, Training AUROC: 0.9213
# Validation Loss: 0.6390, Validation Accuracy: 75.68%, Validation AUROC: 0.9058
# Epoch [63/100]
# Training Loss: 0.5730, Training Accuracy: 77.05%, Training AUROC: 0.9239
# Validation Loss: 0.6439, Validation Accuracy: 76.07%, Validation AUROC: 0.8981
# Epoch [64/100]
# Training Loss: 0.5849, Training Accuracy: 76.42%, Training AUROC: 0.9238
# Validation Loss: 0.6366, Validation Accuracy: 76.26%, Validation AUROC: 0.8984
# Epoch [65/100]
# Training Loss: 0.5703, Training Accuracy: 77.44%, Training AUROC: 0.9259
# Validation Loss: 0.6320, Validation Accuracy: 76.26%, Validation AUROC: 0.9046
# Epoch [66/100]
# Training Loss: 0.5753, Training Accuracy: 77.69%, Training AUROC: 0.9227
# Validation Loss: 0.6326, Validation Accuracy: 76.07%, Validation AUROC: 0.9045
# Epoch [67/100]
# Training Loss: 0.5808, Training Accuracy: 77.73%, Training AUROC: 0.9210
# Validation Loss: 0.6278, Validation Accuracy: 76.07%, Validation AUROC: 0.9068
# Epoch [68/100]
# Training Loss: 0.5611, Training Accuracy: 78.61%, Training AUROC: 0.9263
# Validation Loss: 0.6288, Validation Accuracy: 76.65%, Validation AUROC: 0.9056
# Epoch [69/100]
# Training Loss: 0.5726, Training Accuracy: 78.08%, Training AUROC: 0.9252
# Validation Loss: 0.6268, Validation Accuracy: 76.65%, Validation AUROC: 0.9017
# Epoch [70/100]
# Training Loss: 0.5662, Training Accuracy: 77.34%, Training AUROC: 0.9270
# Validation Loss: 0.6280, Validation Accuracy: 76.26%, Validation AUROC: 0.9062
# Epoch [71/100]
# Training Loss: 0.5670, Training Accuracy: 77.83%, Training AUROC: 0.9228
# Validation Loss: 0.6268, Validation Accuracy: 76.65%, Validation AUROC: 0.9053
# Epoch [72/100]
# Training Loss: 0.5577, Training Accuracy: 77.69%, Training AUROC: 0.9284
# Validation Loss: 0.6265, Validation Accuracy: 76.65%, Validation AUROC: 0.9033
# Epoch [73/100]
# Training Loss: 0.5512, Training Accuracy: 78.37%, Training AUROC: 0.9273
# Validation Loss: 0.6268, Validation Accuracy: 77.24%, Validation AUROC: 0.9006
# Epoch [74/100]
# Training Loss: 0.5673, Training Accuracy: 77.78%, Training AUROC: 0.9238
# Validation Loss: 0.6239, Validation Accuracy: 76.65%, Validation AUROC: 0.9051
# Epoch [75/100]
# Training Loss: 0.5721, Training Accuracy: 77.88%, Training AUROC: 0.9240
# Validation Loss: 0.6364, Validation Accuracy: 75.88%, Validation AUROC: 0.9054
# Epoch [76/100]
# Training Loss: 0.5608, Training Accuracy: 77.20%, Training AUROC: 0.9283
# Validation Loss: 0.6222, Validation Accuracy: 77.24%, Validation AUROC: 0.9031
# Epoch [77/100]
# Training Loss: 0.5563, Training Accuracy: 78.81%, Training AUROC: 0.9304
# Validation Loss: 0.6291, Validation Accuracy: 75.29%, Validation AUROC: 0.9069
# Epoch [78/100]
# Training Loss: 0.5449, Training Accuracy: 78.81%, Training AUROC: 0.9281
# Validation Loss: 0.6228, Validation Accuracy: 75.88%, Validation AUROC: 0.9070
# Epoch [79/100]
# Training Loss: 0.5505, Training Accuracy: 77.69%, Training AUROC: 0.9273
# Validation Loss: 0.6346, Validation Accuracy: 76.46%, Validation AUROC: 0.8991
# Epoch [80/100]
# Training Loss: 0.5522, Training Accuracy: 78.22%, Training AUROC: 0.9265
# Validation Loss: 0.6312, Validation Accuracy: 76.26%, Validation AUROC: 0.9012
# Epoch [81/100]
# Training Loss: 0.5551, Training Accuracy: 78.81%, Training AUROC: 0.9235
# Validation Loss: 0.6175, Validation Accuracy: 77.04%, Validation AUROC: 0.9039
# Epoch [82/100]
# Training Loss: 0.5336, Training Accuracy: 78.96%, Training AUROC: 0.9321
# Validation Loss: 0.6295, Validation Accuracy: 76.07%, Validation AUROC: 0.9060
# Epoch [83/100]
# Training Loss: 0.5275, Training Accuracy: 79.20%, Training AUROC: 0.9313
# Validation Loss: 0.6164, Validation Accuracy: 76.65%, Validation AUROC: 0.9059
# Epoch [84/100]
# Training Loss: 0.5458, Training Accuracy: 78.12%, Training AUROC: 0.9297
# Validation Loss: 0.6204, Validation Accuracy: 76.26%, Validation AUROC: 0.9030
# Epoch [85/100]
# Training Loss: 0.5488, Training Accuracy: 78.52%, Training AUROC: 0.9276
# Validation Loss: 0.6202, Validation Accuracy: 77.43%, Validation AUROC: 0.9031
# Epoch [86/100]
# Training Loss: 0.5449, Training Accuracy: 79.15%, Training AUROC: 0.9318
# Validation Loss: 0.6216, Validation Accuracy: 76.07%, Validation AUROC: 0.9022
# Epoch [87/100]
# Training Loss: 0.5359, Training Accuracy: 78.61%, Training AUROC: 0.9299
# Validation Loss: 0.6163, Validation Accuracy: 77.24%, Validation AUROC: 0.9059
# Epoch [88/100]
# Training Loss: 0.5322, Training Accuracy: 80.08%, Training AUROC: 0.9299
# Validation Loss: 0.6336, Validation Accuracy: 76.46%, Validation AUROC: 0.8983
# Epoch [89/100]
# Training Loss: 0.5304, Training Accuracy: 78.86%, Training AUROC: 0.9318
# Validation Loss: 0.6263, Validation Accuracy: 76.07%, Validation AUROC: 0.9064
# Epoch [90/100]
# Training Loss: 0.5324, Training Accuracy: 78.91%, Training AUROC: 0.9314
# Validation Loss: 0.6217, Validation Accuracy: 76.26%, Validation AUROC: 0.9063
# Epoch [91/100]
# Training Loss: 0.5470, Training Accuracy: 79.05%, Training AUROC: 0.9303
# Validation Loss: 0.6214, Validation Accuracy: 77.04%, Validation AUROC: 0.9037
# Epoch [92/100]
# Training Loss: 0.5288, Training Accuracy: 78.76%, Training AUROC: 0.9331
# Validation Loss: 0.6230, Validation Accuracy: 77.24%, Validation AUROC: 0.9054
# Epoch [93/100]
# Training Loss: 0.5409, Training Accuracy: 78.86%, Training AUROC: 0.9292
# Validation Loss: 0.6536, Validation Accuracy: 73.15%, Validation AUROC: 0.9077
# Epoch [94/100]
# Training Loss: 0.5385, Training Accuracy: 79.49%, Training AUROC: 0.9318
# Validation Loss: 0.6240, Validation Accuracy: 77.04%, Validation AUROC: 0.9044
# Epoch [95/100]
# Training Loss: 0.5370, Training Accuracy: 79.15%, Training AUROC: 0.9289
# Validation Loss: 0.6289, Validation Accuracy: 76.46%, Validation AUROC: 0.8994
# Epoch [96/100]
# Training Loss: 0.5272, Training Accuracy: 80.42%, Training AUROC: 0.9310
# Validation Loss: 0.6257, Validation Accuracy: 76.26%, Validation AUROC: 0.9079
# Epoch [97/100]
# Training Loss: 0.5172, Training Accuracy: 80.13%, Training AUROC: 0.9334
# Validation Loss: 0.6139, Validation Accuracy: 77.43%, Validation AUROC: 0.9019
# Epoch [98/100]
# Training Loss: 0.5393, Training Accuracy: 78.96%, Training AUROC: 0.9290
# Validation Loss: 0.6166, Validation Accuracy: 76.65%, Validation AUROC: 0.9035
# Epoch [99/100]
# Training Loss: 0.5239, Training Accuracy: 79.39%, Training AUROC: 0.9330
# Validation Loss: 0.6189, Validation Accuracy: 77.04%, Validation AUROC: 0.9008
# Epoch [100/100]
# Training Loss: 0.5285, Training Accuracy: 80.13%, Training AUROC: 0.9303
# Validation Loss: 0.6202, Validation Accuracy: 76.85%, Validation AUROC: 0.9041

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.7682
# F1 Score: 0.7278
# Precision: 0.7358
# Recall: 0.7682
# AUROC: 0.9041
#
# Normal Model Metrics:
# Accuracy: 0.7764
# F1 Score: 0.7594
# Precision: 0.7620
# Recall: 0.7764
# AUROC: 0.9104

# %% [markdown]
# ## Seed Experiment 5

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 31:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.4598, Training Accuracy: 35.55%, Training AUROC: 0.5090
# Validation Loss: 1.3023, Validation Accuracy: 48.83%, Validation AUROC: 0.5762
# Epoch [2/100]
# Training Loss: 1.2307, Training Accuracy: 54.15%, Training AUROC: 0.6292
# Validation Loss: 1.1489, Validation Accuracy: 57.98%, Validation AUROC: 0.7169
# Epoch [3/100]
# Training Loss: 1.0860, Training Accuracy: 62.74%, Training AUROC: 0.7475
# Validation Loss: 1.0199, Validation Accuracy: 66.34%, Validation AUROC: 0.7892
# Epoch [4/100]
# Training Loss: 0.9821, Training Accuracy: 67.09%, Training AUROC: 0.8022
# Validation Loss: 0.9235, Validation Accuracy: 69.46%, Validation AUROC: 0.8308
# Epoch [5/100]
# Training Loss: 0.8883, Training Accuracy: 69.53%, Training AUROC: 0.8431
# Validation Loss: 0.8578, Validation Accuracy: 70.23%, Validation AUROC: 0.8542
# Epoch [6/100]
# Training Loss: 0.8177, Training Accuracy: 70.95%, Training AUROC: 0.8662
# Validation Loss: 0.8373, Validation Accuracy: 70.82%, Validation AUROC: 0.8594
# Epoch [7/100]
# Training Loss: 0.7868, Training Accuracy: 71.92%, Training AUROC: 0.8706
# Validation Loss: 0.7787, Validation Accuracy: 71.98%, Validation AUROC: 0.8735
# Epoch [8/100]
# Training Loss: 0.7404, Training Accuracy: 73.97%, Training AUROC: 0.8826
# Validation Loss: 0.7479, Validation Accuracy: 71.98%, Validation AUROC: 0.8813
# Epoch [9/100]
# Training Loss: 0.7196, Training Accuracy: 73.19%, Training AUROC: 0.8906
# Validation Loss: 0.7282, Validation Accuracy: 72.76%, Validation AUROC: 0.8856
# Epoch [10/100]
# Training Loss: 0.6922, Training Accuracy: 74.80%, Training AUROC: 0.8979
# Validation Loss: 0.7209, Validation Accuracy: 72.37%, Validation AUROC: 0.8883
# Epoch [11/100]
# Training Loss: 0.6791, Training Accuracy: 74.71%, Training AUROC: 0.9039
# Validation Loss: 0.6979, Validation Accuracy: 73.74%, Validation AUROC: 0.8926
# Epoch [12/100]
# Training Loss: 0.6526, Training Accuracy: 76.90%, Training AUROC: 0.9092
# Validation Loss: 0.6964, Validation Accuracy: 74.12%, Validation AUROC: 0.8954
# Epoch [13/100]
# Training Loss: 0.6472, Training Accuracy: 75.78%, Training AUROC: 0.9111
# Validation Loss: 0.6898, Validation Accuracy: 73.93%, Validation AUROC: 0.8953
# Epoch [14/100]
# Training Loss: 0.6254, Training Accuracy: 77.15%, Training AUROC: 0.9158
# Validation Loss: 0.6957, Validation Accuracy: 73.74%, Validation AUROC: 0.8974
# Epoch [15/100]
# Training Loss: 0.6133, Training Accuracy: 78.03%, Training AUROC: 0.9194
# Validation Loss: 0.6692, Validation Accuracy: 74.32%, Validation AUROC: 0.8999
# Epoch [16/100]
# Training Loss: 0.6054, Training Accuracy: 78.47%, Training AUROC: 0.9214
# Validation Loss: 0.6906, Validation Accuracy: 74.12%, Validation AUROC: 0.8996
# Epoch [17/100]
# Training Loss: 0.6063, Training Accuracy: 77.29%, Training AUROC: 0.9217
# Validation Loss: 0.6634, Validation Accuracy: 74.12%, Validation AUROC: 0.9014
# Epoch [18/100]
# Training Loss: 0.5885, Training Accuracy: 78.86%, Training AUROC: 0.9274
# Validation Loss: 0.6610, Validation Accuracy: 75.88%, Validation AUROC: 0.9026
# Epoch [19/100]
# Training Loss: 0.5911, Training Accuracy: 77.88%, Training AUROC: 0.9243
# Validation Loss: 0.6766, Validation Accuracy: 74.51%, Validation AUROC: 0.9009
# Epoch [20/100]
# Training Loss: 0.5797, Training Accuracy: 79.39%, Training AUROC: 0.9278
# Validation Loss: 0.6637, Validation Accuracy: 74.51%, Validation AUROC: 0.9026
# Epoch [21/100]
# Training Loss: 0.5761, Training Accuracy: 79.15%, Training AUROC: 0.9266
# Validation Loss: 0.6440, Validation Accuracy: 74.71%, Validation AUROC: 0.9043
# Epoch [22/100]
# Training Loss: 0.5707, Training Accuracy: 79.69%, Training AUROC: 0.9301
# Validation Loss: 0.6380, Validation Accuracy: 75.10%, Validation AUROC: 0.9055
# Epoch [23/100]
# Training Loss: 0.5559, Training Accuracy: 79.49%, Training AUROC: 0.9325
# Validation Loss: 0.6481, Validation Accuracy: 74.90%, Validation AUROC: 0.9062
# Epoch [24/100]
# Training Loss: 0.5559, Training Accuracy: 79.39%, Training AUROC: 0.9345
# Validation Loss: 0.6395, Validation Accuracy: 75.49%, Validation AUROC: 0.9066
# Epoch [25/100]
# Training Loss: 0.5597, Training Accuracy: 79.93%, Training AUROC: 0.9300
# Validation Loss: 0.6434, Validation Accuracy: 75.10%, Validation AUROC: 0.9078
# Epoch [26/100]
# Training Loss: 0.5480, Training Accuracy: 80.42%, Training AUROC: 0.9339
# Validation Loss: 0.6397, Validation Accuracy: 75.29%, Validation AUROC: 0.9062
# Epoch [27/100]
# Training Loss: 0.5614, Training Accuracy: 79.79%, Training AUROC: 0.9309
# Validation Loss: 0.6321, Validation Accuracy: 76.85%, Validation AUROC: 0.9081
# Epoch [28/100]
# Training Loss: 0.5366, Training Accuracy: 80.03%, Training AUROC: 0.9372
# Validation Loss: 0.6224, Validation Accuracy: 76.85%, Validation AUROC: 0.9086
# Epoch [29/100]
# Training Loss: 0.5360, Training Accuracy: 80.57%, Training AUROC: 0.9371
# Validation Loss: 0.6349, Validation Accuracy: 76.46%, Validation AUROC: 0.9079
# Epoch [30/100]
# Training Loss: 0.5422, Training Accuracy: 81.01%, Training AUROC: 0.9378
# Validation Loss: 0.6276, Validation Accuracy: 77.04%, Validation AUROC: 0.9087
# Epoch [31/100]
# Training Loss: 0.5295, Training Accuracy: 81.49%, Training AUROC: 0.9391
# Validation Loss: 0.6223, Validation Accuracy: 76.07%, Validation AUROC: 0.9091
# Epoch [32/100]
# Training Loss: 0.5278, Training Accuracy: 80.52%, Training AUROC: 0.9393
# Validation Loss: 0.6282, Validation Accuracy: 75.68%, Validation AUROC: 0.9090
# Epoch [33/100]
# Training Loss: 0.5257, Training Accuracy: 80.86%, Training AUROC: 0.9412
# Validation Loss: 0.6249, Validation Accuracy: 77.24%, Validation AUROC: 0.9092
# Epoch [34/100]
# Training Loss: 0.5380, Training Accuracy: 80.47%, Training AUROC: 0.9379
# Validation Loss: 0.6199, Validation Accuracy: 76.65%, Validation AUROC: 0.9105
# Epoch [35/100]
# Training Loss: 0.5254, Training Accuracy: 80.18%, Training AUROC: 0.9407
# Validation Loss: 0.6162, Validation Accuracy: 76.85%, Validation AUROC: 0.9107
# Epoch [36/100]
# Training Loss: 0.5287, Training Accuracy: 80.57%, Training AUROC: 0.9413
# Validation Loss: 0.6243, Validation Accuracy: 76.26%, Validation AUROC: 0.9109
# Epoch [37/100]
# Training Loss: 0.5085, Training Accuracy: 81.59%, Training AUROC: 0.9451
# Validation Loss: 0.6147, Validation Accuracy: 76.26%, Validation AUROC: 0.9111
# Epoch [38/100]
# Training Loss: 0.5118, Training Accuracy: 81.20%, Training AUROC: 0.9436
# Validation Loss: 0.6168, Validation Accuracy: 75.88%, Validation AUROC: 0.9125
# Epoch [39/100]
# Training Loss: 0.5107, Training Accuracy: 80.91%, Training AUROC: 0.9446
# Validation Loss: 0.6170, Validation Accuracy: 77.43%, Validation AUROC: 0.9111
# Epoch [40/100]
# Training Loss: 0.5150, Training Accuracy: 81.54%, Training AUROC: 0.9420
# Validation Loss: 0.6170, Validation Accuracy: 78.02%, Validation AUROC: 0.9118
# Epoch [41/100]
# Training Loss: 0.5095, Training Accuracy: 80.86%, Training AUROC: 0.9445
# Validation Loss: 0.6167, Validation Accuracy: 77.24%, Validation AUROC: 0.9112
# Epoch [42/100]
# Training Loss: 0.4945, Training Accuracy: 81.88%, Training AUROC: 0.9464
# Validation Loss: 0.6260, Validation Accuracy: 76.65%, Validation AUROC: 0.9086
# Epoch [43/100]
# Training Loss: 0.5010, Training Accuracy: 82.13%, Training AUROC: 0.9454
# Validation Loss: 0.6410, Validation Accuracy: 77.24%, Validation AUROC: 0.9088
# Epoch [44/100]
# Training Loss: 0.5050, Training Accuracy: 82.32%, Training AUROC: 0.9445
# Validation Loss: 0.6235, Validation Accuracy: 77.24%, Validation AUROC: 0.9091
# Epoch [45/100]
# Training Loss: 0.4997, Training Accuracy: 81.25%, Training AUROC: 0.9453
# Validation Loss: 0.6196, Validation Accuracy: 77.04%, Validation AUROC: 0.9113
# Epoch [46/100]
# Training Loss: 0.5018, Training Accuracy: 81.45%, Training AUROC: 0.9467
# Validation Loss: 0.6154, Validation Accuracy: 76.85%, Validation AUROC: 0.9121
# Epoch [47/100]
# Training Loss: 0.4945, Training Accuracy: 81.88%, Training AUROC: 0.9464
# Validation Loss: 0.6225, Validation Accuracy: 77.43%, Validation AUROC: 0.9109
# Early stopping triggered after 47 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.5265, Training Accuracy: 36.96%, Training AUROC: 0.5181
# Validation Loss: 1.4038, Validation Accuracy: 49.03%, Validation AUROC: 0.5736
# Epoch [2/100]
# Training Loss: 1.3568, Training Accuracy: 49.85%, Training AUROC: 0.6029
# Validation Loss: 1.3100, Validation Accuracy: 49.81%, Validation AUROC: 0.6394
# Epoch [3/100]
# Training Loss: 1.2668, Training Accuracy: 57.03%, Training AUROC: 0.6737
# Validation Loss: 1.2145, Validation Accuracy: 64.01%, Validation AUROC: 0.7205
# Epoch [4/100]
# Training Loss: 1.1837, Training Accuracy: 65.58%, Training AUROC: 0.7252
# Validation Loss: 1.1490, Validation Accuracy: 68.87%, Validation AUROC: 0.7408
# Epoch [5/100]
# Training Loss: 1.1356, Training Accuracy: 67.97%, Training AUROC: 0.7375
# Validation Loss: 1.1024, Validation Accuracy: 67.32%, Validation AUROC: 0.7590
# Epoch [6/100]
# Training Loss: 1.0843, Training Accuracy: 69.82%, Training AUROC: 0.7458
# Validation Loss: 1.0523, Validation Accuracy: 70.23%, Validation AUROC: 0.7602
# Epoch [7/100]
# Training Loss: 1.0395, Training Accuracy: 71.09%, Training AUROC: 0.7572
# Validation Loss: 1.0219, Validation Accuracy: 72.57%, Validation AUROC: 0.7558
# Epoch [8/100]
# Training Loss: 1.0083, Training Accuracy: 71.09%, Training AUROC: 0.7580
# Validation Loss: 0.9846, Validation Accuracy: 72.96%, Validation AUROC: 0.7595
# Epoch [9/100]
# Training Loss: 0.9726, Training Accuracy: 71.68%, Training AUROC: 0.7589
# Validation Loss: 0.9486, Validation Accuracy: 72.96%, Validation AUROC: 0.7774
# Epoch [10/100]
# Training Loss: 0.9425, Training Accuracy: 72.12%, Training AUROC: 0.7738
# Validation Loss: 0.9156, Validation Accuracy: 73.15%, Validation AUROC: 0.7945
# Epoch [11/100]
# Training Loss: 0.8926, Training Accuracy: 72.41%, Training AUROC: 0.8069
# Validation Loss: 0.8735, Validation Accuracy: 73.54%, Validation AUROC: 0.8173
# Epoch [12/100]
# Training Loss: 0.8603, Training Accuracy: 72.56%, Training AUROC: 0.8367
# Validation Loss: 0.8486, Validation Accuracy: 73.54%, Validation AUROC: 0.8449
# Epoch [13/100]
# Training Loss: 0.8453, Training Accuracy: 72.71%, Training AUROC: 0.8516
# Validation Loss: 0.8279, Validation Accuracy: 73.74%, Validation AUROC: 0.8536
# Epoch [14/100]
# Training Loss: 0.8175, Training Accuracy: 72.90%, Training AUROC: 0.8627
# Validation Loss: 0.8112, Validation Accuracy: 73.93%, Validation AUROC: 0.8580
# Epoch [15/100]
# Training Loss: 0.7968, Training Accuracy: 73.49%, Training AUROC: 0.8635
# Validation Loss: 0.7973, Validation Accuracy: 73.74%, Validation AUROC: 0.8572
# Epoch [16/100]
# Training Loss: 0.7925, Training Accuracy: 73.14%, Training AUROC: 0.8615
# Validation Loss: 0.7855, Validation Accuracy: 73.93%, Validation AUROC: 0.8553
# Epoch [17/100]
# Training Loss: 0.7781, Training Accuracy: 73.14%, Training AUROC: 0.8630
# Validation Loss: 0.7746, Validation Accuracy: 73.93%, Validation AUROC: 0.8579
# Epoch [18/100]
# Training Loss: 0.7586, Training Accuracy: 73.78%, Training AUROC: 0.8671
# Validation Loss: 0.7682, Validation Accuracy: 73.93%, Validation AUROC: 0.8558
# Epoch [19/100]
# Training Loss: 0.7401, Training Accuracy: 73.83%, Training AUROC: 0.8758
# Validation Loss: 0.7505, Validation Accuracy: 74.12%, Validation AUROC: 0.8705
# Epoch [20/100]
# Training Loss: 0.7416, Training Accuracy: 73.54%, Training AUROC: 0.8708
# Validation Loss: 0.7629, Validation Accuracy: 73.74%, Validation AUROC: 0.8642
# Epoch [21/100]
# Training Loss: 0.7448, Training Accuracy: 73.49%, Training AUROC: 0.8659
# Validation Loss: 0.7507, Validation Accuracy: 74.12%, Validation AUROC: 0.8659
# Epoch [22/100]
# Training Loss: 0.7279, Training Accuracy: 73.68%, Training AUROC: 0.8711
# Validation Loss: 0.7340, Validation Accuracy: 74.32%, Validation AUROC: 0.8733
# Epoch [23/100]
# Training Loss: 0.7097, Training Accuracy: 74.46%, Training AUROC: 0.8738
# Validation Loss: 0.7300, Validation Accuracy: 74.51%, Validation AUROC: 0.8715
# Epoch [24/100]
# Training Loss: 0.7131, Training Accuracy: 73.97%, Training AUROC: 0.8759
# Validation Loss: 0.7315, Validation Accuracy: 74.90%, Validation AUROC: 0.8673
# Epoch [25/100]
# Training Loss: 0.7038, Training Accuracy: 74.17%, Training AUROC: 0.8784
# Validation Loss: 0.7198, Validation Accuracy: 73.93%, Validation AUROC: 0.8767
# Epoch [26/100]
# Training Loss: 0.7052, Training Accuracy: 74.61%, Training AUROC: 0.8756
# Validation Loss: 0.7172, Validation Accuracy: 74.71%, Validation AUROC: 0.8710
# Epoch [27/100]
# Training Loss: 0.7165, Training Accuracy: 73.97%, Training AUROC: 0.8753
# Validation Loss: 0.7125, Validation Accuracy: 74.71%, Validation AUROC: 0.8784
# Epoch [28/100]
# Training Loss: 0.6914, Training Accuracy: 74.80%, Training AUROC: 0.8827
# Validation Loss: 0.7137, Validation Accuracy: 75.29%, Validation AUROC: 0.8712
# Epoch [29/100]
# Training Loss: 0.6819, Training Accuracy: 75.24%, Training AUROC: 0.8896
# Validation Loss: 0.7046, Validation Accuracy: 75.88%, Validation AUROC: 0.8808
# Epoch [30/100]
# Training Loss: 0.6763, Training Accuracy: 76.56%, Training AUROC: 0.8930
# Validation Loss: 0.7107, Validation Accuracy: 74.90%, Validation AUROC: 0.8788
# Epoch [31/100]
# Training Loss: 0.6770, Training Accuracy: 76.03%, Training AUROC: 0.8927
# Validation Loss: 0.6793, Validation Accuracy: 75.29%, Validation AUROC: 0.8951
# Epoch [32/100]
# Training Loss: 0.6442, Training Accuracy: 78.03%, Training AUROC: 0.9080
# Validation Loss: 0.6671, Validation Accuracy: 76.85%, Validation AUROC: 0.8977
# Epoch [33/100]
# Training Loss: 0.6419, Training Accuracy: 78.03%, Training AUROC: 0.9079
# Validation Loss: 0.6798, Validation Accuracy: 75.88%, Validation AUROC: 0.8938
# Epoch [34/100]
# Training Loss: 0.6314, Training Accuracy: 78.17%, Training AUROC: 0.9088
# Validation Loss: 0.6714, Validation Accuracy: 75.49%, Validation AUROC: 0.8984
# Epoch [35/100]
# Training Loss: 0.6256, Training Accuracy: 78.32%, Training AUROC: 0.9128
# Validation Loss: 0.6617, Validation Accuracy: 76.46%, Validation AUROC: 0.8984
# Epoch [36/100]
# Training Loss: 0.6208, Training Accuracy: 78.47%, Training AUROC: 0.9154
# Validation Loss: 0.6526, Validation Accuracy: 77.04%, Validation AUROC: 0.9001
# Epoch [37/100]
# Training Loss: 0.6046, Training Accuracy: 79.05%, Training AUROC: 0.9193
# Validation Loss: 0.6500, Validation Accuracy: 77.63%, Validation AUROC: 0.9013
# Epoch [38/100]
# Training Loss: 0.6170, Training Accuracy: 77.54%, Training AUROC: 0.9160
# Validation Loss: 0.6469, Validation Accuracy: 76.65%, Validation AUROC: 0.9029
# Epoch [39/100]
# Training Loss: 0.5897, Training Accuracy: 79.44%, Training AUROC: 0.9252
# Validation Loss: 0.6505, Validation Accuracy: 77.43%, Validation AUROC: 0.8986
# Epoch [40/100]
# Training Loss: 0.5794, Training Accuracy: 79.64%, Training AUROC: 0.9237
# Validation Loss: 0.6553, Validation Accuracy: 76.07%, Validation AUROC: 0.8998
# Epoch [41/100]
# Training Loss: 0.5780, Training Accuracy: 79.83%, Training AUROC: 0.9240
# Validation Loss: 0.6505, Validation Accuracy: 77.04%, Validation AUROC: 0.9049
# Epoch [42/100]
# Training Loss: 0.6002, Training Accuracy: 79.30%, Training AUROC: 0.9199
# Validation Loss: 0.6422, Validation Accuracy: 77.82%, Validation AUROC: 0.9027
# Epoch [43/100]
# Training Loss: 0.5750, Training Accuracy: 79.15%, Training AUROC: 0.9251
# Validation Loss: 0.6542, Validation Accuracy: 75.68%, Validation AUROC: 0.9014
# Epoch [44/100]
# Training Loss: 0.5646, Training Accuracy: 79.98%, Training AUROC: 0.9280
# Validation Loss: 0.6294, Validation Accuracy: 78.21%, Validation AUROC: 0.9081
# Epoch [45/100]
# Training Loss: 0.5653, Training Accuracy: 79.98%, Training AUROC: 0.9269
# Validation Loss: 0.6348, Validation Accuracy: 78.02%, Validation AUROC: 0.9053
# Epoch [46/100]
# Training Loss: 0.5678, Training Accuracy: 80.42%, Training AUROC: 0.9258
# Validation Loss: 0.6287, Validation Accuracy: 77.43%, Validation AUROC: 0.9091
# Epoch [47/100]
# Training Loss: 0.5510, Training Accuracy: 81.30%, Training AUROC: 0.9307
# Validation Loss: 0.6277, Validation Accuracy: 77.04%, Validation AUROC: 0.9094
# Epoch [48/100]
# Training Loss: 0.5481, Training Accuracy: 81.20%, Training AUROC: 0.9355
# Validation Loss: 0.6232, Validation Accuracy: 77.63%, Validation AUROC: 0.9086
# Epoch [49/100]
# Training Loss: 0.5489, Training Accuracy: 80.27%, Training AUROC: 0.9290
# Validation Loss: 0.6215, Validation Accuracy: 75.88%, Validation AUROC: 0.9097
# Epoch [50/100]
# Training Loss: 0.5438, Training Accuracy: 80.81%, Training AUROC: 0.9318
# Validation Loss: 0.6305, Validation Accuracy: 77.24%, Validation AUROC: 0.9026
# Epoch [51/100]
# Training Loss: 0.5435, Training Accuracy: 80.37%, Training AUROC: 0.9304
# Validation Loss: 0.6386, Validation Accuracy: 77.24%, Validation AUROC: 0.9014
# Epoch [52/100]
# Training Loss: 0.5505, Training Accuracy: 80.76%, Training AUROC: 0.9276
# Validation Loss: 0.6201, Validation Accuracy: 78.02%, Validation AUROC: 0.9089
# Epoch [53/100]
# Training Loss: 0.5340, Training Accuracy: 81.30%, Training AUROC: 0.9327
# Validation Loss: 0.6270, Validation Accuracy: 77.63%, Validation AUROC: 0.9034
# Epoch [54/100]
# Training Loss: 0.5385, Training Accuracy: 81.01%, Training AUROC: 0.9349
# Validation Loss: 0.6233, Validation Accuracy: 77.63%, Validation AUROC: 0.9068
# Epoch [55/100]
# Training Loss: 0.5318, Training Accuracy: 81.25%, Training AUROC: 0.9342
# Validation Loss: 0.6307, Validation Accuracy: 77.04%, Validation AUROC: 0.9065
# Epoch [56/100]
# Training Loss: 0.5503, Training Accuracy: 79.88%, Training AUROC: 0.9301
# Validation Loss: 0.6454, Validation Accuracy: 76.85%, Validation AUROC: 0.9011
# Epoch [57/100]
# Training Loss: 0.5379, Training Accuracy: 81.30%, Training AUROC: 0.9337
# Validation Loss: 0.6426, Validation Accuracy: 75.10%, Validation AUROC: 0.9025
# Epoch [58/100]
# Training Loss: 0.5434, Training Accuracy: 80.57%, Training AUROC: 0.9317
# Validation Loss: 0.6329, Validation Accuracy: 77.43%, Validation AUROC: 0.8998
# Epoch [59/100]
# Training Loss: 0.5311, Training Accuracy: 80.76%, Training AUROC: 0.9349
# Validation Loss: 0.6389, Validation Accuracy: 77.43%, Validation AUROC: 0.8991
# Epoch [60/100]
# Training Loss: 0.5282, Training Accuracy: 81.25%, Training AUROC: 0.9330
# Validation Loss: 0.6332, Validation Accuracy: 76.85%, Validation AUROC: 0.9019
# Epoch [61/100]
# Training Loss: 0.5141, Training Accuracy: 81.40%, Training AUROC: 0.9379
# Validation Loss: 0.6188, Validation Accuracy: 77.82%, Validation AUROC: 0.9091
# Epoch [62/100]
# Training Loss: 0.5125, Training Accuracy: 82.03%, Training AUROC: 0.9389
# Validation Loss: 0.6496, Validation Accuracy: 77.82%, Validation AUROC: 0.8977
# Epoch [63/100]
# Training Loss: 0.5178, Training Accuracy: 81.64%, Training AUROC: 0.9371
# Validation Loss: 0.6557, Validation Accuracy: 76.85%, Validation AUROC: 0.8994
# Epoch [64/100]
# Training Loss: 0.5184, Training Accuracy: 80.81%, Training AUROC: 0.9357
# Validation Loss: 0.6496, Validation Accuracy: 76.65%, Validation AUROC: 0.8972
# Epoch [65/100]
# Training Loss: 0.5155, Training Accuracy: 81.54%, Training AUROC: 0.9386
# Validation Loss: 0.6239, Validation Accuracy: 75.10%, Validation AUROC: 0.9077
# Epoch [66/100]
# Training Loss: 0.5080, Training Accuracy: 81.20%, Training AUROC: 0.9390
# Validation Loss: 0.6508, Validation Accuracy: 75.68%, Validation AUROC: 0.9052
# Epoch [67/100]
# Training Loss: 0.5135, Training Accuracy: 81.69%, Training AUROC: 0.9388
# Validation Loss: 0.6403, Validation Accuracy: 75.68%, Validation AUROC: 0.9017
# Epoch [68/100]
# Training Loss: 0.4988, Training Accuracy: 81.54%, Training AUROC: 0.9431
# Validation Loss: 0.6324, Validation Accuracy: 75.10%, Validation AUROC: 0.9023
# Epoch [69/100]
# Training Loss: 0.4902, Training Accuracy: 82.37%, Training AUROC: 0.9422
# Validation Loss: 0.6302, Validation Accuracy: 76.85%, Validation AUROC: 0.9023
# Epoch [70/100]
# Training Loss: 0.5104, Training Accuracy: 81.35%, Training AUROC: 0.9369
# Validation Loss: 0.6267, Validation Accuracy: 76.85%, Validation AUROC: 0.9057
# Epoch [71/100]
# Training Loss: 0.5095, Training Accuracy: 82.08%, Training AUROC: 0.9396
# Validation Loss: 0.6738, Validation Accuracy: 75.68%, Validation AUROC: 0.8945
# Early stopping triggered after 71 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model Metrics:
# Accuracy: 0.7827
# F1 Score: 0.7699
# Precision: 0.7736
# Recall: 0.7827
# AUROC: 0.9098
#
# Normal Model Metrics:
# Accuracy: 0.7845
# F1 Score: 0.7652
# Precision: 0.7714
# Recall: 0.7845
# AUROC: 0.9102
