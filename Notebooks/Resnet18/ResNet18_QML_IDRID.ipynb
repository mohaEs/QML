# %% [markdown]
# ## This notebook presents the reproducible procedure that we followed in comparing the performance of Hybrid Quantum-Classical Neural Networks and Classical Convolutional Neural Networks on the IDRID dataset. The IDRID dataset is a diabetic-retinopathy dataset with 516 fundus images. The dataset was produced in India and is labeled with five-category classification (no diabetic retinopathy, mild diabetic retinopathy, moderate diabetic retinopathy, severe diabetic retinopathy, and proliferative diabetic retinopathy).

# %% [markdown]
# ### Installing and Importing Dependencies

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.40.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.1 in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.4.2)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.7.0)
# Collecting tomlkit (from pennylane)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.1)
# Collecting pennylane-lightning>=0.40 (from pennylane)
#   Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (24.2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.40->pennylane)
#   Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (2.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.1.31)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading PennyLane-0.40.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.3 MB/s eta 0:00:00
# Downloading autoray-0.7.0-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.0/930.0 kB 53.9 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 92.7 MB/s eta 0:00:00
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 14.7 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 112.6 MB/s eta 0:00:00
# Installing collected packages: appdirs, tomlkit, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.0 diastatic-malt-2.15.2 pennylane-0.40.0 pennylane-lightning-0.40.0 rustworkx-0.16.0 scipy-openblas32-0.3.29.0.0 tomlkit-0.13.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
from google.colab import drive
import cv2
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, Sampler
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms
from PIL import Image
import time
import os
import copy
from torch.optim.lr_scheduler import CosineAnnealingLR
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve,
    precision_recall_curve, auc
)
from sklearn.preprocessing import label_binarize
import random


os.environ["OMP_NUM_THREADS"] = "1"

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
MODEL_SAVE_PATH = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/Resnet-18-IDRID_models/"

# %% [markdown]
# ### Classical Resnet-18 Construction

# %%
class NormalModel(nn.Module):
  def __init__(self, freeze, num_classes, device='cuda'):
        super(NormalModel, self).__init__()

        weights = torchvision.models.ResNet18_Weights.IMAGENET1K_V1
        self.model = torchvision.models.resnet18(weights=weights)

        if freeze:
          for param in self.model.parameters():
              param.requires_grad = False

        self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)
        self.model = self.model.to(device)

  def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### General Training, Validation, Testing Functions

# %%
import torchvision
from torchvision import datasets, transforms

# %%
def train_model(model, train_loader, optimizer, criterion):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_probs = []

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        probs = torch.softmax(outputs, dim=1)
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.detach().cpu().numpy())



    avg_train_loss = train_loss / len(train_loader.dataset)
    accuracy = correct / total * 100

    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_train_loss, accuracy, avg_auroc

# %%
def validate_model(model, valid_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            probs = torch.softmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.detach().cpu().numpy())

    avg_val_loss = val_loss / len(valid_loader.dataset)
    accuracy = correct / total * 100
    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_val_loss, accuracy, avg_auroc

# %%
import pickle

def train_validate_model(n_epochs, model, model_name, train_loader, valid_loader, seed):

  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

  def adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max):
        if epoch < lr_warmup_epochs:
            lr = lr_max * (epoch + 1) / lr_warmup_epochs
        else:
            lr = lr_max
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

  scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs - 10, eta_min=1e-6)

  best_val_loss = float('inf')
  best_model_weights = model.state_dict()
  epochs_without_improvement = 0
  early_stopping_patience = 10

  train_losses = []
  train_accuracies = []
  val_losses = []
  val_accuracies = []
  train_aucs = []
  val_aucs = []

  lr_max = 5e-4
  lr_warmup_epochs = 10

  for epoch in range(n_epochs):
      print(f'Epoch [{epoch+1}/{n_epochs}]')

      adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max)

      train_loss, train_accuracy, train_auroc = train_model(model, train_loader, optimizer, criterion)
      val_loss, val_accuracy, val_auroc = validate_model(model, valid_loader, criterion)


      print(f'Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Training AUROC: {train_auroc:.4f}')
      print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%, Validation AUROC: {val_auroc:.4f}')
      train_losses.append(train_loss)
      train_accuracies.append(train_accuracy)
      train_aucs.append(train_auroc)
      val_losses.append(val_loss)
      val_accuracies.append(val_accuracy)
      val_aucs.append(val_auroc)

      if epoch >= lr_warmup_epochs:
            scheduler.step()

      if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict()
            epochs_without_improvement = 0  # Reset counter

      else:
            epochs_without_improvement += 1

      if epochs_without_improvement >= early_stopping_patience:
            print(f"Early stopping triggered after {epoch+1} epochs.")
            break

  model.load_state_dict(best_model_weights)
  torch.save(model, os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}.pth'))

  metrics = {
        "train_losses": train_losses,
        "train_accuracies": train_accuracies,
        "train_aucs": train_aucs,
        "val_losses": val_losses,
        "val_accuracies": val_accuracies,
        "val_aucs": val_aucs
    }

  with open(os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}_metrics.pkl'), 'wb') as f:
        pickle.dump(metrics, f)


  return model, train_losses, train_accuracies, val_losses, val_accuracies, train_aucs, val_aucs

# %%
import math
import matplotlib.pyplot as plt

def plot(quantum_loss, normal_loss, quantum_acc, normal_acc, quantum_auc, normal_auc):
    plt.style.use("default")

    loss_min = math.floor(min(min(quantum_loss), min(normal_loss)) * 10) / 10
    loss_max = math.ceil(max(max(quantum_loss), max(normal_loss)) * 10) / 10

    acc_min = math.floor(min(min(quantum_acc), min(normal_acc)) * 10) / 10
    acc_max = math.ceil(max(max(quantum_acc), max(normal_acc)) * 10) / 10

    auc_min = math.floor(min(min(quantum_auc), min(normal_auc)) * 10) / 10
    auc_max = math.ceil(max(max(quantum_auc), max(normal_auc)) * 10) / 10

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_loss, label="With quantum layer")
    plt.plot(normal_loss, label="Without quantum layer")
    plt.ylabel("Loss")
    plt.ylim([loss_min, loss_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Loss vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_acc, label="With quantum layer")
    plt.plot(normal_acc, label="Without quantum layer")
    plt.ylabel("Accuracy")
    plt.ylim([acc_min, acc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Accuracy vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_auc, label="With quantum layer")
    plt.plot(normal_auc, label="Without quantum layer")
    plt.ylabel("ROCAUC")
    plt.ylim([auc_min, auc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("ROCAUC vs. Epoch")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.preprocessing import label_binarize
from itertools import cycle


def test(model_hybrid, model_normal, test_loader, num_classes):
    model_hybrid.eval()
    model_normal.eval()

    all_labels = []
    all_preds_hybrid = []
    all_preds_normal = []
    all_probs_hybrid = []
    all_probs_normal = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)


            outputs_hybrid = model_hybrid(images)
            _, preds_hybrid = torch.max(outputs_hybrid, 1)
            probs_hybrid = torch.softmax(outputs_hybrid, dim=1)
            # Normal model predictions
            outputs_normal = model_normal(images)
            _, preds_normal = torch.max(outputs_normal, 1)
            probs_normal = torch.softmax(outputs_normal, dim=1)

            all_labels.extend(labels.cpu().numpy())
            all_preds_hybrid.extend(preds_hybrid.cpu().numpy())
            all_preds_normal.extend(preds_normal.cpu().numpy())
            all_probs_hybrid.extend(probs_hybrid.cpu().numpy())
            all_probs_normal.extend(probs_normal.cpu().numpy())

    all_labels = np.array(all_labels)
    all_preds_hybrid = np.array(all_preds_hybrid)
    all_preds_normal = np.array(all_preds_normal)
    all_probs_hybrid = np.array(all_probs_hybrid)
    all_probs_normal = np.array(all_probs_normal)


    accuracy_hybrid = accuracy_score(all_labels, all_preds_hybrid)
    accuracy_normal = accuracy_score(all_labels, all_preds_normal)


    f1_hybrid = f1_score(all_labels, all_preds_hybrid, average='weighted')
    f1_normal = f1_score(all_labels, all_preds_normal, average='weighted')


    if num_classes == 2:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, pos_label=1)
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, pos_label=1)
        precision_normal = precision_score(all_labels, all_preds_normal, pos_label=1)
        recall_normal = recall_score(all_labels, all_preds_normal, pos_label=1)
    else:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, average='weighted')
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, average='weighted')
        precision_normal = precision_score(all_labels, all_preds_normal, average='weighted')
        recall_normal = recall_score(all_labels, all_preds_normal, average='weighted')


    hybrid_aucs = []
    normal_aucs = []

    if num_classes == 2:

        all_probs_hybrid_class1 = all_probs_hybrid[:, 1]
        all_probs_normal_class1 = all_probs_normal[:, 1]

        auc_hybrid = roc_auc_score(all_labels, all_probs_hybrid_class1)
        auc_normal = roc_auc_score(all_labels, all_probs_normal_class1)

        print(f'Hybrid Model AUROC: {auc_hybrid:.4f}')
        print(f'Normal Model AUROC: {auc_normal:.4f}')

        fpr_hybrid, tpr_hybrid, _ = roc_curve(all_labels, all_probs_hybrid_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_hybrid, tpr_hybrid, label=f'Hybrid Model AUROC = {auc_hybrid:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Hybrid Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curve for the Normal Model
        fpr_normal, tpr_normal, _ = roc_curve(all_labels, all_probs_normal_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_normal, tpr_normal, label=f'Normal Model AUROC = {auc_normal:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Normal Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

    else:  # Multi-class Classification

        all_labels_binarized = label_binarize(all_labels, classes=np.arange(num_classes))

        # Define a color cycle for plotting
        colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red'])
        # Plot ROC curves for the Hybrid Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_hybrid[:, i])
            roc_auc = auc(fpr, tpr)
            hybrid_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Hybrid Model')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curves for the Normal Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_normal[:, i])
            roc_auc = auc(fpr, tpr)
            normal_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Normal Model')
        plt.legend(loc='lower right')
        plt.show()



    normal_auc = f"{sum(normal_aucs) / len(normal_aucs):.4f}"
    hybrid_auc = f"{sum(hybrid_aucs) / len(hybrid_aucs):.4f}"

    print("\nHybrid Model Metrics:")
    print(f'Accuracy: {accuracy_hybrid:.4f}')
    print(f'F1 Score: {f1_hybrid:.4f}')
    print(f'Precision: {precision_hybrid:.4f}')
    print(f'Recall: {recall_hybrid:.4f}')
    print(f'AUROC: {hybrid_auc}')

    print("\nNormal Model Metrics:")
    print(f'Accuracy: {accuracy_normal:.4f}')
    print(f'F1 Score: {f1_normal:.4f}')
    print(f'Precision: {precision_normal:.4f}')
    print(f'Recall: {recall_normal:.4f}')
    print(f'AUROC: {normal_auc} \n')

    cm_hybrid = confusion_matrix(all_labels, all_preds_hybrid)


    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_hybrid, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Hybrid Model (Avg AUC = {hybrid_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    cm_normal = confusion_matrix(all_labels, all_preds_normal)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_normal, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Classical Model (Avg AUC = {normal_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
def load_data(batch_size, dataset):

  train_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])

  valid_test_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])


  if dataset == 'APTOS':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/APTOS2019/"

  elif dataset == "IDRID":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/IDRID_images/"

  elif dataset == "Messidor":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/MESSIDOR2/"

  elif dataset == "GlaucomaFundus":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/Glaucoma_fundus/"

  elif dataset == "PAPILA":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/PAPILA/"

  elif dataset == 'G1020':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020/"


  train_dataset = datasets.ImageFolder(root=data_dir + 'train', transform=train_transform)
  val_dataset = datasets.ImageFolder(root=data_dir + 'val', transform=valid_test_transform)
  test_dataset = datasets.ImageFolder(root=data_dir + 'test', transform=valid_test_transform)

  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
  valid_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

  return train_loader, valid_loader, test_loader

# %% [markdown]
# ### Hybrid Quantum-Classical Resnet-18 Construction

# %%
n_qubits = 4                # Number of qubits
step = 0.0004               # Learning rate
batch_size = 4              # Number of samples for each training step
q_delta = 0.01              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer

# %%
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)


def RY_layer(w):
    """Layer of parametrized qubit rotations around the y axis.
    """
    for idx, element in enumerate(w):
        qml.RY(element, wires=idx)


def entangling_layer(nqubits):
    """Layer of CNOTs followed by another shifted layer of CNOT.
    """
    for i in range(0, nqubits - 1, 2):
        qml.CNOT(wires=[i, i + 1])
    for i in range(1, nqubits - 1, 2):
        qml.CNOT(wires=[i, i + 1])

# %%
dev = qml.device("default.qubit", wires=n_qubits)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
@qml.qnode(dev)
def quantum_net(q_input_features, q_weights_flat):
    """
    The variational quantum circuit.
    """

    # Reshape weights
    q_weights = q_weights_flat.reshape(q_depth, n_qubits)

    # Start from state |+> , unbiased w.r.t. |0> and |1>
    H_layer(n_qubits)

    # Embed features in the quantum node
    RY_layer(q_input_features)

    # Sequence of trainable variational layers
    for k in range(q_depth):
        entangling_layer(n_qubits)
        RY_layer(q_weights[k])

    # Expectation values in the Z basis
    exp_vals = [qml.expval(qml.PauliZ(position)) for position in range(n_qubits)]
    return tuple(exp_vals)

# %%
class DressedQuantumNet(nn.Module):

    def __init__(self, q_depth, num_classes):

        super().__init__()
        self.pre_net = nn.Linear(512, n_qubits)
        self.q_params = nn.Parameter(q_delta * torch.randn(q_depth * n_qubits))
        self.post_net = nn.Linear(n_qubits, num_classes)

    def forward(self, input_features):


        pre_out = self.pre_net(input_features)
        q_in = torch.tanh(pre_out) * np.pi / 2.0

        # Apply the quantum circuit to each element of the batch and append to q_out
        q_out = torch.Tensor(0, n_qubits)
        q_out = q_out.to(device)
        for elem in q_in:
            q_out_elem = torch.hstack(quantum_net(elem, self.q_params)).float().unsqueeze(0)
            q_out = torch.cat((q_out, q_out_elem))

        # return the two-dimensional prediction from the postprocessing layer
        return self.post_net(q_out)

# %%
class QuantumHybridModel(nn.Module):
  def __init__(self, q_depth, freeze, num_classes, device='cuda'):
        super(QuantumHybridModel, self).__init__()

        weights = torchvision.models.ResNet18_Weights.IMAGENET1K_V1
        self.model = torchvision.models.resnet18(weights=weights)

        if freeze:
          for param in self.model.parameters():
              param.requires_grad = False

        self.model.fc = DressedQuantumNet(q_depth, num_classes)

        self.model = self.model.to(device)

  def forward(self, x):
        return self.model(x)

# %% [markdown]
# # Experiments

# %%
n_epochs = 100
num_classes = 5
batch_size = 32
dataset = "IDRID"
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
q_depth = 4

# %% [markdown]
# ## Seed Experiment 1

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 24:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 221MB/s]

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.6513, Training Accuracy: 19.08%, Training AUROC: 0.4914
# Validation Loss: 1.5654, Validation Accuracy: 27.85%, Validation AUROC: 0.5617
# Epoch [2/100]
# Training Loss: 1.5822, Training Accuracy: 21.91%, Training AUROC: 0.4961
# Validation Loss: 1.4261, Validation Accuracy: 41.77%, Validation AUROC: 0.5958
# Epoch [3/100]
# Training Loss: 1.5182, Training Accuracy: 26.15%, Training AUROC: 0.4956
# Validation Loss: 1.3510, Validation Accuracy: 44.30%, Validation AUROC: 0.6162
# Epoch [4/100]
# Training Loss: 1.4565, Training Accuracy: 29.68%, Training AUROC: 0.5492
# Validation Loss: 1.3103, Validation Accuracy: 44.30%, Validation AUROC: 0.6390
# Epoch [5/100]
# Training Loss: 1.4135, Training Accuracy: 37.10%, Training AUROC: 0.6060
# Validation Loss: 1.2705, Validation Accuracy: 49.37%, Validation AUROC: 0.6757
# Epoch [6/100]
# Training Loss: 1.3746, Training Accuracy: 38.87%, Training AUROC: 0.6488
# Validation Loss: 1.2223, Validation Accuracy: 54.43%, Validation AUROC: 0.7073
# Epoch [7/100]
# Training Loss: 1.3289, Training Accuracy: 44.88%, Training AUROC: 0.6793
# Validation Loss: 1.1800, Validation Accuracy: 51.90%, Validation AUROC: 0.7259
# Epoch [8/100]
# Training Loss: 1.2801, Training Accuracy: 48.41%, Training AUROC: 0.7125
# Validation Loss: 1.1515, Validation Accuracy: 51.90%, Validation AUROC: 0.7383
# Epoch [9/100]
# Training Loss: 1.2210, Training Accuracy: 52.30%, Training AUROC: 0.7634
# Validation Loss: 1.1192, Validation Accuracy: 53.16%, Validation AUROC: 0.7539
# Epoch [10/100]
# Training Loss: 1.1924, Training Accuracy: 53.71%, Training AUROC: 0.7670
# Validation Loss: 1.0956, Validation Accuracy: 51.90%, Validation AUROC: 0.7742
# Epoch [11/100]
# Training Loss: 1.1583, Training Accuracy: 53.71%, Training AUROC: 0.7972
# Validation Loss: 1.0675, Validation Accuracy: 53.16%, Validation AUROC: 0.7841
# Epoch [12/100]
# Training Loss: 1.1271, Training Accuracy: 55.48%, Training AUROC: 0.8190
# Validation Loss: 1.0535, Validation Accuracy: 54.43%, Validation AUROC: 0.7891
# Epoch [13/100]
# Training Loss: 1.0973, Training Accuracy: 58.30%, Training AUROC: 0.8276
# Validation Loss: 1.0462, Validation Accuracy: 53.16%, Validation AUROC: 0.7961
# Epoch [14/100]
# Training Loss: 1.0694, Training Accuracy: 57.24%, Training AUROC: 0.8404
# Validation Loss: 1.0310, Validation Accuracy: 53.16%, Validation AUROC: 0.7980
# Epoch [15/100]
# Training Loss: 1.0390, Training Accuracy: 60.42%, Training AUROC: 0.8616
# Validation Loss: 1.0300, Validation Accuracy: 53.16%, Validation AUROC: 0.8026
# Epoch [16/100]
# Training Loss: 1.0173, Training Accuracy: 60.42%, Training AUROC: 0.8698
# Validation Loss: 1.0248, Validation Accuracy: 54.43%, Validation AUROC: 0.8051
# Epoch [17/100]
# Training Loss: 1.0404, Training Accuracy: 64.31%, Training AUROC: 0.8560
# Validation Loss: 1.0216, Validation Accuracy: 55.70%, Validation AUROC: 0.8057
# Epoch [18/100]
# Training Loss: 0.9774, Training Accuracy: 65.37%, Training AUROC: 0.8829
# Validation Loss: 1.0105, Validation Accuracy: 50.63%, Validation AUROC: 0.8082
# Epoch [19/100]
# Training Loss: 0.9664, Training Accuracy: 63.60%, Training AUROC: 0.8918
# Validation Loss: 1.0089, Validation Accuracy: 53.16%, Validation AUROC: 0.8095
# Epoch [20/100]
# Training Loss: 0.9580, Training Accuracy: 63.60%, Training AUROC: 0.8847
# Validation Loss: 1.0095, Validation Accuracy: 55.70%, Validation AUROC: 0.8085
# Epoch [21/100]
# Training Loss: 0.9546, Training Accuracy: 64.66%, Training AUROC: 0.8822
# Validation Loss: 1.0223, Validation Accuracy: 56.96%, Validation AUROC: 0.8070
# Epoch [22/100]
# Training Loss: 0.9462, Training Accuracy: 63.25%, Training AUROC: 0.8938
# Validation Loss: 1.0072, Validation Accuracy: 53.16%, Validation AUROC: 0.8113
# Epoch [23/100]
# Training Loss: 0.9535, Training Accuracy: 62.19%, Training AUROC: 0.8800
# Validation Loss: 1.0033, Validation Accuracy: 55.70%, Validation AUROC: 0.8068
# Epoch [24/100]
# Training Loss: 0.9299, Training Accuracy: 67.84%, Training AUROC: 0.8918
# Validation Loss: 1.0166, Validation Accuracy: 54.43%, Validation AUROC: 0.8066
# Epoch [25/100]
# Training Loss: 0.8945, Training Accuracy: 67.14%, Training AUROC: 0.9057
# Validation Loss: 1.0043, Validation Accuracy: 55.70%, Validation AUROC: 0.8081
# Epoch [26/100]
# Training Loss: 0.8980, Training Accuracy: 67.14%, Training AUROC: 0.9061
# Validation Loss: 1.0038, Validation Accuracy: 55.70%, Validation AUROC: 0.8069
# Epoch [27/100]
# Training Loss: 0.8912, Training Accuracy: 65.37%, Training AUROC: 0.9087
# Validation Loss: 1.0146, Validation Accuracy: 53.16%, Validation AUROC: 0.8084
# Epoch [28/100]
# Training Loss: 0.8597, Training Accuracy: 67.49%, Training AUROC: 0.9146
# Validation Loss: 1.0075, Validation Accuracy: 56.96%, Validation AUROC: 0.8070
# Epoch [29/100]
# Training Loss: 0.8575, Training Accuracy: 68.20%, Training AUROC: 0.9166
# Validation Loss: 1.0067, Validation Accuracy: 55.70%, Validation AUROC: 0.8052
# Epoch [30/100]
# Training Loss: 0.8572, Training Accuracy: 69.26%, Training AUROC: 0.9161
# Validation Loss: 1.0222, Validation Accuracy: 56.96%, Validation AUROC: 0.8053
# Epoch [31/100]
# Training Loss: 0.8307, Training Accuracy: 70.32%, Training AUROC: 0.9224
# Validation Loss: 1.0067, Validation Accuracy: 54.43%, Validation AUROC: 0.8042
# Epoch [32/100]
# Training Loss: 0.8174, Training Accuracy: 71.73%, Training AUROC: 0.9295
# Validation Loss: 1.0032, Validation Accuracy: 56.96%, Validation AUROC: 0.8089
# Epoch [33/100]
# Training Loss: 0.8285, Training Accuracy: 67.84%, Training AUROC: 0.9131
# Validation Loss: 1.0065, Validation Accuracy: 55.70%, Validation AUROC: 0.8070
# Epoch [34/100]
# Training Loss: 0.7929, Training Accuracy: 69.61%, Training AUROC: 0.9312
# Validation Loss: 1.0134, Validation Accuracy: 54.43%, Validation AUROC: 0.8084
# Epoch [35/100]
# Training Loss: 0.8335, Training Accuracy: 66.08%, Training AUROC: 0.9172
# Validation Loss: 1.0135, Validation Accuracy: 55.70%, Validation AUROC: 0.8070
# Epoch [36/100]
# Training Loss: 0.8071, Training Accuracy: 72.08%, Training AUROC: 0.9270
# Validation Loss: 1.0173, Validation Accuracy: 56.96%, Validation AUROC: 0.8046
# Epoch [37/100]
# Training Loss: 0.7991, Training Accuracy: 68.90%, Training AUROC: 0.9210
# Validation Loss: 1.0138, Validation Accuracy: 55.70%, Validation AUROC: 0.8083
# Epoch [38/100]
# Training Loss: 0.7865, Training Accuracy: 71.02%, Training AUROC: 0.9298
# Validation Loss: 1.0212, Validation Accuracy: 55.70%, Validation AUROC: 0.8097
# Epoch [39/100]
# Training Loss: 0.7680, Training Accuracy: 72.79%, Training AUROC: 0.9398
# Validation Loss: 1.0186, Validation Accuracy: 58.23%, Validation AUROC: 0.8042
# Epoch [40/100]
# Training Loss: 0.7860, Training Accuracy: 71.73%, Training AUROC: 0.9275
# Validation Loss: 1.0196, Validation Accuracy: 55.70%, Validation AUROC: 0.8068
# Epoch [41/100]
# Training Loss: 0.7816, Training Accuracy: 70.32%, Training AUROC: 0.9327
# Validation Loss: 1.0190, Validation Accuracy: 54.43%, Validation AUROC: 0.8097
# Epoch [42/100]
# Training Loss: 0.7671, Training Accuracy: 70.67%, Training AUROC: 0.9308
# Validation Loss: 1.0219, Validation Accuracy: 55.70%, Validation AUROC: 0.8081
# Early stopping triggered after 42 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.7361, Training Accuracy: 9.19%, Training AUROC: 0.4864
# Validation Loss: 1.6289, Validation Accuracy: 21.52%, Validation AUROC: 0.6149
# Epoch [2/100]
# Training Loss: 1.6206, Training Accuracy: 22.61%, Training AUROC: 0.5245
# Validation Loss: 1.5644, Validation Accuracy: 27.85%, Validation AUROC: 0.6051
# Epoch [3/100]
# Training Loss: 1.5767, Training Accuracy: 31.10%, Training AUROC: 0.5298
# Validation Loss: 1.5390, Validation Accuracy: 30.38%, Validation AUROC: 0.6405
# Epoch [4/100]
# Training Loss: 1.5684, Training Accuracy: 31.45%, Training AUROC: 0.5364
# Validation Loss: 1.5270, Validation Accuracy: 30.38%, Validation AUROC: 0.6524
# Epoch [5/100]
# Training Loss: 1.5656, Training Accuracy: 31.10%, Training AUROC: 0.5347
# Validation Loss: 1.5111, Validation Accuracy: 30.38%, Validation AUROC: 0.6526
# Epoch [6/100]
# Training Loss: 1.5422, Training Accuracy: 31.45%, Training AUROC: 0.5663
# Validation Loss: 1.4938, Validation Accuracy: 29.11%, Validation AUROC: 0.6659
# Epoch [7/100]
# Training Loss: 1.5163, Training Accuracy: 28.98%, Training AUROC: 0.5915
# Validation Loss: 1.4858, Validation Accuracy: 26.58%, Validation AUROC: 0.6690
# Epoch [8/100]
# Training Loss: 1.5072, Training Accuracy: 24.38%, Training AUROC: 0.5872
# Validation Loss: 1.4717, Validation Accuracy: 25.32%, Validation AUROC: 0.6781
# Epoch [9/100]
# Training Loss: 1.4908, Training Accuracy: 28.62%, Training AUROC: 0.6214
# Validation Loss: 1.4587, Validation Accuracy: 26.58%, Validation AUROC: 0.6805
# Epoch [10/100]
# Training Loss: 1.4543, Training Accuracy: 31.10%, Training AUROC: 0.6486
# Validation Loss: 1.4543, Validation Accuracy: 25.32%, Validation AUROC: 0.6792
# Epoch [11/100]
# Training Loss: 1.4438, Training Accuracy: 28.27%, Training AUROC: 0.6378
# Validation Loss: 1.4408, Validation Accuracy: 25.32%, Validation AUROC: 0.6755
# Epoch [12/100]
# Training Loss: 1.4388, Training Accuracy: 30.74%, Training AUROC: 0.6322
# Validation Loss: 1.4305, Validation Accuracy: 26.58%, Validation AUROC: 0.6796
# Epoch [13/100]
# Training Loss: 1.4005, Training Accuracy: 30.39%, Training AUROC: 0.6663
# Validation Loss: 1.4273, Validation Accuracy: 25.32%, Validation AUROC: 0.6791
# Epoch [14/100]
# Training Loss: 1.3981, Training Accuracy: 29.68%, Training AUROC: 0.6646
# Validation Loss: 1.4175, Validation Accuracy: 26.58%, Validation AUROC: 0.6742
# Epoch [15/100]
# Training Loss: 1.3763, Training Accuracy: 32.16%, Training AUROC: 0.6637
# Validation Loss: 1.4105, Validation Accuracy: 26.58%, Validation AUROC: 0.6717
# Epoch [16/100]
# Training Loss: 1.3605, Training Accuracy: 32.51%, Training AUROC: 0.6725
# Validation Loss: 1.4118, Validation Accuracy: 26.58%, Validation AUROC: 0.6746
# Epoch [17/100]
# Training Loss: 1.3508, Training Accuracy: 33.92%, Training AUROC: 0.6850
# Validation Loss: 1.4034, Validation Accuracy: 27.85%, Validation AUROC: 0.6711
# Epoch [18/100]
# Training Loss: 1.3489, Training Accuracy: 34.63%, Training AUROC: 0.6762
# Validation Loss: 1.3971, Validation Accuracy: 27.85%, Validation AUROC: 0.6703
# Epoch [19/100]
# Training Loss: 1.3277, Training Accuracy: 34.98%, Training AUROC: 0.6920
# Validation Loss: 1.3991, Validation Accuracy: 25.32%, Validation AUROC: 0.6730
# Epoch [20/100]
# Training Loss: 1.3337, Training Accuracy: 36.40%, Training AUROC: 0.6902
# Validation Loss: 1.3917, Validation Accuracy: 26.58%, Validation AUROC: 0.6692
# Epoch [21/100]
# Training Loss: 1.3089, Training Accuracy: 39.22%, Training AUROC: 0.6843
# Validation Loss: 1.3878, Validation Accuracy: 26.58%, Validation AUROC: 0.6674
# Epoch [22/100]
# Training Loss: 1.3035, Training Accuracy: 42.05%, Training AUROC: 0.6787
# Validation Loss: 1.3846, Validation Accuracy: 25.32%, Validation AUROC: 0.6680
# Epoch [23/100]
# Training Loss: 1.2786, Training Accuracy: 42.05%, Training AUROC: 0.7089
# Validation Loss: 1.3796, Validation Accuracy: 26.58%, Validation AUROC: 0.6661
# Epoch [24/100]
# Training Loss: 1.2864, Training Accuracy: 41.34%, Training AUROC: 0.7011
# Validation Loss: 1.3792, Validation Accuracy: 26.58%, Validation AUROC: 0.6639
# Epoch [25/100]
# Training Loss: 1.2845, Training Accuracy: 42.76%, Training AUROC: 0.7006
# Validation Loss: 1.3754, Validation Accuracy: 26.58%, Validation AUROC: 0.6639
# Epoch [26/100]
# Training Loss: 1.2499, Training Accuracy: 46.64%, Training AUROC: 0.7107
# Validation Loss: 1.3730, Validation Accuracy: 27.85%, Validation AUROC: 0.6620
# Epoch [27/100]
# Training Loss: 1.2741, Training Accuracy: 41.70%, Training AUROC: 0.7051
# Validation Loss: 1.3754, Validation Accuracy: 27.85%, Validation AUROC: 0.6617
# Epoch [28/100]
# Training Loss: 1.2582, Training Accuracy: 46.29%, Training AUROC: 0.7063
# Validation Loss: 1.3698, Validation Accuracy: 26.58%, Validation AUROC: 0.6596
# Epoch [29/100]
# Training Loss: 1.2213, Training Accuracy: 50.53%, Training AUROC: 0.7300
# Validation Loss: 1.3668, Validation Accuracy: 32.91%, Validation AUROC: 0.6619
# Epoch [30/100]
# Training Loss: 1.2532, Training Accuracy: 47.00%, Training AUROC: 0.7147
# Validation Loss: 1.3652, Validation Accuracy: 30.38%, Validation AUROC: 0.6593
# Epoch [31/100]
# Training Loss: 1.2174, Training Accuracy: 51.24%, Training AUROC: 0.7355
# Validation Loss: 1.3632, Validation Accuracy: 37.97%, Validation AUROC: 0.6571
# Epoch [32/100]
# Training Loss: 1.2176, Training Accuracy: 50.53%, Training AUROC: 0.7410
# Validation Loss: 1.3630, Validation Accuracy: 36.71%, Validation AUROC: 0.6585
# Epoch [33/100]
# Training Loss: 1.2240, Training Accuracy: 54.42%, Training AUROC: 0.7117
# Validation Loss: 1.3552, Validation Accuracy: 44.30%, Validation AUROC: 0.6572
# Epoch [34/100]
# Training Loss: 1.2134, Training Accuracy: 61.84%, Training AUROC: 0.7335
# Validation Loss: 1.3550, Validation Accuracy: 48.10%, Validation AUROC: 0.6567
# Epoch [35/100]
# Training Loss: 1.2040, Training Accuracy: 60.42%, Training AUROC: 0.7248
# Validation Loss: 1.3549, Validation Accuracy: 53.16%, Validation AUROC: 0.6574
# Epoch [36/100]
# Training Loss: 1.1984, Training Accuracy: 58.30%, Training AUROC: 0.7253
# Validation Loss: 1.3521, Validation Accuracy: 51.90%, Validation AUROC: 0.6559
# Epoch [37/100]
# Training Loss: 1.2042, Training Accuracy: 59.01%, Training AUROC: 0.7144
# Validation Loss: 1.3499, Validation Accuracy: 53.16%, Validation AUROC: 0.6579
# Epoch [38/100]
# Training Loss: 1.1849, Training Accuracy: 58.66%, Training AUROC: 0.7449
# Validation Loss: 1.3477, Validation Accuracy: 51.90%, Validation AUROC: 0.6562
# Epoch [39/100]
# Training Loss: 1.1818, Training Accuracy: 59.72%, Training AUROC: 0.7428
# Validation Loss: 1.3478, Validation Accuracy: 53.16%, Validation AUROC: 0.6525
# Epoch [40/100]
# Training Loss: 1.1850, Training Accuracy: 61.84%, Training AUROC: 0.7273
# Validation Loss: 1.3479, Validation Accuracy: 51.90%, Validation AUROC: 0.6515
# Epoch [41/100]
# Training Loss: 1.1821, Training Accuracy: 60.07%, Training AUROC: 0.7291
# Validation Loss: 1.3402, Validation Accuracy: 50.63%, Validation AUROC: 0.6503
# Epoch [42/100]
# Training Loss: 1.1874, Training Accuracy: 62.19%, Training AUROC: 0.7399
# Validation Loss: 1.3492, Validation Accuracy: 48.10%, Validation AUROC: 0.6492
# Epoch [43/100]
# Training Loss: 1.1574, Training Accuracy: 62.54%, Training AUROC: 0.7338
# Validation Loss: 1.3437, Validation Accuracy: 53.16%, Validation AUROC: 0.6469
# Epoch [44/100]
# Training Loss: 1.1523, Training Accuracy: 60.07%, Training AUROC: 0.7375
# Validation Loss: 1.3381, Validation Accuracy: 50.63%, Validation AUROC: 0.6495
# Epoch [45/100]
# Training Loss: 1.1463, Training Accuracy: 59.36%, Training AUROC: 0.7468
# Validation Loss: 1.3355, Validation Accuracy: 49.37%, Validation AUROC: 0.6465
# Epoch [46/100]
# Training Loss: 1.1462, Training Accuracy: 63.60%, Training AUROC: 0.7381
# Validation Loss: 1.3379, Validation Accuracy: 46.84%, Validation AUROC: 0.6425
# Epoch [47/100]
# Training Loss: 1.1448, Training Accuracy: 61.48%, Training AUROC: 0.7474
# Validation Loss: 1.3316, Validation Accuracy: 48.10%, Validation AUROC: 0.6409
# Epoch [48/100]
# Training Loss: 1.1388, Training Accuracy: 60.78%, Training AUROC: 0.7496
# Validation Loss: 1.3284, Validation Accuracy: 50.63%, Validation AUROC: 0.6409
# Epoch [49/100]
# Training Loss: 1.1052, Training Accuracy: 66.43%, Training AUROC: 0.7607
# Validation Loss: 1.3231, Validation Accuracy: 49.37%, Validation AUROC: 0.6410
# Epoch [50/100]
# Training Loss: 1.1343, Training Accuracy: 61.84%, Training AUROC: 0.7439
# Validation Loss: 1.3263, Validation Accuracy: 49.37%, Validation AUROC: 0.6404
# Epoch [51/100]
# Training Loss: 1.1257, Training Accuracy: 64.66%, Training AUROC: 0.7576
# Validation Loss: 1.3181, Validation Accuracy: 51.90%, Validation AUROC: 0.6404
# Epoch [52/100]
# Training Loss: 1.1597, Training Accuracy: 59.72%, Training AUROC: 0.7286
# Validation Loss: 1.3092, Validation Accuracy: 48.10%, Validation AUROC: 0.6480
# Epoch [53/100]
# Training Loss: 1.1115, Training Accuracy: 63.96%, Training AUROC: 0.7563
# Validation Loss: 1.3250, Validation Accuracy: 49.37%, Validation AUROC: 0.6387
# Epoch [54/100]
# Training Loss: 1.0982, Training Accuracy: 63.96%, Training AUROC: 0.7521
# Validation Loss: 1.3317, Validation Accuracy: 50.63%, Validation AUROC: 0.6370
# Epoch [55/100]
# Training Loss: 1.1057, Training Accuracy: 60.78%, Training AUROC: 0.7482
# Validation Loss: 1.3140, Validation Accuracy: 49.37%, Validation AUROC: 0.6420
# Epoch [56/100]
# Training Loss: 1.0946, Training Accuracy: 65.02%, Training AUROC: 0.7674
# Validation Loss: 1.3148, Validation Accuracy: 50.63%, Validation AUROC: 0.6390
# Epoch [57/100]
# Training Loss: 1.0823, Training Accuracy: 64.31%, Training AUROC: 0.7689
# Validation Loss: 1.3135, Validation Accuracy: 49.37%, Validation AUROC: 0.6398
# Epoch [58/100]
# Training Loss: 1.0806, Training Accuracy: 66.78%, Training AUROC: 0.7573
# Validation Loss: 1.3147, Validation Accuracy: 46.84%, Validation AUROC: 0.6383
# Epoch [59/100]
# Training Loss: 1.0835, Training Accuracy: 62.90%, Training AUROC: 0.7672
# Validation Loss: 1.3078, Validation Accuracy: 49.37%, Validation AUROC: 0.6441
# Epoch [60/100]
# Training Loss: 1.0789, Training Accuracy: 64.66%, Training AUROC: 0.7655
# Validation Loss: 1.3042, Validation Accuracy: 48.10%, Validation AUROC: 0.6420
# Epoch [61/100]
# Training Loss: 1.0752, Training Accuracy: 68.90%, Training AUROC: 0.7677
# Validation Loss: 1.3042, Validation Accuracy: 49.37%, Validation AUROC: 0.6360
# Epoch [62/100]
# Training Loss: 1.0819, Training Accuracy: 66.43%, Training AUROC: 0.7576
# Validation Loss: 1.3088, Validation Accuracy: 46.84%, Validation AUROC: 0.6338
# Epoch [63/100]
# Training Loss: 1.0540, Training Accuracy: 65.37%, Training AUROC: 0.7750
# Validation Loss: 1.2986, Validation Accuracy: 49.37%, Validation AUROC: 0.6340
# Epoch [64/100]
# Training Loss: 1.0515, Training Accuracy: 65.37%, Training AUROC: 0.7661
# Validation Loss: 1.3029, Validation Accuracy: 48.10%, Validation AUROC: 0.6326
# Epoch [65/100]
# Training Loss: 1.0501, Training Accuracy: 66.08%, Training AUROC: 0.7772
# Validation Loss: 1.3117, Validation Accuracy: 46.84%, Validation AUROC: 0.6321
# Epoch [66/100]
# Training Loss: 1.0689, Training Accuracy: 61.13%, Training AUROC: 0.7682
# Validation Loss: 1.2964, Validation Accuracy: 50.63%, Validation AUROC: 0.6337
# Epoch [67/100]
# Training Loss: 1.0530, Training Accuracy: 62.90%, Training AUROC: 0.7790
# Validation Loss: 1.3012, Validation Accuracy: 49.37%, Validation AUROC: 0.6329
# Epoch [68/100]
# Training Loss: 1.0385, Training Accuracy: 66.08%, Training AUROC: 0.7703
# Validation Loss: 1.2970, Validation Accuracy: 46.84%, Validation AUROC: 0.6347
# Epoch [69/100]
# Training Loss: 1.0552, Training Accuracy: 66.78%, Training AUROC: 0.7674
# Validation Loss: 1.2913, Validation Accuracy: 46.84%, Validation AUROC: 0.6335
# Epoch [70/100]
# Training Loss: 1.0427, Training Accuracy: 62.90%, Training AUROC: 0.7830
# Validation Loss: 1.3036, Validation Accuracy: 46.84%, Validation AUROC: 0.6309
# Epoch [71/100]
# Training Loss: 1.0260, Training Accuracy: 66.78%, Training AUROC: 0.7965
# Validation Loss: 1.2872, Validation Accuracy: 46.84%, Validation AUROC: 0.6376
# Epoch [72/100]
# Training Loss: 1.0310, Training Accuracy: 67.49%, Training AUROC: 0.7889
# Validation Loss: 1.2822, Validation Accuracy: 50.63%, Validation AUROC: 0.6402
# Epoch [73/100]
# Training Loss: 1.0319, Training Accuracy: 67.49%, Training AUROC: 0.7759
# Validation Loss: 1.2901, Validation Accuracy: 46.84%, Validation AUROC: 0.6355
# Epoch [74/100]
# Training Loss: 1.0121, Training Accuracy: 65.72%, Training AUROC: 0.7944
# Validation Loss: 1.2848, Validation Accuracy: 50.63%, Validation AUROC: 0.6408
# Epoch [75/100]
# Training Loss: 1.0042, Training Accuracy: 69.61%, Training AUROC: 0.7931
# Validation Loss: 1.2767, Validation Accuracy: 53.16%, Validation AUROC: 0.6360
# Epoch [76/100]
# Training Loss: 1.0044, Training Accuracy: 66.08%, Training AUROC: 0.8004
# Validation Loss: 1.2850, Validation Accuracy: 48.10%, Validation AUROC: 0.6327
# Epoch [77/100]
# Training Loss: 1.0028, Training Accuracy: 68.20%, Training AUROC: 0.7822
# Validation Loss: 1.2825, Validation Accuracy: 49.37%, Validation AUROC: 0.6303
# Epoch [78/100]
# Training Loss: 0.9986, Training Accuracy: 66.43%, Training AUROC: 0.7874
# Validation Loss: 1.2805, Validation Accuracy: 51.90%, Validation AUROC: 0.6356
# Epoch [79/100]
# Training Loss: 1.0081, Training Accuracy: 66.08%, Training AUROC: 0.7939
# Validation Loss: 1.2814, Validation Accuracy: 46.84%, Validation AUROC: 0.6355
# Epoch [80/100]
# Training Loss: 0.9964, Training Accuracy: 71.38%, Training AUROC: 0.8122
# Validation Loss: 1.2603, Validation Accuracy: 54.43%, Validation AUROC: 0.6383
# Epoch [81/100]
# Training Loss: 1.0026, Training Accuracy: 67.49%, Training AUROC: 0.8056
# Validation Loss: 1.2756, Validation Accuracy: 49.37%, Validation AUROC: 0.6342
# Epoch [82/100]
# Training Loss: 0.9870, Training Accuracy: 69.96%, Training AUROC: 0.7971
# Validation Loss: 1.2680, Validation Accuracy: 49.37%, Validation AUROC: 0.6356
# Epoch [83/100]
# Training Loss: 0.9886, Training Accuracy: 68.55%, Training AUROC: 0.8022
# Validation Loss: 1.2659, Validation Accuracy: 50.63%, Validation AUROC: 0.6358
# Epoch [84/100]
# Training Loss: 0.9791, Training Accuracy: 71.02%, Training AUROC: 0.8162
# Validation Loss: 1.2639, Validation Accuracy: 48.10%, Validation AUROC: 0.6349
# Epoch [85/100]
# Training Loss: 0.9731, Training Accuracy: 71.38%, Training AUROC: 0.8094
# Validation Loss: 1.2633, Validation Accuracy: 50.63%, Validation AUROC: 0.6347
# Epoch [86/100]
# Training Loss: 0.9607, Training Accuracy: 70.67%, Training AUROC: 0.8024
# Validation Loss: 1.2709, Validation Accuracy: 49.37%, Validation AUROC: 0.6325
# Epoch [87/100]
# Training Loss: 0.9906, Training Accuracy: 66.43%, Training AUROC: 0.8065
# Validation Loss: 1.2726, Validation Accuracy: 49.37%, Validation AUROC: 0.6315
# Epoch [88/100]
# Training Loss: 0.9752, Training Accuracy: 70.67%, Training AUROC: 0.8099
# Validation Loss: 1.2565, Validation Accuracy: 50.63%, Validation AUROC: 0.6383
# Epoch [89/100]
# Training Loss: 0.9491, Training Accuracy: 73.50%, Training AUROC: 0.8160
# Validation Loss: 1.2625, Validation Accuracy: 48.10%, Validation AUROC: 0.6339
# Epoch [90/100]
# Training Loss: 0.9459, Training Accuracy: 71.02%, Training AUROC: 0.8306
# Validation Loss: 1.2573, Validation Accuracy: 48.10%, Validation AUROC: 0.6309
# Epoch [91/100]
# Training Loss: 0.9941, Training Accuracy: 65.02%, Training AUROC: 0.7988
# Validation Loss: 1.2553, Validation Accuracy: 49.37%, Validation AUROC: 0.6368
# Epoch [92/100]
# Training Loss: 0.9438, Training Accuracy: 72.08%, Training AUROC: 0.8223
# Validation Loss: 1.2536, Validation Accuracy: 50.63%, Validation AUROC: 0.6335
# Epoch [93/100]
# Training Loss: 0.9481, Training Accuracy: 72.79%, Training AUROC: 0.8319
# Validation Loss: 1.2524, Validation Accuracy: 50.63%, Validation AUROC: 0.6357
# Epoch [94/100]
# Training Loss: 0.9638, Training Accuracy: 69.26%, Training AUROC: 0.8153
# Validation Loss: 1.2484, Validation Accuracy: 48.10%, Validation AUROC: 0.6337
# Epoch [95/100]
# Training Loss: 0.9548, Training Accuracy: 72.79%, Training AUROC: 0.8351
# Validation Loss: 1.2406, Validation Accuracy: 51.90%, Validation AUROC: 0.6372
# Epoch [96/100]
# Training Loss: 0.9330, Training Accuracy: 74.91%, Training AUROC: 0.8437
# Validation Loss: 1.2482, Validation Accuracy: 49.37%, Validation AUROC: 0.6317
# Epoch [97/100]
# Training Loss: 0.9280, Training Accuracy: 70.67%, Training AUROC: 0.8300
# Validation Loss: 1.2512, Validation Accuracy: 48.10%, Validation AUROC: 0.6339
# Epoch [98/100]
# Training Loss: 0.9291, Training Accuracy: 73.14%, Training AUROC: 0.8294
# Validation Loss: 1.2405, Validation Accuracy: 51.90%, Validation AUROC: 0.6371
# Epoch [99/100]
# Training Loss: 0.9194, Training Accuracy: 71.38%, Training AUROC: 0.8502
# Validation Loss: 1.2394, Validation Accuracy: 49.37%, Validation AUROC: 0.6367
# Epoch [100/100]
# Training Loss: 0.9267, Training Accuracy: 75.62%, Training AUROC: 0.8221
# Validation Loss: 1.2311, Validation Accuracy: 51.90%, Validation AUROC: 0.6377

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.5974
# F1 Score: 0.5774
# Precision: 0.5989
# Recall: 0.5974
# AUROC: 0.6637
#
# Normal Model Metrics:
# Accuracy: 0.6104
# F1 Score: 0.5900
# Precision: 0.6045
# Recall: 0.6104
# AUROC: 0.8409

# %% [markdown]
# ## Seed Experiment 2

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 92:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.6304, Training Accuracy: 25.44%, Training AUROC: 0.5119
# Validation Loss: 1.6046, Validation Accuracy: 20.25%, Validation AUROC: 0.4547
# Epoch [2/100]
# Training Loss: 1.5632, Training Accuracy: 31.80%, Training AUROC: 0.5070
# Validation Loss: 1.4975, Validation Accuracy: 27.85%, Validation AUROC: 0.4863
# Epoch [3/100]
# Training Loss: 1.5014, Training Accuracy: 35.34%, Training AUROC: 0.5389
# Validation Loss: 1.4071, Validation Accuracy: 39.24%, Validation AUROC: 0.5383
# Epoch [4/100]
# Training Loss: 1.4640, Training Accuracy: 33.92%, Training AUROC: 0.5728
# Validation Loss: 1.3414, Validation Accuracy: 45.57%, Validation AUROC: 0.6004
# Epoch [5/100]
# Training Loss: 1.4224, Training Accuracy: 38.87%, Training AUROC: 0.6022
# Validation Loss: 1.3007, Validation Accuracy: 48.10%, Validation AUROC: 0.6421
# Epoch [6/100]
# Training Loss: 1.3869, Training Accuracy: 42.05%, Training AUROC: 0.6425
# Validation Loss: 1.2602, Validation Accuracy: 51.90%, Validation AUROC: 0.6718
# Epoch [7/100]
# Training Loss: 1.3299, Training Accuracy: 44.52%, Training AUROC: 0.6993
# Validation Loss: 1.2118, Validation Accuracy: 48.10%, Validation AUROC: 0.7007
# Epoch [8/100]
# Training Loss: 1.2702, Training Accuracy: 49.47%, Training AUROC: 0.7529
# Validation Loss: 1.1809, Validation Accuracy: 54.43%, Validation AUROC: 0.7230
# Epoch [9/100]
# Training Loss: 1.2274, Training Accuracy: 52.65%, Training AUROC: 0.7761
# Validation Loss: 1.1614, Validation Accuracy: 53.16%, Validation AUROC: 0.7358
# Epoch [10/100]
# Training Loss: 1.2099, Training Accuracy: 52.65%, Training AUROC: 0.7743
# Validation Loss: 1.1225, Validation Accuracy: 55.70%, Validation AUROC: 0.7552
# Epoch [11/100]
# Training Loss: 1.1562, Training Accuracy: 53.36%, Training AUROC: 0.8152
# Validation Loss: 1.1037, Validation Accuracy: 55.70%, Validation AUROC: 0.7620
# Epoch [12/100]
# Training Loss: 1.1647, Training Accuracy: 52.65%, Training AUROC: 0.8146
# Validation Loss: 1.0898, Validation Accuracy: 53.16%, Validation AUROC: 0.7686
# Epoch [13/100]
# Training Loss: 1.1139, Training Accuracy: 55.83%, Training AUROC: 0.8259
# Validation Loss: 1.0970, Validation Accuracy: 54.43%, Validation AUROC: 0.7678
# Epoch [14/100]
# Training Loss: 1.0648, Training Accuracy: 59.72%, Training AUROC: 0.8554
# Validation Loss: 1.0759, Validation Accuracy: 54.43%, Validation AUROC: 0.7709
# Epoch [15/100]
# Training Loss: 1.0549, Training Accuracy: 61.84%, Training AUROC: 0.8586
# Validation Loss: 1.0619, Validation Accuracy: 54.43%, Validation AUROC: 0.7781
# Epoch [16/100]
# Training Loss: 1.0542, Training Accuracy: 60.78%, Training AUROC: 0.8524
# Validation Loss: 1.0730, Validation Accuracy: 53.16%, Validation AUROC: 0.7770
# Epoch [17/100]
# Training Loss: 1.0580, Training Accuracy: 57.24%, Training AUROC: 0.8554
# Validation Loss: 1.0597, Validation Accuracy: 51.90%, Validation AUROC: 0.7830
# Epoch [18/100]
# Training Loss: 0.9970, Training Accuracy: 64.31%, Training AUROC: 0.8770
# Validation Loss: 1.0645, Validation Accuracy: 55.70%, Validation AUROC: 0.7778
# Epoch [19/100]
# Training Loss: 0.9901, Training Accuracy: 64.66%, Training AUROC: 0.8755
# Validation Loss: 1.0605, Validation Accuracy: 54.43%, Validation AUROC: 0.7805
# Epoch [20/100]
# Training Loss: 0.9325, Training Accuracy: 67.84%, Training AUROC: 0.8981
# Validation Loss: 1.0573, Validation Accuracy: 53.16%, Validation AUROC: 0.7805
# Epoch [21/100]
# Training Loss: 0.9453, Training Accuracy: 68.55%, Training AUROC: 0.8924
# Validation Loss: 1.0502, Validation Accuracy: 56.96%, Validation AUROC: 0.7822
# Epoch [22/100]
# Training Loss: 0.9565, Training Accuracy: 64.66%, Training AUROC: 0.8860
# Validation Loss: 1.0543, Validation Accuracy: 56.96%, Validation AUROC: 0.7847
# Epoch [23/100]
# Training Loss: 0.9305, Training Accuracy: 65.72%, Training AUROC: 0.8939
# Validation Loss: 1.0551, Validation Accuracy: 55.70%, Validation AUROC: 0.7845
# Epoch [24/100]
# Training Loss: 0.9145, Training Accuracy: 68.20%, Training AUROC: 0.9016
# Validation Loss: 1.0521, Validation Accuracy: 54.43%, Validation AUROC: 0.7847
# Epoch [25/100]
# Training Loss: 0.8993, Training Accuracy: 68.20%, Training AUROC: 0.9107
# Validation Loss: 1.0585, Validation Accuracy: 53.16%, Validation AUROC: 0.7878
# Epoch [26/100]
# Training Loss: 0.9102, Training Accuracy: 67.14%, Training AUROC: 0.9063
# Validation Loss: 1.0590, Validation Accuracy: 56.96%, Validation AUROC: 0.7891
# Epoch [27/100]
# Training Loss: 0.8636, Training Accuracy: 70.67%, Training AUROC: 0.9189
# Validation Loss: 1.0543, Validation Accuracy: 54.43%, Validation AUROC: 0.7865
# Epoch [28/100]
# Training Loss: 0.8663, Training Accuracy: 68.55%, Training AUROC: 0.9136
# Validation Loss: 1.0472, Validation Accuracy: 54.43%, Validation AUROC: 0.7908
# Epoch [29/100]
# Training Loss: 0.8554, Training Accuracy: 67.84%, Training AUROC: 0.9169
# Validation Loss: 1.0522, Validation Accuracy: 56.96%, Validation AUROC: 0.7926
# Epoch [30/100]
# Training Loss: 0.8792, Training Accuracy: 64.31%, Training AUROC: 0.9051
# Validation Loss: 1.0605, Validation Accuracy: 51.90%, Validation AUROC: 0.7920
# Epoch [31/100]
# Training Loss: 0.8445, Training Accuracy: 71.02%, Training AUROC: 0.9231
# Validation Loss: 1.0683, Validation Accuracy: 53.16%, Validation AUROC: 0.7872
# Epoch [32/100]
# Training Loss: 0.8374, Training Accuracy: 68.20%, Training AUROC: 0.9211
# Validation Loss: 1.0572, Validation Accuracy: 54.43%, Validation AUROC: 0.7900
# Epoch [33/100]
# Training Loss: 0.8363, Training Accuracy: 69.61%, Training AUROC: 0.9152
# Validation Loss: 1.0639, Validation Accuracy: 53.16%, Validation AUROC: 0.7908
# Epoch [34/100]
# Training Loss: 0.8251, Training Accuracy: 70.32%, Training AUROC: 0.9199
# Validation Loss: 1.0580, Validation Accuracy: 54.43%, Validation AUROC: 0.7929
# Epoch [35/100]
# Training Loss: 0.8305, Training Accuracy: 68.90%, Training AUROC: 0.9221
# Validation Loss: 1.0572, Validation Accuracy: 54.43%, Validation AUROC: 0.7909
# Epoch [36/100]
# Training Loss: 0.8051, Training Accuracy: 71.02%, Training AUROC: 0.9263
# Validation Loss: 1.0660, Validation Accuracy: 53.16%, Validation AUROC: 0.7906
# Epoch [37/100]
# Training Loss: 0.8118, Training Accuracy: 68.90%, Training AUROC: 0.9230
# Validation Loss: 1.0655, Validation Accuracy: 54.43%, Validation AUROC: 0.7899
# Epoch [38/100]
# Training Loss: 0.7750, Training Accuracy: 69.96%, Training AUROC: 0.9337
# Validation Loss: 1.0699, Validation Accuracy: 51.90%, Validation AUROC: 0.7894
# Early stopping triggered after 38 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.6510, Training Accuracy: 16.96%, Training AUROC: 0.5244
# Validation Loss: 1.6143, Validation Accuracy: 20.25%, Validation AUROC: 0.5704
# Epoch [2/100]
# Training Loss: 1.5758, Training Accuracy: 20.85%, Training AUROC: 0.5377
# Validation Loss: 1.5056, Validation Accuracy: 26.58%, Validation AUROC: 0.6024
# Epoch [3/100]
# Training Loss: 1.5039, Training Accuracy: 31.45%, Training AUROC: 0.5802
# Validation Loss: 1.4752, Validation Accuracy: 31.65%, Validation AUROC: 0.6073
# Epoch [4/100]
# Training Loss: 1.4911, Training Accuracy: 32.16%, Training AUROC: 0.5899
# Validation Loss: 1.4688, Validation Accuracy: 31.65%, Validation AUROC: 0.6241
# Epoch [5/100]
# Training Loss: 1.4926, Training Accuracy: 31.80%, Training AUROC: 0.5855
# Validation Loss: 1.4654, Validation Accuracy: 31.65%, Validation AUROC: 0.6337
# Epoch [6/100]
# Training Loss: 1.4745, Training Accuracy: 32.16%, Training AUROC: 0.6240
# Validation Loss: 1.4559, Validation Accuracy: 31.65%, Validation AUROC: 0.6543
# Epoch [7/100]
# Training Loss: 1.4696, Training Accuracy: 32.16%, Training AUROC: 0.6360
# Validation Loss: 1.4440, Validation Accuracy: 26.58%, Validation AUROC: 0.6792
# Epoch [8/100]
# Training Loss: 1.4470, Training Accuracy: 32.51%, Training AUROC: 0.6557
# Validation Loss: 1.4361, Validation Accuracy: 27.85%, Validation AUROC: 0.6708
# Epoch [9/100]
# Training Loss: 1.4315, Training Accuracy: 34.98%, Training AUROC: 0.6709
# Validation Loss: 1.4261, Validation Accuracy: 26.58%, Validation AUROC: 0.6863
# Epoch [10/100]
# Training Loss: 1.4126, Training Accuracy: 34.63%, Training AUROC: 0.7051
# Validation Loss: 1.4173, Validation Accuracy: 24.05%, Validation AUROC: 0.6916
# Epoch [11/100]
# Training Loss: 1.3919, Training Accuracy: 37.46%, Training AUROC: 0.7117
# Validation Loss: 1.4094, Validation Accuracy: 26.58%, Validation AUROC: 0.6941
# Epoch [12/100]
# Training Loss: 1.3814, Training Accuracy: 40.99%, Training AUROC: 0.7190
# Validation Loss: 1.4035, Validation Accuracy: 31.65%, Validation AUROC: 0.6999
# Epoch [13/100]
# Training Loss: 1.3677, Training Accuracy: 36.40%, Training AUROC: 0.7365
# Validation Loss: 1.3977, Validation Accuracy: 31.65%, Validation AUROC: 0.6912
# Epoch [14/100]
# Training Loss: 1.3695, Training Accuracy: 38.52%, Training AUROC: 0.7225
# Validation Loss: 1.3900, Validation Accuracy: 39.24%, Validation AUROC: 0.6995
# Epoch [15/100]
# Training Loss: 1.3426, Training Accuracy: 43.46%, Training AUROC: 0.7545
# Validation Loss: 1.3895, Validation Accuracy: 29.11%, Validation AUROC: 0.6860
# Epoch [16/100]
# Training Loss: 1.3285, Training Accuracy: 43.82%, Training AUROC: 0.7551
# Validation Loss: 1.3780, Validation Accuracy: 37.97%, Validation AUROC: 0.6998
# Epoch [17/100]
# Training Loss: 1.3211, Training Accuracy: 49.12%, Training AUROC: 0.7603
# Validation Loss: 1.3730, Validation Accuracy: 34.18%, Validation AUROC: 0.6910
# Epoch [18/100]
# Training Loss: 1.3239, Training Accuracy: 48.06%, Training AUROC: 0.7501
# Validation Loss: 1.3659, Validation Accuracy: 37.97%, Validation AUROC: 0.7020
# Epoch [19/100]
# Training Loss: 1.3096, Training Accuracy: 52.30%, Training AUROC: 0.7594
# Validation Loss: 1.3619, Validation Accuracy: 41.77%, Validation AUROC: 0.7007
# Epoch [20/100]
# Training Loss: 1.2853, Training Accuracy: 50.53%, Training AUROC: 0.7801
# Validation Loss: 1.3632, Validation Accuracy: 44.30%, Validation AUROC: 0.6894
# Epoch [21/100]
# Training Loss: 1.2841, Training Accuracy: 54.06%, Training AUROC: 0.7691
# Validation Loss: 1.3552, Validation Accuracy: 45.57%, Validation AUROC: 0.6962
# Epoch [22/100]
# Training Loss: 1.2664, Training Accuracy: 53.71%, Training AUROC: 0.7857
# Validation Loss: 1.3486, Validation Accuracy: 44.30%, Validation AUROC: 0.6966
# Epoch [23/100]
# Training Loss: 1.2709, Training Accuracy: 56.18%, Training AUROC: 0.7836
# Validation Loss: 1.3428, Validation Accuracy: 44.30%, Validation AUROC: 0.7029
# Epoch [24/100]
# Training Loss: 1.2520, Training Accuracy: 59.01%, Training AUROC: 0.7936
# Validation Loss: 1.3430, Validation Accuracy: 45.57%, Validation AUROC: 0.6896
# Epoch [25/100]
# Training Loss: 1.2619, Training Accuracy: 56.89%, Training AUROC: 0.7859
# Validation Loss: 1.3393, Validation Accuracy: 46.84%, Validation AUROC: 0.6895
# Epoch [26/100]
# Training Loss: 1.2309, Training Accuracy: 61.48%, Training AUROC: 0.8093
# Validation Loss: 1.3335, Validation Accuracy: 46.84%, Validation AUROC: 0.6911
# Epoch [27/100]
# Training Loss: 1.2266, Training Accuracy: 58.66%, Training AUROC: 0.7970
# Validation Loss: 1.3321, Validation Accuracy: 46.84%, Validation AUROC: 0.6947
# Epoch [28/100]
# Training Loss: 1.2242, Training Accuracy: 59.36%, Training AUROC: 0.8142
# Validation Loss: 1.3264, Validation Accuracy: 45.57%, Validation AUROC: 0.6891
# Epoch [29/100]
# Training Loss: 1.2033, Training Accuracy: 60.78%, Training AUROC: 0.8140
# Validation Loss: 1.3213, Validation Accuracy: 45.57%, Validation AUROC: 0.6899
# Epoch [30/100]
# Training Loss: 1.2102, Training Accuracy: 60.42%, Training AUROC: 0.8007
# Validation Loss: 1.3178, Validation Accuracy: 45.57%, Validation AUROC: 0.6870
# Epoch [31/100]
# Training Loss: 1.1952, Training Accuracy: 58.30%, Training AUROC: 0.8201
# Validation Loss: 1.3176, Validation Accuracy: 48.10%, Validation AUROC: 0.6848
# Epoch [32/100]
# Training Loss: 1.1955, Training Accuracy: 62.19%, Training AUROC: 0.8176
# Validation Loss: 1.3153, Validation Accuracy: 48.10%, Validation AUROC: 0.6891
# Epoch [33/100]
# Training Loss: 1.1885, Training Accuracy: 61.48%, Training AUROC: 0.8219
# Validation Loss: 1.3077, Validation Accuracy: 49.37%, Validation AUROC: 0.6831
# Epoch [34/100]
# Training Loss: 1.1956, Training Accuracy: 57.60%, Training AUROC: 0.8222
# Validation Loss: 1.3054, Validation Accuracy: 50.63%, Validation AUROC: 0.6859
# Epoch [35/100]
# Training Loss: 1.1719, Training Accuracy: 61.84%, Training AUROC: 0.8322
# Validation Loss: 1.2993, Validation Accuracy: 48.10%, Validation AUROC: 0.6925
# Epoch [36/100]
# Training Loss: 1.1802, Training Accuracy: 61.48%, Training AUROC: 0.8148
# Validation Loss: 1.2928, Validation Accuracy: 51.90%, Validation AUROC: 0.6883
# Epoch [37/100]
# Training Loss: 1.1664, Training Accuracy: 65.37%, Training AUROC: 0.8283
# Validation Loss: 1.2897, Validation Accuracy: 50.63%, Validation AUROC: 0.6852
# Epoch [38/100]
# Training Loss: 1.1662, Training Accuracy: 61.48%, Training AUROC: 0.8273
# Validation Loss: 1.2851, Validation Accuracy: 53.16%, Validation AUROC: 0.6865
# Epoch [39/100]
# Training Loss: 1.1589, Training Accuracy: 61.48%, Training AUROC: 0.8224
# Validation Loss: 1.2786, Validation Accuracy: 53.16%, Validation AUROC: 0.6838
# Epoch [40/100]
# Training Loss: 1.1474, Training Accuracy: 67.14%, Training AUROC: 0.8398
# Validation Loss: 1.2755, Validation Accuracy: 50.63%, Validation AUROC: 0.6844
# Epoch [41/100]
# Training Loss: 1.1355, Training Accuracy: 67.49%, Training AUROC: 0.8290
# Validation Loss: 1.2692, Validation Accuracy: 53.16%, Validation AUROC: 0.6862
# Epoch [42/100]
# Training Loss: 1.1186, Training Accuracy: 66.08%, Training AUROC: 0.8485
# Validation Loss: 1.2756, Validation Accuracy: 50.63%, Validation AUROC: 0.6773
# Epoch [43/100]
# Training Loss: 1.1255, Training Accuracy: 67.14%, Training AUROC: 0.8456
# Validation Loss: 1.2620, Validation Accuracy: 53.16%, Validation AUROC: 0.6795
# Epoch [44/100]
# Training Loss: 1.1387, Training Accuracy: 63.60%, Training AUROC: 0.8315
# Validation Loss: 1.2530, Validation Accuracy: 55.70%, Validation AUROC: 0.6846
# Epoch [45/100]
# Training Loss: 1.1364, Training Accuracy: 65.72%, Training AUROC: 0.8299
# Validation Loss: 1.2550, Validation Accuracy: 50.63%, Validation AUROC: 0.6915
# Epoch [46/100]
# Training Loss: 1.1080, Training Accuracy: 63.60%, Training AUROC: 0.8332
# Validation Loss: 1.2515, Validation Accuracy: 54.43%, Validation AUROC: 0.6822
# Epoch [47/100]
# Training Loss: 1.0974, Training Accuracy: 65.37%, Training AUROC: 0.8553
# Validation Loss: 1.2541, Validation Accuracy: 54.43%, Validation AUROC: 0.6818
# Epoch [48/100]
# Training Loss: 1.1135, Training Accuracy: 66.78%, Training AUROC: 0.8376
# Validation Loss: 1.2501, Validation Accuracy: 54.43%, Validation AUROC: 0.6813
# Epoch [49/100]
# Training Loss: 1.0715, Training Accuracy: 70.32%, Training AUROC: 0.8595
# Validation Loss: 1.2475, Validation Accuracy: 56.96%, Validation AUROC: 0.6835
# Epoch [50/100]
# Training Loss: 1.0828, Training Accuracy: 66.78%, Training AUROC: 0.8551
# Validation Loss: 1.2470, Validation Accuracy: 50.63%, Validation AUROC: 0.6874
# Epoch [51/100]
# Training Loss: 1.0759, Training Accuracy: 67.84%, Training AUROC: 0.8638
# Validation Loss: 1.2507, Validation Accuracy: 50.63%, Validation AUROC: 0.6835
# Epoch [52/100]
# Training Loss: 1.0972, Training Accuracy: 64.31%, Training AUROC: 0.8425
# Validation Loss: 1.2316, Validation Accuracy: 54.43%, Validation AUROC: 0.6872
# Epoch [53/100]
# Training Loss: 1.0569, Training Accuracy: 67.84%, Training AUROC: 0.8678
# Validation Loss: 1.2462, Validation Accuracy: 53.16%, Validation AUROC: 0.6788
# Epoch [54/100]
# Training Loss: 1.0612, Training Accuracy: 68.90%, Training AUROC: 0.8632
# Validation Loss: 1.2286, Validation Accuracy: 55.70%, Validation AUROC: 0.6862
# Epoch [55/100]
# Training Loss: 1.0762, Training Accuracy: 67.49%, Training AUROC: 0.8697
# Validation Loss: 1.2263, Validation Accuracy: 53.16%, Validation AUROC: 0.6885
# Epoch [56/100]
# Training Loss: 1.0395, Training Accuracy: 70.67%, Training AUROC: 0.8644
# Validation Loss: 1.2269, Validation Accuracy: 53.16%, Validation AUROC: 0.6828
# Epoch [57/100]
# Training Loss: 1.0426, Training Accuracy: 67.84%, Training AUROC: 0.8672
# Validation Loss: 1.2185, Validation Accuracy: 54.43%, Validation AUROC: 0.6873
# Epoch [58/100]
# Training Loss: 1.0319, Training Accuracy: 71.73%, Training AUROC: 0.8747
# Validation Loss: 1.2244, Validation Accuracy: 54.43%, Validation AUROC: 0.6876
# Epoch [59/100]
# Training Loss: 1.0279, Training Accuracy: 69.61%, Training AUROC: 0.8678
# Validation Loss: 1.2094, Validation Accuracy: 56.96%, Validation AUROC: 0.6909
# Epoch [60/100]
# Training Loss: 1.0283, Training Accuracy: 70.67%, Training AUROC: 0.8814
# Validation Loss: 1.2141, Validation Accuracy: 58.23%, Validation AUROC: 0.6891
# Epoch [61/100]
# Training Loss: 1.0215, Training Accuracy: 69.61%, Training AUROC: 0.8820
# Validation Loss: 1.2148, Validation Accuracy: 56.96%, Validation AUROC: 0.6875
# Epoch [62/100]
# Training Loss: 1.0084, Training Accuracy: 69.61%, Training AUROC: 0.8797
# Validation Loss: 1.2038, Validation Accuracy: 55.70%, Validation AUROC: 0.6928
# Epoch [63/100]
# Training Loss: 0.9879, Training Accuracy: 70.67%, Training AUROC: 0.9091
# Validation Loss: 1.2044, Validation Accuracy: 58.23%, Validation AUROC: 0.6947
# Epoch [64/100]
# Training Loss: 1.0011, Training Accuracy: 69.26%, Training AUROC: 0.8905
# Validation Loss: 1.2149, Validation Accuracy: 53.16%, Validation AUROC: 0.6915
# Epoch [65/100]
# Training Loss: 0.9998, Training Accuracy: 69.26%, Training AUROC: 0.8914
# Validation Loss: 1.2017, Validation Accuracy: 58.23%, Validation AUROC: 0.6939
# Epoch [66/100]
# Training Loss: 0.9956, Training Accuracy: 71.02%, Training AUROC: 0.8926
# Validation Loss: 1.1999, Validation Accuracy: 56.96%, Validation AUROC: 0.6906
# Epoch [67/100]
# Training Loss: 0.9725, Training Accuracy: 72.08%, Training AUROC: 0.9025
# Validation Loss: 1.2030, Validation Accuracy: 55.70%, Validation AUROC: 0.6942
# Epoch [68/100]
# Training Loss: 1.0032, Training Accuracy: 71.02%, Training AUROC: 0.8804
# Validation Loss: 1.2069, Validation Accuracy: 55.70%, Validation AUROC: 0.6971
# Epoch [69/100]
# Training Loss: 0.9624, Training Accuracy: 73.14%, Training AUROC: 0.9094
# Validation Loss: 1.1979, Validation Accuracy: 55.70%, Validation AUROC: 0.6900
# Epoch [70/100]
# Training Loss: 0.9534, Training Accuracy: 73.85%, Training AUROC: 0.9104
# Validation Loss: 1.2074, Validation Accuracy: 55.70%, Validation AUROC: 0.6985
# Epoch [71/100]
# Training Loss: 0.9780, Training Accuracy: 72.79%, Training AUROC: 0.9012
# Validation Loss: 1.1954, Validation Accuracy: 56.96%, Validation AUROC: 0.6906
# Epoch [72/100]
# Training Loss: 0.9644, Training Accuracy: 71.38%, Training AUROC: 0.9023
# Validation Loss: 1.1985, Validation Accuracy: 58.23%, Validation AUROC: 0.6861
# Epoch [73/100]
# Training Loss: 0.9818, Training Accuracy: 70.67%, Training AUROC: 0.9012
# Validation Loss: 1.1994, Validation Accuracy: 55.70%, Validation AUROC: 0.6909
# Epoch [74/100]
# Training Loss: 0.9444, Training Accuracy: 73.85%, Training AUROC: 0.9107
# Validation Loss: 1.1916, Validation Accuracy: 55.70%, Validation AUROC: 0.6915
# Epoch [75/100]
# Training Loss: 1.0038, Training Accuracy: 68.20%, Training AUROC: 0.8789
# Validation Loss: 1.2027, Validation Accuracy: 55.70%, Validation AUROC: 0.6952
# Epoch [76/100]
# Training Loss: 0.9315, Training Accuracy: 76.68%, Training AUROC: 0.9077
# Validation Loss: 1.1826, Validation Accuracy: 55.70%, Validation AUROC: 0.6923
# Epoch [77/100]
# Training Loss: 0.9355, Training Accuracy: 73.50%, Training AUROC: 0.9184
# Validation Loss: 1.2008, Validation Accuracy: 58.23%, Validation AUROC: 0.6863
# Epoch [78/100]
# Training Loss: 0.9231, Training Accuracy: 74.20%, Training AUROC: 0.9318
# Validation Loss: 1.1852, Validation Accuracy: 58.23%, Validation AUROC: 0.6902
# Epoch [79/100]
# Training Loss: 0.9242, Training Accuracy: 72.79%, Training AUROC: 0.9163
# Validation Loss: 1.1821, Validation Accuracy: 56.96%, Validation AUROC: 0.6953
# Epoch [80/100]
# Training Loss: 0.9173, Training Accuracy: 75.97%, Training AUROC: 0.9109
# Validation Loss: 1.1921, Validation Accuracy: 55.70%, Validation AUROC: 0.6982
# Epoch [81/100]
# Training Loss: 0.9187, Training Accuracy: 76.68%, Training AUROC: 0.9304
# Validation Loss: 1.1897, Validation Accuracy: 59.49%, Validation AUROC: 0.6927
# Epoch [82/100]
# Training Loss: 0.9378, Training Accuracy: 69.26%, Training AUROC: 0.9224
# Validation Loss: 1.1932, Validation Accuracy: 56.96%, Validation AUROC: 0.6975
# Epoch [83/100]
# Training Loss: 0.9152, Training Accuracy: 74.56%, Training AUROC: 0.9142
# Validation Loss: 1.1786, Validation Accuracy: 55.70%, Validation AUROC: 0.6929
# Epoch [84/100]
# Training Loss: 0.9068, Training Accuracy: 73.50%, Training AUROC: 0.9206
# Validation Loss: 1.1774, Validation Accuracy: 55.70%, Validation AUROC: 0.6942
# Epoch [85/100]
# Training Loss: 0.8919, Training Accuracy: 76.68%, Training AUROC: 0.9318
# Validation Loss: 1.1789, Validation Accuracy: 55.70%, Validation AUROC: 0.6952
# Epoch [86/100]
# Training Loss: 0.8768, Training Accuracy: 76.68%, Training AUROC: 0.9361
# Validation Loss: 1.1829, Validation Accuracy: 58.23%, Validation AUROC: 0.6922
# Epoch [87/100]
# Training Loss: 0.8782, Training Accuracy: 78.80%, Training AUROC: 0.9270
# Validation Loss: 1.1813, Validation Accuracy: 56.96%, Validation AUROC: 0.6927
# Epoch [88/100]
# Training Loss: 0.9244, Training Accuracy: 68.20%, Training AUROC: 0.8974
# Validation Loss: 1.1807, Validation Accuracy: 56.96%, Validation AUROC: 0.6940
# Epoch [89/100]
# Training Loss: 0.8877, Training Accuracy: 76.68%, Training AUROC: 0.9301
# Validation Loss: 1.1786, Validation Accuracy: 58.23%, Validation AUROC: 0.6886
# Epoch [90/100]
# Training Loss: 0.8858, Training Accuracy: 75.27%, Training AUROC: 0.9236
# Validation Loss: 1.1882, Validation Accuracy: 56.96%, Validation AUROC: 0.6876
# Epoch [91/100]
# Training Loss: 0.8768, Training Accuracy: 76.33%, Training AUROC: 0.9245
# Validation Loss: 1.1669, Validation Accuracy: 55.70%, Validation AUROC: 0.6908
# Epoch [92/100]
# Training Loss: 0.8768, Training Accuracy: 75.27%, Training AUROC: 0.9318
# Validation Loss: 1.1788, Validation Accuracy: 56.96%, Validation AUROC: 0.6950
# Epoch [93/100]
# Training Loss: 0.8515, Training Accuracy: 77.39%, Training AUROC: 0.9470
# Validation Loss: 1.1800, Validation Accuracy: 54.43%, Validation AUROC: 0.6957
# Epoch [94/100]
# Training Loss: 0.8842, Training Accuracy: 72.44%, Training AUROC: 0.9254
# Validation Loss: 1.1698, Validation Accuracy: 51.90%, Validation AUROC: 0.6968
# Epoch [95/100]
# Training Loss: 0.8911, Training Accuracy: 72.44%, Training AUROC: 0.9212
# Validation Loss: 1.1713, Validation Accuracy: 56.96%, Validation AUROC: 0.6997
# Epoch [96/100]
# Training Loss: 0.8397, Training Accuracy: 77.03%, Training AUROC: 0.9354
# Validation Loss: 1.1736, Validation Accuracy: 58.23%, Validation AUROC: 0.6969
# Epoch [97/100]
# Training Loss: 0.8359, Training Accuracy: 78.09%, Training AUROC: 0.9480
# Validation Loss: 1.1867, Validation Accuracy: 54.43%, Validation AUROC: 0.7155
# Epoch [98/100]
# Training Loss: 0.8373, Training Accuracy: 79.86%, Training AUROC: 0.9398
# Validation Loss: 1.1818, Validation Accuracy: 56.96%, Validation AUROC: 0.6964
# Epoch [99/100]
# Training Loss: 0.8291, Training Accuracy: 78.80%, Training AUROC: 0.9281
# Validation Loss: 1.1694, Validation Accuracy: 56.96%, Validation AUROC: 0.6956
# Epoch [100/100]
# Training Loss: 0.8163, Training Accuracy: 79.51%, Training AUROC: 0.9419
# Validation Loss: 1.1802, Validation Accuracy: 56.96%, Validation AUROC: 0.6946

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.6688
# F1 Score: 0.6476
# Precision: 0.6411
# Recall: 0.6688
# AUROC: 0.7647
#
# Normal Model Metrics:
# Accuracy: 0.6169
# F1 Score: 0.5944
# Precision: 0.5878
# Recall: 0.6169
# AUROC: 0.8422

# %% [markdown]
# ## Seed Experiment 3

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 54:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.9439, Training Accuracy: 7.77%, Training AUROC: 0.5308
# Validation Loss: 1.7373, Validation Accuracy: 12.66%, Validation AUROC: 0.4799
# Epoch [2/100]
# Training Loss: 1.7670, Training Accuracy: 14.84%, Training AUROC: 0.5435
# Validation Loss: 1.6571, Validation Accuracy: 21.52%, Validation AUROC: 0.4720
# Epoch [3/100]
# Training Loss: 1.5730, Training Accuracy: 29.33%, Training AUROC: 0.5734
# Validation Loss: 1.4869, Validation Accuracy: 35.44%, Validation AUROC: 0.5119
# Epoch [4/100]
# Training Loss: 1.4331, Training Accuracy: 37.46%, Training AUROC: 0.6367
# Validation Loss: 1.3806, Validation Accuracy: 44.30%, Validation AUROC: 0.5744
# Epoch [5/100]
# Training Loss: 1.3926, Training Accuracy: 40.28%, Training AUROC: 0.6405
# Validation Loss: 1.3279, Validation Accuracy: 45.57%, Validation AUROC: 0.6141
# Epoch [6/100]
# Training Loss: 1.3662, Training Accuracy: 43.46%, Training AUROC: 0.6624
# Validation Loss: 1.2741, Validation Accuracy: 50.63%, Validation AUROC: 0.6437
# Epoch [7/100]
# Training Loss: 1.3274, Training Accuracy: 45.58%, Training AUROC: 0.6807
# Validation Loss: 1.2456, Validation Accuracy: 51.90%, Validation AUROC: 0.6683
# Epoch [8/100]
# Training Loss: 1.2806, Training Accuracy: 48.41%, Training AUROC: 0.7224
# Validation Loss: 1.1994, Validation Accuracy: 51.90%, Validation AUROC: 0.6883
# Epoch [9/100]
# Training Loss: 1.2390, Training Accuracy: 50.53%, Training AUROC: 0.7528
# Validation Loss: 1.1678, Validation Accuracy: 50.63%, Validation AUROC: 0.6995
# Epoch [10/100]
# Training Loss: 1.1969, Training Accuracy: 53.00%, Training AUROC: 0.7651
# Validation Loss: 1.1501, Validation Accuracy: 53.16%, Validation AUROC: 0.7150
# Epoch [11/100]
# Training Loss: 1.1756, Training Accuracy: 53.36%, Training AUROC: 0.7766
# Validation Loss: 1.1210, Validation Accuracy: 50.63%, Validation AUROC: 0.7200
# Epoch [12/100]
# Training Loss: 1.1444, Training Accuracy: 56.89%, Training AUROC: 0.7907
# Validation Loss: 1.0970, Validation Accuracy: 53.16%, Validation AUROC: 0.7215
# Epoch [13/100]
# Training Loss: 1.1088, Training Accuracy: 56.54%, Training AUROC: 0.8172
# Validation Loss: 1.0934, Validation Accuracy: 54.43%, Validation AUROC: 0.7335
# Epoch [14/100]
# Training Loss: 1.0741, Training Accuracy: 57.95%, Training AUROC: 0.8319
# Validation Loss: 1.0813, Validation Accuracy: 54.43%, Validation AUROC: 0.7395
# Epoch [15/100]
# Training Loss: 1.0593, Training Accuracy: 60.07%, Training AUROC: 0.8429
# Validation Loss: 1.0740, Validation Accuracy: 53.16%, Validation AUROC: 0.7473
# Epoch [16/100]
# Training Loss: 1.0596, Training Accuracy: 59.01%, Training AUROC: 0.8475
# Validation Loss: 1.0691, Validation Accuracy: 53.16%, Validation AUROC: 0.7473
# Epoch [17/100]
# Training Loss: 1.0289, Training Accuracy: 61.13%, Training AUROC: 0.8485
# Validation Loss: 1.0571, Validation Accuracy: 54.43%, Validation AUROC: 0.7518
# Epoch [18/100]
# Training Loss: 0.9675, Training Accuracy: 66.78%, Training AUROC: 0.8841
# Validation Loss: 1.0482, Validation Accuracy: 54.43%, Validation AUROC: 0.7546
# Epoch [19/100]
# Training Loss: 0.9992, Training Accuracy: 61.13%, Training AUROC: 0.8624
# Validation Loss: 1.0461, Validation Accuracy: 55.70%, Validation AUROC: 0.7563
# Epoch [20/100]
# Training Loss: 0.9769, Training Accuracy: 64.31%, Training AUROC: 0.8703
# Validation Loss: 1.0419, Validation Accuracy: 53.16%, Validation AUROC: 0.7595
# Epoch [21/100]
# Training Loss: 0.9723, Training Accuracy: 63.96%, Training AUROC: 0.8792
# Validation Loss: 1.0455, Validation Accuracy: 54.43%, Validation AUROC: 0.7625
# Epoch [22/100]
# Training Loss: 0.9722, Training Accuracy: 63.60%, Training AUROC: 0.8746
# Validation Loss: 1.0504, Validation Accuracy: 54.43%, Validation AUROC: 0.7606
# Epoch [23/100]
# Training Loss: 0.9631, Training Accuracy: 64.66%, Training AUROC: 0.8827
# Validation Loss: 1.0404, Validation Accuracy: 51.90%, Validation AUROC: 0.7728
# Epoch [24/100]
# Training Loss: 0.9362, Training Accuracy: 62.54%, Training AUROC: 0.8904
# Validation Loss: 1.0380, Validation Accuracy: 53.16%, Validation AUROC: 0.7681
# Epoch [25/100]
# Training Loss: 0.9365, Training Accuracy: 64.66%, Training AUROC: 0.8880
# Validation Loss: 1.0360, Validation Accuracy: 51.90%, Validation AUROC: 0.7678
# Epoch [26/100]
# Training Loss: 0.8911, Training Accuracy: 66.08%, Training AUROC: 0.9136
# Validation Loss: 1.0463, Validation Accuracy: 53.16%, Validation AUROC: 0.7704
# Epoch [27/100]
# Training Loss: 0.9028, Training Accuracy: 66.08%, Training AUROC: 0.8955
# Validation Loss: 1.0340, Validation Accuracy: 54.43%, Validation AUROC: 0.7716
# Epoch [28/100]
# Training Loss: 0.8751, Training Accuracy: 65.72%, Training AUROC: 0.9097
# Validation Loss: 1.0388, Validation Accuracy: 50.63%, Validation AUROC: 0.7692
# Epoch [29/100]
# Training Loss: 0.8790, Training Accuracy: 67.84%, Training AUROC: 0.9092
# Validation Loss: 1.0402, Validation Accuracy: 53.16%, Validation AUROC: 0.7712
# Epoch [30/100]
# Training Loss: 0.8691, Training Accuracy: 67.84%, Training AUROC: 0.9064
# Validation Loss: 1.0365, Validation Accuracy: 53.16%, Validation AUROC: 0.7768
# Epoch [31/100]
# Training Loss: 0.8498, Training Accuracy: 68.20%, Training AUROC: 0.9166
# Validation Loss: 1.0327, Validation Accuracy: 53.16%, Validation AUROC: 0.7733
# Epoch [32/100]
# Training Loss: 0.8336, Training Accuracy: 67.84%, Training AUROC: 0.9261
# Validation Loss: 1.0372, Validation Accuracy: 53.16%, Validation AUROC: 0.7771
# Epoch [33/100]
# Training Loss: 0.8474, Training Accuracy: 67.84%, Training AUROC: 0.9179
# Validation Loss: 1.0342, Validation Accuracy: 53.16%, Validation AUROC: 0.7752
# Epoch [34/100]
# Training Loss: 0.8361, Training Accuracy: 67.84%, Training AUROC: 0.9174
# Validation Loss: 1.0420, Validation Accuracy: 54.43%, Validation AUROC: 0.7760
# Epoch [35/100]
# Training Loss: 0.8070, Training Accuracy: 68.20%, Training AUROC: 0.9309
# Validation Loss: 1.0429, Validation Accuracy: 51.90%, Validation AUROC: 0.7779
# Epoch [36/100]
# Training Loss: 0.8355, Training Accuracy: 67.84%, Training AUROC: 0.9173
# Validation Loss: 1.0418, Validation Accuracy: 53.16%, Validation AUROC: 0.7796
# Epoch [37/100]
# Training Loss: 0.8118, Training Accuracy: 67.84%, Training AUROC: 0.9244
# Validation Loss: 1.0399, Validation Accuracy: 53.16%, Validation AUROC: 0.7795
# Epoch [38/100]
# Training Loss: 0.7914, Training Accuracy: 71.38%, Training AUROC: 0.9295
# Validation Loss: 1.0548, Validation Accuracy: 50.63%, Validation AUROC: 0.7799
# Epoch [39/100]
# Training Loss: 0.7678, Training Accuracy: 73.85%, Training AUROC: 0.9369
# Validation Loss: 1.0445, Validation Accuracy: 54.43%, Validation AUROC: 0.7817
# Epoch [40/100]
# Training Loss: 0.8119, Training Accuracy: 68.20%, Training AUROC: 0.9204
# Validation Loss: 1.0478, Validation Accuracy: 53.16%, Validation AUROC: 0.7815
# Epoch [41/100]
# Training Loss: 0.7546, Training Accuracy: 71.38%, Training AUROC: 0.9395
# Validation Loss: 1.0427, Validation Accuracy: 53.16%, Validation AUROC: 0.7781
# Early stopping triggered after 41 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.7818, Training Accuracy: 6.36%, Training AUROC: 0.5816
# Validation Loss: 1.8214, Validation Accuracy: 3.80%, Validation AUROC: 0.5539
# Epoch [2/100]
# Training Loss: 1.7125, Training Accuracy: 15.55%, Training AUROC: 0.5959
# Validation Loss: 1.7401, Validation Accuracy: 13.92%, Validation AUROC: 0.5504
# Epoch [3/100]
# Training Loss: 1.6432, Training Accuracy: 26.15%, Training AUROC: 0.5937
# Validation Loss: 1.6775, Validation Accuracy: 22.78%, Validation AUROC: 0.5328
# Epoch [4/100]
# Training Loss: 1.6147, Training Accuracy: 27.56%, Training AUROC: 0.5873
# Validation Loss: 1.6424, Validation Accuracy: 18.99%, Validation AUROC: 0.5308
# Epoch [5/100]
# Training Loss: 1.5878, Training Accuracy: 26.86%, Training AUROC: 0.6270
# Validation Loss: 1.6224, Validation Accuracy: 17.72%, Validation AUROC: 0.5455
# Epoch [6/100]
# Training Loss: 1.5867, Training Accuracy: 24.73%, Training AUROC: 0.6167
# Validation Loss: 1.6071, Validation Accuracy: 18.99%, Validation AUROC: 0.5689
# Epoch [7/100]
# Training Loss: 1.5497, Training Accuracy: 27.21%, Training AUROC: 0.6774
# Validation Loss: 1.5887, Validation Accuracy: 20.25%, Validation AUROC: 0.5986
# Epoch [8/100]
# Training Loss: 1.5450, Training Accuracy: 25.44%, Training AUROC: 0.6731
# Validation Loss: 1.5741, Validation Accuracy: 21.52%, Validation AUROC: 0.5967
# Epoch [9/100]
# Training Loss: 1.5321, Training Accuracy: 24.73%, Training AUROC: 0.6758
# Validation Loss: 1.5555, Validation Accuracy: 22.78%, Validation AUROC: 0.5995
# Epoch [10/100]
# Training Loss: 1.5059, Training Accuracy: 28.98%, Training AUROC: 0.7255
# Validation Loss: 1.5383, Validation Accuracy: 20.25%, Validation AUROC: 0.6162
# Epoch [11/100]
# Training Loss: 1.4857, Training Accuracy: 26.86%, Training AUROC: 0.7280
# Validation Loss: 1.5243, Validation Accuracy: 20.25%, Validation AUROC: 0.6212
# Epoch [12/100]
# Training Loss: 1.4877, Training Accuracy: 28.62%, Training AUROC: 0.7176
# Validation Loss: 1.5164, Validation Accuracy: 17.72%, Validation AUROC: 0.6221
# Epoch [13/100]
# Training Loss: 1.4599, Training Accuracy: 32.86%, Training AUROC: 0.7377
# Validation Loss: 1.4924, Validation Accuracy: 27.85%, Validation AUROC: 0.6129
# Epoch [14/100]
# Training Loss: 1.4483, Training Accuracy: 32.51%, Training AUROC: 0.7427
# Validation Loss: 1.4852, Validation Accuracy: 26.58%, Validation AUROC: 0.6150
# Epoch [15/100]
# Training Loss: 1.4288, Training Accuracy: 36.40%, Training AUROC: 0.7789
# Validation Loss: 1.4789, Validation Accuracy: 30.38%, Validation AUROC: 0.6271
# Epoch [16/100]
# Training Loss: 1.4122, Training Accuracy: 41.34%, Training AUROC: 0.7753
# Validation Loss: 1.4642, Validation Accuracy: 35.44%, Validation AUROC: 0.6262
# Epoch [17/100]
# Training Loss: 1.3980, Training Accuracy: 42.05%, Training AUROC: 0.7880
# Validation Loss: 1.4650, Validation Accuracy: 34.18%, Validation AUROC: 0.6353
# Epoch [18/100]
# Training Loss: 1.3992, Training Accuracy: 46.64%, Training AUROC: 0.7734
# Validation Loss: 1.4507, Validation Accuracy: 44.30%, Validation AUROC: 0.6334
# Epoch [19/100]
# Training Loss: 1.3774, Training Accuracy: 45.94%, Training AUROC: 0.7972
# Validation Loss: 1.4417, Validation Accuracy: 45.57%, Validation AUROC: 0.6315
# Epoch [20/100]
# Training Loss: 1.3617, Training Accuracy: 48.76%, Training AUROC: 0.8062
# Validation Loss: 1.4397, Validation Accuracy: 46.84%, Validation AUROC: 0.6389
# Epoch [21/100]
# Training Loss: 1.3446, Training Accuracy: 52.30%, Training AUROC: 0.8285
# Validation Loss: 1.4336, Validation Accuracy: 55.70%, Validation AUROC: 0.6401
# Epoch [22/100]
# Training Loss: 1.3488, Training Accuracy: 50.53%, Training AUROC: 0.8226
# Validation Loss: 1.4208, Validation Accuracy: 46.84%, Validation AUROC: 0.6497
# Epoch [23/100]
# Training Loss: 1.3221, Training Accuracy: 54.77%, Training AUROC: 0.8254
# Validation Loss: 1.4111, Validation Accuracy: 54.43%, Validation AUROC: 0.6465
# Epoch [24/100]
# Training Loss: 1.3174, Training Accuracy: 56.89%, Training AUROC: 0.8355
# Validation Loss: 1.4101, Validation Accuracy: 53.16%, Validation AUROC: 0.6533
# Epoch [25/100]
# Training Loss: 1.3195, Training Accuracy: 59.36%, Training AUROC: 0.8240
# Validation Loss: 1.4079, Validation Accuracy: 54.43%, Validation AUROC: 0.6640
# Epoch [26/100]
# Training Loss: 1.3021, Training Accuracy: 51.59%, Training AUROC: 0.8329
# Validation Loss: 1.3863, Validation Accuracy: 54.43%, Validation AUROC: 0.6400
# Epoch [27/100]
# Training Loss: 1.2727, Training Accuracy: 57.95%, Training AUROC: 0.8555
# Validation Loss: 1.3928, Validation Accuracy: 53.16%, Validation AUROC: 0.6736
# Epoch [28/100]
# Training Loss: 1.2739, Training Accuracy: 59.01%, Training AUROC: 0.8475
# Validation Loss: 1.3799, Validation Accuracy: 55.70%, Validation AUROC: 0.6662
# Epoch [29/100]
# Training Loss: 1.2703, Training Accuracy: 58.30%, Training AUROC: 0.8478
# Validation Loss: 1.3838, Validation Accuracy: 50.63%, Validation AUROC: 0.6574
# Epoch [30/100]
# Training Loss: 1.2841, Training Accuracy: 58.30%, Training AUROC: 0.8408
# Validation Loss: 1.3682, Validation Accuracy: 58.23%, Validation AUROC: 0.6645
# Epoch [31/100]
# Training Loss: 1.2276, Training Accuracy: 60.78%, Training AUROC: 0.8620
# Validation Loss: 1.3618, Validation Accuracy: 51.90%, Validation AUROC: 0.6706
# Epoch [32/100]
# Training Loss: 1.2700, Training Accuracy: 58.30%, Training AUROC: 0.8398
# Validation Loss: 1.3621, Validation Accuracy: 55.70%, Validation AUROC: 0.6719
# Epoch [33/100]
# Training Loss: 1.2180, Training Accuracy: 62.19%, Training AUROC: 0.8762
# Validation Loss: 1.3455, Validation Accuracy: 56.96%, Validation AUROC: 0.6657
# Epoch [34/100]
# Training Loss: 1.2192, Training Accuracy: 60.07%, Training AUROC: 0.8640
# Validation Loss: 1.3529, Validation Accuracy: 51.90%, Validation AUROC: 0.6967
# Epoch [35/100]
# Training Loss: 1.2057, Training Accuracy: 60.07%, Training AUROC: 0.8769
# Validation Loss: 1.3388, Validation Accuracy: 55.70%, Validation AUROC: 0.6755
# Epoch [36/100]
# Training Loss: 1.1974, Training Accuracy: 58.30%, Training AUROC: 0.8715
# Validation Loss: 1.3351, Validation Accuracy: 56.96%, Validation AUROC: 0.6752
# Epoch [37/100]
# Training Loss: 1.1758, Training Accuracy: 63.96%, Training AUROC: 0.8902
# Validation Loss: 1.3327, Validation Accuracy: 50.63%, Validation AUROC: 0.6902
# Epoch [38/100]
# Training Loss: 1.1629, Training Accuracy: 65.02%, Training AUROC: 0.8944
# Validation Loss: 1.3186, Validation Accuracy: 55.70%, Validation AUROC: 0.6833
# Epoch [39/100]
# Training Loss: 1.1924, Training Accuracy: 60.42%, Training AUROC: 0.8782
# Validation Loss: 1.3345, Validation Accuracy: 48.10%, Validation AUROC: 0.7014
# Epoch [40/100]
# Training Loss: 1.1569, Training Accuracy: 66.08%, Training AUROC: 0.8932
# Validation Loss: 1.3077, Validation Accuracy: 53.16%, Validation AUROC: 0.6847
# Epoch [41/100]
# Training Loss: 1.1473, Training Accuracy: 63.25%, Training AUROC: 0.8971
# Validation Loss: 1.3059, Validation Accuracy: 55.70%, Validation AUROC: 0.6947
# Epoch [42/100]
# Training Loss: 1.1520, Training Accuracy: 62.19%, Training AUROC: 0.8851
# Validation Loss: 1.3042, Validation Accuracy: 55.70%, Validation AUROC: 0.6948
# Epoch [43/100]
# Training Loss: 1.1405, Training Accuracy: 62.19%, Training AUROC: 0.8887
# Validation Loss: 1.2925, Validation Accuracy: 55.70%, Validation AUROC: 0.6947
# Epoch [44/100]
# Training Loss: 1.1322, Training Accuracy: 66.08%, Training AUROC: 0.8911
# Validation Loss: 1.3010, Validation Accuracy: 55.70%, Validation AUROC: 0.6919
# Epoch [45/100]
# Training Loss: 1.1193, Training Accuracy: 66.08%, Training AUROC: 0.9010
# Validation Loss: 1.2874, Validation Accuracy: 54.43%, Validation AUROC: 0.7098
# Epoch [46/100]
# Training Loss: 1.1092, Training Accuracy: 64.31%, Training AUROC: 0.8999
# Validation Loss: 1.2855, Validation Accuracy: 55.70%, Validation AUROC: 0.6993
# Epoch [47/100]
# Training Loss: 1.0882, Training Accuracy: 66.08%, Training AUROC: 0.9102
# Validation Loss: 1.2818, Validation Accuracy: 55.70%, Validation AUROC: 0.6996
# Epoch [48/100]
# Training Loss: 1.0964, Training Accuracy: 65.72%, Training AUROC: 0.9002
# Validation Loss: 1.2841, Validation Accuracy: 53.16%, Validation AUROC: 0.7110
# Epoch [49/100]
# Training Loss: 1.0931, Training Accuracy: 65.72%, Training AUROC: 0.9032
# Validation Loss: 1.2671, Validation Accuracy: 56.96%, Validation AUROC: 0.7014
# Epoch [50/100]
# Training Loss: 1.0951, Training Accuracy: 65.02%, Training AUROC: 0.8974
# Validation Loss: 1.2711, Validation Accuracy: 53.16%, Validation AUROC: 0.7135
# Epoch [51/100]
# Training Loss: 1.0756, Training Accuracy: 66.43%, Training AUROC: 0.9121
# Validation Loss: 1.2610, Validation Accuracy: 56.96%, Validation AUROC: 0.7049
# Epoch [52/100]
# Training Loss: 1.0555, Training Accuracy: 66.43%, Training AUROC: 0.9125
# Validation Loss: 1.2571, Validation Accuracy: 55.70%, Validation AUROC: 0.7130
# Epoch [53/100]
# Training Loss: 1.0810, Training Accuracy: 67.84%, Training AUROC: 0.8954
# Validation Loss: 1.2548, Validation Accuracy: 56.96%, Validation AUROC: 0.7013
# Epoch [54/100]
# Training Loss: 1.0613, Training Accuracy: 67.49%, Training AUROC: 0.9090
# Validation Loss: 1.2581, Validation Accuracy: 53.16%, Validation AUROC: 0.7221
# Epoch [55/100]
# Training Loss: 1.0541, Training Accuracy: 66.08%, Training AUROC: 0.9092
# Validation Loss: 1.2407, Validation Accuracy: 58.23%, Validation AUROC: 0.7073
# Epoch [56/100]
# Training Loss: 1.0628, Training Accuracy: 66.43%, Training AUROC: 0.9069
# Validation Loss: 1.2442, Validation Accuracy: 55.70%, Validation AUROC: 0.7201
# Epoch [57/100]
# Training Loss: 1.0346, Training Accuracy: 68.20%, Training AUROC: 0.9153
# Validation Loss: 1.2352, Validation Accuracy: 56.96%, Validation AUROC: 0.7039
# Epoch [58/100]
# Training Loss: 1.0295, Training Accuracy: 66.08%, Training AUROC: 0.9192
# Validation Loss: 1.2395, Validation Accuracy: 51.90%, Validation AUROC: 0.7209
# Epoch [59/100]
# Training Loss: 1.0217, Training Accuracy: 72.44%, Training AUROC: 0.9197
# Validation Loss: 1.2284, Validation Accuracy: 55.70%, Validation AUROC: 0.7226
# Epoch [60/100]
# Training Loss: 1.0330, Training Accuracy: 66.43%, Training AUROC: 0.9132
# Validation Loss: 1.2165, Validation Accuracy: 56.96%, Validation AUROC: 0.7229
# Epoch [61/100]
# Training Loss: 1.0215, Training Accuracy: 65.02%, Training AUROC: 0.9164
# Validation Loss: 1.2409, Validation Accuracy: 55.70%, Validation AUROC: 0.7120
# Epoch [62/100]
# Training Loss: 0.9927, Training Accuracy: 72.44%, Training AUROC: 0.9261
# Validation Loss: 1.2150, Validation Accuracy: 54.43%, Validation AUROC: 0.7294
# Epoch [63/100]
# Training Loss: 0.9882, Training Accuracy: 70.32%, Training AUROC: 0.9277
# Validation Loss: 1.2126, Validation Accuracy: 54.43%, Validation AUROC: 0.7282
# Epoch [64/100]
# Training Loss: 0.9849, Training Accuracy: 72.79%, Training AUROC: 0.9239
# Validation Loss: 1.2177, Validation Accuracy: 54.43%, Validation AUROC: 0.7248
# Epoch [65/100]
# Training Loss: 0.9847, Training Accuracy: 72.08%, Training AUROC: 0.9197
# Validation Loss: 1.2123, Validation Accuracy: 56.96%, Validation AUROC: 0.7085
# Epoch [66/100]
# Training Loss: 0.9911, Training Accuracy: 67.84%, Training AUROC: 0.9207
# Validation Loss: 1.2104, Validation Accuracy: 54.43%, Validation AUROC: 0.7577
# Epoch [67/100]
# Training Loss: 1.0075, Training Accuracy: 67.84%, Training AUROC: 0.9136
# Validation Loss: 1.2109, Validation Accuracy: 55.70%, Validation AUROC: 0.7237
# Epoch [68/100]
# Training Loss: 0.9536, Training Accuracy: 74.91%, Training AUROC: 0.9343
# Validation Loss: 1.2025, Validation Accuracy: 55.70%, Validation AUROC: 0.7326
# Epoch [69/100]
# Training Loss: 0.9667, Training Accuracy: 69.96%, Training AUROC: 0.9296
# Validation Loss: 1.1956, Validation Accuracy: 58.23%, Validation AUROC: 0.7216
# Epoch [70/100]
# Training Loss: 0.9590, Training Accuracy: 69.96%, Training AUROC: 0.9252
# Validation Loss: 1.1955, Validation Accuracy: 58.23%, Validation AUROC: 0.7325
# Epoch [71/100]
# Training Loss: 0.9641, Training Accuracy: 69.96%, Training AUROC: 0.9318
# Validation Loss: 1.1938, Validation Accuracy: 55.70%, Validation AUROC: 0.7412
# Epoch [72/100]
# Training Loss: 0.9531, Training Accuracy: 71.38%, Training AUROC: 0.9294
# Validation Loss: 1.1947, Validation Accuracy: 59.49%, Validation AUROC: 0.7260
# Epoch [73/100]
# Training Loss: 0.9330, Training Accuracy: 71.38%, Training AUROC: 0.9355
# Validation Loss: 1.1847, Validation Accuracy: 58.23%, Validation AUROC: 0.7418
# Epoch [74/100]
# Training Loss: 0.9439, Training Accuracy: 72.08%, Training AUROC: 0.9318
# Validation Loss: 1.1907, Validation Accuracy: 55.70%, Validation AUROC: 0.7510
# Epoch [75/100]
# Training Loss: 0.9324, Training Accuracy: 72.79%, Training AUROC: 0.9316
# Validation Loss: 1.1877, Validation Accuracy: 58.23%, Validation AUROC: 0.7193
# Epoch [76/100]
# Training Loss: 0.9295, Training Accuracy: 71.38%, Training AUROC: 0.9320
# Validation Loss: 1.1827, Validation Accuracy: 55.70%, Validation AUROC: 0.7509
# Epoch [77/100]
# Training Loss: 0.9582, Training Accuracy: 69.96%, Training AUROC: 0.9282
# Validation Loss: 1.1780, Validation Accuracy: 58.23%, Validation AUROC: 0.7540
# Epoch [78/100]
# Training Loss: 0.8965, Training Accuracy: 75.62%, Training AUROC: 0.9461
# Validation Loss: 1.1764, Validation Accuracy: 56.96%, Validation AUROC: 0.7490
# Epoch [79/100]
# Training Loss: 0.9158, Training Accuracy: 73.50%, Training AUROC: 0.9398
# Validation Loss: 1.1774, Validation Accuracy: 53.16%, Validation AUROC: 0.7468
# Epoch [80/100]
# Training Loss: 0.9051, Training Accuracy: 77.03%, Training AUROC: 0.9371
# Validation Loss: 1.1800, Validation Accuracy: 59.49%, Validation AUROC: 0.7154
# Epoch [81/100]
# Training Loss: 0.8977, Training Accuracy: 74.91%, Training AUROC: 0.9335
# Validation Loss: 1.1722, Validation Accuracy: 54.43%, Validation AUROC: 0.7338
# Epoch [82/100]
# Training Loss: 0.9193, Training Accuracy: 72.44%, Training AUROC: 0.9349
# Validation Loss: 1.1770, Validation Accuracy: 55.70%, Validation AUROC: 0.7324
# Epoch [83/100]
# Training Loss: 0.8838, Training Accuracy: 74.91%, Training AUROC: 0.9427
# Validation Loss: 1.1699, Validation Accuracy: 55.70%, Validation AUROC: 0.7504
# Epoch [84/100]
# Training Loss: 0.8704, Training Accuracy: 76.68%, Training AUROC: 0.9467
# Validation Loss: 1.1693, Validation Accuracy: 59.49%, Validation AUROC: 0.7355
# Epoch [85/100]
# Training Loss: 0.8801, Training Accuracy: 74.56%, Training AUROC: 0.9423
# Validation Loss: 1.1722, Validation Accuracy: 55.70%, Validation AUROC: 0.7522
# Epoch [86/100]
# Training Loss: 0.8795, Training Accuracy: 75.62%, Training AUROC: 0.9418
# Validation Loss: 1.1606, Validation Accuracy: 55.70%, Validation AUROC: 0.7563
# Epoch [87/100]
# Training Loss: 0.9002, Training Accuracy: 68.20%, Training AUROC: 0.9357
# Validation Loss: 1.1614, Validation Accuracy: 58.23%, Validation AUROC: 0.7426
# Epoch [88/100]
# Training Loss: 0.8539, Training Accuracy: 77.74%, Training AUROC: 0.9430
# Validation Loss: 1.1569, Validation Accuracy: 56.96%, Validation AUROC: 0.7499
# Epoch [89/100]
# Training Loss: 0.8448, Training Accuracy: 75.97%, Training AUROC: 0.9522
# Validation Loss: 1.1582, Validation Accuracy: 59.49%, Validation AUROC: 0.7477
# Epoch [90/100]
# Training Loss: 0.8457, Training Accuracy: 78.80%, Training AUROC: 0.9460
# Validation Loss: 1.1562, Validation Accuracy: 58.23%, Validation AUROC: 0.7452
# Epoch [91/100]
# Training Loss: 0.8701, Training Accuracy: 73.14%, Training AUROC: 0.9408
# Validation Loss: 1.1614, Validation Accuracy: 58.23%, Validation AUROC: 0.7506
# Epoch [92/100]
# Training Loss: 0.8396, Training Accuracy: 77.03%, Training AUROC: 0.9512
# Validation Loss: 1.1542, Validation Accuracy: 59.49%, Validation AUROC: 0.7402
# Epoch [93/100]
# Training Loss: 0.8129, Training Accuracy: 77.39%, Training AUROC: 0.9558
# Validation Loss: 1.1631, Validation Accuracy: 59.49%, Validation AUROC: 0.7360
# Epoch [94/100]
# Training Loss: 0.8091, Training Accuracy: 80.57%, Training AUROC: 0.9587
# Validation Loss: 1.1547, Validation Accuracy: 56.96%, Validation AUROC: 0.7513
# Epoch [95/100]
# Training Loss: 0.8540, Training Accuracy: 76.33%, Training AUROC: 0.9431
# Validation Loss: 1.1649, Validation Accuracy: 54.43%, Validation AUROC: 0.7322
# Epoch [96/100]
# Training Loss: 0.8297, Training Accuracy: 77.03%, Training AUROC: 0.9476
# Validation Loss: 1.1523, Validation Accuracy: 59.49%, Validation AUROC: 0.7450
# Epoch [97/100]
# Training Loss: 0.8185, Training Accuracy: 78.80%, Training AUROC: 0.9564
# Validation Loss: 1.1532, Validation Accuracy: 56.96%, Validation AUROC: 0.7534
# Epoch [98/100]
# Training Loss: 0.7979, Training Accuracy: 79.86%, Training AUROC: 0.9553
# Validation Loss: 1.1546, Validation Accuracy: 59.49%, Validation AUROC: 0.7406
# Epoch [99/100]
# Training Loss: 0.8945, Training Accuracy: 71.73%, Training AUROC: 0.9291
# Validation Loss: 1.1527, Validation Accuracy: 58.23%, Validation AUROC: 0.7565
# Epoch [100/100]
# Training Loss: 0.8045, Training Accuracy: 80.57%, Training AUROC: 0.9538
# Validation Loss: 1.1511, Validation Accuracy: 55.70%, Validation AUROC: 0.7478

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.5779
# F1 Score: 0.5574
# Precision: 0.5960
# Recall: 0.5779
# AUROC: 0.7957
#
# Normal Model Metrics:
# Accuracy: 0.6104
# F1 Score: 0.5960
# Precision: 0.5924
# Recall: 0.6104
# AUROC: 0.8163

# %% [markdown]
# ## Seed Experiment 4

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 18:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.8070, Training Accuracy: 13.43%, Training AUROC: 0.5005
# Validation Loss: 1.7814, Validation Accuracy: 21.52%, Validation AUROC: 0.5918
# Epoch [2/100]
# Training Loss: 1.6632, Training Accuracy: 24.73%, Training AUROC: 0.5099
# Validation Loss: 1.5179, Validation Accuracy: 32.91%, Validation AUROC: 0.6304
# Epoch [3/100]
# Training Loss: 1.5286, Training Accuracy: 30.74%, Training AUROC: 0.5261
# Validation Loss: 1.3636, Validation Accuracy: 45.57%, Validation AUROC: 0.6590
# Epoch [4/100]
# Training Loss: 1.4487, Training Accuracy: 38.52%, Training AUROC: 0.5718
# Validation Loss: 1.3044, Validation Accuracy: 49.37%, Validation AUROC: 0.6806
# Epoch [5/100]
# Training Loss: 1.4311, Training Accuracy: 39.22%, Training AUROC: 0.5982
# Validation Loss: 1.2652, Validation Accuracy: 50.63%, Validation AUROC: 0.7056
# Epoch [6/100]
# Training Loss: 1.3901, Training Accuracy: 39.22%, Training AUROC: 0.6515
# Validation Loss: 1.2356, Validation Accuracy: 53.16%, Validation AUROC: 0.7284
# Epoch [7/100]
# Training Loss: 1.3597, Training Accuracy: 43.82%, Training AUROC: 0.6646
# Validation Loss: 1.2125, Validation Accuracy: 53.16%, Validation AUROC: 0.7505
# Epoch [8/100]
# Training Loss: 1.3174, Training Accuracy: 44.17%, Training AUROC: 0.7047
# Validation Loss: 1.1662, Validation Accuracy: 54.43%, Validation AUROC: 0.7836
# Epoch [9/100]
# Training Loss: 1.2754, Training Accuracy: 49.47%, Training AUROC: 0.7312
# Validation Loss: 1.1365, Validation Accuracy: 55.70%, Validation AUROC: 0.7918
# Epoch [10/100]
# Training Loss: 1.2091, Training Accuracy: 50.53%, Training AUROC: 0.7827
# Validation Loss: 1.1009, Validation Accuracy: 54.43%, Validation AUROC: 0.8072
# Epoch [11/100]
# Training Loss: 1.1742, Training Accuracy: 53.00%, Training AUROC: 0.8144
# Validation Loss: 1.0781, Validation Accuracy: 56.96%, Validation AUROC: 0.8145
# Epoch [12/100]
# Training Loss: 1.1763, Training Accuracy: 54.06%, Training AUROC: 0.8068
# Validation Loss: 1.0766, Validation Accuracy: 55.70%, Validation AUROC: 0.8134
# Epoch [13/100]
# Training Loss: 1.1337, Training Accuracy: 50.88%, Training AUROC: 0.8215
# Validation Loss: 1.0413, Validation Accuracy: 56.96%, Validation AUROC: 0.8186
# Epoch [14/100]
# Training Loss: 1.1034, Training Accuracy: 55.48%, Training AUROC: 0.8275
# Validation Loss: 1.0452, Validation Accuracy: 55.70%, Validation AUROC: 0.8214
# Epoch [15/100]
# Training Loss: 1.0715, Training Accuracy: 58.66%, Training AUROC: 0.8555
# Validation Loss: 1.0324, Validation Accuracy: 53.16%, Validation AUROC: 0.8158
# Epoch [16/100]
# Training Loss: 1.0518, Training Accuracy: 60.07%, Training AUROC: 0.8583
# Validation Loss: 1.0234, Validation Accuracy: 55.70%, Validation AUROC: 0.8215
# Epoch [17/100]
# Training Loss: 1.0281, Training Accuracy: 59.72%, Training AUROC: 0.8689
# Validation Loss: 1.0209, Validation Accuracy: 54.43%, Validation AUROC: 0.8202
# Epoch [18/100]
# Training Loss: 1.0022, Training Accuracy: 62.19%, Training AUROC: 0.8701
# Validation Loss: 1.0189, Validation Accuracy: 51.90%, Validation AUROC: 0.8138
# Epoch [19/100]
# Training Loss: 0.9878, Training Accuracy: 61.48%, Training AUROC: 0.8778
# Validation Loss: 1.0167, Validation Accuracy: 54.43%, Validation AUROC: 0.8201
# Epoch [20/100]
# Training Loss: 0.9759, Training Accuracy: 65.37%, Training AUROC: 0.8862
# Validation Loss: 1.0095, Validation Accuracy: 54.43%, Validation AUROC: 0.8225
# Epoch [21/100]
# Training Loss: 0.9679, Training Accuracy: 65.37%, Training AUROC: 0.8913
# Validation Loss: 1.0006, Validation Accuracy: 53.16%, Validation AUROC: 0.8195
# Epoch [22/100]
# Training Loss: 0.9481, Training Accuracy: 65.02%, Training AUROC: 0.8884
# Validation Loss: 1.0114, Validation Accuracy: 55.70%, Validation AUROC: 0.8174
# Epoch [23/100]
# Training Loss: 0.9359, Training Accuracy: 65.37%, Training AUROC: 0.8969
# Validation Loss: 1.0006, Validation Accuracy: 53.16%, Validation AUROC: 0.8185
# Epoch [24/100]
# Training Loss: 0.9069, Training Accuracy: 66.78%, Training AUROC: 0.9035
# Validation Loss: 1.0081, Validation Accuracy: 53.16%, Validation AUROC: 0.8150
# Epoch [25/100]
# Training Loss: 0.9047, Training Accuracy: 67.14%, Training AUROC: 0.9057
# Validation Loss: 1.0034, Validation Accuracy: 53.16%, Validation AUROC: 0.8149
# Epoch [26/100]
# Training Loss: 0.8856, Training Accuracy: 67.84%, Training AUROC: 0.9135
# Validation Loss: 1.0026, Validation Accuracy: 53.16%, Validation AUROC: 0.8169
# Epoch [27/100]
# Training Loss: 0.9120, Training Accuracy: 66.78%, Training AUROC: 0.8951
# Validation Loss: 1.0050, Validation Accuracy: 53.16%, Validation AUROC: 0.8142
# Epoch [28/100]
# Training Loss: 0.9019, Training Accuracy: 66.78%, Training AUROC: 0.8960
# Validation Loss: 1.0086, Validation Accuracy: 53.16%, Validation AUROC: 0.8116
# Epoch [29/100]
# Training Loss: 0.8621, Training Accuracy: 67.49%, Training AUROC: 0.9109
# Validation Loss: 1.0147, Validation Accuracy: 51.90%, Validation AUROC: 0.8150
# Epoch [30/100]
# Training Loss: 0.8938, Training Accuracy: 65.37%, Training AUROC: 0.9059
# Validation Loss: 1.0075, Validation Accuracy: 53.16%, Validation AUROC: 0.8139
# Epoch [31/100]
# Training Loss: 0.8775, Training Accuracy: 66.78%, Training AUROC: 0.9036
# Validation Loss: 1.0100, Validation Accuracy: 55.70%, Validation AUROC: 0.8093
# Epoch [32/100]
# Training Loss: 0.8533, Training Accuracy: 66.08%, Training AUROC: 0.9132
# Validation Loss: 1.0164, Validation Accuracy: 50.63%, Validation AUROC: 0.8148
# Epoch [33/100]
# Training Loss: 0.8269, Training Accuracy: 67.84%, Training AUROC: 0.9223
# Validation Loss: 1.0072, Validation Accuracy: 53.16%, Validation AUROC: 0.8140
# Early stopping triggered after 33 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.7743, Training Accuracy: 14.13%, Training AUROC: 0.5292
# Validation Loss: 1.7828, Validation Accuracy: 15.19%, Validation AUROC: 0.4960
# Epoch [2/100]
# Training Loss: 1.6740, Training Accuracy: 19.79%, Training AUROC: 0.5104
# Validation Loss: 1.6015, Validation Accuracy: 30.38%, Validation AUROC: 0.4768
# Epoch [3/100]
# Training Loss: 1.5492, Training Accuracy: 30.04%, Training AUROC: 0.5465
# Validation Loss: 1.4493, Validation Accuracy: 39.24%, Validation AUROC: 0.4850
# Epoch [4/100]
# Training Loss: 1.4825, Training Accuracy: 32.86%, Training AUROC: 0.5605
# Validation Loss: 1.4004, Validation Accuracy: 43.04%, Validation AUROC: 0.5177
# Epoch [5/100]
# Training Loss: 1.4669, Training Accuracy: 34.63%, Training AUROC: 0.5773
# Validation Loss: 1.3856, Validation Accuracy: 39.24%, Validation AUROC: 0.5546
# Epoch [6/100]
# Training Loss: 1.4490, Training Accuracy: 33.92%, Training AUROC: 0.6300
# Validation Loss: 1.3758, Validation Accuracy: 40.51%, Validation AUROC: 0.5769
# Epoch [7/100]
# Training Loss: 1.4347, Training Accuracy: 34.28%, Training AUROC: 0.6590
# Validation Loss: 1.3630, Validation Accuracy: 43.04%, Validation AUROC: 0.5994
# Epoch [8/100]
# Training Loss: 1.4087, Training Accuracy: 37.10%, Training AUROC: 0.6899
# Validation Loss: 1.3443, Validation Accuracy: 45.57%, Validation AUROC: 0.6144
# Epoch [9/100]
# Training Loss: 1.4048, Training Accuracy: 40.99%, Training AUROC: 0.6610
# Validation Loss: 1.3357, Validation Accuracy: 49.37%, Validation AUROC: 0.6199
# Epoch [10/100]
# Training Loss: 1.3806, Training Accuracy: 40.28%, Training AUROC: 0.7066
# Validation Loss: 1.3142, Validation Accuracy: 48.10%, Validation AUROC: 0.6455
# Epoch [11/100]
# Training Loss: 1.3644, Training Accuracy: 40.99%, Training AUROC: 0.7100
# Validation Loss: 1.3049, Validation Accuracy: 49.37%, Validation AUROC: 0.6450
# Epoch [12/100]
# Training Loss: 1.3548, Training Accuracy: 45.23%, Training AUROC: 0.7152
# Validation Loss: 1.2957, Validation Accuracy: 48.10%, Validation AUROC: 0.6549
# Epoch [13/100]
# Training Loss: 1.3424, Training Accuracy: 44.88%, Training AUROC: 0.7387
# Validation Loss: 1.2890, Validation Accuracy: 51.90%, Validation AUROC: 0.6529
# Epoch [14/100]
# Training Loss: 1.3381, Training Accuracy: 48.06%, Training AUROC: 0.7338
# Validation Loss: 1.2799, Validation Accuracy: 50.63%, Validation AUROC: 0.6604
# Epoch [15/100]
# Training Loss: 1.3264, Training Accuracy: 47.00%, Training AUROC: 0.7649
# Validation Loss: 1.2727, Validation Accuracy: 50.63%, Validation AUROC: 0.6670
# Epoch [16/100]
# Training Loss: 1.3160, Training Accuracy: 46.64%, Training AUROC: 0.7592
# Validation Loss: 1.2681, Validation Accuracy: 50.63%, Validation AUROC: 0.6751
# Epoch [17/100]
# Training Loss: 1.3061, Training Accuracy: 49.12%, Training AUROC: 0.7743
# Validation Loss: 1.2643, Validation Accuracy: 51.90%, Validation AUROC: 0.6790
# Epoch [18/100]
# Training Loss: 1.2948, Training Accuracy: 47.70%, Training AUROC: 0.7731
# Validation Loss: 1.2567, Validation Accuracy: 51.90%, Validation AUROC: 0.6753
# Epoch [19/100]
# Training Loss: 1.2973, Training Accuracy: 49.12%, Training AUROC: 0.7733
# Validation Loss: 1.2518, Validation Accuracy: 54.43%, Validation AUROC: 0.6564
# Epoch [20/100]
# Training Loss: 1.2830, Training Accuracy: 49.82%, Training AUROC: 0.7748
# Validation Loss: 1.2476, Validation Accuracy: 53.16%, Validation AUROC: 0.6754
# Epoch [21/100]
# Training Loss: 1.2685, Training Accuracy: 51.94%, Training AUROC: 0.7910
# Validation Loss: 1.2424, Validation Accuracy: 50.63%, Validation AUROC: 0.6627
# Epoch [22/100]
# Training Loss: 1.2594, Training Accuracy: 53.36%, Training AUROC: 0.8000
# Validation Loss: 1.2391, Validation Accuracy: 51.90%, Validation AUROC: 0.6527
# Epoch [23/100]
# Training Loss: 1.2556, Training Accuracy: 51.94%, Training AUROC: 0.7928
# Validation Loss: 1.2315, Validation Accuracy: 51.90%, Validation AUROC: 0.6545
# Epoch [24/100]
# Training Loss: 1.2640, Training Accuracy: 50.18%, Training AUROC: 0.7976
# Validation Loss: 1.2252, Validation Accuracy: 53.16%, Validation AUROC: 0.6549
# Epoch [25/100]
# Training Loss: 1.2463, Training Accuracy: 54.42%, Training AUROC: 0.7965
# Validation Loss: 1.2236, Validation Accuracy: 51.90%, Validation AUROC: 0.6704
# Epoch [26/100]
# Training Loss: 1.2287, Training Accuracy: 54.06%, Training AUROC: 0.8061
# Validation Loss: 1.2193, Validation Accuracy: 55.70%, Validation AUROC: 0.6419
# Epoch [27/100]
# Training Loss: 1.2097, Training Accuracy: 58.30%, Training AUROC: 0.8351
# Validation Loss: 1.2271, Validation Accuracy: 53.16%, Validation AUROC: 0.6587
# Epoch [28/100]
# Training Loss: 1.2129, Training Accuracy: 55.12%, Training AUROC: 0.8062
# Validation Loss: 1.2155, Validation Accuracy: 51.90%, Validation AUROC: 0.6546
# Epoch [29/100]
# Training Loss: 1.1987, Training Accuracy: 57.24%, Training AUROC: 0.8263
# Validation Loss: 1.2159, Validation Accuracy: 54.43%, Validation AUROC: 0.6507
# Epoch [30/100]
# Training Loss: 1.2022, Training Accuracy: 58.66%, Training AUROC: 0.8227
# Validation Loss: 1.2079, Validation Accuracy: 53.16%, Validation AUROC: 0.6479
# Epoch [31/100]
# Training Loss: 1.1816, Training Accuracy: 57.60%, Training AUROC: 0.8351
# Validation Loss: 1.2135, Validation Accuracy: 53.16%, Validation AUROC: 0.6499
# Epoch [32/100]
# Training Loss: 1.1819, Training Accuracy: 60.07%, Training AUROC: 0.8388
# Validation Loss: 1.2057, Validation Accuracy: 53.16%, Validation AUROC: 0.6522
# Epoch [33/100]
# Training Loss: 1.1689, Training Accuracy: 57.95%, Training AUROC: 0.8227
# Validation Loss: 1.1997, Validation Accuracy: 54.43%, Validation AUROC: 0.6502
# Epoch [34/100]
# Training Loss: 1.1651, Training Accuracy: 59.72%, Training AUROC: 0.8312
# Validation Loss: 1.2039, Validation Accuracy: 54.43%, Validation AUROC: 0.6487
# Epoch [35/100]
# Training Loss: 1.1710, Training Accuracy: 57.60%, Training AUROC: 0.8336
# Validation Loss: 1.1946, Validation Accuracy: 54.43%, Validation AUROC: 0.6538
# Epoch [36/100]
# Training Loss: 1.1421, Training Accuracy: 59.72%, Training AUROC: 0.8420
# Validation Loss: 1.2218, Validation Accuracy: 50.63%, Validation AUROC: 0.6489
# Epoch [37/100]
# Training Loss: 1.1443, Training Accuracy: 63.60%, Training AUROC: 0.8451
# Validation Loss: 1.1939, Validation Accuracy: 51.90%, Validation AUROC: 0.6536
# Epoch [38/100]
# Training Loss: 1.1167, Training Accuracy: 62.90%, Training AUROC: 0.8570
# Validation Loss: 1.1978, Validation Accuracy: 50.63%, Validation AUROC: 0.6637
# Epoch [39/100]
# Training Loss: 1.1036, Training Accuracy: 66.43%, Training AUROC: 0.8616
# Validation Loss: 1.1955, Validation Accuracy: 53.16%, Validation AUROC: 0.6560
# Epoch [40/100]
# Training Loss: 1.0904, Training Accuracy: 67.49%, Training AUROC: 0.8631
# Validation Loss: 1.2014, Validation Accuracy: 54.43%, Validation AUROC: 0.6526
# Epoch [41/100]
# Training Loss: 1.0903, Training Accuracy: 68.90%, Training AUROC: 0.8607
# Validation Loss: 1.1989, Validation Accuracy: 51.90%, Validation AUROC: 0.6718
# Epoch [42/100]
# Training Loss: 1.0931, Training Accuracy: 65.72%, Training AUROC: 0.8599
# Validation Loss: 1.1855, Validation Accuracy: 54.43%, Validation AUROC: 0.6567
# Epoch [43/100]
# Training Loss: 1.0769, Training Accuracy: 65.72%, Training AUROC: 0.8649
# Validation Loss: 1.2032, Validation Accuracy: 53.16%, Validation AUROC: 0.6569
# Epoch [44/100]
# Training Loss: 1.0717, Training Accuracy: 68.20%, Training AUROC: 0.8640
# Validation Loss: 1.1926, Validation Accuracy: 54.43%, Validation AUROC: 0.6552
# Epoch [45/100]
# Training Loss: 1.0565, Training Accuracy: 70.67%, Training AUROC: 0.8709
# Validation Loss: 1.1985, Validation Accuracy: 51.90%, Validation AUROC: 0.6673
# Epoch [46/100]
# Training Loss: 1.0549, Training Accuracy: 67.14%, Training AUROC: 0.8691
# Validation Loss: 1.1836, Validation Accuracy: 49.37%, Validation AUROC: 0.6511
# Epoch [47/100]
# Training Loss: 1.0655, Training Accuracy: 67.84%, Training AUROC: 0.8596
# Validation Loss: 1.2004, Validation Accuracy: 55.70%, Validation AUROC: 0.6464
# Epoch [48/100]
# Training Loss: 1.0370, Training Accuracy: 70.67%, Training AUROC: 0.8800
# Validation Loss: 1.1795, Validation Accuracy: 50.63%, Validation AUROC: 0.6833
# Epoch [49/100]
# Training Loss: 1.0150, Training Accuracy: 70.32%, Training AUROC: 0.9035
# Validation Loss: 1.1941, Validation Accuracy: 53.16%, Validation AUROC: 0.6639
# Epoch [50/100]
# Training Loss: 1.0210, Training Accuracy: 70.67%, Training AUROC: 0.8850
# Validation Loss: 1.1714, Validation Accuracy: 54.43%, Validation AUROC: 0.6583
# Epoch [51/100]
# Training Loss: 1.0264, Training Accuracy: 71.02%, Training AUROC: 0.8783
# Validation Loss: 1.1708, Validation Accuracy: 54.43%, Validation AUROC: 0.6842
# Epoch [52/100]
# Training Loss: 1.0055, Training Accuracy: 73.50%, Training AUROC: 0.8946
# Validation Loss: 1.1776, Validation Accuracy: 53.16%, Validation AUROC: 0.6584
# Epoch [53/100]
# Training Loss: 0.9954, Training Accuracy: 71.38%, Training AUROC: 0.9049
# Validation Loss: 1.1673, Validation Accuracy: 55.70%, Validation AUROC: 0.6853
# Epoch [54/100]
# Training Loss: 0.9947, Training Accuracy: 72.44%, Training AUROC: 0.9067
# Validation Loss: 1.1685, Validation Accuracy: 54.43%, Validation AUROC: 0.6591
# Epoch [55/100]
# Training Loss: 0.9978, Training Accuracy: 72.79%, Training AUROC: 0.8962
# Validation Loss: 1.1751, Validation Accuracy: 54.43%, Validation AUROC: 0.6902
# Epoch [56/100]
# Training Loss: 0.9958, Training Accuracy: 71.38%, Training AUROC: 0.8860
# Validation Loss: 1.1684, Validation Accuracy: 54.43%, Validation AUROC: 0.6612
# Epoch [57/100]
# Training Loss: 0.9869, Training Accuracy: 71.38%, Training AUROC: 0.8963
# Validation Loss: 1.1657, Validation Accuracy: 55.70%, Validation AUROC: 0.6761
# Epoch [58/100]
# Training Loss: 0.9841, Training Accuracy: 73.50%, Training AUROC: 0.8976
# Validation Loss: 1.1691, Validation Accuracy: 53.16%, Validation AUROC: 0.6838
# Epoch [59/100]
# Training Loss: 0.9732, Training Accuracy: 72.44%, Training AUROC: 0.8969
# Validation Loss: 1.1559, Validation Accuracy: 53.16%, Validation AUROC: 0.6852
# Epoch [60/100]
# Training Loss: 0.9588, Training Accuracy: 72.08%, Training AUROC: 0.9021
# Validation Loss: 1.1693, Validation Accuracy: 55.70%, Validation AUROC: 0.6684
# Epoch [61/100]
# Training Loss: 0.9260, Training Accuracy: 73.50%, Training AUROC: 0.9194
# Validation Loss: 1.1490, Validation Accuracy: 55.70%, Validation AUROC: 0.6821
# Epoch [62/100]
# Training Loss: 0.9302, Training Accuracy: 74.56%, Training AUROC: 0.9162
# Validation Loss: 1.1586, Validation Accuracy: 55.70%, Validation AUROC: 0.6701
# Epoch [63/100]
# Training Loss: 0.9455, Training Accuracy: 75.27%, Training AUROC: 0.9164
# Validation Loss: 1.1502, Validation Accuracy: 55.70%, Validation AUROC: 0.6800
# Epoch [64/100]
# Training Loss: 0.9244, Training Accuracy: 71.73%, Training AUROC: 0.9230
# Validation Loss: 1.1566, Validation Accuracy: 53.16%, Validation AUROC: 0.6925
# Epoch [65/100]
# Training Loss: 0.9436, Training Accuracy: 74.20%, Training AUROC: 0.9176
# Validation Loss: 1.1462, Validation Accuracy: 56.96%, Validation AUROC: 0.6814
# Epoch [66/100]
# Training Loss: 0.9314, Training Accuracy: 74.20%, Training AUROC: 0.9147
# Validation Loss: 1.1477, Validation Accuracy: 55.70%, Validation AUROC: 0.6942
# Epoch [67/100]
# Training Loss: 0.9074, Training Accuracy: 75.97%, Training AUROC: 0.9314
# Validation Loss: 1.1565, Validation Accuracy: 55.70%, Validation AUROC: 0.6791
# Epoch [68/100]
# Training Loss: 0.9268, Training Accuracy: 73.50%, Training AUROC: 0.9029
# Validation Loss: 1.1441, Validation Accuracy: 54.43%, Validation AUROC: 0.6708
# Epoch [69/100]
# Training Loss: 0.8921, Training Accuracy: 75.62%, Training AUROC: 0.9319
# Validation Loss: 1.1528, Validation Accuracy: 53.16%, Validation AUROC: 0.6880
# Epoch [70/100]
# Training Loss: 0.9036, Training Accuracy: 74.20%, Training AUROC: 0.9288
# Validation Loss: 1.1447, Validation Accuracy: 55.70%, Validation AUROC: 0.6761
# Epoch [71/100]
# Training Loss: 0.9072, Training Accuracy: 74.20%, Training AUROC: 0.9292
# Validation Loss: 1.1414, Validation Accuracy: 55.70%, Validation AUROC: 0.6767
# Epoch [72/100]
# Training Loss: 0.9042, Training Accuracy: 74.91%, Training AUROC: 0.9246
# Validation Loss: 1.1567, Validation Accuracy: 53.16%, Validation AUROC: 0.6905
# Epoch [73/100]
# Training Loss: 0.8723, Training Accuracy: 77.39%, Training AUROC: 0.9350
# Validation Loss: 1.1395, Validation Accuracy: 54.43%, Validation AUROC: 0.6763
# Epoch [74/100]
# Training Loss: 0.8722, Training Accuracy: 77.03%, Training AUROC: 0.9348
# Validation Loss: 1.1351, Validation Accuracy: 55.70%, Validation AUROC: 0.6841
# Epoch [75/100]
# Training Loss: 0.8894, Training Accuracy: 75.27%, Training AUROC: 0.9259
# Validation Loss: 1.1452, Validation Accuracy: 56.96%, Validation AUROC: 0.6917
# Epoch [76/100]
# Training Loss: 0.8982, Training Accuracy: 72.44%, Training AUROC: 0.9220
# Validation Loss: 1.1241, Validation Accuracy: 59.49%, Validation AUROC: 0.6880
# Epoch [77/100]
# Training Loss: 0.8491, Training Accuracy: 75.97%, Training AUROC: 0.9378
# Validation Loss: 1.1410, Validation Accuracy: 55.70%, Validation AUROC: 0.6957
# Epoch [78/100]
# Training Loss: 0.8451, Training Accuracy: 78.45%, Training AUROC: 0.9469
# Validation Loss: 1.1347, Validation Accuracy: 55.70%, Validation AUROC: 0.6848
# Epoch [79/100]
# Training Loss: 0.8505, Training Accuracy: 77.39%, Training AUROC: 0.9417
# Validation Loss: 1.1436, Validation Accuracy: 56.96%, Validation AUROC: 0.6863
# Epoch [80/100]
# Training Loss: 0.8467, Training Accuracy: 77.39%, Training AUROC: 0.9421
# Validation Loss: 1.1279, Validation Accuracy: 58.23%, Validation AUROC: 0.6888
# Epoch [81/100]
# Training Loss: 0.8235, Training Accuracy: 80.92%, Training AUROC: 0.9490
# Validation Loss: 1.1391, Validation Accuracy: 54.43%, Validation AUROC: 0.6935
# Epoch [82/100]
# Training Loss: 0.8254, Training Accuracy: 78.45%, Training AUROC: 0.9539
# Validation Loss: 1.1329, Validation Accuracy: 55.70%, Validation AUROC: 0.6926
# Epoch [83/100]
# Training Loss: 0.8112, Training Accuracy: 77.03%, Training AUROC: 0.9568
# Validation Loss: 1.1328, Validation Accuracy: 55.70%, Validation AUROC: 0.6922
# Epoch [84/100]
# Training Loss: 0.8339, Training Accuracy: 77.03%, Training AUROC: 0.9491
# Validation Loss: 1.1370, Validation Accuracy: 54.43%, Validation AUROC: 0.6877
# Epoch [85/100]
# Training Loss: 0.7915, Training Accuracy: 82.33%, Training AUROC: 0.9568
# Validation Loss: 1.1431, Validation Accuracy: 55.70%, Validation AUROC: 0.6765
# Epoch [86/100]
# Training Loss: 0.8249, Training Accuracy: 77.03%, Training AUROC: 0.9471
# Validation Loss: 1.1310, Validation Accuracy: 53.16%, Validation AUROC: 0.6948
# Early stopping triggered after 86 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.5909
# F1 Score: 0.5746
# Precision: 0.5678
# Recall: 0.5909
# AUROC: 0.7634
#
# Normal Model Metrics:
# Accuracy: 0.5844
# F1 Score: 0.5556
# Precision: 0.5484
# Recall: 0.5844
# AUROC: 0.8133

# %% [markdown]
# ## Seed Experiment 5

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
model = NormalModel(freeze=True, num_classes=5)
hybrid_model = QuantumHybridModel(q_depth=4, freeze=True, num_classes=5)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 12:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 223MB/s]

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.6513, Training Accuracy: 19.08%, Training AUROC: 0.4914
# Validation Loss: 1.5654, Validation Accuracy: 27.85%, Validation AUROC: 0.5617
# Epoch [2/100]
# Training Loss: 1.5822, Training Accuracy: 21.91%, Training AUROC: 0.4961
# Validation Loss: 1.4261, Validation Accuracy: 41.77%, Validation AUROC: 0.5958
# Epoch [3/100]
# Training Loss: 1.5182, Training Accuracy: 26.15%, Training AUROC: 0.4956
# Validation Loss: 1.3510, Validation Accuracy: 44.30%, Validation AUROC: 0.6162
# Epoch [4/100]
# Training Loss: 1.4565, Training Accuracy: 29.68%, Training AUROC: 0.5492
# Validation Loss: 1.3103, Validation Accuracy: 44.30%, Validation AUROC: 0.6390
# Epoch [5/100]
# Training Loss: 1.4135, Training Accuracy: 37.10%, Training AUROC: 0.6060
# Validation Loss: 1.2705, Validation Accuracy: 49.37%, Validation AUROC: 0.6757
# Epoch [6/100]
# Training Loss: 1.3746, Training Accuracy: 38.87%, Training AUROC: 0.6488
# Validation Loss: 1.2223, Validation Accuracy: 54.43%, Validation AUROC: 0.7073
# Epoch [7/100]
# Training Loss: 1.3289, Training Accuracy: 44.88%, Training AUROC: 0.6793
# Validation Loss: 1.1800, Validation Accuracy: 51.90%, Validation AUROC: 0.7259
# Epoch [8/100]
# Training Loss: 1.2801, Training Accuracy: 48.41%, Training AUROC: 0.7125
# Validation Loss: 1.1515, Validation Accuracy: 51.90%, Validation AUROC: 0.7383
# Epoch [9/100]
# Training Loss: 1.2210, Training Accuracy: 52.30%, Training AUROC: 0.7634
# Validation Loss: 1.1192, Validation Accuracy: 53.16%, Validation AUROC: 0.7539
# Epoch [10/100]
# Training Loss: 1.1924, Training Accuracy: 53.71%, Training AUROC: 0.7670
# Validation Loss: 1.0956, Validation Accuracy: 51.90%, Validation AUROC: 0.7742
# Epoch [11/100]
# Training Loss: 1.1583, Training Accuracy: 53.71%, Training AUROC: 0.7972
# Validation Loss: 1.0675, Validation Accuracy: 53.16%, Validation AUROC: 0.7841
# Epoch [12/100]
# Training Loss: 1.1271, Training Accuracy: 55.48%, Training AUROC: 0.8190
# Validation Loss: 1.0535, Validation Accuracy: 54.43%, Validation AUROC: 0.7891
# Epoch [13/100]
# Training Loss: 1.0973, Training Accuracy: 58.30%, Training AUROC: 0.8276
# Validation Loss: 1.0462, Validation Accuracy: 53.16%, Validation AUROC: 0.7961
# Epoch [14/100]
# Training Loss: 1.0694, Training Accuracy: 57.24%, Training AUROC: 0.8404
# Validation Loss: 1.0310, Validation Accuracy: 53.16%, Validation AUROC: 0.7980
# Epoch [15/100]
# Training Loss: 1.0390, Training Accuracy: 60.42%, Training AUROC: 0.8616
# Validation Loss: 1.0300, Validation Accuracy: 53.16%, Validation AUROC: 0.8026
# Epoch [16/100]
# Training Loss: 1.0173, Training Accuracy: 60.42%, Training AUROC: 0.8698
# Validation Loss: 1.0248, Validation Accuracy: 54.43%, Validation AUROC: 0.8051
# Epoch [17/100]
# Training Loss: 1.0404, Training Accuracy: 64.31%, Training AUROC: 0.8560
# Validation Loss: 1.0216, Validation Accuracy: 55.70%, Validation AUROC: 0.8057
# Epoch [18/100]
# Training Loss: 0.9774, Training Accuracy: 65.37%, Training AUROC: 0.8829
# Validation Loss: 1.0105, Validation Accuracy: 50.63%, Validation AUROC: 0.8082
# Epoch [19/100]
# Training Loss: 0.9664, Training Accuracy: 63.60%, Training AUROC: 0.8918
# Validation Loss: 1.0089, Validation Accuracy: 53.16%, Validation AUROC: 0.8095
# Epoch [20/100]
# Training Loss: 0.9580, Training Accuracy: 63.60%, Training AUROC: 0.8847
# Validation Loss: 1.0095, Validation Accuracy: 55.70%, Validation AUROC: 0.8085
# Epoch [21/100]
# Training Loss: 0.9546, Training Accuracy: 64.66%, Training AUROC: 0.8822
# Validation Loss: 1.0223, Validation Accuracy: 56.96%, Validation AUROC: 0.8070
# Epoch [22/100]
# Training Loss: 0.9462, Training Accuracy: 63.25%, Training AUROC: 0.8938
# Validation Loss: 1.0072, Validation Accuracy: 53.16%, Validation AUROC: 0.8113
# Epoch [23/100]
# Training Loss: 0.9535, Training Accuracy: 62.19%, Training AUROC: 0.8800
# Validation Loss: 1.0033, Validation Accuracy: 55.70%, Validation AUROC: 0.8068
# Epoch [24/100]
# Training Loss: 0.9299, Training Accuracy: 67.84%, Training AUROC: 0.8918
# Validation Loss: 1.0166, Validation Accuracy: 54.43%, Validation AUROC: 0.8066
# Epoch [25/100]
# Training Loss: 0.8945, Training Accuracy: 67.14%, Training AUROC: 0.9057
# Validation Loss: 1.0043, Validation Accuracy: 55.70%, Validation AUROC: 0.8081
# Epoch [26/100]
# Training Loss: 0.8980, Training Accuracy: 67.14%, Training AUROC: 0.9061
# Validation Loss: 1.0038, Validation Accuracy: 55.70%, Validation AUROC: 0.8069
# Epoch [27/100]
# Training Loss: 0.8912, Training Accuracy: 65.37%, Training AUROC: 0.9087
# Validation Loss: 1.0146, Validation Accuracy: 53.16%, Validation AUROC: 0.8084
# Epoch [28/100]
# Training Loss: 0.8597, Training Accuracy: 67.49%, Training AUROC: 0.9146
# Validation Loss: 1.0075, Validation Accuracy: 56.96%, Validation AUROC: 0.8070
# Epoch [29/100]
# Training Loss: 0.8575, Training Accuracy: 68.20%, Training AUROC: 0.9166
# Validation Loss: 1.0067, Validation Accuracy: 55.70%, Validation AUROC: 0.8052
# Epoch [30/100]
# Training Loss: 0.8572, Training Accuracy: 69.26%, Training AUROC: 0.9161
# Validation Loss: 1.0222, Validation Accuracy: 56.96%, Validation AUROC: 0.8053
# Epoch [31/100]
# Training Loss: 0.8307, Training Accuracy: 70.32%, Training AUROC: 0.9224
# Validation Loss: 1.0067, Validation Accuracy: 54.43%, Validation AUROC: 0.8042
# Epoch [32/100]
# Training Loss: 0.8174, Training Accuracy: 71.73%, Training AUROC: 0.9295
# Validation Loss: 1.0032, Validation Accuracy: 56.96%, Validation AUROC: 0.8089
# Epoch [33/100]
# Training Loss: 0.8285, Training Accuracy: 67.84%, Training AUROC: 0.9131
# Validation Loss: 1.0065, Validation Accuracy: 55.70%, Validation AUROC: 0.8070
# Epoch [34/100]
# Training Loss: 0.7929, Training Accuracy: 69.61%, Training AUROC: 0.9312
# Validation Loss: 1.0134, Validation Accuracy: 54.43%, Validation AUROC: 0.8084
# Epoch [35/100]
# Training Loss: 0.8335, Training Accuracy: 66.08%, Training AUROC: 0.9172
# Validation Loss: 1.0135, Validation Accuracy: 55.70%, Validation AUROC: 0.8070
# Epoch [36/100]
# Training Loss: 0.8071, Training Accuracy: 72.08%, Training AUROC: 0.9270
# Validation Loss: 1.0173, Validation Accuracy: 56.96%, Validation AUROC: 0.8046
# Epoch [37/100]
# Training Loss: 0.7991, Training Accuracy: 68.90%, Training AUROC: 0.9210
# Validation Loss: 1.0138, Validation Accuracy: 55.70%, Validation AUROC: 0.8083
# Epoch [38/100]
# Training Loss: 0.7865, Training Accuracy: 71.02%, Training AUROC: 0.9298
# Validation Loss: 1.0212, Validation Accuracy: 55.70%, Validation AUROC: 0.8097
# Epoch [39/100]
# Training Loss: 0.7680, Training Accuracy: 72.79%, Training AUROC: 0.9398
# Validation Loss: 1.0186, Validation Accuracy: 58.23%, Validation AUROC: 0.8042
# Epoch [40/100]
# Training Loss: 0.7860, Training Accuracy: 71.73%, Training AUROC: 0.9275
# Validation Loss: 1.0196, Validation Accuracy: 55.70%, Validation AUROC: 0.8068
# Epoch [41/100]
# Training Loss: 0.7816, Training Accuracy: 70.32%, Training AUROC: 0.9327
# Validation Loss: 1.0190, Validation Accuracy: 54.43%, Validation AUROC: 0.8097
# Epoch [42/100]
# Training Loss: 0.7671, Training Accuracy: 70.67%, Training AUROC: 0.9308
# Validation Loss: 1.0219, Validation Accuracy: 55.70%, Validation AUROC: 0.8081
# Early stopping triggered after 42 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 1.7361, Training Accuracy: 9.19%, Training AUROC: 0.4864
# Validation Loss: 1.6289, Validation Accuracy: 21.52%, Validation AUROC: 0.6149
# Epoch [2/100]
# Training Loss: 1.6206, Training Accuracy: 22.61%, Training AUROC: 0.5245
# Validation Loss: 1.5644, Validation Accuracy: 27.85%, Validation AUROC: 0.6051
# Epoch [3/100]
# Training Loss: 1.5767, Training Accuracy: 31.10%, Training AUROC: 0.5298
# Validation Loss: 1.5390, Validation Accuracy: 30.38%, Validation AUROC: 0.6405
# Epoch [4/100]
# Training Loss: 1.5684, Training Accuracy: 31.45%, Training AUROC: 0.5364
# Validation Loss: 1.5270, Validation Accuracy: 30.38%, Validation AUROC: 0.6524
# Epoch [5/100]
# Training Loss: 1.5656, Training Accuracy: 31.10%, Training AUROC: 0.5347
# Validation Loss: 1.5111, Validation Accuracy: 30.38%, Validation AUROC: 0.6526
# Epoch [6/100]
# Training Loss: 1.5422, Training Accuracy: 31.45%, Training AUROC: 0.5663
# Validation Loss: 1.4938, Validation Accuracy: 29.11%, Validation AUROC: 0.6659
# Epoch [7/100]
# Training Loss: 1.5163, Training Accuracy: 28.98%, Training AUROC: 0.5915
# Validation Loss: 1.4858, Validation Accuracy: 26.58%, Validation AUROC: 0.6690
# Epoch [8/100]
# Training Loss: 1.5072, Training Accuracy: 24.38%, Training AUROC: 0.5872
# Validation Loss: 1.4717, Validation Accuracy: 25.32%, Validation AUROC: 0.6781
# Epoch [9/100]
# Training Loss: 1.4908, Training Accuracy: 28.62%, Training AUROC: 0.6214
# Validation Loss: 1.4587, Validation Accuracy: 26.58%, Validation AUROC: 0.6805
# Epoch [10/100]
# Training Loss: 1.4543, Training Accuracy: 31.10%, Training AUROC: 0.6486
# Validation Loss: 1.4543, Validation Accuracy: 25.32%, Validation AUROC: 0.6792
# Epoch [11/100]
# Training Loss: 1.4438, Training Accuracy: 28.27%, Training AUROC: 0.6378
# Validation Loss: 1.4408, Validation Accuracy: 25.32%, Validation AUROC: 0.6755
# Epoch [12/100]
# Training Loss: 1.4388, Training Accuracy: 30.74%, Training AUROC: 0.6322
# Validation Loss: 1.4305, Validation Accuracy: 26.58%, Validation AUROC: 0.6796
# Epoch [13/100]
# Training Loss: 1.4005, Training Accuracy: 30.39%, Training AUROC: 0.6663
# Validation Loss: 1.4273, Validation Accuracy: 25.32%, Validation AUROC: 0.6791
# Epoch [14/100]
# Training Loss: 1.3981, Training Accuracy: 29.68%, Training AUROC: 0.6646
# Validation Loss: 1.4175, Validation Accuracy: 26.58%, Validation AUROC: 0.6742
# Epoch [15/100]
# Training Loss: 1.3763, Training Accuracy: 32.16%, Training AUROC: 0.6637
# Validation Loss: 1.4105, Validation Accuracy: 26.58%, Validation AUROC: 0.6717
# Epoch [16/100]
# Training Loss: 1.3605, Training Accuracy: 32.51%, Training AUROC: 0.6725
# Validation Loss: 1.4118, Validation Accuracy: 26.58%, Validation AUROC: 0.6746
# Epoch [17/100]
# Training Loss: 1.3508, Training Accuracy: 33.92%, Training AUROC: 0.6850
# Validation Loss: 1.4034, Validation Accuracy: 27.85%, Validation AUROC: 0.6711
# Epoch [18/100]
# Training Loss: 1.3489, Training Accuracy: 34.63%, Training AUROC: 0.6762
# Validation Loss: 1.3971, Validation Accuracy: 27.85%, Validation AUROC: 0.6703
# Epoch [19/100]
# Training Loss: 1.3277, Training Accuracy: 34.98%, Training AUROC: 0.6920
# Validation Loss: 1.3991, Validation Accuracy: 25.32%, Validation AUROC: 0.6730
# Epoch [20/100]
# Training Loss: 1.3337, Training Accuracy: 36.40%, Training AUROC: 0.6902
# Validation Loss: 1.3917, Validation Accuracy: 26.58%, Validation AUROC: 0.6692
# Epoch [21/100]
# Training Loss: 1.3089, Training Accuracy: 39.22%, Training AUROC: 0.6843
# Validation Loss: 1.3878, Validation Accuracy: 26.58%, Validation AUROC: 0.6674
# Epoch [22/100]
# Training Loss: 1.3035, Training Accuracy: 42.05%, Training AUROC: 0.6787
# Validation Loss: 1.3846, Validation Accuracy: 25.32%, Validation AUROC: 0.6680
# Epoch [23/100]
# Training Loss: 1.2786, Training Accuracy: 42.05%, Training AUROC: 0.7089
# Validation Loss: 1.3796, Validation Accuracy: 26.58%, Validation AUROC: 0.6661
# Epoch [24/100]
# Training Loss: 1.2864, Training Accuracy: 41.34%, Training AUROC: 0.7011
# Validation Loss: 1.3792, Validation Accuracy: 26.58%, Validation AUROC: 0.6639
# Epoch [25/100]
# Training Loss: 1.2845, Training Accuracy: 42.76%, Training AUROC: 0.7006
# Validation Loss: 1.3754, Validation Accuracy: 26.58%, Validation AUROC: 0.6639
# Epoch [26/100]
# Training Loss: 1.2499, Training Accuracy: 46.64%, Training AUROC: 0.7107
# Validation Loss: 1.3730, Validation Accuracy: 27.85%, Validation AUROC: 0.6620
# Epoch [27/100]
# Training Loss: 1.2741, Training Accuracy: 41.70%, Training AUROC: 0.7051
# Validation Loss: 1.3754, Validation Accuracy: 27.85%, Validation AUROC: 0.6617
# Epoch [28/100]
# Training Loss: 1.2582, Training Accuracy: 46.29%, Training AUROC: 0.7063
# Validation Loss: 1.3698, Validation Accuracy: 26.58%, Validation AUROC: 0.6596
# Epoch [29/100]
# Training Loss: 1.2213, Training Accuracy: 50.53%, Training AUROC: 0.7300
# Validation Loss: 1.3668, Validation Accuracy: 32.91%, Validation AUROC: 0.6619
# Epoch [30/100]
# Training Loss: 1.2532, Training Accuracy: 47.00%, Training AUROC: 0.7147
# Validation Loss: 1.3652, Validation Accuracy: 30.38%, Validation AUROC: 0.6593
# Epoch [31/100]
# Training Loss: 1.2174, Training Accuracy: 51.24%, Training AUROC: 0.7355
# Validation Loss: 1.3632, Validation Accuracy: 37.97%, Validation AUROC: 0.6571
# Epoch [32/100]
# Training Loss: 1.2176, Training Accuracy: 50.53%, Training AUROC: 0.7410
# Validation Loss: 1.3630, Validation Accuracy: 36.71%, Validation AUROC: 0.6585
# Epoch [33/100]
# Training Loss: 1.2240, Training Accuracy: 54.42%, Training AUROC: 0.7117
# Validation Loss: 1.3552, Validation Accuracy: 44.30%, Validation AUROC: 0.6572
# Epoch [34/100]
# Training Loss: 1.2134, Training Accuracy: 61.84%, Training AUROC: 0.7335
# Validation Loss: 1.3550, Validation Accuracy: 48.10%, Validation AUROC: 0.6567
# Epoch [35/100]
# Training Loss: 1.2040, Training Accuracy: 60.42%, Training AUROC: 0.7248
# Validation Loss: 1.3549, Validation Accuracy: 53.16%, Validation AUROC: 0.6574
# Epoch [36/100]
# Training Loss: 1.1984, Training Accuracy: 58.30%, Training AUROC: 0.7253
# Validation Loss: 1.3521, Validation Accuracy: 51.90%, Validation AUROC: 0.6559
# Epoch [37/100]
# Training Loss: 1.2042, Training Accuracy: 59.01%, Training AUROC: 0.7144
# Validation Loss: 1.3499, Validation Accuracy: 53.16%, Validation AUROC: 0.6579
# Epoch [38/100]
# Training Loss: 1.1849, Training Accuracy: 58.66%, Training AUROC: 0.7449
# Validation Loss: 1.3477, Validation Accuracy: 51.90%, Validation AUROC: 0.6562
# Epoch [39/100]
# Training Loss: 1.1818, Training Accuracy: 59.72%, Training AUROC: 0.7428
# Validation Loss: 1.3478, Validation Accuracy: 53.16%, Validation AUROC: 0.6525
# Epoch [40/100]
# Training Loss: 1.1850, Training Accuracy: 61.84%, Training AUROC: 0.7273
# Validation Loss: 1.3479, Validation Accuracy: 51.90%, Validation AUROC: 0.6515
# Epoch [41/100]
# Training Loss: 1.1821, Training Accuracy: 60.07%, Training AUROC: 0.7291
# Validation Loss: 1.3402, Validation Accuracy: 50.63%, Validation AUROC: 0.6503
# Epoch [42/100]
# Training Loss: 1.1874, Training Accuracy: 62.19%, Training AUROC: 0.7399
# Validation Loss: 1.3492, Validation Accuracy: 48.10%, Validation AUROC: 0.6492
# Epoch [43/100]
# Training Loss: 1.1574, Training Accuracy: 62.54%, Training AUROC: 0.7338
# Validation Loss: 1.3437, Validation Accuracy: 53.16%, Validation AUROC: 0.6469
# Epoch [44/100]
# Training Loss: 1.1523, Training Accuracy: 60.07%, Training AUROC: 0.7375
# Validation Loss: 1.3381, Validation Accuracy: 50.63%, Validation AUROC: 0.6495
# Epoch [45/100]
# Training Loss: 1.1463, Training Accuracy: 59.36%, Training AUROC: 0.7468
# Validation Loss: 1.3355, Validation Accuracy: 49.37%, Validation AUROC: 0.6465
# Epoch [46/100]
# Training Loss: 1.1462, Training Accuracy: 63.60%, Training AUROC: 0.7381
# Validation Loss: 1.3379, Validation Accuracy: 46.84%, Validation AUROC: 0.6425
# Epoch [47/100]
# Training Loss: 1.1448, Training Accuracy: 61.48%, Training AUROC: 0.7474
# Validation Loss: 1.3316, Validation Accuracy: 48.10%, Validation AUROC: 0.6409
# Epoch [48/100]
# Training Loss: 1.1388, Training Accuracy: 60.78%, Training AUROC: 0.7496
# Validation Loss: 1.3284, Validation Accuracy: 50.63%, Validation AUROC: 0.6409
# Epoch [49/100]
# Training Loss: 1.1052, Training Accuracy: 66.43%, Training AUROC: 0.7607
# Validation Loss: 1.3231, Validation Accuracy: 49.37%, Validation AUROC: 0.6410
# Epoch [50/100]
# Training Loss: 1.1343, Training Accuracy: 61.84%, Training AUROC: 0.7439
# Validation Loss: 1.3263, Validation Accuracy: 49.37%, Validation AUROC: 0.6404
# Epoch [51/100]
# Training Loss: 1.1257, Training Accuracy: 64.66%, Training AUROC: 0.7576
# Validation Loss: 1.3181, Validation Accuracy: 51.90%, Validation AUROC: 0.6404
# Epoch [52/100]
# Training Loss: 1.1597, Training Accuracy: 59.72%, Training AUROC: 0.7286
# Validation Loss: 1.3092, Validation Accuracy: 48.10%, Validation AUROC: 0.6480
# Epoch [53/100]
# Training Loss: 1.1115, Training Accuracy: 63.96%, Training AUROC: 0.7563
# Validation Loss: 1.3250, Validation Accuracy: 49.37%, Validation AUROC: 0.6387
# Epoch [54/100]
# Training Loss: 1.0982, Training Accuracy: 63.96%, Training AUROC: 0.7521
# Validation Loss: 1.3317, Validation Accuracy: 50.63%, Validation AUROC: 0.6370
# Epoch [55/100]
# Training Loss: 1.1057, Training Accuracy: 60.78%, Training AUROC: 0.7482
# Validation Loss: 1.3140, Validation Accuracy: 49.37%, Validation AUROC: 0.6420
# Epoch [56/100]
# Training Loss: 1.0946, Training Accuracy: 65.02%, Training AUROC: 0.7674
# Validation Loss: 1.3148, Validation Accuracy: 50.63%, Validation AUROC: 0.6390
# Epoch [57/100]
# Training Loss: 1.0823, Training Accuracy: 64.31%, Training AUROC: 0.7689
# Validation Loss: 1.3135, Validation Accuracy: 49.37%, Validation AUROC: 0.6398
# Epoch [58/100]
# Training Loss: 1.0806, Training Accuracy: 66.78%, Training AUROC: 0.7573
# Validation Loss: 1.3147, Validation Accuracy: 46.84%, Validation AUROC: 0.6383
# Epoch [59/100]
# Training Loss: 1.0835, Training Accuracy: 62.90%, Training AUROC: 0.7672
# Validation Loss: 1.3078, Validation Accuracy: 49.37%, Validation AUROC: 0.6441
# Epoch [60/100]
# Training Loss: 1.0789, Training Accuracy: 64.66%, Training AUROC: 0.7655
# Validation Loss: 1.3042, Validation Accuracy: 48.10%, Validation AUROC: 0.6420
# Epoch [61/100]
# Training Loss: 1.0752, Training Accuracy: 68.90%, Training AUROC: 0.7677
# Validation Loss: 1.3042, Validation Accuracy: 49.37%, Validation AUROC: 0.6360
# Epoch [62/100]
# Training Loss: 1.0819, Training Accuracy: 66.43%, Training AUROC: 0.7576
# Validation Loss: 1.3088, Validation Accuracy: 46.84%, Validation AUROC: 0.6338
# Epoch [63/100]
# Training Loss: 1.0540, Training Accuracy: 65.37%, Training AUROC: 0.7750
# Validation Loss: 1.2986, Validation Accuracy: 49.37%, Validation AUROC: 0.6340
# Epoch [64/100]
# Training Loss: 1.0515, Training Accuracy: 65.37%, Training AUROC: 0.7661
# Validation Loss: 1.3029, Validation Accuracy: 48.10%, Validation AUROC: 0.6326
# Epoch [65/100]
# Training Loss: 1.0501, Training Accuracy: 66.08%, Training AUROC: 0.7772
# Validation Loss: 1.3117, Validation Accuracy: 46.84%, Validation AUROC: 0.6321
# Epoch [66/100]
# Training Loss: 1.0689, Training Accuracy: 61.13%, Training AUROC: 0.7682
# Validation Loss: 1.2964, Validation Accuracy: 50.63%, Validation AUROC: 0.6337
# Epoch [67/100]
# Training Loss: 1.0530, Training Accuracy: 62.90%, Training AUROC: 0.7790
# Validation Loss: 1.3012, Validation Accuracy: 49.37%, Validation AUROC: 0.6329
# Epoch [68/100]
# Training Loss: 1.0385, Training Accuracy: 66.08%, Training AUROC: 0.7703
# Validation Loss: 1.2970, Validation Accuracy: 46.84%, Validation AUROC: 0.6347
# Epoch [69/100]
# Training Loss: 1.0552, Training Accuracy: 66.78%, Training AUROC: 0.7674
# Validation Loss: 1.2913, Validation Accuracy: 46.84%, Validation AUROC: 0.6335
# Epoch [70/100]
# Training Loss: 1.0427, Training Accuracy: 62.90%, Training AUROC: 0.7830
# Validation Loss: 1.3036, Validation Accuracy: 46.84%, Validation AUROC: 0.6309
# Epoch [71/100]
# Training Loss: 1.0260, Training Accuracy: 66.78%, Training AUROC: 0.7965
# Validation Loss: 1.2872, Validation Accuracy: 46.84%, Validation AUROC: 0.6376
# Epoch [72/100]
# Training Loss: 1.0310, Training Accuracy: 67.49%, Training AUROC: 0.7889
# Validation Loss: 1.2822, Validation Accuracy: 50.63%, Validation AUROC: 0.6402
# Epoch [73/100]
# Training Loss: 1.0319, Training Accuracy: 67.49%, Training AUROC: 0.7759
# Validation Loss: 1.2901, Validation Accuracy: 46.84%, Validation AUROC: 0.6355
# Epoch [74/100]
# Training Loss: 1.0121, Training Accuracy: 65.72%, Training AUROC: 0.7944
# Validation Loss: 1.2848, Validation Accuracy: 50.63%, Validation AUROC: 0.6408
# Epoch [75/100]
# Training Loss: 1.0042, Training Accuracy: 69.61%, Training AUROC: 0.7931
# Validation Loss: 1.2767, Validation Accuracy: 53.16%, Validation AUROC: 0.6360
# Epoch [76/100]
# Training Loss: 1.0044, Training Accuracy: 66.08%, Training AUROC: 0.8004
# Validation Loss: 1.2850, Validation Accuracy: 48.10%, Validation AUROC: 0.6327
# Epoch [77/100]
# Training Loss: 1.0028, Training Accuracy: 68.20%, Training AUROC: 0.7822
# Validation Loss: 1.2825, Validation Accuracy: 49.37%, Validation AUROC: 0.6303
# Epoch [78/100]
# Training Loss: 0.9986, Training Accuracy: 66.43%, Training AUROC: 0.7874
# Validation Loss: 1.2805, Validation Accuracy: 51.90%, Validation AUROC: 0.6356
# Epoch [79/100]
# Training Loss: 1.0081, Training Accuracy: 66.08%, Training AUROC: 0.7939
# Validation Loss: 1.2814, Validation Accuracy: 46.84%, Validation AUROC: 0.6355
# Epoch [80/100]
# Training Loss: 0.9964, Training Accuracy: 71.38%, Training AUROC: 0.8122
# Validation Loss: 1.2603, Validation Accuracy: 54.43%, Validation AUROC: 0.6383
# Epoch [81/100]
# Training Loss: 1.0026, Training Accuracy: 67.49%, Training AUROC: 0.8056
# Validation Loss: 1.2756, Validation Accuracy: 49.37%, Validation AUROC: 0.6342
# Epoch [82/100]
# Training Loss: 0.9870, Training Accuracy: 69.96%, Training AUROC: 0.7971
# Validation Loss: 1.2680, Validation Accuracy: 49.37%, Validation AUROC: 0.6356
# Epoch [83/100]
# Training Loss: 0.9886, Training Accuracy: 68.55%, Training AUROC: 0.8022
# Validation Loss: 1.2659, Validation Accuracy: 50.63%, Validation AUROC: 0.6358
# Epoch [84/100]
# Training Loss: 0.9791, Training Accuracy: 71.02%, Training AUROC: 0.8162
# Validation Loss: 1.2639, Validation Accuracy: 48.10%, Validation AUROC: 0.6349
# Epoch [85/100]
# Training Loss: 0.9731, Training Accuracy: 71.38%, Training AUROC: 0.8094
# Validation Loss: 1.2633, Validation Accuracy: 50.63%, Validation AUROC: 0.6347
# Epoch [86/100]
# Training Loss: 0.9607, Training Accuracy: 70.67%, Training AUROC: 0.8024
# Validation Loss: 1.2709, Validation Accuracy: 49.37%, Validation AUROC: 0.6325
# Epoch [87/100]
# Training Loss: 0.9906, Training Accuracy: 66.43%, Training AUROC: 0.8065
# Validation Loss: 1.2726, Validation Accuracy: 49.37%, Validation AUROC: 0.6315
# Epoch [88/100]
# Training Loss: 0.9752, Training Accuracy: 70.67%, Training AUROC: 0.8099
# Validation Loss: 1.2565, Validation Accuracy: 50.63%, Validation AUROC: 0.6383
# Epoch [89/100]
# Training Loss: 0.9491, Training Accuracy: 73.50%, Training AUROC: 0.8160
# Validation Loss: 1.2625, Validation Accuracy: 48.10%, Validation AUROC: 0.6339
# Epoch [90/100]
# Training Loss: 0.9459, Training Accuracy: 71.02%, Training AUROC: 0.8306
# Validation Loss: 1.2573, Validation Accuracy: 48.10%, Validation AUROC: 0.6309
# Epoch [91/100]
# Training Loss: 0.9941, Training Accuracy: 65.02%, Training AUROC: 0.7988
# Validation Loss: 1.2553, Validation Accuracy: 49.37%, Validation AUROC: 0.6368
# Epoch [92/100]
# Training Loss: 0.9438, Training Accuracy: 72.08%, Training AUROC: 0.8223
# Validation Loss: 1.2536, Validation Accuracy: 50.63%, Validation AUROC: 0.6335
# Epoch [93/100]
# Training Loss: 0.9481, Training Accuracy: 72.79%, Training AUROC: 0.8319
# Validation Loss: 1.2524, Validation Accuracy: 50.63%, Validation AUROC: 0.6357
# Epoch [94/100]
# Training Loss: 0.9638, Training Accuracy: 69.26%, Training AUROC: 0.8153
# Validation Loss: 1.2484, Validation Accuracy: 48.10%, Validation AUROC: 0.6337
# Epoch [95/100]
# Training Loss: 0.9548, Training Accuracy: 72.79%, Training AUROC: 0.8351
# Validation Loss: 1.2406, Validation Accuracy: 51.90%, Validation AUROC: 0.6372
# Epoch [96/100]
# Training Loss: 0.9330, Training Accuracy: 74.91%, Training AUROC: 0.8437
# Validation Loss: 1.2482, Validation Accuracy: 49.37%, Validation AUROC: 0.6317
# Epoch [97/100]
# Training Loss: 0.9280, Training Accuracy: 70.67%, Training AUROC: 0.8300
# Validation Loss: 1.2512, Validation Accuracy: 48.10%, Validation AUROC: 0.6339
# Epoch [98/100]
# Training Loss: 0.9291, Training Accuracy: 73.14%, Training AUROC: 0.8294
# Validation Loss: 1.2405, Validation Accuracy: 51.90%, Validation AUROC: 0.6371
# Epoch [99/100]
# Training Loss: 0.9194, Training Accuracy: 71.38%, Training AUROC: 0.8502
# Validation Loss: 1.2394, Validation Accuracy: 49.37%, Validation AUROC: 0.6367
# Epoch [100/100]
# Training Loss: 0.9267, Training Accuracy: 75.62%, Training AUROC: 0.8221
# Validation Loss: 1.2311, Validation Accuracy: 51.90%, Validation AUROC: 0.6377

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(model_hybrid, model_normal, test_loader, num_classes=num_classes)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Hybrid Model Metrics:
# Accuracy: 0.5974
# F1 Score: 0.5774
# Precision: 0.5989
# Recall: 0.5974
# AUROC: 0.6637
#
# Normal Model Metrics:
# Accuracy: 0.6104
# F1 Score: 0.5900
# Precision: 0.6045
# Recall: 0.6104
# AUROC: 0.8409
