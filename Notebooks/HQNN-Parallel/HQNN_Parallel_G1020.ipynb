# %% [markdown]
# ## This notebook presents the reproducible procedure that we followed in comparing the performance of Hybrid Quantum Neural Networks-Parallel and Classical Convolutional Neural Networks on the G1020 dataset. The G1020 dataset is a glaucoma-focused dataset with 1020 fundus images. The dataset was produced in Germany and is labeled with binary classification (Non-Glaucoma and Glaucoma).

# %% [markdown]
# ### Installing and Importing Dependencies

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.40.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.1 in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.4.2)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.7.0)
# Collecting tomlkit (from pennylane)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.1)
# Collecting pennylane-lightning>=0.40 (from pennylane)
#   Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (24.2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.40->pennylane)
#   Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (2.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.1.31)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading PennyLane-0.40.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.5 MB/s eta 0:00:00
# Downloading autoray-0.7.0-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.0/930.0 kB 55.2 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 63.0 MB/s eta 0:00:00
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 79.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 14.9 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 108.3 MB/s eta 0:00:00
# Installing collected packages: appdirs, tomlkit, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.0 diastatic-malt-2.15.2 pennylane-0.40.0 pennylane-lightning-0.40.0 rustworkx-0.16.0 scipy-openblas32-0.3.29.0.0 tomlkit-0.13.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
from google.colab import drive
import cv2
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, Sampler
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms
from PIL import Image
import time
import os
import copy
from torch.optim.lr_scheduler import CosineAnnealingLR
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve,
    precision_recall_curve, auc, ConfusionMatrixDisplay
)
from sklearn.preprocessing import label_binarize
import random
from itertools import cycle

os.environ["OMP_NUM_THREADS"] = "1"

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
MODEL_SAVE_PATH = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020_models_QNN-Parallel/"

# %% [markdown]
# ### General Training, Validation, Testing Functions

# %%
import torchvision
from torchvision import datasets, transforms

# %%
def train_model(model, train_loader, optimizer, criterion):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_probs = []

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        probs = torch.softmax(outputs, dim=1)
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.detach().cpu().numpy())



    avg_train_loss = train_loss / len(train_loader.dataset)
    accuracy = correct / total * 100

    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_train_loss, accuracy, avg_auroc

# %%
def validate_model(model, valid_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            probs = torch.softmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.detach().cpu().numpy())

    avg_val_loss = val_loss / len(valid_loader.dataset)
    accuracy = correct / total * 100
    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_val_loss, accuracy, avg_auroc

# %%
import pickle

def train_validate_model(n_epochs, model, model_name, train_loader, valid_loader, seed, quantum=False):

  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

  def adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max):
        if epoch < lr_warmup_epochs:
            lr = lr_max * (epoch + 1) / lr_warmup_epochs
        else:
            lr = lr_max
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

  scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs - 10, eta_min=1e-6)

  best_val_loss = float('inf')
  best_model_weights = model.state_dict()
  epochs_without_improvement = 0
  early_stopping_patience = 10

  train_losses = []
  train_accuracies = []
  val_losses = []
  val_accuracies = []
  train_aucs = []
  val_aucs = []

  lr_max = 5e-4
  lr_warmup_epochs = 10

  for epoch in range(n_epochs):
      print(f'Epoch [{epoch+1}/{n_epochs}]')

      adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max)

      train_loss, train_accuracy, train_auroc = train_model(model, train_loader, optimizer, criterion)
      val_loss, val_accuracy, val_auroc = validate_model(model, valid_loader, criterion)


      print(f'Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Training AUROC: {train_auroc:.4f}')
      print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%, Validation AUROC: {val_auroc:.4f}')
      train_losses.append(train_loss)
      train_accuracies.append(train_accuracy)
      train_aucs.append(train_auroc)
      val_losses.append(val_loss)
      val_accuracies.append(val_accuracy)
      val_aucs.append(val_auroc)

      if epoch >= lr_warmup_epochs:
            scheduler.step()

      if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict()
            epochs_without_improvement = 0  # Reset counter

      else:
            epochs_without_improvement += 1

      if epochs_without_improvement >= early_stopping_patience:
            print(f"Early stopping triggered after {epoch+1} epochs.")
            break


  model.load_state_dict(best_model_weights)

  if quantum:
    torch.save(model.state_dict(), os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}.pth'))
  else:
    torch.save(model, os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}.pth'))

  metrics = {
        "train_losses": train_losses,
        "train_accuracies": train_accuracies,
        "train_aucs": train_aucs,
        "val_losses": val_losses,
        "val_accuracies": val_accuracies,
        "val_aucs": val_aucs
    }

  with open(os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}_metrics.pkl'), 'wb') as f:
        pickle.dump(metrics, f)

  return model, train_losses, train_accuracies, val_losses, val_accuracies, train_aucs, val_aucs

# %%
import math
import matplotlib.pyplot as plt

def plot(quantum_loss, normal_loss, quantum_acc, normal_acc, quantum_auc, normal_auc):
    plt.style.use("default")

    loss_min = math.floor(min(min(quantum_loss), min(normal_loss)) * 10) / 10
    loss_max = math.ceil(max(max(quantum_loss), max(normal_loss)) * 10) / 10

    acc_min = math.floor(min(min(quantum_acc), min(normal_acc)) * 10) / 10
    acc_max = math.ceil(max(max(quantum_acc), max(normal_acc)) * 10) / 10

    auc_min = math.floor(min(min(quantum_auc), min(normal_auc)) * 10) / 10
    auc_max = math.ceil(max(max(quantum_auc), max(normal_auc)) * 10) / 10

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_loss, label="With quantum layer")
    plt.plot(normal_loss, label="Without quantum layer")
    plt.ylabel("Loss")
    plt.ylim([loss_min, loss_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Loss vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_acc, label="With quantum layer")
    plt.plot(normal_acc, label="Without quantum layer")
    plt.ylabel("Accuracy")
    plt.ylim([acc_min, acc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Accuracy vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_auc, label="With quantum layer")
    plt.plot(normal_auc, label="Without quantum layer")
    plt.ylabel("ROCAUC")
    plt.ylim([auc_min, auc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("ROCAUC vs. Epoch")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.preprocessing import label_binarize
from itertools import cycle


def test(model_hybrid, model_normal, test_loader, num_classes):
    model_hybrid.eval()
    model_normal.eval()

    all_labels = []
    all_preds_hybrid = []
    all_preds_normal = []
    all_probs_hybrid = []
    all_probs_normal = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)


            outputs_hybrid = model_hybrid(images)
            _, preds_hybrid = torch.max(outputs_hybrid, 1)
            probs_hybrid = torch.softmax(outputs_hybrid, dim=1)
            # Normal model predictions
            outputs_normal = model_normal(images)
            _, preds_normal = torch.max(outputs_normal, 1)
            probs_normal = torch.softmax(outputs_normal, dim=1)

            all_labels.extend(labels.cpu().numpy())
            all_preds_hybrid.extend(preds_hybrid.cpu().numpy())
            all_preds_normal.extend(preds_normal.cpu().numpy())
            all_probs_hybrid.extend(probs_hybrid.cpu().numpy())
            all_probs_normal.extend(probs_normal.cpu().numpy())

    all_labels = np.array(all_labels)
    all_preds_hybrid = np.array(all_preds_hybrid)
    all_preds_normal = np.array(all_preds_normal)
    all_probs_hybrid = np.array(all_probs_hybrid)
    all_probs_normal = np.array(all_probs_normal)


    accuracy_hybrid = accuracy_score(all_labels, all_preds_hybrid)
    accuracy_normal = accuracy_score(all_labels, all_preds_normal)


    f1_hybrid = f1_score(all_labels, all_preds_hybrid, average='weighted')
    f1_normal = f1_score(all_labels, all_preds_normal, average='weighted')


    if num_classes == 2:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, pos_label=1)
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, pos_label=1)
        precision_normal = precision_score(all_labels, all_preds_normal, pos_label=1)
        recall_normal = recall_score(all_labels, all_preds_normal, pos_label=1)
    else:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, average='weighted')
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, average='weighted')
        precision_normal = precision_score(all_labels, all_preds_normal, average='weighted')
        recall_normal = recall_score(all_labels, all_preds_normal, average='weighted')


    hybrid_aucs = []
    normal_aucs = []

    if num_classes == 2:

        all_probs_hybrid_class1 = all_probs_hybrid[:, 1]
        all_probs_normal_class1 = all_probs_normal[:, 1]

        auc_hybrid = roc_auc_score(all_labels, all_probs_hybrid_class1)
        auc_normal = roc_auc_score(all_labels, all_probs_normal_class1)

        print(f'Hybrid Model AUROC: {auc_hybrid:.4f}')
        print(f'Normal Model AUROC: {auc_normal:.4f}')

        fpr_hybrid, tpr_hybrid, _ = roc_curve(all_labels, all_probs_hybrid_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_hybrid, tpr_hybrid, label=f'Hybrid Model AUROC = {auc_hybrid:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Hybrid Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curve for the Normal Model
        fpr_normal, tpr_normal, _ = roc_curve(all_labels, all_probs_normal_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_normal, tpr_normal, label=f'Normal Model AUROC = {auc_normal:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Normal Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

    else:  # Multi-class Classification

        all_labels_binarized = label_binarize(all_labels, classes=np.arange(num_classes))

        # Define a color cycle for plotting
        colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red'])
        # Plot ROC curves for the Hybrid Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_hybrid[:, i])
            roc_auc = auc(fpr, tpr)
            hybrid_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Hybrid Model')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curves for the Normal Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_normal[:, i])
            roc_auc = auc(fpr, tpr)
            normal_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Normal Model')
        plt.legend(loc='lower right')
        plt.show()



    filtered_normal_aucs = [auc for auc in normal_aucs if auc > 0]
    filtered_hybrid_aucs = [auc for auc in hybrid_aucs if auc > 0]
    print(filtered_normal_aucs)
    print(filtered_hybrid_aucs)

    # Calculate average AUC, handling cases where all values might be zero
    normal_auc = f"{sum(filtered_normal_aucs) / len(filtered_normal_aucs):.4f}" if filtered_normal_aucs else "N/A"
    hybrid_auc = f"{sum(filtered_hybrid_aucs) / len(filtered_hybrid_aucs):.4f}" if filtered_hybrid_aucs else "N/A"

    print("\nHybrid Model Metrics:")
    print(f'Accuracy: {accuracy_hybrid:.4f}')
    print(f'F1 Score: {f1_hybrid:.4f}')
    print(f'Precision: {precision_hybrid:.4f}')
    print(f'Recall: {recall_hybrid:.4f}')
    print(f'AUROC: {hybrid_auc}')

    print("\nNormal Model Metrics:")
    print(f'Accuracy: {accuracy_normal:.4f}')
    print(f'F1 Score: {f1_normal:.4f}')
    print(f'Precision: {precision_normal:.4f}')
    print(f'Recall: {recall_normal:.4f}')
    print(f'AUROC: {normal_auc} \n')

    cm_hybrid = confusion_matrix(all_labels, all_preds_hybrid)


    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_hybrid, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Hybrid Model (Avg AUC = {hybrid_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    cm_normal = confusion_matrix(all_labels, all_preds_normal)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_normal, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Classical Model (Avg AUC = {normal_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
def load_data(batch_size, dataset):

  train_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])

  valid_test_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])


  if dataset == 'APTOS':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/APTOS2019/"

  elif dataset == "IDRID":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/IDRID_images/"

  elif dataset == "Messidor":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/MESSIDOR2/"

  elif dataset == "GlaucomaFundus":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/Glaucoma_fundus/"

  elif dataset == "PAPILA":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/PAPILA/"

  elif dataset == 'G1020':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020/"


  train_dataset = datasets.ImageFolder(root=data_dir + 'train', transform=train_transform)
  val_dataset = datasets.ImageFolder(root=data_dir + 'val', transform=valid_test_transform)
  test_dataset = datasets.ImageFolder(root=data_dir + 'test', transform=valid_test_transform)

  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
  valid_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

  return train_loader, valid_loader, test_loader

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ### Classical CNN Model Construction and General Methods

# %%
class NormalModel(nn.Module):
    def __init__(self, num_classes):
        super(NormalModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.fc1 = nn.Linear(32 * 56 * 56, 120)
        self.fc2 = nn.Linear(120, 20)
        self.fc3 = nn.Linear(20, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ### Hybrid Quantum Neural Network Construction

# %%
step = 0.0004               # Learning rate
batch_size = 4              # Number of samples for each training step
q_delta = 0.01              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer

# %%
n_qubits = 5
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev)
def qnode(inputs, weights):
    qml.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.BasicEntanglerLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# Define the QLayer
n_layers = 3
weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
class QuantumHybridModel(nn.Module):
    def __init__(self, num_classes):
      super(QuantumHybridModel, self).__init__()
      self.conv1 = nn.Conv2d(3, 16, 5, stride=1, padding=2)
      self.bn1 = nn.BatchNorm2d(16)
      self.pool = nn.MaxPool2d(2, 2)
      self.conv2 = nn.Conv2d(16, 32, 5, stride=1, padding=2)
      self.bn2 = nn.BatchNorm2d(32)
      self.qlayer1 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.qlayer2 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.qlayer3 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.qlayer4 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.fc1 = nn.Linear(32 * 56 * 56, 120)
      self.fc2 = nn.Linear(120, 20)
      self.fc3 = nn.Linear(20, num_classes)

    def forward(self, x):
        # Propagate the input through the CNN layers
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        # Flatten the output from the convolutional layers
        x = x.view(x.size(0), -1)
        # Pass the output to the quantum layer
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x_1, x_2, x_3, x_4 = torch.split(x, 5, dim=1)
        x_1 = self.qlayer1(x_1)
        x_2 = self.qlayer2(x_2)
        x_3 = self.qlayer3(x_3)
        x_4 = self.qlayer4(x_4)
        x = torch.cat([x_1, x_2, x_3, x_4], axis=1)
        x = self.fc3(x)
        return x

# %% [markdown]
# # Experiments

# %%
n_epochs = 100
num_classes = 2
batch_size = 32
dataset = "G1020"
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'

# %% [markdown]
# ## Seed Experiment 1

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 31:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6326, Training Accuracy: 70.94%, Training AUROC: 0.4734
# Validation Loss: 0.6301, Validation Accuracy: 71.05%, Validation AUROC: 0.5922
# Epoch [2/100]
# Training Loss: 0.6278, Training Accuracy: 70.94%, Training AUROC: 0.4616
# Validation Loss: 0.5941, Validation Accuracy: 71.05%, Validation AUROC: 0.5699
# Epoch [3/100]
# Training Loss: 0.6149, Training Accuracy: 70.77%, Training AUROC: 0.5199
# Validation Loss: 0.6076, Validation Accuracy: 71.05%, Validation AUROC: 0.4949
# Epoch [4/100]
# Training Loss: 0.6169, Training Accuracy: 71.30%, Training AUROC: 0.5250
# Validation Loss: 0.6193, Validation Accuracy: 68.42%, Validation AUROC: 0.5208
# Epoch [5/100]
# Training Loss: 0.6138, Training Accuracy: 70.94%, Training AUROC: 0.5693
# Validation Loss: 0.6153, Validation Accuracy: 69.74%, Validation AUROC: 0.5215
# Epoch [6/100]
# Training Loss: 0.5880, Training Accuracy: 72.01%, Training AUROC: 0.6022
# Validation Loss: 0.6342, Validation Accuracy: 71.05%, Validation AUROC: 0.4987
# Epoch [7/100]
# Training Loss: 0.6249, Training Accuracy: 70.23%, Training AUROC: 0.5500
# Validation Loss: 0.5917, Validation Accuracy: 72.37%, Validation AUROC: 0.5768
# Epoch [8/100]
# Training Loss: 0.6131, Training Accuracy: 70.59%, Training AUROC: 0.5126
# Validation Loss: 0.6156, Validation Accuracy: 71.05%, Validation AUROC: 0.5345
# Epoch [9/100]
# Training Loss: 0.6053, Training Accuracy: 70.59%, Training AUROC: 0.5732
# Validation Loss: 0.6259, Validation Accuracy: 69.74%, Validation AUROC: 0.4617
# Epoch [10/100]
# Training Loss: 0.6085, Training Accuracy: 71.12%, Training AUROC: 0.5405
# Validation Loss: 0.6031, Validation Accuracy: 71.05%, Validation AUROC: 0.5231
# Epoch [11/100]
# Training Loss: 0.6075, Training Accuracy: 70.05%, Training AUROC: 0.5830
# Validation Loss: 0.6843, Validation Accuracy: 50.00%, Validation AUROC: 0.5034
# Epoch [12/100]
# Training Loss: 0.6326, Training Accuracy: 64.71%, Training AUROC: 0.5552
# Validation Loss: 0.6080, Validation Accuracy: 71.05%, Validation AUROC: 0.5522
# Epoch [13/100]
# Training Loss: 0.5969, Training Accuracy: 70.94%, Training AUROC: 0.5718
# Validation Loss: 0.6749, Validation Accuracy: 71.05%, Validation AUROC: 0.5406
# Epoch [14/100]
# Training Loss: 0.6284, Training Accuracy: 70.23%, Training AUROC: 0.5147
# Validation Loss: 0.6101, Validation Accuracy: 69.74%, Validation AUROC: 0.5795
# Epoch [15/100]
# Training Loss: 0.6199, Training Accuracy: 70.94%, Training AUROC: 0.4699
# Validation Loss: 0.6067, Validation Accuracy: 71.05%, Validation AUROC: 0.5368
# Epoch [16/100]
# Training Loss: 0.5973, Training Accuracy: 71.12%, Training AUROC: 0.5593
# Validation Loss: 0.5997, Validation Accuracy: 71.05%, Validation AUROC: 0.5322
# Epoch [17/100]
# Training Loss: 0.5954, Training Accuracy: 71.12%, Training AUROC: 0.5773
# Validation Loss: 0.6131, Validation Accuracy: 70.39%, Validation AUROC: 0.5303
# Early stopping triggered after 17 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6136, Training Accuracy: 70.94%, Training AUROC: 0.4962
# Validation Loss: 0.6088, Validation Accuracy: 71.05%, Validation AUROC: 0.6050
# Epoch [2/100]
# Training Loss: 0.6122, Training Accuracy: 70.94%, Training AUROC: 0.4611
# Validation Loss: 0.6131, Validation Accuracy: 71.05%, Validation AUROC: 0.4291
# Training Loss: 0.5942, Training Accuracy: 70.94%, Training AUROC: 0.5855
# Validation Loss: 0.6055, Validation Accuracy: 71.05%, Validation AUROC: 0.4776
# Early stopping triggered after 35 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.4944
# Normal Model AUROC: 0.4710
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.7092
# F1 Score: 0.5885
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.7124
# F1 Score: 0.6072
# Precision: 0.6000
# Recall: 0.0337
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 2

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 2:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6271, Training Accuracy: 69.70%, Training AUROC: 0.5013
# Validation Loss: 0.6392, Validation Accuracy: 71.05%, Validation AUROC: 0.6046
# Epoch [2/100]
# Training Loss: 0.6217, Training Accuracy: 68.45%, Training AUROC: 0.5348
# Validation Loss: 0.6248, Validation Accuracy: 71.05%, Validation AUROC: 0.5307
# Epoch [3/100]
# Training Loss: 0.6389, Training Accuracy: 67.38%, Training AUROC: 0.5449
# Validation Loss: 0.6601, Validation Accuracy: 66.45%, Validation AUROC: 0.4655
# Epoch [4/100]
# Training Loss: 0.6270, Training Accuracy: 70.59%, Training AUROC: 0.4942
# Validation Loss: 0.6307, Validation Accuracy: 69.74%, Validation AUROC: 0.5419
# Epoch [5/100]
# Training Loss: 0.5936, Training Accuracy: 70.41%, Training AUROC: 0.5922
# Validation Loss: 0.6350, Validation Accuracy: 67.11%, Validation AUROC: 0.5280
# Epoch [6/100]
# Training Loss: 0.6233, Training Accuracy: 71.12%, Training AUROC: 0.5189
# Validation Loss: 0.6183, Validation Accuracy: 71.05%, Validation AUROC: 0.4756
# Epoch [7/100]
# Training Loss: 0.5869, Training Accuracy: 71.12%, Training AUROC: 0.6132
# Validation Loss: 0.6390, Validation Accuracy: 70.39%, Validation AUROC: 0.4888
# Epoch [8/100]
# Training Loss: 0.6031, Training Accuracy: 70.59%, Training AUROC: 0.5835
# Validation Loss: 0.7251, Validation Accuracy: 51.32%, Validation AUROC: 0.4859
# Epoch [9/100]
# Training Loss: 0.6191, Training Accuracy: 69.34%, Training AUROC: 0.5597
# Validation Loss: 0.6620, Validation Accuracy: 71.05%, Validation AUROC: 0.4762
# Epoch [10/100]
# Training Loss: 0.5814, Training Accuracy: 71.48%, Training AUROC: 0.6394
# Validation Loss: 0.7292, Validation Accuracy: 71.05%, Validation AUROC: 0.4402
# Epoch [11/100]
# Training Loss: 0.5805, Training Accuracy: 71.66%, Training AUROC: 0.6265
# Validation Loss: 0.6765, Validation Accuracy: 68.42%, Validation AUROC: 0.4613
# Epoch [12/100]
# Training Loss: 0.6154, Training Accuracy: 67.56%, Training AUROC: 0.6373
# Validation Loss: 0.7488, Validation Accuracy: 67.76%, Validation AUROC: 0.4487
# Epoch [13/100]
# Training Loss: 0.6087, Training Accuracy: 70.77%, Training AUROC: 0.6325
# Validation Loss: 0.7362, Validation Accuracy: 69.74%, Validation AUROC: 0.4247
# Epoch [14/100]
# Training Loss: 0.5798, Training Accuracy: 71.66%, Training AUROC: 0.6391
# Validation Loss: 0.6995, Validation Accuracy: 58.55%, Validation AUROC: 0.4499
# Epoch [15/100]
# Training Loss: 0.5549, Training Accuracy: 73.62%, Training AUROC: 0.6917
# Validation Loss: 0.7031, Validation Accuracy: 69.74%, Validation AUROC: 0.4297
# Epoch [16/100]
# Training Loss: 0.5610, Training Accuracy: 73.08%, Training AUROC: 0.6878
# Validation Loss: 0.7989, Validation Accuracy: 70.39%, Validation AUROC: 0.4444
# Early stopping triggered after 16 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6248, Training Accuracy: 70.94%, Training AUROC: 0.4530
# Validation Loss: 0.6203, Validation Accuracy: 71.05%, Validation AUROC: 0.5088
# Epoch [2/100]
# Training Loss: 0.6303, Training Accuracy: 70.94%, Training AUROC: 0.5068
# Validation Loss: 0.6310, Validation Accuracy: 71.05%, Validation AUROC: 0.4571
# Epoch [3/100]
# Training Loss: 0.6274, Training Accuracy: 70.94%, Training AUROC: 0.4978
# Validation Loss: 0.6249, Validation Accuracy: 71.05%, Validation AUROC: 0.4640
# Epoch [4/100]
# Training Loss: 0.6231, Training Accuracy: 70.94%, Training AUROC: 0.4859
# Validation Loss: 0.6272, Validation Accuracy: 71.05%, Validation AUROC: 0.3533
# Epoch [5/100]
# Training Loss: 0.6202, Training Accuracy: 70.94%, Training AUROC: 0.5149
# Validation Loss: 0.6187, Validation Accuracy: 71.05%, Validation AUROC: 0.5051
# Epoch [6/100]
# Training Loss: 0.6179, Training Accuracy: 70.94%, Training AUROC: 0.4986
# Validation Loss: 0.6096, Validation Accuracy: 71.05%, Validation AUROC: 0.6229
# Epoch [39/100]
# Training Loss: 0.6054, Training Accuracy: 70.94%, Training AUROC: 0.4442
# Validation Loss: 0.6014, Validation Accuracy: 71.05%, Validation AUROC: 0.5532
# Epoch [40/100]
# Training Loss: 0.6056, Training Accuracy: 70.94%, Training AUROC: 0.4943
# Validation Loss: 0.5985, Validation Accuracy: 71.05%, Validation AUROC: 0.5705
# Epoch [41/100]
# Training Loss: 0.6142, Training Accuracy: 70.94%, Training AUROC: 0.4741
# Validation Loss: 0.6138, Validation Accuracy: 71.05%, Validation AUROC: 0.5166
# Epoch [42/100]
# Training Loss: 0.6129, Training Accuracy: 70.94%, Training AUROC: 0.4984
# Validation Loss: 0.6088, Validation Accuracy: 71.05%, Validation AUROC: 0.4912
# Epoch [43/100]
# Training Loss: 0.6057, Training Accuracy: 70.94%, Training AUROC: 0.4894
# Validation Loss: 0.6048, Validation Accuracy: 71.05%, Validation AUROC: 0.5168
# Epoch [44/100]
# Training Loss: 0.6089, Training Accuracy: 70.94%, Training AUROC: 0.4399
# Validation Loss: 0.6052, Validation Accuracy: 71.05%, Validation AUROC: 0.4844
# Epoch [45/100]
# Training Loss: 0.6063, Training Accuracy: 70.94%, Training AUROC: 0.4852
# Validation Loss: 0.5967, Validation Accuracy: 71.05%, Validation AUROC: 0.5644
# Epoch [46/100]
# Training Loss: 0.6084, Training Accuracy: 70.94%, Training AUROC: 0.4889
# Validation Loss: 0.6093, Validation Accuracy: 71.05%, Validation AUROC: 0.4903
# Early stopping triggered after 46 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.4245
# Normal Model AUROC: 0.5147
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.7092
# F1 Score: 0.5885
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.7026
# F1 Score: 0.5853
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 3

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 8:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6371, Training Accuracy: 68.27%, Training AUROC: 0.4653
# Validation Loss: 0.6804, Validation Accuracy: 59.21%, Validation AUROC: 0.5078
# Epoch [2/100]
# Training Loss: 0.6206, Training Accuracy: 69.70%, Training AUROC: 0.5549
# Validation Loss: 0.6149, Validation Accuracy: 71.05%, Validation AUROC: 0.5408
# Epoch [3/100]
# Training Loss: 0.6307, Training Accuracy: 68.81%, Training AUROC: 0.5501
# Validation Loss: 0.6072, Validation Accuracy: 71.05%, Validation AUROC: 0.5320
# Epoch [4/100]
# Training Loss: 0.6213, Training Accuracy: 71.30%, Training AUROC: 0.5722
# Validation Loss: 0.5976, Validation Accuracy: 71.71%, Validation AUROC: 0.5720
# Epoch [5/100]
# Training Loss: 0.5809, Training Accuracy: 71.48%, Training AUROC: 0.6247
# Validation Loss: 0.6541, Validation Accuracy: 71.05%, Validation AUROC: 0.5770
# Epoch [6/100]
# Training Loss: 0.5887, Training Accuracy: 68.98%, Training AUROC: 0.6394
# Validation Loss: 0.7074, Validation Accuracy: 69.74%, Validation AUROC: 0.5118
# Epoch [7/100]
# Training Loss: 0.5669, Training Accuracy: 71.12%, Training AUROC: 0.6763
# Validation Loss: 0.6448, Validation Accuracy: 63.82%, Validation AUROC: 0.5156
# Epoch [8/100]
# Training Loss: 0.5861, Training Accuracy: 69.70%, Training AUROC: 0.6419
# Validation Loss: 0.6465, Validation Accuracy: 64.47%, Validation AUROC: 0.4630
# Epoch [9/100]
# Training Loss: 0.5837, Training Accuracy: 70.77%, Training AUROC: 0.6514
# Validation Loss: 0.6527, Validation Accuracy: 69.08%, Validation AUROC: 0.4482
# Epoch [10/100]
# Training Loss: 0.5667, Training Accuracy: 71.84%, Training AUROC: 0.6545
# Validation Loss: 0.6730, Validation Accuracy: 65.79%, Validation AUROC: 0.5069
# Epoch [11/100]
# Training Loss: 0.6428, Training Accuracy: 67.56%, Training AUROC: 0.5901
# Validation Loss: 0.6566, Validation Accuracy: 70.39%, Validation AUROC: 0.5194
# Epoch [12/100]
# Training Loss: 0.5858, Training Accuracy: 72.73%, Training AUROC: 0.6426
# Validation Loss: 0.6549, Validation Accuracy: 71.05%, Validation AUROC: 0.4895
# Epoch [13/100]
# Training Loss: 0.5612, Training Accuracy: 72.91%, Training AUROC: 0.6780
# Validation Loss: 0.6246, Validation Accuracy: 69.74%, Validation AUROC: 0.5090
# Epoch [14/100]
# Training Loss: 0.5376, Training Accuracy: 73.26%, Training AUROC: 0.7127
# Validation Loss: 0.6559, Validation Accuracy: 69.08%, Validation AUROC: 0.4756
# Early stopping triggered after 14 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6491, Training Accuracy: 67.20%, Training AUROC: 0.4935
# Validation Loss: 0.6171, Validation Accuracy: 68.42%, Validation AUROC: 0.5267
# Epoch [18/100]
# Training Loss: 0.6013, Training Accuracy: 71.48%, Training AUROC: 0.4939
# Validation Loss: 0.5977, Validation Accuracy: 71.71%, Validation AUROC: 0.6060
# Epoch [19/100]
# Training Loss: 0.5971, Training Accuracy: 70.94%, Training AUROC: 0.5405
# Validation Loss: 0.6027, Validation Accuracy: 72.37%, Validation AUROC: 0.4465
# Epoch [20/100]
# Training Loss: 0.5965, Training Accuracy: 71.84%, Training AUROC: 0.5782
# Validation Loss: 0.5955, Validation Accuracy: 70.39%, Validation AUROC: 0.5786
# Epoch [21/100]
# Training Loss: 0.5952, Training Accuracy: 71.12%, Training AUROC: 0.5606
# Validation Loss: 0.6125, Validation Accuracy: 71.71%, Validation AUROC: 0.4501
# Epoch [22/100]
# Training Loss: 0.5956, Training Accuracy: 71.48%, Training AUROC: 0.5327
# Validation Loss: 0.6018, Validation Accuracy: 71.71%, Validation AUROC: 0.5269
# Epoch [23/100]
# Training Loss: 0.5904, Training Accuracy: 71.48%, Training AUROC: 0.5690
# Validation Loss: 0.6094, Validation Accuracy: 71.05%, Validation AUROC: 0.4958
# Epoch [24/100]
# Training Loss: 0.5907, Training Accuracy: 72.01%, Training AUROC: 0.5912
# Validation Loss: 0.5971, Validation Accuracy: 71.05%, Validation AUROC: 0.5295
# Epoch [25/100]
# Training Loss: 0.5905, Training Accuracy: 72.37%, Training AUROC: 0.5463
# Validation Loss: 0.6018, Validation Accuracy: 71.05%, Validation AUROC: 0.5370
# Epoch [26/100]
# Training Loss: 0.5876, Training Accuracy: 71.84%, Training AUROC: 0.5905
# Validation Loss: 0.6021, Validation Accuracy: 70.39%, Validation AUROC: 0.5341
# Epoch [27/100]
# Training Loss: 0.5893, Training Accuracy: 72.01%, Training AUROC: 0.5932
# Validation Loss: 0.6041, Validation Accuracy: 71.71%, Validation AUROC: 0.5162
# Epoch [28/100]
# Training Loss: 0.5843, Training Accuracy: 72.19%, Training AUROC: 0.6064
# Validation Loss: 0.6006, Validation Accuracy: 72.37%, Validation AUROC: 0.5987
# Epoch [29/100]
# Training Loss: 0.5809, Training Accuracy: 72.19%, Training AUROC: 0.6240
# Validation Loss: 0.6331, Validation Accuracy: 65.13%, Validation AUROC: 0.5038
# Epoch [30/100]
# Training Loss: 0.5914, Training Accuracy: 72.19%, Training AUROC: 0.5878
# Validation Loss: 0.6064, Validation Accuracy: 72.37%, Validation AUROC: 0.5305
# Early stopping triggered after 30 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.4726
# Normal Model AUROC: 0.4688
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.7157
# F1 Score: 0.6035
# Precision: 1.0000
# Recall: 0.0225
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.7026
# F1 Score: 0.5911
# Precision: 0.2500
# Recall: 0.0112
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 4

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 30:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6250, Training Accuracy: 71.84%, Training AUROC: 0.5125
# Validation Loss: 0.6323, Validation Accuracy: 70.39%, Validation AUROC: 0.4977
# Epoch [2/100]
# Training Loss: 0.6198, Training Accuracy: 70.59%, Training AUROC: 0.4989
# Validation Loss: 0.6007, Validation Accuracy: 70.39%, Validation AUROC: 0.5636
# Epoch [3/100]
# Training Loss: 0.6078, Training Accuracy: 70.77%, Training AUROC: 0.5486
# Validation Loss: 0.6299, Validation Accuracy: 71.71%, Validation AUROC: 0.5598
# Epoch [4/100]
# Training Loss: 0.6387, Training Accuracy: 68.81%, Training AUROC: 0.5084
# Validation Loss: 0.6178, Validation Accuracy: 70.39%, Validation AUROC: 0.5587
# Epoch [5/100]
# Training Loss: 0.6024, Training Accuracy: 69.16%, Training AUROC: 0.5890
# Validation Loss: 0.6182, Validation Accuracy: 70.39%, Validation AUROC: 0.5147
# Epoch [6/100]
# Training Loss: 0.6145, Training Accuracy: 68.81%, Training AUROC: 0.5750
# Validation Loss: 0.6166, Validation Accuracy: 70.39%, Validation AUROC: 0.5187
# Epoch [7/100]
# Training Loss: 0.5848, Training Accuracy: 71.12%, Training AUROC: 0.6168
# Validation Loss: 0.6192, Validation Accuracy: 70.39%, Validation AUROC: 0.5027
# Epoch [8/100]
# Training Loss: 0.5850, Training Accuracy: 69.34%, Training AUROC: 0.6256
# Validation Loss: 0.7492, Validation Accuracy: 71.05%, Validation AUROC: 0.5553
# Epoch [9/100]
# Training Loss: 0.6096, Training Accuracy: 69.70%, Training AUROC: 0.5864
# Validation Loss: 0.6493, Validation Accuracy: 69.74%, Validation AUROC: 0.4566
# Epoch [10/100]
# Training Loss: 0.6028, Training Accuracy: 69.70%, Training AUROC: 0.5838
# Validation Loss: 0.6197, Validation Accuracy: 70.39%, Validation AUROC: 0.5282
# Epoch [11/100]
# Training Loss: 0.5920, Training Accuracy: 70.77%, Training AUROC: 0.5944
# Validation Loss: 0.6650, Validation Accuracy: 71.05%, Validation AUROC: 0.4888
# Epoch [12/100]
# Training Loss: 0.5732, Training Accuracy: 71.66%, Training AUROC: 0.6483
# Validation Loss: 0.6622, Validation Accuracy: 70.39%, Validation AUROC: 0.4945
# Early stopping triggered after 12 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6677, Training Accuracy: 66.84%, Training AUROC: 0.5397
# Validation Loss: 0.6758, Validation Accuracy: 71.05%, Validation AUROC: 0.4606
# Epoch [2/100]
# Training Loss: 0.6614, Training Accuracy: 71.30%, Training AUROC: 0.4776
# Validation Loss: 0.6489, Validation Accuracy: 70.39%, Validation AUROC: 0.4935
# Epoch [3/100]
# Training Loss: 0.6584, Training Accuracy: 67.74%, Training AUROC: 0.5399
# Validation Loss: 0.6550, Validation Accuracy: 68.42%, Validation AUROC: 0.5484
# Epoch [4/100]
# Training Loss: 0.6528, Training Accuracy: 70.59%, Training AUROC: 0.5392
# Validation Loss: 0.6486, Validation Accuracy: 69.74%, Validation AUROC: 0.5204
# Epoch [5/100]
# Training Loss: 0.6452, Training Accuracy: 70.94%, Training AUROC: 0.5429
# Validation Loss: 0.6583, Validation Accuracy: 71.05%, Validation AUROC: 0.4400
# Epoch [6/100]
# Training Loss: 0.6486, Training Accuracy: 70.23%, Training AUROC: 0.5334
# Validation Loss: 0.6386, Validation Accuracy: 71.05%, Validation AUROC: 0.5852
# Epoch [7/100]
# Training Loss: 0.6552, Training Accuracy: 66.13%, Training AUROC: 0.5180
# Validation Loss: 0.6893, Validation Accuracy: 55.92%, Validation AUROC: 0.3676
# Epoch [8/100]
# Training Loss: 0.6626, Training Accuracy: 68.63%, Training AUROC: 0.4645
# Validation Loss: 0.6518, Validation Accuracy: 70.39%, Validation AUROC: 0.5766
# Epoch [9/100]
# Training Loss: 0.6410, Training Accuracy: 70.05%, Training AUROC: 0.5727
# Validation Loss: 0.6693, Validation Accuracy: 70.39%, Validation AUROC: 0.4836
# Epoch [10/100]
# Training Loss: 0.6506, Training Accuracy: 69.88%, Training AUROC: 0.5220
# Validation Loss: 0.6685, Validation Accuracy: 60.53%, Validation AUROC: 0.5229
# Epoch [11/100]
# Training Loss: 0.6522, Training Accuracy: 68.27%, Training AUROC: 0.5318
# Validation Loss: 0.6563, Validation Accuracy: 61.84%, Validation AUROC: 0.5034
# Epoch [12/100]
# Training Loss: 0.6314, Training Accuracy: 70.41%, Training AUROC: 0.5363
# Validation Loss: 0.6313, Validation Accuracy: 70.39%, Validation AUROC: 0.4701
# Epoch [13/100]
# Training Loss: 0.6224, Training Accuracy: 70.77%, Training AUROC: 0.5236
# Validation Loss: 0.6265, Validation Accuracy: 71.71%, Validation AUROC: 0.4834
# Epoch [14/100]
# Training Loss: 0.6238, Training Accuracy: 71.12%, Training AUROC: 0.5293
# Validation Loss: 0.6085, Validation Accuracy: 71.05%, Validation AUROC: 0.5320
# Epoch [31/100]
# Training Loss: 0.6125, Training Accuracy: 70.94%, Training AUROC: 0.5215
# Validation Loss: 0.5980, Validation Accuracy: 71.05%, Validation AUROC: 0.5719
# Epoch [32/100]
# Training Loss: 0.6030, Training Accuracy: 70.94%, Training AUROC: 0.5559
# Validation Loss: 0.6200, Validation Accuracy: 71.05%, Validation AUROC: 0.4596
# Epoch [33/100]
# Training Loss: 0.6021, Training Accuracy: 70.94%, Training AUROC: 0.5539
# Validation Loss: 0.6137, Validation Accuracy: 71.05%, Validation AUROC: 0.4701
# Epoch [34/100]
# Training Loss: 0.6022, Training Accuracy: 70.94%, Training AUROC: 0.5478
# Validation Loss: 0.6024, Validation Accuracy: 71.05%, Validation AUROC: 0.5377
# Epoch [35/100]
# Training Loss: 0.6047, Training Accuracy: 70.94%, Training AUROC: 0.5373
# Validation Loss: 0.6090, Validation Accuracy: 71.05%, Validation AUROC: 0.5082
# Epoch [36/100]
# Training Loss: 0.6108, Training Accuracy: 70.59%, Training AUROC: 0.5028
# Validation Loss: 0.6057, Validation Accuracy: 71.05%, Validation AUROC: 0.5253
# Epoch [37/100]
# Training Loss: 0.6095, Training Accuracy: 70.94%, Training AUROC: 0.5050
# Validation Loss: 0.6130, Validation Accuracy: 71.05%, Validation AUROC: 0.4476
# Epoch [38/100]
# Training Loss: 0.6036, Training Accuracy: 70.94%, Training AUROC: 0.5170
# Validation Loss: 0.6039, Validation Accuracy: 70.39%, Validation AUROC: 0.5219
# Epoch [39/100]
# Training Loss: 0.6006, Training Accuracy: 70.94%, Training AUROC: 0.5430
# Validation Loss: 0.6020, Validation Accuracy: 71.05%, Validation AUROC: 0.5305
# Epoch [40/100]
# Training Loss: 0.6068, Training Accuracy: 70.77%, Training AUROC: 0.5212
# Validation Loss: 0.6079, Validation Accuracy: 71.05%, Validation AUROC: 0.4566
# Epoch [41/100]
# Training Loss: 0.6048, Training Accuracy: 70.94%, Training AUROC: 0.4879
# Validation Loss: 0.6029, Validation Accuracy: 71.05%, Validation AUROC: 0.4834
# Early stopping triggered after 41 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.5173
# Normal Model AUROC: 0.4588
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.7092
# F1 Score: 0.5885
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.7092
# F1 Score: 0.6001
# Precision: 0.5000
# Recall: 0.0225
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 5

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 70:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6595, Training Accuracy: 63.99%, Training AUROC: 0.4620
# Validation Loss: 0.6186, Validation Accuracy: 71.05%, Validation AUROC: 0.4851
# Epoch [2/100]
# Training Loss: 0.6553, Training Accuracy: 67.02%, Training AUROC: 0.5115
# Validation Loss: 0.6123, Validation Accuracy: 71.71%, Validation AUROC: 0.4895
# Epoch [3/100]
# Training Loss: 0.6165, Training Accuracy: 69.52%, Training AUROC: 0.5584
# Validation Loss: 0.6343, Validation Accuracy: 71.05%, Validation AUROC: 0.4327
# Epoch [4/100]
# Training Loss: 0.6410, Training Accuracy: 64.88%, Training AUROC: 0.5704
# Validation Loss: 0.7086, Validation Accuracy: 70.39%, Validation AUROC: 0.4611
# Epoch [5/100]
# Training Loss: 0.6222, Training Accuracy: 68.45%, Training AUROC: 0.5669
# Validation Loss: 0.6558, Validation Accuracy: 68.42%, Validation AUROC: 0.4257
# Epoch [6/100]
# Training Loss: 0.6115, Training Accuracy: 69.52%, Training AUROC: 0.6154
# Validation Loss: 0.6704, Validation Accuracy: 64.47%, Validation AUROC: 0.4903
# Epoch [7/100]
# Training Loss: 0.6096, Training Accuracy: 69.34%, Training AUROC: 0.6426
# Validation Loss: 0.8354, Validation Accuracy: 70.39%, Validation AUROC: 0.4962
# Epoch [8/100]
# Training Loss: 0.6163, Training Accuracy: 70.94%, Training AUROC: 0.6195
# Validation Loss: 0.6494, Validation Accuracy: 70.39%, Validation AUROC: 0.4602
# Epoch [9/100]
# Training Loss: 0.6147, Training Accuracy: 67.38%, Training AUROC: 0.6407
# Validation Loss: 0.8175, Validation Accuracy: 44.74%, Validation AUROC: 0.4966
# Epoch [10/100]
# Training Loss: 0.7450, Training Accuracy: 65.06%, Training AUROC: 0.5778
# Validation Loss: 0.8379, Validation Accuracy: 71.05%, Validation AUROC: 0.4888
# Epoch [11/100]
# Training Loss: 0.6868, Training Accuracy: 65.78%, Training AUROC: 0.5134
# Validation Loss: 0.7475, Validation Accuracy: 40.79%, Validation AUROC: 0.4581
# Epoch [12/100]
# Training Loss: 0.6305, Training Accuracy: 69.34%, Training AUROC: 0.5567
# Validation Loss: 0.6347, Validation Accuracy: 69.74%, Validation AUROC: 0.4897
# Early stopping triggered after 12 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6355, Training Accuracy: 71.48%, Training AUROC: 0.4890
# Validation Loss: 0.6407, Validation Accuracy: 71.05%, Validation AUROC: 0.5450
# Epoch [2/100]
# Training Loss: 0.6307, Training Accuracy: 70.94%, Training AUROC: 0.4846
# Validation Loss: 0.6231, Validation Accuracy: 71.05%, Validation AUROC: 0.4857
# Epoch [3/100]
# Training Loss: 0.6220, Training Accuracy: 70.77%, Training AUROC: 0.5390
# Validation Loss: 0.6211, Validation Accuracy: 71.05%, Validation AUROC: 0.5703
# Epoch [4/100]
# Training Loss: 0.6196, Training Accuracy: 71.12%, Training AUROC: 0.5117
# Validation Loss: 0.6186, Validation Accuracy: 71.05%, Validation AUROC: 0.5072
# Epoch [5/100]
# Training Loss: 0.6312, Training Accuracy: 70.94%, Training AUROC: 0.4804
# Validation Loss: 0.6273, Validation Accuracy: 71.05%, Validation AUROC: 0.5137
# Epoch [6/100]
# Training Loss: 0.6355, Training Accuracy: 70.94%, Training AUROC: 0.4503
# Validation Loss: 0.6299, Validation Accuracy: 71.05%, Validation AUROC: 0.5006
# Epoch [7/100]
# Training Loss: 0.6235, Training Accuracy: 70.94%, Training AUROC: 0.5320
# Validation Loss: 0.6288, Validation Accuracy: 71.05%, Validation AUROC: 0.5379
# Epoch [8/100]
# Training Loss: 0.6272, Training Accuracy: 70.94%, Training AUROC: 0.5072
# Validation Loss: 0.6577, Validation Accuracy: 65.13%, Validation AUROC: 0.4566
# Epoch [9/100]
# Training Loss: 0.6252, Training Accuracy: 70.94%, Training AUROC: 0.4975
# Validation Loss: 0.6114, Validation Accuracy: 71.05%, Validation AUROC: 0.5328
# Epoch [10/100]
# Training Loss: 0.6164, Training Accuracy: 70.94%, Training AUROC: 0.5519
# Validation Loss: 0.6160, Validation Accuracy: 71.05%, Validation AUROC: 0.5537
# Epoch [11/100]
# Training Loss: 0.6173, Training Accuracy: 71.12%, Training AUROC: 0.4654
# Validation Loss: 0.6134, Validation Accuracy: 71.05%, Validation AUROC: 0.5215
# Epoch [12/100]
# Training Loss: 0.6110, Training Accuracy: 70.94%, Training AUROC: 0.5010
# Validation Loss: 0.6084, Validation Accuracy: 71.05%, Validation AUROC: 0.4947
# Epoch [13/100]
# Training Loss: 0.6077, Training Accuracy: 70.94%, Training AUROC: 0.4881
# Validation Loss: 0.6106, Validation Accuracy: 71.05%, Validation AUROC: 0.4493
# Epoch [14/100]
# Training Loss: 0.6113, Training Accuracy: 70.94%, Training AUROC: 0.4818
# Validation Loss: 0.6150, Validation Accuracy: 71.05%, Validation AUROC: 0.4333
# Epoch [15/100]
# Training Loss: 0.6092, Training Accuracy: 70.94%, Training AUROC: 0.5268
# Validation Loss: 0.6069, Validation Accuracy: 71.05%, Validation AUROC: 0.5080
# Epoch [16/100]
# Training Loss: 0.6022, Training Accuracy: 70.94%, Training AUROC: 0.5093
# Validation Loss: 0.5968, Validation Accuracy: 71.05%, Validation AUROC: 0.6019
# Epoch [33/100]
# Training Loss: 0.6074, Training Accuracy: 70.94%, Training AUROC: 0.4297
# Validation Loss: 0.6017, Validation Accuracy: 71.05%, Validation AUROC: 0.4903
# Epoch [34/100]
# Training Loss: 0.6047, Training Accuracy: 70.94%, Training AUROC: 0.4734
# Validation Loss: 0.6024, Validation Accuracy: 71.05%, Validation AUROC: 0.4920
# Epoch [35/100]
# Training Loss: 0.6040, Training Accuracy: 70.94%, Training AUROC: 0.4893
# Validation Loss: 0.6065, Validation Accuracy: 71.05%, Validation AUROC: 0.4426
# Epoch [36/100]
# Training Loss: 0.6051, Training Accuracy: 70.94%, Training AUROC: 0.4777
# Validation Loss: 0.6041, Validation Accuracy: 71.05%, Validation AUROC: 0.4423
# Epoch [37/100]
# Training Loss: 0.6033, Training Accuracy: 70.94%, Training AUROC: 0.5008
# Validation Loss: 0.6051, Validation Accuracy: 71.05%, Validation AUROC: 0.4619
# Epoch [38/100]
# Training Loss: 0.6030, Training Accuracy: 70.94%, Training AUROC: 0.4997
# Validation Loss: 0.6019, Validation Accuracy: 71.05%, Validation AUROC: 0.5408
# Epoch [39/100]
# Training Loss: 0.6024, Training Accuracy: 70.94%, Training AUROC: 0.5103
# Validation Loss: 0.6009, Validation Accuracy: 71.05%, Validation AUROC: 0.5370
# Epoch [40/100]
# Training Loss: 0.6015, Training Accuracy: 70.94%, Training AUROC: 0.5386
# Validation Loss: 0.6020, Validation Accuracy: 71.05%, Validation AUROC: 0.5368
# Early stopping triggered after 40 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
model_normal = torch.load("/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020_models_QNN-Parallel/normal_model_70.pth")
model_hybrid = torch.load("/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020_models_QNN-Parallel/quantum_hybrid_model_70.pth")
# Out:
# <ipython-input-22-fb40187e4553>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_normal = torch.load("/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020_models_QNN-Parallel/normal_model_70.pth")
# <ipython-input-22-fb40187e4553>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_hybrid = torch.load("/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020_models_QNN-Parallel/quantum_hybrid_model_70.pth")

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.5658
# Normal Model AUROC: 0.5638
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.7092
# F1 Score: 0.5885
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.2908
# F1 Score: 0.1311
# Precision: 0.2908
# Recall: 1.0000
# AUROC: N/A
