# %% [markdown]
# ## This notebook presents the reproducible procedure that we followed in comparing the performance of Hybrid Quantum Neural Networks-Parallel and Classical Convolutional Neural Networks on the G1020 dataset. The G1020 dataset is a glaucoma-focused dataset with 1020 fundus images. The dataset was produced in Germany and is labeled with binary classification (Non-Glaucoma and Glaucoma).

# %% [markdown]
# ### Installing and Importing Dependencies

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.40.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.1 in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.4.2)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.7.0)
# Collecting tomlkit (from pennylane)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.40 (from pennylane)
#   Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pennylane) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pennylane) (24.2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.40->pennylane)
#   Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from diastatic-malt->pennylane) (2.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pennylane) (2025.1.31)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading PennyLane-0.40.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 28.4 MB/s eta 0:00:00
# Downloading autoray-0.7.1-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 48.2 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.40.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 69.8 MB/s eta 0:00:00
# Downloading rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.0 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 8.1 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading scipy_openblas32-0.3.29.0.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 73.2 MB/s eta 0:00:00
# Installing collected packages: appdirs, tomlkit, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.7.1 diastatic-malt-2.15.2 pennylane-0.40.0 pennylane-lightning-0.40.0 rustworkx-0.16.0 scipy-openblas32-0.3.29.0.0 tomlkit-0.13.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
from google.colab import drive
import cv2
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, Sampler
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms
from PIL import Image
import time
import os
import copy
from torch.optim.lr_scheduler import CosineAnnealingLR
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score, confusion_matrix, roc_curve,
    precision_recall_curve, auc, ConfusionMatrixDisplay
)
from sklearn.preprocessing import label_binarize
import random
from itertools import cycle

os.environ["OMP_NUM_THREADS"] = "1"

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
MODEL_SAVE_PATH = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020_models_QNN-Parallel/"

# %% [markdown]
# ### General Training, Validation, Testing Functions

# %%
import torchvision
from torchvision import datasets, transforms

# %%
def train_model(model, train_loader, optimizer, criterion):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_probs = []

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        probs = torch.softmax(outputs, dim=1)
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.detach().cpu().numpy())



    avg_train_loss = train_loss / len(train_loader.dataset)
    accuracy = correct / total * 100

    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_train_loss, accuracy, avg_auroc

# %%
def validate_model(model, valid_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            probs = torch.softmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.detach().cpu().numpy())

    avg_val_loss = val_loss / len(valid_loader.dataset)
    accuracy = correct / total * 100
    aurocs = []
    for i in range(probs.shape[1]):
        try:
            auroc = roc_auc_score([1 if label == i else 0 for label in all_labels], [prob[i] for prob in all_probs])
            aurocs.append(auroc)
        except ValueError:
            aurocs.append(0)

    avg_auroc = sum(aurocs) / len(aurocs)

    return avg_val_loss, accuracy, avg_auroc

# %%
import pickle

def train_validate_model(n_epochs, model, model_name, train_loader, valid_loader, seed, quantum=False):

  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

  def adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max):
        if epoch < lr_warmup_epochs:
            lr = lr_max * (epoch + 1) / lr_warmup_epochs
        else:
            lr = lr_max
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

  scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs - 10, eta_min=1e-6)

  best_val_loss = float('inf')
  best_model_weights = model.state_dict()
  epochs_without_improvement = 0
  early_stopping_patience = 10

  train_losses = []
  train_accuracies = []
  val_losses = []
  val_accuracies = []
  train_aucs = []
  val_aucs = []

  lr_max = 5e-4
  lr_warmup_epochs = 10

  for epoch in range(n_epochs):
      print(f'Epoch [{epoch+1}/{n_epochs}]')

      adjust_learning_rate(optimizer, epoch, lr_warmup_epochs, lr_max)

      train_loss, train_accuracy, train_auroc = train_model(model, train_loader, optimizer, criterion)
      val_loss, val_accuracy, val_auroc = validate_model(model, valid_loader, criterion)


      print(f'Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Training AUROC: {train_auroc:.4f}')
      print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%, Validation AUROC: {val_auroc:.4f}')
      train_losses.append(train_loss)
      train_accuracies.append(train_accuracy)
      train_aucs.append(train_auroc)
      val_losses.append(val_loss)
      val_accuracies.append(val_accuracy)
      val_aucs.append(val_auroc)

      if epoch >= lr_warmup_epochs:
            scheduler.step()

      if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict()
            epochs_without_improvement = 0  # Reset counter

      else:
            epochs_without_improvement += 1

      if epochs_without_improvement >= early_stopping_patience:
            print(f"Early stopping triggered after {epoch+1} epochs.")
            break


  model.load_state_dict(best_model_weights)

  if quantum:
    torch.save(model.state_dict(), os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}.pth'))
  else:
    torch.save(model, os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}.pth'))

  metrics = {
        "train_losses": train_losses,
        "train_accuracies": train_accuracies,
        "train_aucs": train_aucs,
        "val_losses": val_losses,
        "val_accuracies": val_accuracies,
        "val_aucs": val_aucs
    }

  with open(os.path.join(MODEL_SAVE_PATH, f'{model_name}_{seed}_metrics.pkl'), 'wb') as f:
        pickle.dump(metrics, f)

  return model, train_losses, train_accuracies, val_losses, val_accuracies, train_aucs, val_aucs

# %%
import math
import matplotlib.pyplot as plt

def plot(quantum_loss, normal_loss, quantum_acc, normal_acc, quantum_auc, normal_auc):
    plt.style.use("default")

    loss_min = math.floor(min(min(quantum_loss), min(normal_loss)) * 10) / 10
    loss_max = math.ceil(max(max(quantum_loss), max(normal_loss)) * 10) / 10

    acc_min = math.floor(min(min(quantum_acc), min(normal_acc)) * 10) / 10
    acc_max = math.ceil(max(max(quantum_acc), max(normal_acc)) * 10) / 10

    auc_min = math.floor(min(min(quantum_auc), min(normal_auc)) * 10) / 10
    auc_max = math.ceil(max(max(quantum_auc), max(normal_auc)) * 10) / 10

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_loss, label="With quantum layer")
    plt.plot(normal_loss, label="Without quantum layer")
    plt.ylabel("Loss")
    plt.ylim([loss_min, loss_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Loss vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_acc, label="With quantum layer")
    plt.plot(normal_acc, label="Without quantum layer")
    plt.ylabel("Accuracy")
    plt.ylim([acc_min, acc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("Accuracy vs. Epoch")
    plt.show()

    plt.figure(figsize=(6, 3))
    plt.plot(quantum_auc, label="With quantum layer")
    plt.plot(normal_auc, label="Without quantum layer")
    plt.ylabel("ROCAUC")
    plt.ylim([auc_min, auc_max])
    plt.xlabel("Epoch")
    plt.legend()
    plt.title("ROCAUC vs. Epoch")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.preprocessing import label_binarize
from itertools import cycle


def test(model_hybrid, model_normal, test_loader, num_classes):
    model_hybrid.eval()
    model_normal.eval()

    all_labels = []
    all_preds_hybrid = []
    all_preds_normal = []
    all_probs_hybrid = []
    all_probs_normal = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)


            outputs_hybrid = model_hybrid(images)
            _, preds_hybrid = torch.max(outputs_hybrid, 1)
            probs_hybrid = torch.softmax(outputs_hybrid, dim=1)
            # Normal model predictions
            outputs_normal = model_normal(images)
            _, preds_normal = torch.max(outputs_normal, 1)
            probs_normal = torch.softmax(outputs_normal, dim=1)

            all_labels.extend(labels.cpu().numpy())
            all_preds_hybrid.extend(preds_hybrid.cpu().numpy())
            all_preds_normal.extend(preds_normal.cpu().numpy())
            all_probs_hybrid.extend(probs_hybrid.cpu().numpy())
            all_probs_normal.extend(probs_normal.cpu().numpy())

    all_labels = np.array(all_labels)
    all_preds_hybrid = np.array(all_preds_hybrid)
    all_preds_normal = np.array(all_preds_normal)
    all_probs_hybrid = np.array(all_probs_hybrid)
    all_probs_normal = np.array(all_probs_normal)


    accuracy_hybrid = accuracy_score(all_labels, all_preds_hybrid)
    accuracy_normal = accuracy_score(all_labels, all_preds_normal)


    f1_hybrid = f1_score(all_labels, all_preds_hybrid, average='weighted')
    f1_normal = f1_score(all_labels, all_preds_normal, average='weighted')


    if num_classes == 2:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, pos_label=1)
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, pos_label=1)
        precision_normal = precision_score(all_labels, all_preds_normal, pos_label=1)
        recall_normal = recall_score(all_labels, all_preds_normal, pos_label=1)
    else:
        precision_hybrid = precision_score(all_labels, all_preds_hybrid, average='weighted')
        recall_hybrid = recall_score(all_labels, all_preds_hybrid, average='weighted')
        precision_normal = precision_score(all_labels, all_preds_normal, average='weighted')
        recall_normal = recall_score(all_labels, all_preds_normal, average='weighted')


    hybrid_aucs = []
    normal_aucs = []

    if num_classes == 2:

        all_probs_hybrid_class1 = all_probs_hybrid[:, 1]
        all_probs_normal_class1 = all_probs_normal[:, 1]

        auc_hybrid = roc_auc_score(all_labels, all_probs_hybrid_class1)
        auc_normal = roc_auc_score(all_labels, all_probs_normal_class1)

        print(f'Hybrid Model AUROC: {auc_hybrid:.4f}')
        print(f'Normal Model AUROC: {auc_normal:.4f}')

        fpr_hybrid, tpr_hybrid, _ = roc_curve(all_labels, all_probs_hybrid_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_hybrid, tpr_hybrid, label=f'Hybrid Model AUROC = {auc_hybrid:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Hybrid Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curve for the Normal Model
        fpr_normal, tpr_normal, _ = roc_curve(all_labels, all_probs_normal_class1)
        plt.figure(figsize=(10, 6))
        plt.plot(fpr_normal, tpr_normal, label=f'Normal Model AUROC = {auc_normal:.4f}')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title('ROC Curve - Normal Model')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')
        plt.show()

    else:  # Multi-class Classification

        all_labels_binarized = label_binarize(all_labels, classes=np.arange(num_classes))

        # Define a color cycle for plotting
        colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red'])
        # Plot ROC curves for the Hybrid Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_hybrid[:, i])
            roc_auc = auc(fpr, tpr)
            hybrid_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Hybrid Model')
        plt.legend(loc='lower right')
        plt.show()

        # Plot ROC curves for the Normal Model
        plt.figure(figsize=(10, 8))
        for i, color in zip(range(num_classes), colors):
            fpr, tpr, _ = roc_curve(all_labels_binarized[:, i], all_probs_normal[:, i])
            roc_auc = auc(fpr, tpr)
            normal_aucs.append(roc_auc)
            plt.plot(fpr, tpr, color=color, lw=2,
                    label=f'Class {i} (AUC = {roc_auc:.2f})')


        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves - Normal Model')
        plt.legend(loc='lower right')
        plt.show()



    filtered_normal_aucs = [auc for auc in normal_aucs if auc > 0]
    filtered_hybrid_aucs = [auc for auc in hybrid_aucs if auc > 0]
    print(filtered_normal_aucs)
    print(filtered_hybrid_aucs)

    # Calculate average AUC, handling cases where all values might be zero
    normal_auc = f"{sum(filtered_normal_aucs) / len(filtered_normal_aucs):.4f}" if filtered_normal_aucs else "N/A"
    hybrid_auc = f"{sum(filtered_hybrid_aucs) / len(filtered_hybrid_aucs):.4f}" if filtered_hybrid_aucs else "N/A"

    print("\nHybrid Model Metrics:")
    print(f'Accuracy: {accuracy_hybrid:.4f}')
    print(f'F1 Score: {f1_hybrid:.4f}')
    print(f'Precision: {precision_hybrid:.4f}')
    print(f'Recall: {recall_hybrid:.4f}')
    print(f'AUROC: {hybrid_auc}')

    print("\nNormal Model Metrics:")
    print(f'Accuracy: {accuracy_normal:.4f}')
    print(f'F1 Score: {f1_normal:.4f}')
    print(f'Precision: {precision_normal:.4f}')
    print(f'Recall: {recall_normal:.4f}')
    print(f'AUROC: {normal_auc} \n')

    cm_hybrid = confusion_matrix(all_labels, all_preds_hybrid)


    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_hybrid, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Hybrid Model (Avg AUC = {hybrid_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    cm_normal = confusion_matrix(all_labels, all_preds_normal)

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_normal, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix: Classical Model (Avg AUC = {normal_auc})')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
def load_data(batch_size, dataset):

  train_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])

  valid_test_transform = transforms.Compose([
      transforms.Resize((224, 224)),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
  ])


  if dataset == 'APTOS':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/APTOS2019/"

  elif dataset == "IDRID":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/IDRID_images/"

  elif dataset == "Messidor":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/MESSIDOR2/"

  elif dataset == "GlaucomaFundus":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/Glaucoma_fundus/"

  elif dataset == "PAPILA":
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/PAPILA/"

  elif dataset == 'G1020':
    data_dir = "/content/drive/MyDrive/OphAI-Harvard/QMLExperiments/G1020/"


  train_dataset = datasets.ImageFolder(root=data_dir + 'train', transform=train_transform)
  val_dataset = datasets.ImageFolder(root=data_dir + 'val', transform=valid_test_transform)
  test_dataset = datasets.ImageFolder(root=data_dir + 'test', transform=valid_test_transform)

  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
  valid_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

  return train_loader, valid_loader, test_loader

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ### Classical CNN Model Construction and General Methods

# %%
class NormalModel(nn.Module):
    def __init__(self, num_classes):
        super(NormalModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.fc1 = nn.Linear(32 * 56 * 56, 120)
        self.fc2 = nn.Linear(120, 20)
        self.fc3 = nn.Linear(20, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ### Hybrid Quantum Neural Network Construction

# %%
step = 0.0004               # Learning rate
batch_size = 4              # Number of samples for each training step
q_delta = 0.01              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer

# %%
n_qubits = 5
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev)
def qnode(inputs, weights):
    qml.AngleEmbedding(inputs, wires=range(n_qubits))
    qml.BasicEntanglerLayers(weights, wires=range(n_qubits))
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# Define the QLayer
n_layers = 3
weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
class QuantumHybridModel(nn.Module):
    def __init__(self, num_classes):
      super(QuantumHybridModel, self).__init__()
      self.conv1 = nn.Conv2d(3, 16, 5, stride=1, padding=2)
      self.bn1 = nn.BatchNorm2d(16)
      self.pool = nn.MaxPool2d(2, 2)
      self.conv2 = nn.Conv2d(16, 32, 5, stride=1, padding=2)
      self.bn2 = nn.BatchNorm2d(32)
      self.qlayer1 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.qlayer2 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.qlayer3 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.qlayer4 = qml.qnn.TorchLayer(qnode, weight_shapes)
      self.fc1 = nn.Linear(32 * 56 * 56, 120)
      self.fc2 = nn.Linear(120, 20)
      self.fc3 = nn.Linear(20, num_classes)

    def forward(self, x):
        # Propagate the input through the CNN layers
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        # Flatten the output from the convolutional layers
        x = x.view(x.size(0), -1)
        # Pass the output to the quantum layer
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x_1, x_2, x_3, x_4 = torch.split(x, 5, dim=1)
        x_1 = self.qlayer1(x_1)
        x_2 = self.qlayer2(x_2)
        x_3 = self.qlayer3(x_3)
        x_4 = self.qlayer4(x_4)
        x = torch.cat([x_1, x_2, x_3, x_4], axis=1)
        x = self.fc3(x)
        return x

# %% [markdown]
# # Experiments

# %%
n_epochs = 100
num_classes = 2
batch_size = 32
dataset = "G1020"
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'

# %% [markdown]
# ## Seed Experiment 1

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 8:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6546, Training Accuracy: 65.33%, Training AUROC: 0.5130
# Validation Loss: 0.6209, Validation Accuracy: 76.36%, Validation AUROC: 0.4794
# Epoch [2/100]
# Training Loss: 0.6349, Training Accuracy: 65.69%, Training AUROC: 0.5503
# Validation Loss: 0.6601, Validation Accuracy: 61.82%, Validation AUROC: 0.4705
# Epoch [3/100]
# Training Loss: 0.6906, Training Accuracy: 63.32%, Training AUROC: 0.5471
# Validation Loss: 0.6235, Validation Accuracy: 73.94%, Validation AUROC: 0.4571
# Epoch [4/100]
# Training Loss: 0.6080, Training Accuracy: 70.99%, Training AUROC: 0.5918
# Validation Loss: 0.5505, Validation Accuracy: 76.36%, Validation AUROC: 0.5513
# Epoch [5/100]
# Training Loss: 0.6447, Training Accuracy: 66.42%, Training AUROC: 0.5697
# Validation Loss: 0.5622, Validation Accuracy: 75.76%, Validation AUROC: 0.5010
# Epoch [6/100]
# Training Loss: 0.6615, Training Accuracy: 65.69%, Training AUROC: 0.5660
# Validation Loss: 0.5806, Validation Accuracy: 75.76%, Validation AUROC: 0.4912
# Epoch [7/100]
# Training Loss: 0.6014, Training Accuracy: 68.43%, Training AUROC: 0.6218
# Validation Loss: 0.5567, Validation Accuracy: 76.36%, Validation AUROC: 0.5134
# Epoch [8/100]
# Training Loss: 0.6243, Training Accuracy: 66.61%, Training AUROC: 0.5917
# Validation Loss: 0.5543, Validation Accuracy: 75.76%, Validation AUROC: 0.5576
# Epoch [9/100]
# Training Loss: 0.5797, Training Accuracy: 70.62%, Training AUROC: 0.6565
# Validation Loss: 0.7519, Validation Accuracy: 42.42%, Validation AUROC: 0.4638
# Epoch [10/100]
# Training Loss: 0.5665, Training Accuracy: 71.17%, Training AUROC: 0.6781
# Validation Loss: 0.5940, Validation Accuracy: 74.55%, Validation AUROC: 0.5277
# Epoch [11/100]
# Training Loss: 0.5752, Training Accuracy: 71.72%, Training AUROC: 0.6566
# Validation Loss: 0.6688, Validation Accuracy: 63.64%, Validation AUROC: 0.4723
# Epoch [12/100]
# Training Loss: 0.5655, Training Accuracy: 71.72%, Training AUROC: 0.6718
# Validation Loss: 0.5780, Validation Accuracy: 76.36%, Validation AUROC: 0.5179
# Epoch [13/100]
# Training Loss: 0.5306, Training Accuracy: 75.00%, Training AUROC: 0.7344
# Validation Loss: 0.5958, Validation Accuracy: 75.76%, Validation AUROC: 0.5014
# Epoch [14/100]
# Training Loss: 0.5721, Training Accuracy: 73.36%, Training AUROC: 0.6795
# Validation Loss: 0.5727, Validation Accuracy: 75.76%, Validation AUROC: 0.5208
# Early stopping triggered after 14 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6774, Training Accuracy: 64.96%, Training AUROC: 0.4688
# Validation Loss: 0.6709, Validation Accuracy: 76.36%, Validation AUROC: 0.6093
# Epoch [2/100]
# Training Loss: 0.6656, Training Accuracy: 68.43%, Training AUROC: 0.5152
# Validation Loss: 0.6450, Validation Accuracy: 76.36%, Validation AUROC: 0.5124
# Epoch [3/100]
# Training Loss: 0.6575, Training Accuracy: 70.44%, Training AUROC: 0.5121
# Validation Loss: 0.6387, Validation Accuracy: 75.76%, Validation AUROC: 0.4593
# Epoch [4/100]
# Training Loss: 0.6547, Training Accuracy: 68.80%, Training AUROC: 0.5246
# Validation Loss: 0.6512, Validation Accuracy: 76.36%, Validation AUROC: 0.4695
# Epoch [5/100]
# Training Loss: 0.6670, Training Accuracy: 68.80%, Training AUROC: 0.5181
# Validation Loss: 0.6756, Validation Accuracy: 74.55%, Validation AUROC: 0.4196
# Epoch [6/100]
# Training Loss: 0.6748, Training Accuracy: 68.98%, Training AUROC: 0.4932
# Validation Loss: 0.6479, Validation Accuracy: 76.36%, Validation AUROC: 0.5073
# Epoch [7/100]
# Training Loss: 0.6559, Training Accuracy: 69.53%, Training AUROC: 0.5203
# Validation Loss: 0.6366, Validation Accuracy: 77.58%, Validation AUROC: 0.4815
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.5248
# Normal Model AUROC: 0.4877
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.6895
# F1 Score: 0.5655
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.6830
# F1 Score: 0.5837
# Precision: 0.3636
# Recall: 0.0426
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 2

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 30:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6364, Training Accuracy: 69.89%, Training AUROC: 0.5377
# Validation Loss: 0.5689, Validation Accuracy: 76.36%, Validation AUROC: 0.4740
# Epoch [2/100]
# Training Loss: 0.6234, Training Accuracy: 70.26%, Training AUROC: 0.4836
# Validation Loss: 0.5573, Validation Accuracy: 76.36%, Validation AUROC: 0.4715
# Epoch [3/100]
# Training Loss: 0.6286, Training Accuracy: 70.07%, Training AUROC: 0.4935
# Validation Loss: 0.5528, Validation Accuracy: 76.36%, Validation AUROC: 0.5037
# Epoch [4/100]
# Training Loss: 0.6186, Training Accuracy: 70.26%, Training AUROC: 0.5309
# Validation Loss: 0.5631, Validation Accuracy: 76.36%, Validation AUROC: 0.4444
# Epoch [5/100]
# Training Loss: 0.6108, Training Accuracy: 70.07%, Training AUROC: 0.5559
# Validation Loss: 0.5581, Validation Accuracy: 76.36%, Validation AUROC: 0.4644
# Epoch [6/100]
# Training Loss: 0.6303, Training Accuracy: 68.61%, Training AUROC: 0.4972
# Validation Loss: 0.5593, Validation Accuracy: 76.36%, Validation AUROC: 0.4685
# Epoch [7/100]
# Training Loss: 0.6144, Training Accuracy: 70.44%, Training AUROC: 0.5240
# Validation Loss: 0.5878, Validation Accuracy: 75.76%, Validation AUROC: 0.4512
# Epoch [8/100]
# Training Loss: 0.6220, Training Accuracy: 68.98%, Training AUROC: 0.5533
# Validation Loss: 0.5748, Validation Accuracy: 76.36%, Validation AUROC: 0.4943
# Epoch [9/100]
# Training Loss: 0.6152, Training Accuracy: 70.80%, Training AUROC: 0.5388
# Validation Loss: 0.5736, Validation Accuracy: 76.36%, Validation AUROC: 0.4459
# Epoch [10/100]
# Training Loss: 0.5919, Training Accuracy: 70.26%, Training AUROC: 0.6155
# Validation Loss: 0.5705, Validation Accuracy: 76.36%, Validation AUROC: 0.4656
# Epoch [11/100]
# Training Loss: 0.6014, Training Accuracy: 71.17%, Training AUROC: 0.5863
# Validation Loss: 0.5778, Validation Accuracy: 76.36%, Validation AUROC: 0.4444
# Epoch [12/100]
# Training Loss: 0.6066, Training Accuracy: 71.53%, Training AUROC: 0.5885
# Validation Loss: 0.5714, Validation Accuracy: 76.36%, Validation AUROC: 0.4801
# Epoch [13/100]
# Training Loss: 0.6033, Training Accuracy: 70.44%, Training AUROC: 0.5865
# Validation Loss: 0.5552, Validation Accuracy: 76.36%, Validation AUROC: 0.5045
# Early stopping triggered after 13 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6744, Training Accuracy: 63.50%, Training AUROC: 0.4974
# Validation Loss: 0.6862, Validation Accuracy: 64.85%, Validation AUROC: 0.4471
# Epoch [2/100]
# Training Loss: 0.6610, Training Accuracy: 68.61%, Training AUROC: 0.4879
# Validation Loss: 0.6627, Validation Accuracy: 73.33%, Validation AUROC: 0.5792
# Epoch [3/100]
# Training Loss: 0.6662, Training Accuracy: 68.80%, Training AUROC: 0.4859
# Validation Loss: 0.6431, Validation Accuracy: 75.76%, Validation AUROC: 0.5938
# Epoch [4/100]
# Training Loss: 0.6637, Training Accuracy: 68.43%, Training AUROC: 0.5281
# Validation Loss: 0.6637, Validation Accuracy: 69.70%, Validation AUROC: 0.4428
# Epoch [5/100]
# Training Loss: 0.6678, Training Accuracy: 66.42%, Training AUROC: 0.5055
# Validation Loss: 0.6975, Validation Accuracy: 41.21%, Validation AUROC: 0.4683
# Epoch [6/100]
# Training Loss: 0.6888, Training Accuracy: 55.11%, Training AUROC: 0.4815
# Validation Loss: 0.6817, Validation Accuracy: 56.97%, Validation AUROC: 0.5549
# Epoch [7/100]
# Training Loss: 0.6792, Training Accuracy: 61.68%, Training AUROC: 0.5144
# Validation Loss: 0.6729, Validation Accuracy: 64.85%, Validation AUROC: 0.5224
# Epoch [8/100]
# Training Loss: 0.6825, Training Accuracy: 59.67%, Training AUROC: 0.4939
# Validation Loss: 0.6585, Validation Accuracy: 71.52%, Validation AUROC: 0.4965
# Epoch [9/100]
# Training Loss: 0.6643, Training Accuracy: 67.15%, Training AUROC: 0.5108
# Validation Loss: 0.6427, Validation Accuracy: 73.94%, Validation AUROC: 0.4585
# Epoch [10/100]
# Training Loss: 0.6610, Training Accuracy: 69.16%, Training AUROC: 0.5021
# Validation Loss: 0.6598, Validation Accuracy: 75.15%, Validation AUROC: 0.4707
# Epoch [11/100]
# Training Loss: 0.6622, Training Accuracy: 70.44%, Training AUROC: 0.5062
# Validation Loss: 0.6507, Validation Accuracy: 76.97%, Validation AUROC: 0.4544
# Epoch [12/100]
# Validation Loss: 0.5584, Validation Accuracy: 76.36%, Validation AUROC: 0.5265
# Epoch [29/100]
# Training Loss: 0.6120, Training Accuracy: 70.26%, Training AUROC: 0.4531
# Validation Loss: 0.5626, Validation Accuracy: 76.36%, Validation AUROC: 0.4412
# Epoch [30/100]
# Training Loss: 0.6066, Training Accuracy: 70.26%, Training AUROC: 0.5506
# Validation Loss: 0.5557, Validation Accuracy: 76.36%, Validation AUROC: 0.5313
# Epoch [31/100]
# Training Loss: 0.6085, Training Accuracy: 70.26%, Training AUROC: 0.5152
# Validation Loss: 0.5584, Validation Accuracy: 76.36%, Validation AUROC: 0.5368
# Epoch [32/100]
# Training Loss: 0.6091, Training Accuracy: 70.26%, Training AUROC: 0.5004
# Validation Loss: 0.5617, Validation Accuracy: 76.36%, Validation AUROC: 0.4780
# Epoch [33/100]
# Training Loss: 0.6078, Training Accuracy: 70.26%, Training AUROC: 0.5286
# Validation Loss: 0.5570, Validation Accuracy: 76.36%, Validation AUROC: 0.5065
# Epoch [34/100]
# Training Loss: 0.6106, Training Accuracy: 70.26%, Training AUROC: 0.4753
# Validation Loss: 0.5595, Validation Accuracy: 76.36%, Validation AUROC: 0.5045
# Epoch [35/100]
# Training Loss: 0.6081, Training Accuracy: 70.26%, Training AUROC: 0.5145
# Validation Loss: 0.5605, Validation Accuracy: 76.36%, Validation AUROC: 0.4455
# Epoch [36/100]
# Training Loss: 0.6088, Training Accuracy: 70.26%, Training AUROC: 0.5045
# Validation Loss: 0.5571, Validation Accuracy: 76.36%, Validation AUROC: 0.4915
# Epoch [37/100]
# Training Loss: 0.6108, Training Accuracy: 70.26%, Training AUROC: 0.4603
# Validation Loss: 0.5597, Validation Accuracy: 76.36%, Validation AUROC: 0.4697
# Early stopping triggered after 37 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.4786
# Normal Model AUROC: 0.5285
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5671
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5671
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 3

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 70:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6565, Training Accuracy: 62.04%, Training AUROC: 0.4852
# Validation Loss: 0.6102, Validation Accuracy: 76.36%, Validation AUROC: 0.4440
# Epoch [2/100]
# Training Loss: 0.6232, Training Accuracy: 69.89%, Training AUROC: 0.5237
# Validation Loss: 0.5853, Validation Accuracy: 76.36%, Validation AUROC: 0.5045
# Epoch [3/100]
# Training Loss: 0.6227, Training Accuracy: 68.80%, Training AUROC: 0.5782
# Validation Loss: 0.5628, Validation Accuracy: 76.36%, Validation AUROC: 0.4530
# Epoch [4/100]
# Training Loss: 0.6173, Training Accuracy: 69.16%, Training AUROC: 0.5650
# Validation Loss: 0.5836, Validation Accuracy: 76.36%, Validation AUROC: 0.4483
# Epoch [5/100]
# Training Loss: 0.6271, Training Accuracy: 71.35%, Training AUROC: 0.5587
# Validation Loss: 0.5640, Validation Accuracy: 75.15%, Validation AUROC: 0.5376
# Epoch [6/100]
# Training Loss: 0.6374, Training Accuracy: 67.52%, Training AUROC: 0.5628
# Validation Loss: 0.7058, Validation Accuracy: 54.55%, Validation AUROC: 0.4878
# Epoch [7/100]
# Training Loss: 0.6056, Training Accuracy: 68.98%, Training AUROC: 0.6292
# Validation Loss: 0.5660, Validation Accuracy: 76.36%, Validation AUROC: 0.4969
# Epoch [8/100]
# Training Loss: 0.5774, Training Accuracy: 71.35%, Training AUROC: 0.6575
# Validation Loss: 0.6059, Validation Accuracy: 72.73%, Validation AUROC: 0.4467
# Epoch [9/100]
# Training Loss: 0.5999, Training Accuracy: 69.34%, Training AUROC: 0.6329
# Validation Loss: 0.6556, Validation Accuracy: 76.36%, Validation AUROC: 0.4615
# Epoch [10/100]
# Training Loss: 0.6165, Training Accuracy: 69.34%, Training AUROC: 0.6111
# Validation Loss: 0.6186, Validation Accuracy: 75.76%, Validation AUROC: 0.4499
# Epoch [11/100]
# Training Loss: 0.6005, Training Accuracy: 69.53%, Training AUROC: 0.6181
# Validation Loss: 0.5950, Validation Accuracy: 76.36%, Validation AUROC: 0.4929
# Epoch [12/100]
# Training Loss: 0.5864, Training Accuracy: 71.53%, Training AUROC: 0.6291
# Validation Loss: 0.6164, Validation Accuracy: 68.48%, Validation AUROC: 0.4792
# Epoch [13/100]
# Training Loss: 0.5659, Training Accuracy: 73.72%, Training AUROC: 0.6805
# Validation Loss: 0.5737, Validation Accuracy: 75.76%, Validation AUROC: 0.4957
# Early stopping triggered after 13 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6412, Training Accuracy: 69.53%, Training AUROC: 0.4969
# Epoch [18/100]
# Training Loss: 0.6109, Training Accuracy: 70.26%, Training AUROC: 0.5164
# Validation Loss: 0.5682, Validation Accuracy: 76.36%, Validation AUROC: 0.4892
# Epoch [19/100]
# Training Loss: 0.6119, Training Accuracy: 70.26%, Training AUROC: 0.4705
# Validation Loss: 0.5685, Validation Accuracy: 76.36%, Validation AUROC: 0.4434
# Epoch [20/100]
# Training Loss: 0.6124, Training Accuracy: 70.26%, Training AUROC: 0.4515
# Validation Loss: 0.5653, Validation Accuracy: 76.36%, Validation AUROC: 0.4455
# Epoch [21/100]
# Training Loss: 0.6101, Training Accuracy: 70.26%, Training AUROC: 0.4919
# Validation Loss: 0.5635, Validation Accuracy: 76.36%, Validation AUROC: 0.4560
# Epoch [22/100]
# Training Loss: 0.6099, Training Accuracy: 70.26%, Training AUROC: 0.4908
# Validation Loss: 0.5588, Validation Accuracy: 76.36%, Validation AUROC: 0.5460
# Epoch [23/100]
# Training Loss: 0.6085, Training Accuracy: 70.26%, Training AUROC: 0.5173
# Validation Loss: 0.5619, Validation Accuracy: 76.36%, Validation AUROC: 0.4562
# Epoch [24/100]
# Training Loss: 0.6098, Training Accuracy: 70.26%, Training AUROC: 0.4861
# Validation Loss: 0.5595, Validation Accuracy: 76.36%, Validation AUROC: 0.5602
# Epoch [25/100]
# Training Loss: 0.6098, Training Accuracy: 70.26%, Training AUROC: 0.4837
# Validation Loss: 0.5619, Validation Accuracy: 76.36%, Validation AUROC: 0.4184
# Epoch [26/100]
# Training Loss: 0.6086, Training Accuracy: 70.26%, Training AUROC: 0.5172
# Validation Loss: 0.5607, Validation Accuracy: 76.36%, Validation AUROC: 0.4186
# Epoch [27/100]
# Training Loss: 0.6092, Training Accuracy: 70.26%, Training AUROC: 0.5011
# Validation Loss: 0.5650, Validation Accuracy: 76.36%, Validation AUROC: 0.3606
# Epoch [28/100]
# Training Loss: 0.6086, Training Accuracy: 70.26%, Training AUROC: 0.5013
# Validation Loss: 0.5595, Validation Accuracy: 76.36%, Validation AUROC: 0.5781
# Epoch [29/100]
# Training Loss: 0.6132, Training Accuracy: 70.26%, Training AUROC: 0.4861
# Validation Loss: 0.5680, Validation Accuracy: 76.36%, Validation AUROC: 0.5313
# Epoch [30/100]
# Training Loss: 0.6109, Training Accuracy: 70.26%, Training AUROC: 0.5049
# Validation Loss: 0.5639, Validation Accuracy: 76.36%, Validation AUROC: 0.4872
# Epoch [31/100]
# Training Loss: 0.6128, Training Accuracy: 70.26%, Training AUROC: 0.4714
# Validation Loss: 0.5645, Validation Accuracy: 76.36%, Validation AUROC: 0.4994
# Epoch [32/100]
# Training Loss: 0.6118, Training Accuracy: 70.26%, Training AUROC: 0.4811
# Validation Loss: 0.5648, Validation Accuracy: 76.36%, Validation AUROC: 0.4479
# Early stopping triggered after 32 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.4921
# Normal Model AUROC: 0.5161
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5671
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5730
# Precision: 0.5000
# Recall: 0.0106
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 4

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 16:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6306, Training Accuracy: 67.88%, Training AUROC: 0.5153
# Validation Loss: 0.5889, Validation Accuracy: 76.36%, Validation AUROC: 0.5195
# Epoch [2/100]
# Training Loss: 0.6134, Training Accuracy: 70.26%, Training AUROC: 0.5036
# Validation Loss: 0.6116, Validation Accuracy: 76.36%, Validation AUROC: 0.4788
# Epoch [3/100]
# Training Loss: 0.6207, Training Accuracy: 70.07%, Training AUROC: 0.5160
# Validation Loss: 0.5556, Validation Accuracy: 76.36%, Validation AUROC: 0.4996
# Epoch [4/100]
# Training Loss: 0.6161, Training Accuracy: 70.80%, Training AUROC: 0.5655
# Validation Loss: 0.5866, Validation Accuracy: 76.36%, Validation AUROC: 0.4910
# Epoch [5/100]
# Training Loss: 0.6689, Training Accuracy: 68.98%, Training AUROC: 0.5032
# Validation Loss: 0.5981, Validation Accuracy: 76.36%, Validation AUROC: 0.4731
# Epoch [6/100]
# Training Loss: 0.6249, Training Accuracy: 70.26%, Training AUROC: 0.5423
# Validation Loss: 0.5693, Validation Accuracy: 76.36%, Validation AUROC: 0.5081
# Epoch [7/100]
# Training Loss: 0.6488, Training Accuracy: 70.26%, Training AUROC: 0.4990
# Validation Loss: 0.5880, Validation Accuracy: 76.36%, Validation AUROC: 0.4420
# Epoch [8/100]
# Training Loss: 0.6140, Training Accuracy: 69.53%, Training AUROC: 0.5396
# Validation Loss: 0.5473, Validation Accuracy: 76.36%, Validation AUROC: 0.5116
# Epoch [9/100]
# Training Loss: 0.6205, Training Accuracy: 70.26%, Training AUROC: 0.5188
# Validation Loss: 0.5655, Validation Accuracy: 76.36%, Validation AUROC: 0.4501
# Epoch [10/100]
# Training Loss: 0.6183, Training Accuracy: 70.26%, Training AUROC: 0.4903
# Validation Loss: 0.5709, Validation Accuracy: 76.36%, Validation AUROC: 0.4422
# Epoch [11/100]
# Training Loss: 0.6142, Training Accuracy: 70.26%, Training AUROC: 0.5222
# Validation Loss: 0.5647, Validation Accuracy: 76.36%, Validation AUROC: 0.4438
# Epoch [12/100]
# Training Loss: 0.6073, Training Accuracy: 70.26%, Training AUROC: 0.5330
# Validation Loss: 0.5605, Validation Accuracy: 76.36%, Validation AUROC: 0.4619
# Epoch [13/100]
# Training Loss: 0.6049, Training Accuracy: 70.26%, Training AUROC: 0.5528
# Validation Loss: 0.5588, Validation Accuracy: 76.36%, Validation AUROC: 0.4719
# Epoch [14/100]
# Training Loss: 0.6108, Training Accuracy: 70.26%, Training AUROC: 0.5483
# Validation Loss: 0.5591, Validation Accuracy: 76.36%, Validation AUROC: 0.4754
# Epoch [15/100]
# Training Loss: 0.6112, Training Accuracy: 70.26%, Training AUROC: 0.5709
# Validation Loss: 0.5677, Validation Accuracy: 76.36%, Validation AUROC: 0.5083
# Epoch [16/100]
# Training Loss: 0.6033, Training Accuracy: 70.26%, Training AUROC: 0.5564
# Validation Loss: 0.5527, Validation Accuracy: 76.36%, Validation AUROC: 0.5088
# Epoch [17/100]
# Training Loss: 0.6044, Training Accuracy: 70.26%, Training AUROC: 0.5626
# Validation Loss: 0.5614, Validation Accuracy: 76.36%, Validation AUROC: 0.4833
# Epoch [18/100]
# Training Loss: 0.5963, Training Accuracy: 70.26%, Training AUROC: 0.6139
# Validation Loss: 0.5628, Validation Accuracy: 76.36%, Validation AUROC: 0.4847
# Early stopping triggered after 18 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6824, Training Accuracy: 59.49%, Training AUROC: 0.5005
# Validation Loss: 0.6705, Validation Accuracy: 63.64%, Validation AUROC: 0.5134
# Epoch [2/100]
# Training Loss: 0.6756, Training Accuracy: 61.86%, Training AUROC: 0.5074
# Validation Loss: 0.6647, Validation Accuracy: 69.09%, Validation AUROC: 0.5204
# Epoch [3/100]
# Training Loss: 0.6874, Training Accuracy: 56.39%, Training AUROC: 0.4833
# Validation Loss: 0.6894, Validation Accuracy: 50.30%, Validation AUROC: 0.5645
# Epoch [4/100]
# Training Loss: 0.6900, Training Accuracy: 53.10%, Training AUROC: 0.5479
# Validation Loss: 0.6894, Validation Accuracy: 53.33%, Validation AUROC: 0.5069
# Epoch [5/100]
# Training Loss: 0.6892, Training Accuracy: 53.65%, Training AUROC: 0.4911
# Validation Loss: 0.6967, Validation Accuracy: 48.48%, Validation AUROC: 0.4888
# Epoch [6/100]
# Training Loss: 0.6864, Training Accuracy: 55.84%, Training AUROC: 0.4816
# Validation Loss: 0.6922, Validation Accuracy: 51.52%, Validation AUROC: 0.5397
# Epoch [7/100]
# Training Loss: 0.6869, Training Accuracy: 56.20%, Training AUROC: 0.4998
# Training Loss: 0.6087, Training Accuracy: 70.26%, Training AUROC: 0.4427
# Validation Loss: 0.5561, Validation Accuracy: 76.36%, Validation AUROC: 0.5000
# Early stopping triggered after 40 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.5053
# Normal Model AUROC: 0.4959
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5671
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5671
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A

# %% [markdown]
# ## Seed Experiment 5

# %%
seed = random.randint(1, 100)
print(f"Experiment with Seed {seed}:")
set_seed(seed)
train_loader, valid_loader, test_loader = load_data(batch_size=batch_size, dataset=dataset)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NormalModel(num_classes).to(device)
hybrid_model = QuantumHybridModel(num_classes).to(device)
model_name_hybrid = 'quantum_hybrid_model'
model_name_normal = 'normal_model'
# Out:
# Experiment with Seed 46:

# %%
model_normal, normal_train_losses, normal_train_accs, normal_val_losses, normal_val_accs, normal_train_aucs, normal_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=model,
    model_name=model_name_normal,
    train_loader=train_loader,
    valid_loader=valid_loader,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6365, Training Accuracy: 66.06%, Training AUROC: 0.5335
# Validation Loss: 0.5609, Validation Accuracy: 76.36%, Validation AUROC: 0.4597
# Epoch [2/100]
# Training Loss: 0.7232, Training Accuracy: 62.77%, Training AUROC: 0.5344
# Validation Loss: 0.5572, Validation Accuracy: 76.36%, Validation AUROC: 0.4766
# Epoch [3/100]
# Training Loss: 0.6403, Training Accuracy: 68.80%, Training AUROC: 0.4795
# Validation Loss: 0.5713, Validation Accuracy: 76.36%, Validation AUROC: 0.5120
# Epoch [4/100]
# Training Loss: 0.6116, Training Accuracy: 70.07%, Training AUROC: 0.5710
# Validation Loss: 0.5821, Validation Accuracy: 76.36%, Validation AUROC: 0.5104
# Epoch [5/100]
# Training Loss: 0.6037, Training Accuracy: 70.26%, Training AUROC: 0.5808
# Validation Loss: 0.5781, Validation Accuracy: 75.76%, Validation AUROC: 0.4917
# Epoch [6/100]
# Training Loss: 0.5954, Training Accuracy: 69.53%, Training AUROC: 0.6078
# Validation Loss: 0.6324, Validation Accuracy: 68.48%, Validation AUROC: 0.4505
# Epoch [7/100]
# Training Loss: 0.6304, Training Accuracy: 67.70%, Training AUROC: 0.5949
# Validation Loss: 0.5507, Validation Accuracy: 76.36%, Validation AUROC: 0.5128
# Epoch [8/100]
# Training Loss: 0.6203, Training Accuracy: 70.44%, Training AUROC: 0.5448
# Validation Loss: 0.5769, Validation Accuracy: 76.36%, Validation AUROC: 0.4668
# Epoch [9/100]
# Training Loss: 0.6254, Training Accuracy: 69.34%, Training AUROC: 0.5428
# Validation Loss: 0.5511, Validation Accuracy: 76.36%, Validation AUROC: 0.4666
# Epoch [10/100]
# Training Loss: 0.6255, Training Accuracy: 69.89%, Training AUROC: 0.5194
# Validation Loss: 0.6108, Validation Accuracy: 76.97%, Validation AUROC: 0.4825
# Epoch [11/100]
# Training Loss: 0.5977, Training Accuracy: 70.26%, Training AUROC: 0.6027
# Validation Loss: 0.5662, Validation Accuracy: 76.36%, Validation AUROC: 0.4858
# Epoch [12/100]
# Training Loss: 0.6129, Training Accuracy: 69.89%, Training AUROC: 0.5634
# Validation Loss: 0.5634, Validation Accuracy: 73.94%, Validation AUROC: 0.5374
# Epoch [13/100]
# Training Loss: 0.6128, Training Accuracy: 69.16%, Training AUROC: 0.5447
# Validation Loss: 0.5630, Validation Accuracy: 76.36%, Validation AUROC: 0.4674
# Epoch [14/100]
# Training Loss: 0.6145, Training Accuracy: 70.26%, Training AUROC: 0.5198
# Validation Loss: 0.5620, Validation Accuracy: 76.36%, Validation AUROC: 0.4587
# Epoch [15/100]
# Training Loss: 0.6001, Training Accuracy: 70.26%, Training AUROC: 0.5929
# Validation Loss: 0.5678, Validation Accuracy: 76.36%, Validation AUROC: 0.4656
# Epoch [16/100]
# Training Loss: 0.6019, Training Accuracy: 70.26%, Training AUROC: 0.5797
# Validation Loss: 0.5590, Validation Accuracy: 76.36%, Validation AUROC: 0.4933
# Epoch [17/100]
# Training Loss: 0.6024, Training Accuracy: 70.26%, Training AUROC: 0.5759
# Validation Loss: 0.5763, Validation Accuracy: 76.36%, Validation AUROC: 0.5057
# Early stopping triggered after 17 epochs.

# %%
model_hybrid, hybrid_train_losses, hybrid_train_accs, hybrid_val_losses, hybrid_val_accs, hybrid_train_aucs, hybrid_val_aucs = train_validate_model(
    n_epochs=n_epochs,
    model=hybrid_model,
    model_name=model_name_hybrid,
    train_loader=train_loader,
    valid_loader=valid_loader,
    quantum=True,
    seed=seed
)
# Out:
# Epoch [1/100]
# Training Loss: 0.6971, Training Accuracy: 51.82%, Training AUROC: 0.4428
# Validation Loss: 0.7008, Validation Accuracy: 31.52%, Validation AUROC: 0.4357
# Epoch [2/100]
# Training Loss: 0.7005, Training Accuracy: 31.02%, Training AUROC: 0.4993
# Validation Loss: 0.6969, Validation Accuracy: 34.55%, Validation AUROC: 0.4697
# Epoch [3/100]
# Training Loss: 0.6535, Training Accuracy: 67.34%, Training AUROC: 0.4947
# Validation Loss: 0.6417, Validation Accuracy: 76.36%, Validation AUROC: 0.5049
# Epoch [4/100]
# Training Loss: 0.6480, Training Accuracy: 69.89%, Training AUROC: 0.4695
# Validation Loss: 0.5946, Validation Accuracy: 76.36%, Validation AUROC: 0.5517
# Epoch [5/100]
# Training Loss: 0.6293, Training Accuracy: 70.07%, Training AUROC: 0.5008
# Validation Loss: 0.6068, Validation Accuracy: 76.36%, Validation AUROC: 0.5049
# Epoch [6/100]
# Validation Loss: 0.5857, Validation Accuracy: 76.36%, Validation AUROC: 0.4709
# Epoch [23/100]
# Training Loss: 0.6179, Training Accuracy: 70.26%, Training AUROC: 0.5007
# Validation Loss: 0.5656, Validation Accuracy: 76.36%, Validation AUROC: 0.5804
# Epoch [24/100]
# Training Loss: 0.6177, Training Accuracy: 70.26%, Training AUROC: 0.4833
# Validation Loss: 0.5520, Validation Accuracy: 76.36%, Validation AUROC: 0.6003
# Epoch [25/100]
# Training Loss: 0.6192, Training Accuracy: 70.26%, Training AUROC: 0.5017
# Validation Loss: 0.5833, Validation Accuracy: 76.36%, Validation AUROC: 0.5053
# Epoch [26/100]
# Training Loss: 0.6188, Training Accuracy: 70.26%, Training AUROC: 0.4706
# Validation Loss: 0.5621, Validation Accuracy: 76.36%, Validation AUROC: 0.5722
# Epoch [27/100]
# Training Loss: 0.6084, Training Accuracy: 70.26%, Training AUROC: 0.5568
# Validation Loss: 0.5613, Validation Accuracy: 76.36%, Validation AUROC: 0.5588
# Epoch [28/100]
# Training Loss: 0.6112, Training Accuracy: 70.26%, Training AUROC: 0.4998
# Validation Loss: 0.5579, Validation Accuracy: 76.36%, Validation AUROC: 0.5376
# Epoch [29/100]
# Training Loss: 0.6095, Training Accuracy: 70.26%, Training AUROC: 0.5350
# Validation Loss: 0.5543, Validation Accuracy: 76.36%, Validation AUROC: 0.5547
# Epoch [30/100]
# Training Loss: 0.6069, Training Accuracy: 70.26%, Training AUROC: 0.5271
# Validation Loss: 0.5596, Validation Accuracy: 76.36%, Validation AUROC: 0.5346
# Epoch [31/100]
# Training Loss: 0.6148, Training Accuracy: 70.26%, Training AUROC: 0.4708
# Validation Loss: 0.5679, Validation Accuracy: 76.36%, Validation AUROC: 0.5702
# Epoch [32/100]
# Training Loss: 0.6117, Training Accuracy: 70.26%, Training AUROC: 0.5097
# Validation Loss: 0.5654, Validation Accuracy: 76.36%, Validation AUROC: 0.5775
# Epoch [33/100]
# Training Loss: 0.6100, Training Accuracy: 70.26%, Training AUROC: 0.5120
# Validation Loss: 0.5707, Validation Accuracy: 76.36%, Validation AUROC: 0.4156
# Epoch [34/100]
# Training Loss: 0.6070, Training Accuracy: 70.26%, Training AUROC: 0.5251
# Validation Loss: 0.5637, Validation Accuracy: 76.36%, Validation AUROC: 0.5849
# Early stopping triggered after 34 epochs.

# %%
plot(hybrid_train_losses, normal_train_losses, hybrid_train_accs, normal_train_accs, hybrid_train_aucs, normal_train_aucs)

# %%
plot(hybrid_val_losses, normal_val_losses, hybrid_val_accs, normal_val_accs, hybrid_val_aucs, normal_val_aucs)

# %%
test(hybrid_model, model, test_loader, num_classes=num_classes)
# Out:
# Hybrid Model AUROC: 0.5312
# Normal Model AUROC: 0.4830
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# []
# []
#
# Hybrid Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5671
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
#
# Normal Model Metrics:
# Accuracy: 0.6928
# F1 Score: 0.5671
# Precision: 0.0000
# Recall: 0.0000
# AUROC: N/A
